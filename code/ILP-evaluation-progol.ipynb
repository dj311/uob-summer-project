# %% [markdown]
# # Evaluating our generalised rule in progol

# %% [markdown]
# ### We obtained the rule below from progol 4.4.

# %% [markdown]
# We now run the progol commands below in Blue Crystal, as we need progol 4.4 compiled with GCC 5.4

# %% [markdown]
# We got the below in progol 4.4 (code is from this commit 011359e3)

# %%
import pandas as pd
import tempfile
import subprocess
import graph_visualisation as gv

# %%
gv.jupyter_display_graph(gv.prolog_rule_to_dot(
"""bug(A,B) :- ancestor(A,C), ancestor(B,D), assignment(A), writeToPointer(B), alloc_doesnt_check_sizeOf(C), sizeOfInt(D)."""))

# %% [markdown]
# We will now use a small testing set to see if it can find the buggy source code using this rule.

# %%
ilp_data = pd.read_csv("../data/ilp_test_data.csv.gz")
ilp_data = ilp_data.drop("Unnamed: 0", axis=1)
ilp_data.head()
# Out:
#    testcase_ID                                           filename  \
# 0        62805  000/062/805/CWE121_Stack_Based_Buffer_Overflow...
# 1        62860  000/062/860/CWE121_Stack_Based_Buffer_Overflow...
# 2       231979  000/231/979/CWE122_Heap_Based_Buffer_Overflow_...
# 3       232029  000/232/029/CWE122_Heap_Based_Buffer_Overflow_...
# 4       232103  000/232/103/CWE122_Heap_Based_Buffer_Overflow_...
#
#                                                 code     flaw  flaw_loc  \
# 0  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        36
# 1  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 2  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        34
# 3  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        33
# 4  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        33
#
#      bug  code_length
# 0  False         2502
# 1  False         2495
# 2  False         1771
# 3  False         1809
# 4  False         1815

# %%
prolog = pd.read_csv("../data/ilp_prolog_test_data.csv.gz")
prolog = prolog.drop("Unnamed: 0", axis=1)
prolog.head()
# Out:
#    testcase_ID     flaw   bug  code_length  \
# 0      -232103  CWE-122  True         1671
# 1      -232029  CWE-122  True         1665
# 2      -231979  CWE-122  True         1667
# 3       -62860  CWE-121  True         1670
# 4       -62805  CWE-121  True         1669
#
#                                                 tree  \
# 0  % START: Generated Prolog\n% NODE PROPERTIES \...
# 1  % START: Generated Prolog\n% NODE PROPERTIES \...
# 2  % START: Generated Prolog\n% NODE PROPERTIES \...
# 3  % START: Generated Prolog\n% NODE PROPERTIES \...
# 4  % START: Generated Prolog\n% NODE PROPERTIES \...
#
#                                           source_map
# 0  % CODE\nsource_code(bad_232103_id_0_l_, "p2")....
# 1  % CODE\nsource_code(bad_232029_id_0_l_, "p1")....
# 2  % CODE\nsource_code(bad_231979_id_0_l_, "RET")...
# 3  % CODE\nsource_code(bad_62860_id_0_l_, "p1").\...
# 4  % CODE\nsource_code(bad_62805_id_0_l_, "p1").\...

# %%
print(prolog.tree.iloc[0])
# Out:
# % START: Generated Prolog
# % NODE PROPERTIES
# alloc(bad_232103_id_33_l_).
# compMemberAccess(bad_232103_id_43_l_).
# assignment(bad_232103_id_63_l_).
# sizeOf(bad_232103_id_69_l_).
# writeToPointer(bad_232103_id_80_l_).
# compMemberAccess(bad_232103_id_133_l_).
# compMemberAccess(bad_232103_id_134_l_33).
# sizeOf(bad_232103_id_138_l_).
# sizeOf(bad_232103_id_139_l_32).
# writeToPointer(bad_232103_id_145_l_).
# writeToPointer(bad_232103_id_146_l_32).
# assignment(bad_232103_id_148_l_30).
# alloc(bad_232103_id_163_l_).
# alloc(bad_232103_id_164_l_27).
# assignment(bad_232103_id_168_l_27).
# assignment(bad_232103_id_173_l_).
# assignment(bad_232103_id_174_l_23).
# % METHOD
# pointer(bad_232103_id_21_l_50).
# voidPointer(bad_232103_id_121_l_51).
# pointer(bad_232103_id_123_l_50).
# pointer(bad_232103_id_128_l_34).
# pointer(bad_232103_id_132_l_33).
# sizeOfInt(bad_232103_id_143_l_32).
# array10(bad_232103_id_143_l_32).
# pointer(bad_232103_id_144_l_32).
# sizeOfInt(bad_232103_id_147_l_30).
# array10(bad_232103_id_147_l_30).
# sizeOfInt(bad_232103_id_149_l_).
# array10(bad_232103_id_149_l_).
# voidPointer(bad_232103_id_150_l_30).
# voidPointer(bad_232103_id_156_l_28).
# pointer(bad_232103_id_158_l_28).
# pointer(bad_232103_id_167_l_27).
# pointer(bad_232103_id_172_l_23).
# pointer(bad_232103_id_175_l_).
# voidPointer(bad_232103_id_176_l_22).
# voidPointer(bad_232103_id_177_l_21).
# % AST
# ast(bad_232103_id_130_l_34, bad_232103_id_128_l_34).
#  ast(bad_232103_id_150_l_30, bad_232103_id_130_l_34).
#  ast(bad_232103_id_134_l_33, bad_232103_id_131_l_33).
#  ast(bad_232103_id_134_l_33, bad_232103_id_132_l_33).
#  ast(bad_232103_id_136_l_33, bad_232103_id_134_l_33).
#  ast(bad_232103_id_150_l_30, bad_232103_id_136_l_33).
#  ast(bad_232103_id_139_l_32, bad_232103_id_137_l_32).
#  ast(bad_232103_id_142_l_32, bad_232103_id_139_l_32).
#  ast(bad_232103_id_142_l_32, bad_232103_id_140_l_32).
#  ast(bad_232103_id_146_l_32, bad_232103_id_142_l_32).
#  ast(bad_232103_id_146_l_32, bad_232103_id_143_l_32).
#  ast(bad_232103_id_146_l_32, bad_232103_id_144_l_32).
#  ast(bad_232103_id_150_l_30, bad_232103_id_146_l_32).
#  ast(bad_232103_id_148_l_30, bad_232103_id_147_l_30).
#  ast(bad_232103_id_150_l_30, bad_232103_id_148_l_30).
#  ast(bad_232103_id_150_l_30, bad_232103_id_149_l_).
#  ast(bad_232103_id_176_l_22, bad_232103_id_150_l_30).
#  ast(bad_232103_id_153_l_28, bad_232103_id_151_l_28).
#  ast(bad_232103_id_155_l_28, bad_232103_id_153_l_28).
#  ast(bad_232103_id_156_l_28, bad_232103_id_155_l_28).
#  ast(bad_232103_id_161_l_28, bad_232103_id_156_l_28).
#  ast(bad_232103_id_160_l_28, bad_232103_id_157_l_28).
#  ast(bad_232103_id_160_l_28, bad_232103_id_158_l_28).
#  ast(bad_232103_id_161_l_28, bad_232103_id_160_l_28).
#  ast(bad_232103_id_176_l_22, bad_232103_id_161_l_28).
#  ast(bad_232103_id_164_l_27, bad_232103_id_162_l_27).
#  ast(bad_232103_id_166_l_27, bad_232103_id_164_l_27).
#  ast(bad_232103_id_166_l_27, bad_232103_id_165_l_27).
#  ast(bad_232103_id_168_l_27, bad_232103_id_166_l_27).
#  ast(bad_232103_id_168_l_27, bad_232103_id_167_l_27).
#  ast(bad_232103_id_176_l_22, bad_232103_id_168_l_27).
#  ast(bad_232103_id_176_l_22, bad_232103_id_169_l_25).
#  ast(bad_232103_id_176_l_22, bad_232103_id_170_l_24).
#  ast(bad_232103_id_174_l_23, bad_232103_id_171_l_23).
#  ref(bad_232103_id_133_l_, bad_232103_id_43_l_).
#  ref(bad_232103_id_129_l_, bad_232103_id_83_l_).
#  ref(bad_232103_id_119_l_, bad_232103_id_72_l_).
#  ref(bad_232103_id_117_l_, bad_232103_id_89_l_).
#  ref(bad_232103_id_114_l_, bad_232103_id_59_l_).
#  ref(bad_232103_id_111_l_, bad_232103_id_74_l_).
#  ref(bad_232103_id_108_l_, bad_232103_id_178_l_21).
#  ref(bad_232103_id_127_l_, bad_232103_id_96_l_).
#  ref(bad_232103_id_126_l_, bad_232103_id_93_l_).
#  ref(bad_232103_id_103_l_, bad_232103_id_94_l_).
#  ref(bad_232103_id_102_l_, bad_232103_id_92_l_).
#  ref(bad_232103_id_101_l_, bad_232103_id_97_l_).
#  ref(bad_232103_id_100_l_, bad_232103_id_95_l_).
#  ref(bad_232103_id_99_l_, bad_232103_id_98_l_).
#  ref(bad_232103_id_187_l_, bad_232103_id_41_l_).
#  ref(bad_232103_id_185_l_, bad_232103_id_41_l_).
#  % END: Generated Prolog

# %%
prolog['source_code'] = ''
prolog['flaw_loc'] = 0
prolog['bad_code'] = ''

for i in range(len(prolog)):
    label = prolog.iloc[i].testcase_ID == ilp_data.testcase_ID
    prolog['source_code'].iloc[i] = ilp_data.loc[label].iloc[0].code
    prolog['flaw_loc'].iloc[i] = ilp_data.loc[label].iloc[0].flaw_loc
    
for i in range(len(prolog)):
    loc =  prolog.iloc[i].flaw_loc
    testcase_ID = prolog.iloc[i].testcase_ID
    if testcase_ID < 0:
        prolog['bad_code'].iloc[i] = prolog.iloc[i].source_code.split('\n')[loc-1].strip()[0:-1]
    else:
        prolog['bad_code'].iloc[i] = prolog.loc[prolog.testcase_ID == -testcase_ID].iloc[0].bad_code
        
good_examples = prolog[prolog['bug'] == False]
bad_examples = prolog[prolog['bug'] == True]
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
prolog
# Out:
#    testcase_ID     flaw    bug  code_length  \
# 0      -232103  CWE-122   True         1671
# 1      -232029  CWE-122   True         1665
# 2      -231979  CWE-122   True         1667
# 3       -62860  CWE-121   True         1670
# 4       -62805  CWE-121   True         1669
# 5        62805  CWE-121  False         2502
# 6        62860  CWE-121  False         2495
# 7       231979  CWE-122  False         1771
# 8       232029  CWE-122  False         1809
# 9       232103  CWE-122  False         1815
#
#                                                 tree  \
# 0  % START: Generated Prolog\n% NODE PROPERTIES \...
# 1  % START: Generated Prolog\n% NODE PROPERTIES \...
# 2  % START: Generated Prolog\n% NODE PROPERTIES \...
# 3  % START: Generated Prolog\n% NODE PROPERTIES \...
# 4  % START: Generated Prolog\n% NODE PROPERTIES \...
# 5  % START: Generated Prolog\n% NODE PROPERTIES \...
# 6  % START: Generated Prolog\n% NODE PROPERTIES \...
# 7  % START: Generated Prolog\n% NODE PROPERTIES \...
# 8  % START: Generated Prolog\n% NODE PROPERTIES \...
# 9  % START: Generated Prolog\n% NODE PROPERTIES \...
#
#                                           source_map  \
# 0  % CODE\nsource_code(bad_232103_id_0_l_, "p2")....
# 1  % CODE\nsource_code(bad_232029_id_0_l_, "p1")....
# 2  % CODE\nsource_code(bad_231979_id_0_l_, "RET")...
# 3  % CODE\nsource_code(bad_62860_id_0_l_, "p1").\...
# 4  % CODE\nsource_code(bad_62805_id_0_l_, "p1").\...
# 5  % CODE\nsource_code(good_62805_id_0_l_72, "")....
# 6  % CODE\nsource_code(good_62860_id_1_l_, "p1")....
# 7  % CODE\nsource_code(good_231979_id_1_l_, "p1")...
# 8  % CODE\nsource_code(good_232029_id_1_l_, "p1")...
# 9  % CODE\nsource_code(good_232103_id_1_l_, "p2")...
#
#                                          source_code  flaw_loc  \
# 0  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        33
# 1  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        33
# 2  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        34
# 3  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        33
# 4  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        36
# 5  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        36
# 6  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        33
# 7  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        34
# 8  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        33
# 9  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        33
#
#                                 bad_code
# 0  memmove(data, source, 10*sizeof(int))
# 1   memcpy(data, source, 10*sizeof(int))
# 2                    data[i] = source[i]
# 3   memcpy(data, source, 10*sizeof(int))
# 4                    data[i] = source[i]
# 5                    data[i] = source[i]
# 6   memcpy(data, source, 10*sizeof(int))
# 7                    data[i] = source[i]
# 8   memcpy(data, source, 10*sizeof(int))
# 9  memmove(data, source, 10*sizeof(int))

# %%
def extract_node_ids(tree):
    nodes = set()
    
    in_ast_section = False
    
    for line in tree.split('\n'):
        line = line.strip()
        
        if line == '% AST':
            in_ast_section = True
        
        if line == '% CFG':
            in_ast_section = False

        if in_ast_section and not line.startswith("%"):
            parent, child = line[4:-2].split(", ")
            nodes.add(parent)
            nodes.add(child)
            
    return nodes

# %%
# good nodes_g
nodes_g = set()

for i in range(len(good_examples)):
    good_nodes = extract_node_ids(good_examples.iloc[i].tree)
    nodes_g = set.union(nodes_g,good_nodes)

    
# bad nodes_b
nodes_b = set()

for i in range(len(bad_examples)):
    bad_nodes = extract_node_ids(bad_examples.iloc[i].tree)
    nodes_b = set.union(nodes_b,bad_nodes)

nodes = set.union(nodes_g,nodes_b)

# %%
def find_bug_id(good_examples, i = 0):
    tree = good_examples.source_map.iloc[i]
    parents = []
    children = []
    in_code_section = False
    temp = 0
    for line in tree.split('\n'):
        line = line.strip()
        
        if line == '% CODE':
            in_code_section = True
        
        if in_code_section and not line.startswith("%"):
            try:
                parent, child = line[12:-3].split(', "')
                parents.append(parent)
                children.append(child)
            except:
                temp +=1
                
    zipbObj = zip(children, parents)
    bug_node = dict(zipbObj)
    
    loc = good_examples.iloc[i].flaw_loc
    source_code = good_examples.iloc[i].bad_code

    return bug_node[source_code]

# %%
bad_node = []
good_node = []
for i in range(len(bad_examples)):
    bad_node.append(find_bug_id(bad_examples,i))
    good_node.append(find_bug_id(good_examples,i))

# %%
node_and_tree = []
for node in nodes:
    start, end = node.split('_id')
    node_and_tree.append('(' +start+ ', ' +node+ ')')

node_and_tree[0:5]
# Out:
# ['(good_62805, good_62805_id_81_l_)',
#  '(bad_232029, bad_232029_id_148_l_30)',
#  '(bad_231979, bad_231979_id_20_l_)',
#  '(good_231979, good_231979_id_38_l_)',
#  '(bad_62805, bad_62805_id_113_l_33)']

# %%
node_tree_types = [
    'node_in_tree'+ node_tree +'.' for node_tree in node_and_tree
]

# %%
node_types = [
    'node('+ node_id +').' for node_id in nodes
]

# %%
def extract_tree_ids(tree):
    line = tree.split('\n')[2]
    line = line.strip()
    line = line.split('(')[1]
    tree_id = line.split('_id')[0]

    return tree_id

# %%
tree_ids = []
for tree in prolog.tree:
    tree_ids.append(extract_tree_ids(tree))

# %%
trees = [
    'tree('+ tree_label +').' for tree_label in tree_ids
]

# %%
def make_progol_back_know(testcases=None):
    script_template = """

%% Trees
{trees}

%% Types
{types}

%% background knowledge
{bg_knowledge}

    """
    script = script_template.format(
        trees =  '\n'.join(trees),
        types = '\n'.join(node_tree_types + node_types),
        bg_knowledge = '\n'.join(prolog['tree']),
    )
    
    # keep all testcases unless a testcases set is given in fn call
    if testcases:
        # remove all lines not related to this testcase
        script = '\n'.join([
            line for line in script.split("\n")  if any(
                str(testcase) in line for testcase in testcases
            ) or not ("good_" in line or "bad_" in line)
        ])
    
    return script

# %%
def make_progol_real_labels(positive_examples, negative_examples, testcases=None):
    script_template = """
%% learning task
%% positive examples
{positive_examples}

%% negative examples
{negative_examples}

    """
    script = script_template.format(
        positive_examples='\n'.join(positive_examples),
        negative_examples='\n'.join(negative_examples),
   )
    
    # keep all testcases unless a testcases set is given in fn call
    if testcases:
        # remove all lines not related to this testcase
        script = '\n'.join([
            line for line in script.split("\n")  if any(
                str(testcase) in line for testcase in testcases
            ) or not ("good_" in line or "bad_" in line)
        ])
    
    return script

# %% [markdown]
# Here we try to locate the buggy nodes. For each test case this will be:
#   1. Location where the memory is _allocated_.
#   2. Location where the memory is _written to_.
#
# We already have code above to find the latter. Can we find the first as well?

# %%
bad_write_nodes = bad_node
good_write_nodes = good_node

# %%
bad_write_nodes[0].split("_")[-2], bad_write_nodes
# Out:
# ('l',
#  ['bad_232103_id_146_l_32',
#   'bad_232029_id_146_l_32',
#   'bad_231979_id_135_l_33',
#   'bad_62860_id_120_l_32',
#   'bad_62805_id_111_l_35'])

# %%
# this code is horrible sorry. if you need to figure out what it does speak to Dan.

alloc_source_maps = [
    line
    for source_map in prolog['source_map']
    for line in source_map.split("\n")
    if 'data =' in line.lower() and 'alloc' in line.lower()
]

bad_alloc_nodes = [
    source_map.strip("source_code(").split(",")[0]
    for source_map in alloc_source_maps
    if 'bad' in source_map
]

good_alloc_nodes = [
    source_map.strip("source_code(").split(",")[0]
    for source_map in alloc_source_maps
    if 'good' in source_map
]

positive_examples = []
for write_node in bad_write_nodes:
    # find the alloc node which has a line number before the write
    write_line = int(write_node.split("_")[-1])
    
    testcase_id = '_'.join(write_node.split("_")[0:2])
    
    potential_alloc_nodes = [node for node in bad_alloc_nodes if testcase_id in node]
    for alloc_node in potential_alloc_nodes:
        alloc_line = int(alloc_node.split("_")[-1])
        
        if alloc_line <= write_line:
            positive_examples.append(
                "bug({},{}).".format(alloc_node, write_node)
            )
            
negative_examples = []
for write_node in good_write_nodes:
        
    # find the alloc node which has a line number before the write
    write_line = int(write_node.split("_")[-1])
    
    testcase_id = '_'.join(write_node.split("_")[0:2])
    
    potential_alloc_nodes = [node for node in good_alloc_nodes if testcase_id in node]
    for alloc_node in potential_alloc_nodes:
        alloc_line = int(alloc_node.split("_")[-1])
        
        if alloc_line <= write_line:
            negative_examples.append(
                ":- bug({},{}).".format(alloc_node, write_node)
            )

# %%
len(positive_examples), len(negative_examples)
# Out:
# (5, 5)

# %% [markdown]
# Next we experiment with settings and different rule structures to see if it can learn a rule:

# %%
script = make_progol_back_know(

)

with open("../code/ILP-progol-test-bg.pl", "w") as f:
    f.write(script)

# %%
script = make_progol_real_labels(
    positive_examples,
    negative_examples,
)

with open("../code/ILP-progol-test-labels.pl", "w") as f:
    f.write(script)
