# %% [markdown]
# # Generating a Minimal ILP Dataset
#
# ## Find a nice subset
#
# Find a small number of short buffer overflow examples from the Juliet dataset, and save them into the `../data/ilp_data.csv.gz` dataframe.

# %%
import pandas as pd

# %%
buffer_overflow_juliet = pd.read_csv("../data/buffer_overflow_data.csv.gz")

# %%
buffer_overflow_juliet['code_length'] = buffer_overflow_juliet.code.apply(len)
buffer_overflow_juliet
# Out:
#        Unnamed: 0  Unnamed: 0.1  testcase_ID  \
# 0             984           984        62516
# 1             985           985        62517
# 2             986           986        62518
# 3             987           987        62519
# 4             988           988        62520
# 5             989           989        62521
# 6             990           990        62522
# 7             991           991        62523
# 8             992           992        62524
# 9             993           993        62525
# 10            994           994        62526
# 11            995           995        62527
# 12            996           996        62528
# 13            997           997        62529
# 14            998           998        62530
# 15            999           999        62531
# 16           1000          1000        62532
# 17           1001          1001        62533
# 18           1002          1002        62534
# 19           1003          1003        62535
# 20           1004          1004        62535
# 21           1005          1005        62536
# 22           1006          1006        62537
# 23           1007          1007        62538
# 24           1008          1008        62539
# 25           1009          1009        62540
# 26           1010          1010        62541
# 27           1011          1011        62542
# 28           1012          1012        62543
# 29           1013          1013        62544
# ...           ...           ...          ...
# 36270      189196         84013      -234234
# 36271      189197         84014      -234235
# 36272      189198         84015      -234235
# 36273      189199         84016      -234235
# 36274      189200         84017      -234235
# 36275      189201         84018      -234236
# 36276      189202         84019      -234236
# 36277      189203         84020      -234236
# 36278      189204         84021      -234236
# 36279      189205         84022      -234237
# 36280      189206         84023      -234238
# 36281      189207         84024      -234239
# 36282      189208         84025      -234240
# 36283      189211         84028      -234243
# 36284      189212         84029      -234244
# 36285      189216         84033      -234248
# 36286      189217         84034      -234249
# 36287      189218         84035      -234250
# 36288      189219         84036      -234251
# 36289      189220         84037      -234252
# 36290      189221         84038      -234253
# 36291      189222         84039      -234254
# 36292      189223         84040      -234255
# 36293      189224         84041      -234256
# 36294      189227         84044      -234259
# 36295      189228         84045      -234260
# 36296      189231         84048      -234263
# 36297      189237         84054      -234269
# 36298      189238         84055      -234270
# 36299      189239         84056      -234271
#
#                                                 filename  \
# 0      000/062/516/CWE121_Stack_Based_Buffer_Overflow...
# 1      000/062/517/CWE121_Stack_Based_Buffer_Overflow...
# 2      000/062/518/CWE121_Stack_Based_Buffer_Overflow...
# 3      000/062/519/CWE121_Stack_Based_Buffer_Overflow...
# 4      000/062/520/CWE121_Stack_Based_Buffer_Overflow...
# 5      000/062/521/CWE121_Stack_Based_Buffer_Overflow...
# 6      000/062/522/CWE121_Stack_Based_Buffer_Overflow...
# 7      000/062/523/CWE121_Stack_Based_Buffer_Overflow...
# 8      000/062/524/CWE121_Stack_Based_Buffer_Overflow...
# 9      000/062/525/CWE121_Stack_Based_Buffer_Overflow...
# 10     000/062/526/CWE121_Stack_Based_Buffer_Overflow...
# 11     000/062/527/CWE121_Stack_Based_Buffer_Overflow...
# 12     000/062/528/CWE121_Stack_Based_Buffer_Overflow...
# 13     000/062/529/CWE121_Stack_Based_Buffer_Overflow...
# 14     000/062/530/CWE121_Stack_Based_Buffer_Overflow...
# 15     000/062/531/CWE121_Stack_Based_Buffer_Overflow...
# 16     000/062/532/CWE121_Stack_Based_Buffer_Overflow...
# 17     000/062/533/CWE121_Stack_Based_Buffer_Overflow...
# 18     000/062/534/CWE121_Stack_Based_Buffer_Overflow...
# 19     000/062/535/CWE121_Stack_Based_Buffer_Overflow...
# 20     000/062/535/CWE121_Stack_Based_Buffer_Overflow...
# 21     000/062/536/CWE121_Stack_Based_Buffer_Overflow...
# 22     000/062/537/CWE121_Stack_Based_Buffer_Overflow...
# 23     000/062/538/CWE121_Stack_Based_Buffer_Overflow...
# 24     000/062/539/CWE121_Stack_Based_Buffer_Overflow...
# 25     000/062/540/CWE121_Stack_Based_Buffer_Overflow...
# 26     000/062/541/CWE121_Stack_Based_Buffer_Overflow...
# 27     000/062/542/CWE121_Stack_Based_Buffer_Overflow...
# 28     000/062/543/CWE121_Stack_Based_Buffer_Overflow...
# 29     000/062/544/CWE121_Stack_Based_Buffer_Overflow...
# ...                                                  ...
# 36270  000/234/234/CWE122_Heap_Based_Buffer_Overflow_...
# 36271  000/234/235/CWE122_Heap_Based_Buffer_Overflow_...
# 36272  000/234/235/CWE122_Heap_Based_Buffer_Overflow_...
# 36273  000/234/235/CWE122_Heap_Based_Buffer_Overflow_...
# 36274  000/234/235/CWE122_Heap_Based_Buffer_Overflow_...
# 36275  000/234/236/CWE122_Heap_Based_Buffer_Overflow_...
# 36276  000/234/236/CWE122_Heap_Based_Buffer_Overflow_...
# 36277  000/234/236/CWE122_Heap_Based_Buffer_Overflow_...
# 36278  000/234/236/CWE122_Heap_Based_Buffer_Overflow_...
# 36279  000/234/237/CWE122_Heap_Based_Buffer_Overflow_...
# 36280  000/234/238/CWE122_Heap_Based_Buffer_Overflow_...
# 36281  000/234/239/CWE122_Heap_Based_Buffer_Overflow_...
# 36282  000/234/240/CWE122_Heap_Based_Buffer_Overflow_...
# 36283  000/234/243/CWE122_Heap_Based_Buffer_Overflow_...
# 36284  000/234/244/CWE122_Heap_Based_Buffer_Overflow_...
# 36285  000/234/248/CWE122_Heap_Based_Buffer_Overflow_...
# 36286  000/234/249/CWE122_Heap_Based_Buffer_Overflow_...
# 36287  000/234/250/CWE122_Heap_Based_Buffer_Overflow_...
# 36288  000/234/251/CWE122_Heap_Based_Buffer_Overflow_...
# 36289  000/234/252/CWE122_Heap_Based_Buffer_Overflow_...
# 36290  000/234/253/CWE122_Heap_Based_Buffer_Overflow_...
# 36291  000/234/254/CWE122_Heap_Based_Buffer_Overflow_...
# 36292  000/234/255/CWE122_Heap_Based_Buffer_Overflow_...
# 36293  000/234/256/CWE122_Heap_Based_Buffer_Overflow_...
# 36294  000/234/259/CWE122_Heap_Based_Buffer_Overflow_...
# 36295  000/234/260/CWE122_Heap_Based_Buffer_Overflow_...
# 36296  000/234/263/CWE122_Heap_Based_Buffer_Overflow_...
# 36297  000/234/269/CWE122_Heap_Based_Buffer_Overflow_...
# 36298  000/234/270/CWE122_Heap_Based_Buffer_Overflow_...
# 36299  000/234/271/CWE122_Heap_Based_Buffer_Overflow_...
#
#                                                     code     flaw  flaw_loc  \
# 0      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       112
# 1      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       117
# 2      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       117
# 3      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       123
# 4      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       123
# 5      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       122
# 6      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       122
# 7      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       130
# 8      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       117
# 9      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       117
# 10     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       117
# 11     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       123
# 12     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       117
# 13     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       117
# 14     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       124
# 15     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       118
# 16     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       118
# 17     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       116
# 18     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        58
# 19     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        36
# 20     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        36
# 21     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       115
# 22     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       120
# 23     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       118
# 24     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       122
# 25     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        53
# 26     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       118
# 27     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       120
# 28     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        53
# 29     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        58
# ...                                                  ...      ...       ...
# 36270  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        34
# 36271  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        27
# 36272  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        27
# 36273  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        27
# 36274  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        27
# 36275  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        27
# 36276  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        27
# 36277  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        27
# 36278  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        27
# 36279  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        42
# 36280  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36281  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36282  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        50
# 36283  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        49
# 36284  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        57
# 36285  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36286  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36287  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36288  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        45
# 36289  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36290  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        45
# 36291  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36292  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        42
# 36293  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36294  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        50
# 36295  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        49
# 36296  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36297  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        45
# 36298  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36299  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        45
#
#          bug  code_length
# 0      False         5108
# 1      False         9668
# 2      False         9710
# 3      False        10162
# 4      False        10084
# 5      False        10123
# 6      False        10054
# 7      False        10190
# 8      False         9897
# 9      False         9799
# 10     False         9925
# 11     False         9329
# 12     False         9934
# 13     False         9836
# 14     False        10128
# 15     False         5735
# 16     False         5697
# 17     False         5314
# 18     False         8623
# 19     False         7369
# 20     False         3771
# 21     False         5446
# 22     False         5862
# 23     False         5552
# 24     False         5819
# 25     False         5314
# 26     False         5355
# 27     False         5439
# 28     False         5432
# 29     False         5906
# ...      ...          ...
# 36270   True         1078
# 36271   True         1074
# 36272   True         1030
# 36273   True          606
# 36274   True         2001
# 36275   True         1050
# 36276   True         1022
# 36277   True          604
# 36278   True         2019
# 36279   True         2265
# 36280   True         2360
# 36281   True         2369
# 36282   True         2674
# 36283   True         2614
# 36284   True         2680
# 36285   True         3259
# 36286   True         2417
# 36287   True         2396
# 36288   True         2475
# 36289   True         2371
# 36290   True         2382
# 36291   True         2307
# 36292   True         2242
# 36293   True         2333
# 36294   True         2646
# 36295   True         2579
# 36296   True         2382
# 36297   True         2452
# 36298   True         2344
# 36299   True         2355
#
# [36300 rows x 9 columns]

# %%
buffer_overflow_juliet.groupby(['testcase_ID']).apply(
    lambda testcase, **kwargs: sum(testcase['code_length']),
    axis='columns',
).sort_values()
# Out:
# testcase_ID
# -62852      1570
# -62900      1576
# -62869      1616
# -62804      1618
# -232012     1619
# -62853      1621
# -62917      1622
# -232086     1625
# -62901      1627
# -62854      1630
# -62867      1632
# -62902      1636
# -62915      1638
# -62868      1643
# -62861      1649
# -62916      1649
# -62909      1655
# -62865      1657
# -62913      1663
# -62821      1664
# -232029     1665
# -231979     1667
# -62805      1669
# -62860      1670
# -232103     1671
#  62852      1674
# -232013     1674
# -62908      1676
# -62862      1676
# -62806      1678
#            ...
#  232342    11388
#  67724     11389
#  232346    11425
#  232341    11486
#  232347    11501
#  232196    11511
#  67718     11512
#  232343    11514
#  232345    11523
#  67716     11542
#  70687     11546
#  67717     11581
#  67759     11584
#  67715     11620
#  232339    11643
#  67719     11648
#  232337    11673
#  232364    11690
#  62727     11694
#  232338    11712
#  232336    11751
#  232340    11779
#  232184    11843
#  232352    12397
#  67552     12449
#  67744     12616
#  62548     13047
#  62740     13194
#  232197    13474
#  232365    13621
# Length: 21502, dtype: int64

# %% [markdown]
# Pick 10 smallest:
#   - -62852
#   - -62900
#   - -62869
#   - -62804
#   - -232012
#   - -62853
#   - -62917
#   - -232086
#   - -62901
#   - -62854

# %%
small_testcase_ids = [
  62852,      
  62900,      
  62869,      
  62804,   
  232012, 
  -62852,      
  -62900,      
  -62869,      
  -62804,   
  -232012,
  62853,
  62917,
  232086,
  62901,
  62854,
  -62853,
  -62917,
  -232086,
  -62901,
  -62854,
]

# %%
ilp_dataset = buffer_overflow_juliet[
    (buffer_overflow_juliet['testcase_ID'] == 62852) | 
    (buffer_overflow_juliet['testcase_ID'] == 62900) | 
    (buffer_overflow_juliet['testcase_ID'] == 62869) | 
    (buffer_overflow_juliet['testcase_ID'] == 62804) | 
    (buffer_overflow_juliet['testcase_ID'] == 232012) | 
    (buffer_overflow_juliet['testcase_ID'] == -62852) | 
    (buffer_overflow_juliet['testcase_ID'] == -62900) | 
    (buffer_overflow_juliet['testcase_ID'] == -62869) | 
    (buffer_overflow_juliet['testcase_ID'] == -62804) | 
    (buffer_overflow_juliet['testcase_ID'] == -232012) |
   (buffer_overflow_juliet['testcase_ID'] == 62853) |
   (buffer_overflow_juliet['testcase_ID'] == 62917) |
   (buffer_overflow_juliet['testcase_ID'] == 232086) |
   (buffer_overflow_juliet['testcase_ID'] == 62901) |
   (buffer_overflow_juliet['testcase_ID'] == 62854) |
   (buffer_overflow_juliet['testcase_ID'] == -62853) |
   (buffer_overflow_juliet['testcase_ID'] == -62917) |
   (buffer_overflow_juliet['testcase_ID'] == -232086) |
   (buffer_overflow_juliet['testcase_ID'] == -62901) |
   (buffer_overflow_juliet['testcase_ID'] == -62854)
]
ilp_dataset
# Out:
#        Unnamed: 0  Unnamed: 0.1  testcase_ID  \
# 516          1500          1500        62804
# 581          1565          1565        62852
# 582          1566          1566        62853
# 583          1567          1567        62854
# 598          1582          1582        62869
# 646          1630          1630        62900
# 647          1631          1631        62901
# 663          1647          1647        62917
# 15179       81030         81030       232012
# 15281       81132         81132       232086
# 18666      106683          1500       -62804
# 18731      106748          1565       -62852
# 18732      106749          1566       -62853
# 18733      106750          1567       -62854
# 18748      106765          1582       -62869
# 18796      106813          1630       -62900
# 18797      106814          1631       -62901
# 18813      106830          1647       -62917
# 33329      186213         81030      -232012
# 33431      186315         81132      -232086
#
#                                                 filename  \
# 516    000/062/804/CWE121_Stack_Based_Buffer_Overflow...
# 581    000/062/852/CWE121_Stack_Based_Buffer_Overflow...
# 582    000/062/853/CWE121_Stack_Based_Buffer_Overflow...
# 583    000/062/854/CWE121_Stack_Based_Buffer_Overflow...
# 598    000/062/869/CWE121_Stack_Based_Buffer_Overflow...
# 646    000/062/900/CWE121_Stack_Based_Buffer_Overflow...
# 647    000/062/901/CWE121_Stack_Based_Buffer_Overflow...
# 663    000/062/917/CWE121_Stack_Based_Buffer_Overflow...
# 15179  000/232/012/CWE122_Heap_Based_Buffer_Overflow_...
# 15281  000/232/086/CWE122_Heap_Based_Buffer_Overflow_...
# 18666  000/062/804/CWE121_Stack_Based_Buffer_Overflow...
# 18731  000/062/852/CWE121_Stack_Based_Buffer_Overflow...
# 18732  000/062/853/CWE121_Stack_Based_Buffer_Overflow...
# 18733  000/062/854/CWE121_Stack_Based_Buffer_Overflow...
# 18748  000/062/869/CWE121_Stack_Based_Buffer_Overflow...
# 18796  000/062/900/CWE121_Stack_Based_Buffer_Overflow...
# 18797  000/062/901/CWE121_Stack_Based_Buffer_Overflow...
# 18813  000/062/917/CWE121_Stack_Based_Buffer_Overflow...
# 33329  000/232/012/CWE122_Heap_Based_Buffer_Overflow_...
# 33431  000/232/086/CWE122_Heap_Based_Buffer_Overflow_...
#
#                                                     code     flaw  flaw_loc  \
# 516    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 581    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 582    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 583    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 598    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        32
# 646    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 647    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 663    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        32
# 15179  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        31
# 15281  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        31
# 18666  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 18731  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 18732  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 18733  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 18748  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        32
# 18796  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 18797  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 18813  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        32
# 33329  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        31
# 33431  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        31
#
#          bug  code_length
# 516    False         1722
# 581    False         1674
# 582    False         2396
# 583    False         2414
# 598    False         1760
# 646    False         1680
# 647    False         2403
# 663    False         1766
# 15179  False         1723
# 15281  False         1729
# 18666   True         1618
# 18731   True         1570
# 18732   True         1621
# 18733   True         1630
# 18748   True         1616
# 18796   True         1576
# 18797   True         1627
# 18813   True         1622
# 33329   True         1619
# 33431   True         1625

# %%
ilp_dataset = ilp_dataset.drop(["Unnamed: 0", "Unnamed: 0.1"], axis='columns')

# %%
ilp_dataset
# Out:
#        testcase_ID                                           filename  \
# 516          62804  000/062/804/CWE121_Stack_Based_Buffer_Overflow...
# 581          62852  000/062/852/CWE121_Stack_Based_Buffer_Overflow...
# 582          62853  000/062/853/CWE121_Stack_Based_Buffer_Overflow...
# 583          62854  000/062/854/CWE121_Stack_Based_Buffer_Overflow...
# 598          62869  000/062/869/CWE121_Stack_Based_Buffer_Overflow...
# 646          62900  000/062/900/CWE121_Stack_Based_Buffer_Overflow...
# 647          62901  000/062/901/CWE121_Stack_Based_Buffer_Overflow...
# 663          62917  000/062/917/CWE121_Stack_Based_Buffer_Overflow...
# 15179       232012  000/232/012/CWE122_Heap_Based_Buffer_Overflow_...
# 15281       232086  000/232/086/CWE122_Heap_Based_Buffer_Overflow_...
# 18666       -62804  000/062/804/CWE121_Stack_Based_Buffer_Overflow...
# 18731       -62852  000/062/852/CWE121_Stack_Based_Buffer_Overflow...
# 18732       -62853  000/062/853/CWE121_Stack_Based_Buffer_Overflow...
# 18733       -62854  000/062/854/CWE121_Stack_Based_Buffer_Overflow...
# 18748       -62869  000/062/869/CWE121_Stack_Based_Buffer_Overflow...
# 18796       -62900  000/062/900/CWE121_Stack_Based_Buffer_Overflow...
# 18797       -62901  000/062/901/CWE121_Stack_Based_Buffer_Overflow...
# 18813       -62917  000/062/917/CWE121_Stack_Based_Buffer_Overflow...
# 33329      -232012  000/232/012/CWE122_Heap_Based_Buffer_Overflow_...
# 33431      -232086  000/232/086/CWE122_Heap_Based_Buffer_Overflow_...
#
#                                                     code     flaw  flaw_loc  \
# 516    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 581    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 582    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 583    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 598    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        32
# 646    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 647    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 663    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        32
# 15179  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        31
# 15281  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        31
# 18666  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 18731  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 18732  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 18733  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 18748  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        32
# 18796  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 18797  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 18813  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        32
# 33329  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        31
# 33431  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        31
#
#          bug  code_length
# 516    False         1722
# 581    False         1674
# 582    False         2396
# 583    False         2414
# 598    False         1760
# 646    False         1680
# 647    False         2403
# 663    False         1766
# 15179  False         1723
# 15281  False         1729
# 18666   True         1618
# 18731   True         1570
# 18732   True         1621
# 18733   True         1630
# 18748   True         1616
# 18796   True         1576
# 18797   True         1627
# 18813   True         1622
# 33329   True         1619
# 33431   True         1625

# %%
ilp_dataset.to_csv("../data/ilp_dataset.csv.gz")

# %% [markdown]
# ## Generating Prolog Representations

# %% [markdown]
# Now that we have a set of examples, we want to generate a Prolog representation. To do this we use Joern to derive a code property graph from each source file. Then, using our `../code/joern_cfg_to_prolog.scala` script, we convert a subset of this graph into a set of prolog facts.

# %%
import os
import subprocess
import tempfile

# %%
testcase_IDs = []
flaws = []
bugs = []
code_lengths = []
trees = []

# %%
def generate_prolog(testcase):
    tmp_dir = tempfile.TemporaryDirectory()

    for file in testcase.itertuples():
        short_filename = file.filename.split("/")[-1]
        with open(tmp_dir.name + "/" + short_filename, 'w') as f:
            f.write(file.code)

    subprocess.check_call(["/joern/joern-parse", "--out", tmp_dir.name + "/cpg.bin.zip", tmp_dir.name])

    tree = subprocess.check_output(
        "cd /joern && /joern/joern-query --cpg "+tmp_dir.name + "/cpg.bin.zip -f /project/code/joern_cfg_to_prolog.scala",
        shell=True,
        universal_newlines=True,
    )

    testcase_IDs.append(file.testcase_ID)
    flaws.append( file.flaw)
    bugs.append(file.bug)
    code_lengths.append(file.code_length)
    trees.append(tree)

    tmp_dir.cleanup()

# %%
ilp_data.groupby('testcase_ID').apply(generate_prolog)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
prolog = pd.DataFrame({
    'testcase_ID': testcase_IDs,
    'flaw': flaws,
    'bug': bugs,
    'code_length': code_lengths,
    'tree': trees,
})
prolog = prolog[1:21]  # when we run apply it duplicates the first group
prolog
# Out:
#     testcase_ID     flaw    bug  code_length  \
# 1       -232086  CWE-122   True         1625
# 2       -232012  CWE-122   True         1619
# 3        -62917  CWE-121   True         1622
# 4        -62901  CWE-121   True         1627
# 5        -62900  CWE-121   True         1576
# 6        -62869  CWE-121   True         1616
# 7        -62854  CWE-121   True         1630
# 8        -62853  CWE-121   True         1621
# 9        -62852  CWE-121   True         1570
# 10       -62804  CWE-121   True         1618
# 11        62804  CWE-121  False         1722
# 12        62852  CWE-121  False         1674
# 13        62853  CWE-121  False         2396
# 14        62854  CWE-121  False         2414
# 15        62869  CWE-121  False         1760
# 16        62900  CWE-121  False         1680
# 17        62901  CWE-121  False         2403
# 18        62917  CWE-121  False         1766
# 19       232012  CWE-122  False         1723
# 20       232086  CWE-122  False         1729
#
#                                                  tree
# 1   % START: Generated Prolog\n% NODE PROPERTIES \...
# 2   % START: Generated Prolog\n% NODE PROPERTIES \...
# 3   % START: Generated Prolog\n% NODE PROPERTIES \...
# 4   % START: Generated Prolog\n% NODE PROPERTIES \...
# 5   % START: Generated Prolog\n% NODE PROPERTIES \...
# 6   % START: Generated Prolog\n% NODE PROPERTIES \...
# 7   % START: Generated Prolog\n% NODE PROPERTIES \...
# 8   % START: Generated Prolog\n% NODE PROPERTIES \...
# 9   % START: Generated Prolog\n% NODE PROPERTIES \...
# 10  % START: Generated Prolog\n% NODE PROPERTIES \...
# 11  % START: Generated Prolog\n% NODE PROPERTIES \...
# 12  % START: Generated Prolog\n% NODE PROPERTIES \...
# 13  % START: Generated Prolog\n% NODE PROPERTIES \...
# 14  % START: Generated Prolog\n% NODE PROPERTIES \...
# 15  % START: Generated Prolog\n% NODE PROPERTIES \...
# 16  % START: Generated Prolog\n% NODE PROPERTIES \...
# 17  % START: Generated Prolog\n% NODE PROPERTIES \...
# 18  % START: Generated Prolog\n% NODE PROPERTIES \...
# 19  % START: Generated Prolog\n% NODE PROPERTIES \...
# 20  % START: Generated Prolog\n% NODE PROPERTIES \...

# %%
import re

# %%
def fix_single_rules(testcase):
    find_node_ids = re.compile('\((\w+)\)')
    replacement_node_ids = '({bug}_{testcase_id}_\\1)'.format(
        bug='bad' if testcase.bug else 'good',
        testcase_id=abs(testcase.testcase_ID),
    )
    return find_node_ids.sub(replacement_node_ids, testcase['tree'])

def fix_tree_rules(testcase):
    find_node_ids = re.compile('\((\w+), (\w+)\)')
    replacement_node_ids = '({bug}_{testcase_id}_\\1, {bug}_{testcase_id}_\\2)'.format(
        bug='bad' if testcase.bug else 'good',
        testcase_id=abs(testcase.testcase_ID),
    )
    return find_node_ids.sub(replacement_node_ids, testcase['tree'])

def fix_code_rules(testcase):
    find_node_ids = re.compile('\((\w+), "(.*)"\)')
    replacement_node_ids = '({bug}_{testcase_id}_\\1, "\\2")'.format(
        bug='bad' if testcase.bug else 'good',
        testcase_id=abs(testcase.testcase_ID),
    )
    return find_node_ids.sub(replacement_node_ids, testcase['tree'])

# %%
prolog['tree'] = prolog.apply(fix_single_rules, axis='columns')
prolog['tree'] = prolog.apply(fix_tree_rules, axis='columns')
prolog['tree'] = prolog.apply(fix_code_rules, axis='columns')

# %%
prolog
# Out:
#     testcase_ID     flaw    bug  code_length  \
# 1       -232086  CWE-122   True         1625
# 2       -232012  CWE-122   True         1619
# 3        -62917  CWE-121   True         1622
# 4        -62901  CWE-121   True         1627
# 5        -62900  CWE-121   True         1576
# 6        -62869  CWE-121   True         1616
# 7        -62854  CWE-121   True         1630
# 8        -62853  CWE-121   True         1621
# 9        -62852  CWE-121   True         1570
# 10       -62804  CWE-121   True         1618
# 11        62804  CWE-121  False         1722
# 12        62852  CWE-121  False         1674
# 13        62853  CWE-121  False         2396
# 14        62854  CWE-121  False         2414
# 15        62869  CWE-121  False         1760
# 16        62900  CWE-121  False         1680
# 17        62901  CWE-121  False         2403
# 18        62917  CWE-121  False         1766
# 19       232012  CWE-122  False         1723
# 20       232086  CWE-122  False         1729
#
#                                                  tree
# 1   % START: Generated Prolog\n% NODE PROPERTIES \...
# 2   % START: Generated Prolog\n% NODE PROPERTIES \...
# 3   % START: Generated Prolog\n% NODE PROPERTIES \...
# 4   % START: Generated Prolog\n% NODE PROPERTIES \...
# 5   % START: Generated Prolog\n% NODE PROPERTIES \...
# 6   % START: Generated Prolog\n% NODE PROPERTIES \...
# 7   % START: Generated Prolog\n% NODE PROPERTIES \...
# 8   % START: Generated Prolog\n% NODE PROPERTIES \...
# 9   % START: Generated Prolog\n% NODE PROPERTIES \...
# 10  % START: Generated Prolog\n% NODE PROPERTIES \...
# 11  % START: Generated Prolog\n% NODE PROPERTIES \...
# 12  % START: Generated Prolog\n% NODE PROPERTIES \...
# 13  % START: Generated Prolog\n% NODE PROPERTIES \...
# 14  % START: Generated Prolog\n% NODE PROPERTIES \...
# 15  % START: Generated Prolog\n% NODE PROPERTIES \...
# 16  % START: Generated Prolog\n% NODE PROPERTIES \...
# 17  % START: Generated Prolog\n% NODE PROPERTIES \...
# 18  % START: Generated Prolog\n% NODE PROPERTIES \...
# 19  % START: Generated Prolog\n% NODE PROPERTIES \...
# 20  % START: Generated Prolog\n% NODE PROPERTIES \...

# %%
def extract_source_map(prolog_src):
    output_lines = []
    
    in_source_code_section = False
    
    for line in prolog_src.split("\n"):
        if line == "% CODE":
            in_source_code_section = True
            
        if line == "% AST":
            in_source_code_section = False
        
        if in_source_code_section:
            output_lines.append(line)
            
    return '\n'.join(output_lines)
            
    
def remove_source_map(prolog_src):
    output_lines = []
    
    in_source_code_section = False
    
    for line in prolog_src.split("\n"):
        if line == "% CODE":
            in_source_code_section = True
            
        if line == "% AST":
            in_source_code_section = False
        
        if not in_source_code_section:
            output_lines.append(line)
            
    return '\n'.join(output_lines)

# %%
prolog['source_map'] = prolog['tree'].apply(extract_source_map)
prolog['tree'] = prolog['tree'].apply(remove_source_map)

# %%
prolog.to_csv("../data/ilp_prolog_data.csv.gz")
