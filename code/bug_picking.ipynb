# %%
import pandas as pd

# %%
data = pd.read_csv('../data/juliet_split.csv.gz')

# %%
cwe_list = pd.read_csv('../data/2000.csv.zip', index_col=False)

# %%
cwe_list = cwe_list.rename(columns={"CWE-ID": "CWE_ID"})
cwe_list['CWE_ID'] = cwe_list['CWE_ID'].astype(int)

# %%
cwe_list.CWE_ID = cwe_list.CWE_ID.apply(lambda x: 'CWE-' + str(x))

# %%
cwe_list = cwe_list[['CWE_ID', 'Name']]

# %%
value_counts = data.flaw.value_counts()
bug_df = value_counts.rename_axis('CWE_ID').reset_index(name='counts')
# Out:
# CWE-122    12036
# CWE-121    11968
# CWE-078     9600
# CWE-190     8044
# CWE-762     7128
# CWE-191     5904
# CWE-134     5760
# CWE-590     5360
# CWE-023     4800
# CWE-036     4800
# CWE-127     4096
# CWE-124     4096
# CWE-401     3316
# CWE-126     3176
# CWE-457     2732
# CWE-194     2304
# CWE-195     2304
# CWE-690     2208
# CWE-415     1924
# CWE-789     1920
# CWE-197     1788
# CWE-369     1728
# CWE-400     1440
# CWE-253     1368
# CWE-252     1260
# CWE-758     1162
# CWE-680     1152
# CWE-114     1152
# CWE-761     1152
# CWE-563     1024
#            ...
# CWE-482       36
# CWE-222       36
# CWE-364       36
# CWE-587       36
# CWE-478       36
# CWE-223       36
# CWE-247       36
# CWE-480       36
# CWE-667       36
# CWE-676       36
# CWE-785       36
# CWE-688       36
# CWE-196       36
# CWE-620       36
# CWE-780       36
# CWE-481       36
# CWE-484       36
# CWE-338       36
# CWE-526       36
# CWE-832       36
# CWE-615       36
# CWE-242       36
# CWE-570       32
# CWE-571       32
# CWE-835       12
# CWE-562        6
# CWE-561        4
# CWE-674        4
# CWE-500        2
# CWE-440        2
# Name: flaw, Length: 119, dtype: int64

# %%
bug_df = pd.merge(cwe_list,bug_df, on='CWE_ID')

# %%
bug_df = bug_df.sort_values(by='counts', ascending=False)

# %%
bug_df.to_csv('../data/bug_df.csv')
# Out:
#       CWE_ID                                               Name  counts
# 2    CWE-122                         Heap-based Buffer Overflow   12036
# 1    CWE-121                        Stack-based Buffer Overflow   11968
# 11   CWE-190                     Integer Overflow or Wraparound    8044
# 104  CWE-762              Mismatched Memory Management Routines    7128
# 12   CWE-191             Integer Underflow (Wrap or Wraparound)    5904
# 7    CWE-134         Use of Externally-Controlled Format String    5760
# 83   CWE-590                     Free of Memory not on the Heap    5360
# 6    CWE-127                                  Buffer Under-read    4096
# 4    CWE-124             Buffer Underwrite ('Buffer Underflow')    4096
# 46   CWE-401  Missing Release of Memory after Effective Life...    3316
# 5    CWE-126                                   Buffer Over-read    3176
# 53   CWE-457                      Use of Uninitialized Variable    2732
# 13   CWE-194                          Unexpected Sign Extension    2304
# 14   CWE-195                Signed to Unsigned Conversion Error    2304
# 101  CWE-690  Unchecked Return Value to NULL Pointer Derefer...    2208
# 48   CWE-415                                        Double Free    1924
# 109  CWE-789                     Uncontrolled Memory Allocation    1920
# 16   CWE-197                           Numeric Truncation Error    1788
# 39   CWE-369                                     Divide By Zero    1728
# 45   CWE-400                  Uncontrolled Resource Consumption    1440
# 24   CWE-253           Incorrect Check of Function Return Value    1368
# 23   CWE-252                             Unchecked Return Value    1260
# 102  CWE-758  Reliance on Undefined, Unspecified, or Impleme...    1162
# 0    CWE-114                                    Process Control    1152
# 97   CWE-680                Integer Overflow to Buffer Overflow    1152
# 103  CWE-761             Free of Pointer not at Start of Buffer    1152
# 78   CWE-563                 Assignment to Variable without Use    1024
# 51   CWE-427                   Uncontrolled Search Path Element     960
# 86   CWE-606                 Unchecked Input for Loop Condition     960
# 49   CWE-416                                     Use After Free     918
# ..       ...                                                ...     ...
# 15   CWE-196                Unsigned to Signed Conversion Error      36
# 17   CWE-222        Truncation of Security-relevant Information      36
# 18   CWE-223          Omission of Security-relevant Information      36
# 110  CWE-832            Unlock of a Resource that is not Locked      36
# 20   CWE-242               Use of Inherently Dangerous Function      36
# 100  CWE-688  Function Call With Incorrect Variable or Refer...      36
# 99   CWE-685   Function Call With Incorrect Number of Arguments      36
# 61   CWE-478           Missing Default Case in Switch Statement      36
# 96   CWE-676              Use of Potentially Dangerous Function      36
# 22   CWE-247  DEPRECATED (Duplicate): Reliance on DNS Lookup...      36
# 36   CWE-364                      Signal Handler Race Condition      36
# 67   CWE-484                  Omitted Break Statement in Switch      36
# 63   CWE-480                          Use of Incorrect Operator      36
# 64   CWE-481                     Assigning instead of Comparing      36
# 89   CWE-620                         Unverified Password Change      36
# 65   CWE-482                     Comparing instead of Assigning      36
# 87   CWE-615              Information Exposure Through Comments      36
# 85   CWE-605                    Multiple Binds to the Same Port      36
# 35   CWE-338  Use of Cryptographically Weak Pseudo-Random Nu...      36
# 92   CWE-667                                   Improper Locking      36
# 81   CWE-587         Assignment of a Fixed Address to a Pointer      36
# 72   CWE-526  Information Exposure Through Environmental Var...      36
# 80   CWE-571                          Expression is Always True      32
# 79   CWE-570                         Expression is Always False      32
# 111  CWE-835  Loop with Unreachable Exit Condition ('Infinit...      12
# 77   CWE-562                   Return of Stack Variable Address       6
# 76   CWE-561                                          Dead Code       4
# 94   CWE-674                             Uncontrolled Recursion       4
# 52   CWE-440                        Expected Behavior Violation       2
# 68   CWE-500               Public Static Field Not Marked Final       2
#
# [113 rows x 3 columns]
