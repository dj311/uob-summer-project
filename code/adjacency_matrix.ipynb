# %% [markdown]
# Notebook to generate adjacency matrices of our scripts in the juliet dataset to be used as input for our neural network model.

# %%
import ast
import pickle
import numpy as np
import pandas as pd
from scipy import sparse
import networkx as nx

# %%
from preprocess_code import *
data = pd.read_csv("../data/buffer_overflow_data.csv.gz")
# Out:
# /usr/local/lib/python3.7/dist-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
clang.cindex.Config.set_library_file('/lib/x86_64-linux-gnu/libclang-8.so.1')

# %%
data = data.iloc[0:100]

# %%
def generate_edge_list1(testcase, **kwargs):
    """
    Takes in a list of files/datapoints from juliet.csv.zip 
    or (as loaded with pandas) matching one particular testcase, 
    and returns an edge list of its graph representation.
    """
    parse_list = [
        (datapoint.filename, datapoint.code)
        for datapoint in testcase.itertuples()
    ]

    primary = find_primary_source_file(testcase)

    # Parse the source code with clang, and get out an ast:
    index = clang.cindex.Index.create()
    translation_unit = index.parse(
        path=primary.filename,
        unsaved_files=parse_list,
    )
    ast_root = translation_unit.cursor

    # Memoise/concretise the ast so that we can consistently
    # modify it, then number each node in the tree uniquely.
    concretise_ast(ast_root)
    number_ast_nodes(ast_root)

    # Next, construct an edge list for the graph2vec input:
    edgelist = generate_edgelist(ast_root)
    
    edgelist_representation = {
        "edges": edgelist,
    }

    # Explicitly delete clang objects
    del translation_unit
    del ast_root
    del index

    return json.dumps(edgelist_representation)

# %%
# dask_data = dd.from_pandas(data, npartitions=20)

# generate the graphs for all the testcases in the dataset 

graphs = data.groupby(['testcase_ID']).apply(
        generate_edge_list1,
        axis='columns',
        meta=('generate_edge_list', 'unicode'),
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0b54c0c74acc> in <module>
#       4
#       5 graphs = data.groupby(['testcase_ID']).apply(
# ----> 6         generate_edge_list1,
#       7         axis='columns',
#       8         meta=('generate_edge_list', 'unicode'),
#
# NameError: name 'generate_edge_list1' is not defined

# %%
def gen_adj_matrix1(testcase):
    
    """
    Takes in a list of files/datapoints from buffer_overflow_data.csv.gz 
    matching one particular testcase, and generates an adjacency matrix 
    from the edgelist created.
    """
    
    # extracting the list of edges 

    x = testcase.split('edges": ')
    x = x[1].split('}')
    x = ast.literal_eval(x[0])
    
#     return x

    # generating the matrix
    
    G = nx.Graph()

    G.add_edges_from(x)

    A = nx.adjacency_matrix(G)

    B = A.todense()

    return B

# %%
# create a dataframe containing the testcase ID and its adjacency matrix 
adjacency_df = pd.DataFrame()

# %%
adjacency_df['testcase_ID'] = data.testcase_ID.drop_duplicates()

# %%
# kernel dies when there are more than 200 datapoints

# adj_matrices = graphs.apply(gen_adj_matrix1, meta = ('generate_adj_matrices', 'O'))
adj_matrices = graphs.apply(gen_adj_matrix1)

# %%
# adj_matrices = pd.DataFrame(adj_matrices)
adj_matrices = adj_matrices.to_frame()

# %%
## TODO: in a DASK framework reset_index is not a recognized function like pandas, fix this bug

# adj_matrices = adj_matrices.compute()
adj_matrices = adj_matrices.reset_index(level='testcase_ID')

# %%
adjacency_df['adj_matrix'] = adj_matrices[0]

# %%
adj_df = adjacency_df.dropna()

# %%
adj_df.to_csv("../data/adj_df.csv.gz")

# %% [markdown]
# ## Feature Matrix

# %%
def concretise_ast(node):
    """
    Everytime you run .get_children() on a clang ast node, it
    gives you new objects. So if you want to modify those objects
    they will lose their changes everytime you walk the tree again.
    To avoid this problem, concretise_ast walks the tree once,
    saving the resulting list from .get_children() into a a concrete
    list inside the .children.
    You can then use .children to consistently walk over tree, and
    it will give you the same objects each time.
    """
    node.children = list(node.get_children())

    for child in node.children:
        counter = concretise_ast(child)

def number_ast_nodes(node, counter=1):
    """
    Given a concretised clang ast, assign each node with a unique
    numerical identifier. This will be accessible via the .identifier
    attribute of each node.
    """
    node.identifier = counter
    counter += 1

    node.children = list(node.get_children())
    for child in node.children:
        counter = number_ast_nodes(child, counter)

    return counter


def generate_ast_roots(testcase, **kwargs):
    """
    Takes in a list of files/datapoints from juliet.csv.zip (as loaded with pandas) matching one particular
    testcase, and preprocesses it ready for the feature matrix.
    """
    
    parse_list = [
        (datapoint.filename, datapoint.code)
        for datapoint in testcase.itertuples()
    ]

    primary = find_primary_source_file(testcase)

    # Parse the source code with clang, and get out an ast:
    index = clang.cindex.Index.create()
    translation_unit = index.parse(
        path=primary.filename,
        unsaved_files=parse_list,
    )
    ast_root = translation_unit.cursor
    
    concretise_ast(ast_root)
    number_ast_nodes(ast_root)
    
    return ast_root

# %%
ast_roots = data.groupby(['testcase_ID']).apply(generate_ast_roots)

# %%
example_node = ast_roots.iloc[0].children[19]
dir(example_node)
# Out:
# ['__class__',
#  '__ctypes_from_outparam__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_b_base_',
#  '_b_needsfree_',
#  '_displayname',
#  '_fields_',
#  '_kind_id',
#  '_objects',
#  '_tu',
#  'access_specifier',
#  'availability',
#  'brief_comment',
#  'canonical',
#  'children',
#  'data',
#  'displayname',
#  'enum_type',
#  'enum_value',
#  'exception_specification_kind',
#  'extent',
#  'from_cursor_result',
#  'from_location',
#  'from_result',
#  'get_arguments',
#  'get_bitfield_width',
#  'get_children',
#  'get_definition',
#  'get_field_offsetof',
#  'get_included_file',
#  'get_num_template_arguments',
#  'get_template_argument_kind',
#  'get_template_argument_type',
#  'get_template_argument_unsigned_value',
#  'get_template_argument_value',
#  'get_tokens',
#  'get_usr',
#  'hash',
#  'identifier',
#  'is_abstract_record',
#  'is_anonymous',
#  'is_bitfield',
#  'is_const_method',
#  'is_converting_constructor',
#  'is_copy_constructor',
#  'is_default_constructor',
#  'is_default_method',
#  'is_definition',
#  'is_move_constructor',
#  'is_mutable_field',
#  'is_pure_virtual_method',
#  'is_scoped_enum',
#  'is_static_method',
#  'is_virtual_method',
#  'kind',
#  'lexical_parent',
#  'linkage',
#  'location',
#  'mangled_name',
#  'objc_type_encoding',
#  'raw_comment',
#  'referenced',
#  'result_type',
#  'semantic_parent',
#  'spelling',
#  'storage_class',
#  'tls_kind',
#  'translation_unit',
#  'type',
#  'underlying_typedef_type',
#  'walk_preorder',
#  'xdata']

# %%
example_node.brief_comment

# %%
def generate_features(ast_root):
    """
    Given a concretised & numbered clang ast, return a dictionary of
    features in the form:
        {
            <node_id>: [<degree>, <type>, <identifier>],
            ...
        }
    """
#     features =  set()
    features = {}


    def walk_tree_and_set_features(node):
        out_degree = len(node.children)
        in_degree = 1
        degree = out_degree + in_degree
        
#         features.add(str(node.kind))

        features[node.identifier] = [str(node.kind), node.displayname]

        for child in node.children:
            walk_tree_and_set_features(child)

    walk_tree_and_set_features(ast_root)

    return features

# %%
feature_sets = ast_roots.apply(generate_features)

# %%
feature_sets.iloc[0]
# Out:
# {1: ['CursorKind.TRANSLATION_UNIT',
#   '000/062/516/CWE121_Stack_Based_Buffer_Overflow__CWE129_connect_socket_01.c'],
#  2: ['CursorKind.TYPEDEF_DECL', '__u_char'],
#  3: ['CursorKind.TYPEDEF_DECL', '__u_short'],
#  4: ['CursorKind.TYPEDEF_DECL', '__u_int'],
#  5: ['CursorKind.TYPEDEF_DECL', '__u_long'],
#  6: ['CursorKind.TYPEDEF_DECL', '__int8_t'],
#  7: ['CursorKind.TYPEDEF_DECL', '__uint8_t'],
#  8: ['CursorKind.TYPEDEF_DECL', '__int16_t'],
#  9: ['CursorKind.TYPEDEF_DECL', '__uint16_t'],
#  10: ['CursorKind.TYPEDEF_DECL', '__int32_t'],
#  11: ['CursorKind.TYPEDEF_DECL', '__uint32_t'],
#  12: ['CursorKind.TYPEDEF_DECL', '__int64_t'],
#  13: ['CursorKind.TYPEDEF_DECL', '__uint64_t'],
#  14: ['CursorKind.TYPEDEF_DECL', '__int_least8_t'],
#  15: ['CursorKind.TYPE_REF', '__int8_t'],
#  16: ['CursorKind.TYPEDEF_DECL', '__uint_least8_t'],
#  17: ['CursorKind.TYPE_REF', '__uint8_t'],
#  18: ['CursorKind.TYPEDEF_DECL', '__int_least16_t'],
#  19: ['CursorKind.TYPE_REF', '__int16_t'],
#  20: ['CursorKind.TYPEDEF_DECL', '__uint_least16_t'],
#  21: ['CursorKind.TYPE_REF', '__uint16_t'],
#  22: ['CursorKind.TYPEDEF_DECL', '__int_least32_t'],
#  23: ['CursorKind.TYPE_REF', '__int32_t'],
#  24: ['CursorKind.TYPEDEF_DECL', '__uint_least32_t'],
#  25: ['CursorKind.TYPE_REF', '__uint32_t'],
#  26: ['CursorKind.TYPEDEF_DECL', '__int_least64_t'],
#  27: ['CursorKind.TYPE_REF', '__int64_t'],
#  28: ['CursorKind.TYPEDEF_DECL', '__uint_least64_t'],
#  29: ['CursorKind.TYPE_REF', '__uint64_t'],
#  30: ['CursorKind.TYPEDEF_DECL', '__quad_t'],
#  31: ['CursorKind.TYPEDEF_DECL', '__u_quad_t'],
#  32: ['CursorKind.TYPEDEF_DECL', '__intmax_t'],
#  33: ['CursorKind.TYPEDEF_DECL', '__uintmax_t'],
#  34: ['CursorKind.TYPEDEF_DECL', '__dev_t'],
#  35: ['CursorKind.TYPEDEF_DECL', '__uid_t'],
#  36: ['CursorKind.TYPEDEF_DECL', '__gid_t'],
#  37: ['CursorKind.TYPEDEF_DECL', '__ino_t'],
#  38: ['CursorKind.TYPEDEF_DECL', '__ino64_t'],
#  39: ['CursorKind.TYPEDEF_DECL', '__mode_t'],
#  40: ['CursorKind.TYPEDEF_DECL', '__nlink_t'],
#  41: ['CursorKind.TYPEDEF_DECL', '__off_t'],
#  42: ['CursorKind.TYPEDEF_DECL', '__off64_t'],
#  43: ['CursorKind.TYPEDEF_DECL', '__pid_t'],
#  44: ['CursorKind.STRUCT_DECL', ''],
#  45: ['CursorKind.FIELD_DECL', '__val'],
#  46: ['CursorKind.INTEGER_LITERAL', ''],
#  47: ['CursorKind.TYPEDEF_DECL', '__fsid_t'],
#  48: ['CursorKind.STRUCT_DECL', ''],
#  49: ['CursorKind.FIELD_DECL', '__val'],
#  50: ['CursorKind.INTEGER_LITERAL', ''],
#  51: ['CursorKind.TYPEDEF_DECL', '__clock_t'],
#  52: ['CursorKind.TYPEDEF_DECL', '__rlim_t'],
#  53: ['CursorKind.TYPEDEF_DECL', '__rlim64_t'],
#  54: ['CursorKind.TYPEDEF_DECL', '__id_t'],
#  55: ['CursorKind.TYPEDEF_DECL', '__time_t'],
#  56: ['CursorKind.TYPEDEF_DECL', '__useconds_t'],
#  57: ['CursorKind.TYPEDEF_DECL', '__suseconds_t'],
#  58: ['CursorKind.TYPEDEF_DECL', '__daddr_t'],
#  59: ['CursorKind.TYPEDEF_DECL', '__key_t'],
#  60: ['CursorKind.TYPEDEF_DECL', '__clockid_t'],
#  61: ['CursorKind.TYPEDEF_DECL', '__timer_t'],
#  62: ['CursorKind.TYPEDEF_DECL', '__blksize_t'],
#  63: ['CursorKind.TYPEDEF_DECL', '__blkcnt_t'],
#  64: ['CursorKind.TYPEDEF_DECL', '__blkcnt64_t'],
#  65: ['CursorKind.TYPEDEF_DECL', '__fsblkcnt_t'],
#  66: ['CursorKind.TYPEDEF_DECL', '__fsblkcnt64_t'],
#  67: ['CursorKind.TYPEDEF_DECL', '__fsfilcnt_t'],
#  68: ['CursorKind.TYPEDEF_DECL', '__fsfilcnt64_t'],
#  69: ['CursorKind.TYPEDEF_DECL', '__fsword_t'],
#  70: ['CursorKind.TYPEDEF_DECL', '__ssize_t'],
#  71: ['CursorKind.TYPEDEF_DECL', '__syscall_slong_t'],
#  72: ['CursorKind.TYPEDEF_DECL', '__syscall_ulong_t'],
#  73: ['CursorKind.TYPEDEF_DECL', '__loff_t'],
#  74: ['CursorKind.TYPE_REF', '__off64_t'],
#  75: ['CursorKind.TYPEDEF_DECL', '__caddr_t'],
#  76: ['CursorKind.TYPEDEF_DECL', '__intptr_t'],
#  77: ['CursorKind.TYPEDEF_DECL', '__socklen_t'],
#  78: ['CursorKind.TYPEDEF_DECL', '__sig_atomic_t'],
#  79: ['CursorKind.TYPEDEF_DECL', 'u_char'],
#  80: ['CursorKind.TYPE_REF', '__u_char'],
#  81: ['CursorKind.TYPEDEF_DECL', 'u_short'],
#  82: ['CursorKind.TYPE_REF', '__u_short'],
#  83: ['CursorKind.TYPEDEF_DECL', 'u_int'],
#  84: ['CursorKind.TYPE_REF', '__u_int'],
#  85: ['CursorKind.TYPEDEF_DECL', 'u_long'],
#  86: ['CursorKind.TYPE_REF', '__u_long'],
#  87: ['CursorKind.TYPEDEF_DECL', 'quad_t'],
#  88: ['CursorKind.TYPE_REF', '__quad_t'],
#  89: ['CursorKind.TYPEDEF_DECL', 'u_quad_t'],
#  90: ['CursorKind.TYPE_REF', '__u_quad_t'],
#  91: ['CursorKind.TYPEDEF_DECL', 'fsid_t'],
#  92: ['CursorKind.TYPE_REF', '__fsid_t'],
#  93: ['CursorKind.TYPEDEF_DECL', 'loff_t'],
#  94: ['CursorKind.TYPE_REF', '__loff_t'],
#  95: ['CursorKind.TYPEDEF_DECL', 'ino_t'],
#  96: ['CursorKind.TYPE_REF', '__ino_t'],
#  97: ['CursorKind.TYPEDEF_DECL', 'dev_t'],
#  98: ['CursorKind.TYPE_REF', '__dev_t'],
#  99: ['CursorKind.TYPEDEF_DECL', 'gid_t'],
#  100: ['CursorKind.TYPE_REF', '__gid_t'],
#  101: ['CursorKind.TYPEDEF_DECL', 'mode_t'],
#  102: ['CursorKind.TYPE_REF', '__mode_t'],
#  103: ['CursorKind.TYPEDEF_DECL', 'nlink_t'],
#  104: ['CursorKind.TYPE_REF', '__nlink_t'],
#  105: ['CursorKind.TYPEDEF_DECL', 'uid_t'],
#  106: ['CursorKind.TYPE_REF', '__uid_t'],
#  107: ['CursorKind.TYPEDEF_DECL', 'off_t'],
#  108: ['CursorKind.TYPE_REF', '__off_t'],
#  109: ['CursorKind.TYPEDEF_DECL', 'pid_t'],
#  110: ['CursorKind.TYPE_REF', '__pid_t'],
#  111: ['CursorKind.TYPEDEF_DECL', 'id_t'],
#  112: ['CursorKind.TYPE_REF', '__id_t'],
#  113: ['CursorKind.TYPEDEF_DECL', 'ssize_t'],
#  114: ['CursorKind.TYPE_REF', '__ssize_t'],
#  115: ['CursorKind.TYPEDEF_DECL', 'daddr_t'],
#  116: ['CursorKind.TYPE_REF', '__daddr_t'],
#  117: ['CursorKind.TYPEDEF_DECL', 'caddr_t'],
#  118: ['CursorKind.TYPE_REF', '__caddr_t'],
#  119: ['CursorKind.TYPEDEF_DECL', 'key_t'],
#  120: ['CursorKind.TYPE_REF', '__key_t'],
#  121: ['CursorKind.TYPEDEF_DECL', 'clock_t'],
#  122: ['CursorKind.TYPE_REF', '__clock_t'],
#  123: ['CursorKind.TYPEDEF_DECL', 'clockid_t'],
#  124: ['CursorKind.TYPE_REF', '__clockid_t'],
#  125: ['CursorKind.TYPEDEF_DECL', 'time_t'],
#  126: ['CursorKind.TYPE_REF', '__time_t'],
#  127: ['CursorKind.TYPEDEF_DECL', 'timer_t'],
#  128: ['CursorKind.TYPE_REF', '__timer_t'],
#  129: ['CursorKind.TYPEDEF_DECL', 'ulong'],
#  130: ['CursorKind.TYPEDEF_DECL', 'ushort'],
#  131: ['CursorKind.TYPEDEF_DECL', 'uint'],
#  132: ['CursorKind.TYPEDEF_DECL', 'int8_t'],
#  133: ['CursorKind.TYPE_REF', '__int8_t'],
#  134: ['CursorKind.TYPEDEF_DECL', 'int16_t'],
#  135: ['CursorKind.TYPE_REF', '__int16_t'],
#  136: ['CursorKind.TYPEDEF_DECL', 'int32_t'],
#  137: ['CursorKind.TYPE_REF', '__int32_t'],
#  138: ['CursorKind.TYPEDEF_DECL', 'int64_t'],
#  139: ['CursorKind.TYPE_REF', '__int64_t'],
#  140: ['CursorKind.TYPEDEF_DECL', 'u_int8_t'],
#  141: ['CursorKind.UNEXPOSED_ATTR', ''],
#  142: ['CursorKind.TYPEDEF_DECL', 'u_int16_t'],
#  143: ['CursorKind.UNEXPOSED_ATTR', ''],
#  144: ['CursorKind.TYPEDEF_DECL', 'u_int32_t'],
#  145: ['CursorKind.UNEXPOSED_ATTR', ''],
#  146: ['CursorKind.TYPEDEF_DECL', 'u_int64_t'],
#  147: ['CursorKind.UNEXPOSED_ATTR', ''],
#  148: ['CursorKind.TYPEDEF_DECL', 'register_t'],
#  149: ['CursorKind.UNEXPOSED_ATTR', ''],
#  150: ['CursorKind.FUNCTION_DECL', '__bswap_16(__uint16_t)'],
#  151: ['CursorKind.TYPE_REF', '__uint16_t'],
#  152: ['CursorKind.PARM_DECL', '__bsx'],
#  153: ['CursorKind.TYPE_REF', '__uint16_t'],
#  154: ['CursorKind.COMPOUND_STMT', ''],
#  155: ['CursorKind.RETURN_STMT', ''],
#  156: ['CursorKind.PAREN_EXPR', ''],
#  157: ['CursorKind.CSTYLE_CAST_EXPR', ''],
#  158: ['CursorKind.TYPE_REF', '__uint16_t'],
#  159: ['CursorKind.PAREN_EXPR', ''],
#  160: ['CursorKind.BINARY_OPERATOR', ''],
#  161: ['CursorKind.PAREN_EXPR', ''],
#  162: ['CursorKind.BINARY_OPERATOR', ''],
#  163: ['CursorKind.PAREN_EXPR', ''],
#  164: ['CursorKind.BINARY_OPERATOR', ''],
#  165: ['CursorKind.UNEXPOSED_EXPR', ''],
#  166: ['CursorKind.UNEXPOSED_EXPR', ''],
#  167: ['CursorKind.PAREN_EXPR', ''],
#  168: ['CursorKind.DECL_REF_EXPR', '__bsx'],
#  169: ['CursorKind.INTEGER_LITERAL', ''],
#  170: ['CursorKind.INTEGER_LITERAL', ''],
#  171: ['CursorKind.PAREN_EXPR', ''],
#  172: ['CursorKind.BINARY_OPERATOR', ''],
#  173: ['CursorKind.PAREN_EXPR', ''],
#  174: ['CursorKind.BINARY_OPERATOR', ''],
#  175: ['CursorKind.UNEXPOSED_EXPR', ''],
#  176: ['CursorKind.UNEXPOSED_EXPR', ''],
#  177: ['CursorKind.PAREN_EXPR', ''],
#  178: ['CursorKind.DECL_REF_EXPR', '__bsx'],
#  179: ['CursorKind.INTEGER_LITERAL', ''],
#  180: ['CursorKind.INTEGER_LITERAL', ''],
#  181: ['CursorKind.FUNCTION_DECL', '__bswap_32(__uint32_t)'],
#  182: ['CursorKind.TYPE_REF', '__uint32_t'],
#  183: ['CursorKind.PARM_DECL', '__bsx'],
#  184: ['CursorKind.TYPE_REF', '__uint32_t'],
#  185: ['CursorKind.COMPOUND_STMT', ''],
#  186: ['CursorKind.RETURN_STMT', ''],
#  187: ['CursorKind.PAREN_EXPR', ''],
#  188: ['CursorKind.BINARY_OPERATOR', ''],
#  189: ['CursorKind.BINARY_OPERATOR', ''],
#  190: ['CursorKind.BINARY_OPERATOR', ''],
#  191: ['CursorKind.PAREN_EXPR', ''],
#  192: ['CursorKind.BINARY_OPERATOR', ''],
#  193: ['CursorKind.PAREN_EXPR', ''],
#  194: ['CursorKind.BINARY_OPERATOR', ''],
#  195: ['CursorKind.UNEXPOSED_EXPR', ''],
#  196: ['CursorKind.PAREN_EXPR', ''],
#  197: ['CursorKind.DECL_REF_EXPR', '__bsx'],
#  198: ['CursorKind.INTEGER_LITERAL', ''],
#  199: ['CursorKind.INTEGER_LITERAL', ''],
#  200: ['CursorKind.PAREN_EXPR', ''],
#  201: ['CursorKind.BINARY_OPERATOR', ''],
#  202: ['CursorKind.PAREN_EXPR', ''],
#  203: ['CursorKind.BINARY_OPERATOR', ''],
#  204: ['CursorKind.UNEXPOSED_EXPR', ''],
#  205: ['CursorKind.PAREN_EXPR', ''],
#  206: ['CursorKind.DECL_REF_EXPR', '__bsx'],
#  207: ['CursorKind.INTEGER_LITERAL', ''],
#  208: ['CursorKind.INTEGER_LITERAL', ''],
#  209: ['CursorKind.PAREN_EXPR', ''],
#  210: ['CursorKind.BINARY_OPERATOR', ''],
#  211: ['CursorKind.PAREN_EXPR', ''],
#  212: ['CursorKind.BINARY_OPERATOR', ''],
#  213: ['CursorKind.UNEXPOSED_EXPR', ''],
#  214: ['CursorKind.PAREN_EXPR', ''],
#  215: ['CursorKind.DECL_REF_EXPR', '__bsx'],
#  216: ['CursorKind.INTEGER_LITERAL', ''],
#  217: ['CursorKind.INTEGER_LITERAL', ''],
#  218: ['CursorKind.PAREN_EXPR', ''],
#  219: ['CursorKind.BINARY_OPERATOR', ''],
#  220: ['CursorKind.PAREN_EXPR', ''],
#  221: ['CursorKind.BINARY_OPERATOR', ''],
#  222: ['CursorKind.UNEXPOSED_EXPR', ''],
#  223: ['CursorKind.PAREN_EXPR', ''],
#  224: ['CursorKind.DECL_REF_EXPR', '__bsx'],
#  225: ['CursorKind.INTEGER_LITERAL', ''],
#  226: ['CursorKind.INTEGER_LITERAL', ''],
#  227: ['CursorKind.FUNCTION_DECL', '__bswap_64(__uint64_t)'],
#  228: ['CursorKind.TYPE_REF', '__uint64_t'],
#  229: ['CursorKind.PARM_DECL', '__bsx'],
#  230: ['CursorKind.TYPE_REF', '__uint64_t'],
#  231: ['CursorKind.COMPOUND_STMT', ''],
#  232: ['CursorKind.RETURN_STMT', ''],
#  233: ['CursorKind.UNEXPOSED_EXPR', ''],
#  234: ['CursorKind.PAREN_EXPR', ''],
#  235: ['CursorKind.BINARY_OPERATOR', ''],
#  236: ['CursorKind.BINARY_OPERATOR', ''],
#  237: ['CursorKind.BINARY_OPERATOR', ''],
#  238: ['CursorKind.BINARY_OPERATOR', ''],
#  239: ['CursorKind.BINARY_OPERATOR', ''],
#  240: ['CursorKind.BINARY_OPERATOR', ''],
#  241: ['CursorKind.BINARY_OPERATOR', ''],
#  242: ['CursorKind.PAREN_EXPR', ''],
#  243: ['CursorKind.BINARY_OPERATOR', ''],
#  244: ['CursorKind.PAREN_EXPR', ''],
#  245: ['CursorKind.BINARY_OPERATOR', ''],
#  246: ['CursorKind.UNEXPOSED_EXPR', ''],
#  247: ['CursorKind.UNEXPOSED_EXPR', ''],
#  248: ['CursorKind.PAREN_EXPR', ''],
#  249: ['CursorKind.DECL_REF_EXPR', '__bsx'],
#  250: ['CursorKind.INTEGER_LITERAL', ''],
#  251: ['CursorKind.INTEGER_LITERAL', ''],
#  252: ['CursorKind.PAREN_EXPR', ''],
#  253: ['CursorKind.BINARY_OPERATOR', ''],
#  254: ['CursorKind.PAREN_EXPR', ''],
#  255: ['CursorKind.BINARY_OPERATOR', ''],
#  256: ['CursorKind.UNEXPOSED_EXPR', ''],
#  257: ['CursorKind.UNEXPOSED_EXPR', ''],
#  258: ['CursorKind.PAREN_EXPR', ''],
#  259: ['CursorKind.DECL_REF_EXPR', '__bsx'],
#  260: ['CursorKind.INTEGER_LITERAL', ''],
#  261: ['CursorKind.INTEGER_LITERAL', ''],
#  262: ['CursorKind.PAREN_EXPR', ''],
#  263: ['CursorKind.BINARY_OPERATOR', ''],
#  264: ['CursorKind.PAREN_EXPR', ''],
#  265: ['CursorKind.BINARY_OPERATOR', ''],
#  266: ['CursorKind.UNEXPOSED_EXPR', ''],
#  267: ['CursorKind.UNEXPOSED_EXPR', ''],
#  268: ['CursorKind.PAREN_EXPR', ''],
#  269: ['CursorKind.DECL_REF_EXPR', '__bsx'],
#  270: ['CursorKind.INTEGER_LITERAL', ''],
#  271: ['CursorKind.INTEGER_LITERAL', ''],
#  272: ['CursorKind.PAREN_EXPR', ''],
#  273: ['CursorKind.BINARY_OPERATOR', ''],
#  274: ['CursorKind.PAREN_EXPR', ''],
#  275: ['CursorKind.BINARY_OPERATOR', ''],
#  276: ['CursorKind.UNEXPOSED_EXPR', ''],
#  277: ['CursorKind.UNEXPOSED_EXPR', ''],
#  278: ['CursorKind.PAREN_EXPR', ''],
#  279: ['CursorKind.DECL_REF_EXPR', '__bsx'],
#  280: ['CursorKind.INTEGER_LITERAL', ''],
#  281: ['CursorKind.INTEGER_LITERAL', ''],
#  282: ['CursorKind.PAREN_EXPR', ''],
#  283: ['CursorKind.BINARY_OPERATOR', ''],
#  284: ['CursorKind.PAREN_EXPR', ''],
#  285: ['CursorKind.BINARY_OPERATOR', ''],
#  286: ['CursorKind.UNEXPOSED_EXPR', ''],
#  287: ['CursorKind.UNEXPOSED_EXPR', ''],
#  288: ['CursorKind.PAREN_EXPR', ''],
#  289: ['CursorKind.DECL_REF_EXPR', '__bsx'],
#  290: ['CursorKind.INTEGER_LITERAL', ''],
#  291: ['CursorKind.INTEGER_LITERAL', ''],
#  292: ['CursorKind.PAREN_EXPR', ''],
#  293: ['CursorKind.BINARY_OPERATOR', ''],
#  294: ['CursorKind.PAREN_EXPR', ''],
#  295: ['CursorKind.BINARY_OPERATOR', ''],
#  296: ['CursorKind.UNEXPOSED_EXPR', ''],
#  297: ['CursorKind.UNEXPOSED_EXPR', ''],
#  298: ['CursorKind.PAREN_EXPR', ''],
#  299: ['CursorKind.DECL_REF_EXPR', '__bsx'],
#  300: ['CursorKind.INTEGER_LITERAL', ''],
#  301: ['CursorKind.INTEGER_LITERAL', ''],
#  302: ['CursorKind.PAREN_EXPR', ''],
#  303: ['CursorKind.BINARY_OPERATOR', ''],
#  304: ['CursorKind.PAREN_EXPR', ''],
#  305: ['CursorKind.BINARY_OPERATOR', ''],
#  306: ['CursorKind.UNEXPOSED_EXPR', ''],
#  307: ['CursorKind.UNEXPOSED_EXPR', ''],
#  308: ['CursorKind.PAREN_EXPR', ''],
#  309: ['CursorKind.DECL_REF_EXPR', '__bsx'],
#  310: ['CursorKind.INTEGER_LITERAL', ''],
#  311: ['CursorKind.INTEGER_LITERAL', ''],
#  312: ['CursorKind.PAREN_EXPR', ''],
#  313: ['CursorKind.BINARY_OPERATOR', ''],
#  314: ['CursorKind.PAREN_EXPR', ''],
#  315: ['CursorKind.BINARY_OPERATOR', ''],
#  316: ['CursorKind.UNEXPOSED_EXPR', ''],
#  317: ['CursorKind.UNEXPOSED_EXPR', ''],
#  318: ['CursorKind.PAREN_EXPR', ''],
#  319: ['CursorKind.DECL_REF_EXPR', '__bsx'],
#  320: ['CursorKind.INTEGER_LITERAL', ''],
#  321: ['CursorKind.INTEGER_LITERAL', ''],
#  322: ['CursorKind.FUNCTION_DECL', '__uint16_identity(__uint16_t)'],
#  323: ['CursorKind.TYPE_REF', '__uint16_t'],
#  324: ['CursorKind.PARM_DECL', '__x'],
#  325: ['CursorKind.TYPE_REF', '__uint16_t'],
#  326: ['CursorKind.COMPOUND_STMT', ''],
#  327: ['CursorKind.RETURN_STMT', ''],
#  328: ['CursorKind.UNEXPOSED_EXPR', '__x'],
#  329: ['CursorKind.DECL_REF_EXPR', '__x'],
#  330: ['CursorKind.FUNCTION_DECL', '__uint32_identity(__uint32_t)'],
#  331: ['CursorKind.TYPE_REF', '__uint32_t'],
#  332: ['CursorKind.PARM_DECL', '__x'],
#  333: ['CursorKind.TYPE_REF', '__uint32_t'],
#  334: ['CursorKind.COMPOUND_STMT', ''],
#  335: ['CursorKind.RETURN_STMT', ''],
#  336: ['CursorKind.UNEXPOSED_EXPR', '__x'],
#  337: ['CursorKind.DECL_REF_EXPR', '__x'],
#  338: ['CursorKind.FUNCTION_DECL', '__uint64_identity(__uint64_t)'],
#  339: ['CursorKind.TYPE_REF', '__uint64_t'],
#  340: ['CursorKind.PARM_DECL', '__x'],
#  341: ['CursorKind.TYPE_REF', '__uint64_t'],
#  342: ['CursorKind.COMPOUND_STMT', ''],
#  343: ['CursorKind.RETURN_STMT', ''],
#  344: ['CursorKind.UNEXPOSED_EXPR', '__x'],
#  345: ['CursorKind.DECL_REF_EXPR', '__x'],
#  346: ['CursorKind.STRUCT_DECL', ''],
#  347: ['CursorKind.FIELD_DECL', '__val'],
#  348: ['CursorKind.PAREN_EXPR', ''],
#  349: ['CursorKind.BINARY_OPERATOR', ''],
#  350: ['CursorKind.UNEXPOSED_EXPR', ''],
#  351: ['CursorKind.INTEGER_LITERAL', ''],
#  352: ['CursorKind.PAREN_EXPR', ''],
#  353: ['CursorKind.BINARY_OPERATOR', ''],
#  354: ['CursorKind.UNEXPOSED_EXPR', ''],
#  355: ['CursorKind.INTEGER_LITERAL', ''],
#  356: ['CursorKind.CXX_UNARY_EXPR', ''],
#  357: ['CursorKind.TYPEDEF_DECL', '__sigset_t'],
#  358: ['CursorKind.STRUCT_DECL', ''],
#  359: ['CursorKind.FIELD_DECL', '__val'],
#  360: ['CursorKind.PAREN_EXPR', ''],
#  361: ['CursorKind.BINARY_OPERATOR', ''],
#  362: ['CursorKind.UNEXPOSED_EXPR', ''],
#  363: ['CursorKind.INTEGER_LITERAL', ''],
#  364: ['CursorKind.PAREN_EXPR', ''],
#  365: ['CursorKind.BINARY_OPERATOR', ''],
#  366: ['CursorKind.UNEXPOSED_EXPR', ''],
#  367: ['CursorKind.INTEGER_LITERAL', ''],
#  368: ['CursorKind.CXX_UNARY_EXPR', ''],
#  369: ['CursorKind.TYPEDEF_DECL', 'sigset_t'],
#  370: ['CursorKind.TYPE_REF', '__sigset_t'],
#  371: ['CursorKind.STRUCT_DECL', 'timeval'],
#  372: ['CursorKind.FIELD_DECL', 'tv_sec'],
#  373: ['CursorKind.TYPE_REF', '__time_t'],
#  374: ['CursorKind.FIELD_DECL', 'tv_usec'],
#  375: ['CursorKind.TYPE_REF', '__suseconds_t'],
#  376: ['CursorKind.STRUCT_DECL', 'timespec'],
#  377: ['CursorKind.FIELD_DECL', 'tv_sec'],
#  378: ['CursorKind.TYPE_REF', '__time_t'],
#  379: ['CursorKind.FIELD_DECL', 'tv_nsec'],
#  380: ['CursorKind.TYPE_REF', '__syscall_slong_t'],
#  381: ['CursorKind.TYPEDEF_DECL', 'suseconds_t'],
#  382: ['CursorKind.TYPE_REF', '__suseconds_t'],
#  383: ['CursorKind.TYPEDEF_DECL', '__fd_mask'],
#  384: ['CursorKind.STRUCT_DECL', ''],
#  385: ['CursorKind.FIELD_DECL', '__fds_bits'],
#  386: ['CursorKind.TYPE_REF', '__fd_mask'],
#  387: ['CursorKind.BINARY_OPERATOR', ''],
#  388: ['CursorKind.INTEGER_LITERAL', ''],
#  389: ['CursorKind.PAREN_EXPR', ''],
#  390: ['CursorKind.BINARY_OPERATOR', ''],
#  391: ['CursorKind.INTEGER_LITERAL', ''],
#  392: ['CursorKind.CSTYLE_CAST_EXPR', ''],
#  393: ['CursorKind.CXX_UNARY_EXPR', ''],
#  394: ['CursorKind.TYPE_REF', '__fd_mask'],
#  395: ['CursorKind.TYPEDEF_DECL', 'fd_set'],
#  396: ['CursorKind.STRUCT_DECL', ''],
#  397: ['CursorKind.FIELD_DECL', '__fds_bits'],
#  398: ['CursorKind.TYPE_REF', '__fd_mask'],
#  399: ['CursorKind.BINARY_OPERATOR', ''],
#  400: ['CursorKind.INTEGER_LITERAL', ''],
#  401: ['CursorKind.PAREN_EXPR', ''],
#  402: ['CursorKind.BINARY_OPERATOR', ''],
#  403: ['CursorKind.INTEGER_LITERAL', ''],
#  404: ['CursorKind.CSTYLE_CAST_EXPR', ''],
#  405: ['CursorKind.CXX_UNARY_EXPR', ''],
#  406: ['CursorKind.TYPE_REF', '__fd_mask'],
#  407: ['CursorKind.TYPEDEF_DECL', 'fd_mask'],
#  408: ['CursorKind.TYPE_REF', '__fd_mask'],
#  409: ['CursorKind.FUNCTION_DECL',
#   'select(int, fd_set *restrict, fd_set *restrict, fd_set *restrict, struct timeval *restrict)'],
#  410: ['CursorKind.PARM_DECL', '__nfds'],
#  411: ['CursorKind.PARM_DECL', '__readfds'],
#  412: ['CursorKind.TYPE_REF', 'fd_set'],
#  413: ['CursorKind.PARM_DECL', '__writefds'],
#  414: ['CursorKind.TYPE_REF', 'fd_set'],
#  415: ['CursorKind.PARM_DECL', '__exceptfds'],
#  416: ['CursorKind.TYPE_REF', 'fd_set'],
#  417: ['CursorKind.PARM_DECL', '__timeout'],
#  418: ['CursorKind.TYPE_REF', 'struct timeval'],
#  419: ['CursorKind.FUNCTION_DECL',
#   'pselect(int, fd_set *restrict, fd_set *restrict, fd_set *restrict, const struct timespec *restrict, const __sigset_t *restrict)'],
#  420: ['CursorKind.PARM_DECL', '__nfds'],
#  421: ['CursorKind.PARM_DECL', '__readfds'],
#  422: ['CursorKind.TYPE_REF', 'fd_set'],
#  423: ['CursorKind.PARM_DECL', '__writefds'],
#  424: ['CursorKind.TYPE_REF', 'fd_set'],
#  425: ['CursorKind.PARM_DECL', '__exceptfds'],
#  426: ['CursorKind.TYPE_REF', 'fd_set'],
#  427: ['CursorKind.PARM_DECL', '__timeout'],
#  428: ['CursorKind.TYPE_REF', 'struct timespec'],
#  429: ['CursorKind.PARM_DECL', '__sigmask'],
#  430: ['CursorKind.TYPE_REF', '__sigset_t'],
#  431: ['CursorKind.TYPEDEF_DECL', 'blksize_t'],
#  432: ['CursorKind.TYPE_REF', '__blksize_t'],
#  433: ['CursorKind.TYPEDEF_DECL', 'blkcnt_t'],
#  434: ['CursorKind.TYPE_REF', '__blkcnt_t'],
#  435: ['CursorKind.TYPEDEF_DECL', 'fsblkcnt_t'],
#  436: ['CursorKind.TYPE_REF', '__fsblkcnt_t'],
#  437: ['CursorKind.TYPEDEF_DECL', 'fsfilcnt_t'],
#  438: ['CursorKind.TYPE_REF', '__fsfilcnt_t'],
#  439: ['CursorKind.STRUCT_DECL', '__pthread_rwlock_arch_t'],
#  440: ['CursorKind.FIELD_DECL', '__readers'],
#  441: ['CursorKind.FIELD_DECL', '__writers'],
#  442: ['CursorKind.FIELD_DECL', '__wrphase_futex'],
#  443: ['CursorKind.FIELD_DECL', '__writers_futex'],
#  444: ['CursorKind.FIELD_DECL', '__pad3'],
#  445: ['CursorKind.FIELD_DECL', '__pad4'],
#  446: ['CursorKind.FIELD_DECL', '__cur_writer'],
#  447: ['CursorKind.FIELD_DECL', '__shared'],
#  448: ['CursorKind.FIELD_DECL', '__rwelision'],
#  449: ['CursorKind.FIELD_DECL', '__pad1'],
#  450: ['CursorKind.INTEGER_LITERAL', ''],
#  451: ['CursorKind.FIELD_DECL', '__pad2'],
#  452: ['CursorKind.FIELD_DECL', '__flags'],
#  453: ['CursorKind.STRUCT_DECL', '__pthread_internal_list'],
#  454: ['CursorKind.FIELD_DECL', '__prev'],
#  455: ['CursorKind.TYPE_REF', 'struct __pthread_internal_list'],
#  456: ['CursorKind.FIELD_DECL', '__next'],
#  457: ['CursorKind.TYPE_REF', 'struct __pthread_internal_list'],
#  458: ['CursorKind.TYPEDEF_DECL', '__pthread_list_t'],
#  459: ['CursorKind.STRUCT_DECL', '__pthread_internal_list'],
#  460: ['CursorKind.FIELD_DECL', '__prev'],
#  461: ['CursorKind.TYPE_REF', 'struct __pthread_internal_list'],
#  462: ['CursorKind.FIELD_DECL', '__next'],
#  463: ['CursorKind.TYPE_REF', 'struct __pthread_internal_list'],
#  464: ['CursorKind.STRUCT_DECL', '__pthread_mutex_s'],
#  465: ['CursorKind.FIELD_DECL', '__lock'],
#  466: ['CursorKind.FIELD_DECL', '__count'],
#  467: ['CursorKind.FIELD_DECL', '__owner'],
#  468: ['CursorKind.FIELD_DECL', '__nusers'],
#  469: ['CursorKind.FIELD_DECL', '__kind'],
#  470: ['CursorKind.FIELD_DECL', '__spins'],
#  471: ['CursorKind.FIELD_DECL', '__elision'],
#  472: ['CursorKind.FIELD_DECL', '__list'],
#  473: ['CursorKind.TYPE_REF', '__pthread_list_t'],
#  474: ['CursorKind.STRUCT_DECL', '__pthread_cond_s'],
#  475: ['CursorKind.UNION_DECL', ''],
#  476: ['CursorKind.FIELD_DECL', '__wseq'],
#  477: ['CursorKind.STRUCT_DECL', ''],
#  478: ['CursorKind.FIELD_DECL', '__low'],
#  479: ['CursorKind.FIELD_DECL', '__high'],
#  480: ['CursorKind.FIELD_DECL', '__wseq32'],
#  481: ['CursorKind.STRUCT_DECL', ''],
#  482: ['CursorKind.FIELD_DECL', '__low'],
#  483: ['CursorKind.FIELD_DECL', '__high'],
#  484: ['CursorKind.UNION_DECL', ''],
#  485: ['CursorKind.FIELD_DECL', '__g1_start'],
#  486: ['CursorKind.STRUCT_DECL', ''],
#  487: ['CursorKind.FIELD_DECL', '__low'],
#  488: ['CursorKind.FIELD_DECL', '__high'],
#  489: ['CursorKind.FIELD_DECL', '__g1_start32'],
#  490: ['CursorKind.STRUCT_DECL', ''],
#  491: ['CursorKind.FIELD_DECL', '__low'],
#  492: ['CursorKind.FIELD_DECL', '__high'],
#  493: ['CursorKind.FIELD_DECL', '__g_refs'],
#  494: ['CursorKind.INTEGER_LITERAL', ''],
#  495: ['CursorKind.FIELD_DECL', '__g_size'],
#  496: ['CursorKind.INTEGER_LITERAL', ''],
#  497: ['CursorKind.FIELD_DECL', '__g1_orig_size'],
#  498: ['CursorKind.FIELD_DECL', '__wrefs'],
#  499: ['CursorKind.FIELD_DECL', '__g_signals'],
#  500: ['CursorKind.INTEGER_LITERAL', ''],
#  501: ['CursorKind.TYPEDEF_DECL', 'pthread_t'],
#  502: ['CursorKind.UNION_DECL', ''],
#  503: ['CursorKind.FIELD_DECL', '__size'],
#  504: ['CursorKind.INTEGER_LITERAL', ''],
#  505: ['CursorKind.FIELD_DECL', '__align'],
#  506: ['CursorKind.TYPEDEF_DECL', 'pthread_mutexattr_t'],
#  507: ['CursorKind.UNION_DECL', ''],
#  508: ['CursorKind.FIELD_DECL', '__size'],
#  509: ['CursorKind.INTEGER_LITERAL', ''],
#  510: ['CursorKind.FIELD_DECL', '__align'],
#  511: ['CursorKind.UNION_DECL', ''],
#  512: ['CursorKind.FIELD_DECL', '__size'],
#  513: ['CursorKind.INTEGER_LITERAL', ''],
#  514: ['CursorKind.FIELD_DECL', '__align'],
#  515: ['CursorKind.TYPEDEF_DECL', 'pthread_condattr_t'],
#  516: ['CursorKind.UNION_DECL', ''],
#  517: ['CursorKind.FIELD_DECL', '__size'],
#  518: ['CursorKind.INTEGER_LITERAL', ''],
#  519: ['CursorKind.FIELD_DECL', '__align'],
#  520: ['CursorKind.TYPEDEF_DECL', 'pthread_key_t'],
#  521: ['CursorKind.TYPEDEF_DECL', 'pthread_once_t'],
#  522: ['CursorKind.UNION_DECL', 'pthread_attr_t'],
#  523: ['CursorKind.FIELD_DECL', '__size'],
#  524: ['CursorKind.INTEGER_LITERAL', ''],
#  525: ['CursorKind.FIELD_DECL', '__align'],
#  526: ['CursorKind.TYPEDEF_DECL', 'pthread_attr_t'],
#  527: ['CursorKind.TYPE_REF', 'union pthread_attr_t'],
#  528: ['CursorKind.UNION_DECL', ''],
#  529: ['CursorKind.FIELD_DECL', '__data'],
#  530: ['CursorKind.TYPE_REF', 'struct __pthread_mutex_s'],
#  531: ['CursorKind.FIELD_DECL', '__size'],
#  532: ['CursorKind.INTEGER_LITERAL', ''],
#  533: ['CursorKind.FIELD_DECL', '__align'],
#  534: ['CursorKind.TYPEDEF_DECL', 'pthread_mutex_t'],
#  535: ['CursorKind.UNION_DECL', ''],
#  536: ['CursorKind.FIELD_DECL', '__data'],
#  537: ['CursorKind.TYPE_REF', 'struct __pthread_mutex_s'],
#  538: ['CursorKind.FIELD_DECL', '__size'],
#  539: ['CursorKind.INTEGER_LITERAL', ''],
#  540: ['CursorKind.FIELD_DECL', '__align'],
#  541: ['CursorKind.UNION_DECL', ''],
#  542: ['CursorKind.FIELD_DECL', '__data'],
#  543: ['CursorKind.TYPE_REF', 'struct __pthread_cond_s'],
#  544: ['CursorKind.FIELD_DECL', '__size'],
#  545: ['CursorKind.INTEGER_LITERAL', ''],
#  546: ['CursorKind.FIELD_DECL', '__align'],
#  547: ['CursorKind.TYPEDEF_DECL', 'pthread_cond_t'],
#  548: ['CursorKind.UNION_DECL', ''],
#  549: ['CursorKind.FIELD_DECL', '__data'],
#  550: ['CursorKind.TYPE_REF', 'struct __pthread_cond_s'],
#  551: ['CursorKind.FIELD_DECL', '__size'],
#  552: ['CursorKind.INTEGER_LITERAL', ''],
#  553: ['CursorKind.FIELD_DECL', '__align'],
#  554: ['CursorKind.UNION_DECL', ''],
#  555: ['CursorKind.FIELD_DECL', '__data'],
#  556: ['CursorKind.TYPE_REF', 'struct __pthread_rwlock_arch_t'],
#  557: ['CursorKind.FIELD_DECL', '__size'],
#  558: ['CursorKind.INTEGER_LITERAL', ''],
#  559: ['CursorKind.FIELD_DECL', '__align'],
#  560: ['CursorKind.TYPEDEF_DECL', 'pthread_rwlock_t'],
#  561: ['CursorKind.UNION_DECL', ''],
#  562: ['CursorKind.FIELD_DECL', '__data'],
#  563: ['CursorKind.TYPE_REF', 'struct __pthread_rwlock_arch_t'],
#  564: ['CursorKind.FIELD_DECL', '__size'],
#  565: ['CursorKind.INTEGER_LITERAL', ''],
#  566: ['CursorKind.FIELD_DECL', '__align'],
#  567: ['CursorKind.UNION_DECL', ''],
#  568: ['CursorKind.FIELD_DECL', '__size'],
#  569: ['CursorKind.INTEGER_LITERAL', ''],
#  570: ['CursorKind.FIELD_DECL', '__align'],
#  571: ['CursorKind.TYPEDEF_DECL', 'pthread_rwlockattr_t'],
#  572: ['CursorKind.UNION_DECL', ''],
#  573: ['CursorKind.FIELD_DECL', '__size'],
#  574: ['CursorKind.INTEGER_LITERAL', ''],
#  575: ['CursorKind.FIELD_DECL', '__align'],
#  576: ['CursorKind.TYPEDEF_DECL', 'pthread_spinlock_t'],
#  577: ['CursorKind.UNION_DECL', ''],
#  578: ['CursorKind.FIELD_DECL', '__size'],
#  579: ['CursorKind.INTEGER_LITERAL', ''],
#  580: ['CursorKind.FIELD_DECL', '__align'],
#  581: ['CursorKind.TYPEDEF_DECL', 'pthread_barrier_t'],
#  582: ['CursorKind.UNION_DECL', ''],
#  583: ['CursorKind.FIELD_DECL', '__size'],
#  584: ['CursorKind.INTEGER_LITERAL', ''],
#  585: ['CursorKind.FIELD_DECL', '__align'],
#  586: ['CursorKind.UNION_DECL', ''],
#  587: ['CursorKind.FIELD_DECL', '__size'],
#  588: ['CursorKind.INTEGER_LITERAL', ''],
#  589: ['CursorKind.FIELD_DECL', '__align'],
#  590: ['CursorKind.TYPEDEF_DECL', 'pthread_barrierattr_t'],
#  591: ['CursorKind.UNION_DECL', ''],
#  592: ['CursorKind.FIELD_DECL', '__size'],
#  593: ['CursorKind.INTEGER_LITERAL', ''],
#  594: ['CursorKind.FIELD_DECL', '__align'],
#  595: ['CursorKind.STRUCT_DECL', 'iovec'],
#  596: ['CursorKind.FIELD_DECL', 'iov_base'],
#  597: ['CursorKind.FIELD_DECL', 'iov_len'],
#  598: ['CursorKind.TYPEDEF_DECL', 'socklen_t'],
#  599: ['CursorKind.TYPE_REF', '__socklen_t'],
#  600: ['CursorKind.ENUM_DECL', '__socket_type'],
#  601: ['CursorKind.ENUM_CONSTANT_DECL', 'SOCK_STREAM'],
#  602: ['CursorKind.INTEGER_LITERAL', ''],
#  603: ['CursorKind.ENUM_CONSTANT_DECL', 'SOCK_DGRAM'],
#  604: ['CursorKind.INTEGER_LITERAL', ''],
#  605: ['CursorKind.ENUM_CONSTANT_DECL', 'SOCK_RAW'],
#  606: ['CursorKind.INTEGER_LITERAL', ''],
#  607: ['CursorKind.ENUM_CONSTANT_DECL', 'SOCK_RDM'],
#  608: ['CursorKind.INTEGER_LITERAL', ''],
#  609: ['CursorKind.ENUM_CONSTANT_DECL', 'SOCK_SEQPACKET'],
#  610: ['CursorKind.INTEGER_LITERAL', ''],
#  611: ['CursorKind.ENUM_CONSTANT_DECL', 'SOCK_DCCP'],
#  612: ['CursorKind.INTEGER_LITERAL', ''],
#  613: ['CursorKind.ENUM_CONSTANT_DECL', 'SOCK_PACKET'],
#  614: ['CursorKind.INTEGER_LITERAL', ''],
#  615: ['CursorKind.ENUM_CONSTANT_DECL', 'SOCK_CLOEXEC'],
#  616: ['CursorKind.INTEGER_LITERAL', ''],
#  617: ['CursorKind.ENUM_CONSTANT_DECL', 'SOCK_NONBLOCK'],
#  618: ['CursorKind.INTEGER_LITERAL', ''],
#  619: ['CursorKind.TYPEDEF_DECL', 'sa_family_t'],
#  620: ['CursorKind.STRUCT_DECL', 'sockaddr'],
#  621: ['CursorKind.FIELD_DECL', 'sa_family'],
#  622: ['CursorKind.TYPE_REF', 'sa_family_t'],
#  623: ['CursorKind.FIELD_DECL', 'sa_data'],
#  624: ['CursorKind.INTEGER_LITERAL', ''],
#  625: ['CursorKind.STRUCT_DECL', 'sockaddr_storage'],
#  626: ['CursorKind.FIELD_DECL', 'ss_family'],
#  627: ['CursorKind.TYPE_REF', 'sa_family_t'],
#  628: ['CursorKind.FIELD_DECL', '__ss_padding'],
#  629: ['CursorKind.PAREN_EXPR', ''],
#  630: ['CursorKind.BINARY_OPERATOR', ''],
#  631: ['CursorKind.BINARY_OPERATOR', ''],
#  632: ['CursorKind.UNEXPOSED_EXPR', ''],
#  633: ['CursorKind.INTEGER_LITERAL', ''],
#  634: ['CursorKind.PAREN_EXPR', ''],
#  635: ['CursorKind.CXX_UNARY_EXPR', ''],
#  636: ['CursorKind.CXX_UNARY_EXPR', ''],
#  637: ['CursorKind.FIELD_DECL', '__ss_align'],
#  638: ['CursorKind.ENUM_DECL', ''],
#  639: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_OOB'],
#  640: ['CursorKind.INTEGER_LITERAL', ''],
#  641: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_PEEK'],
#  642: ['CursorKind.INTEGER_LITERAL', ''],
#  643: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_DONTROUTE'],
#  644: ['CursorKind.INTEGER_LITERAL', ''],
#  645: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_CTRUNC'],
#  646: ['CursorKind.INTEGER_LITERAL', ''],
#  647: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_PROXY'],
#  648: ['CursorKind.INTEGER_LITERAL', ''],
#  649: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_TRUNC'],
#  650: ['CursorKind.INTEGER_LITERAL', ''],
#  651: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_DONTWAIT'],
#  652: ['CursorKind.INTEGER_LITERAL', ''],
#  653: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_EOR'],
#  654: ['CursorKind.INTEGER_LITERAL', ''],
#  655: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_WAITALL'],
#  656: ['CursorKind.INTEGER_LITERAL', ''],
#  657: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_FIN'],
#  658: ['CursorKind.INTEGER_LITERAL', ''],
#  659: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_SYN'],
#  660: ['CursorKind.INTEGER_LITERAL', ''],
#  661: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_CONFIRM'],
#  662: ['CursorKind.INTEGER_LITERAL', ''],
#  663: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_RST'],
#  664: ['CursorKind.INTEGER_LITERAL', ''],
#  665: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_ERRQUEUE'],
#  666: ['CursorKind.INTEGER_LITERAL', ''],
#  667: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_NOSIGNAL'],
#  668: ['CursorKind.INTEGER_LITERAL', ''],
#  669: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_MORE'],
#  670: ['CursorKind.INTEGER_LITERAL', ''],
#  671: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_WAITFORONE'],
#  672: ['CursorKind.INTEGER_LITERAL', ''],
#  673: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_BATCH'],
#  674: ['CursorKind.INTEGER_LITERAL', ''],
#  675: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_ZEROCOPY'],
#  676: ['CursorKind.INTEGER_LITERAL', ''],
#  677: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_FASTOPEN'],
#  678: ['CursorKind.INTEGER_LITERAL', ''],
#  679: ['CursorKind.ENUM_CONSTANT_DECL', 'MSG_CMSG_CLOEXEC'],
#  680: ['CursorKind.INTEGER_LITERAL', ''],
#  681: ['CursorKind.STRUCT_DECL', 'msghdr'],
#  682: ['CursorKind.FIELD_DECL', 'msg_name'],
#  683: ['CursorKind.FIELD_DECL', 'msg_namelen'],
#  684: ['CursorKind.TYPE_REF', 'socklen_t'],
#  685: ['CursorKind.FIELD_DECL', 'msg_iov'],
#  686: ['CursorKind.TYPE_REF', 'struct iovec'],
#  687: ['CursorKind.FIELD_DECL', 'msg_iovlen'],
#  688: ['CursorKind.FIELD_DECL', 'msg_control'],
#  689: ['CursorKind.FIELD_DECL', 'msg_controllen'],
#  690: ['CursorKind.FIELD_DECL', 'msg_flags'],
#  691: ['CursorKind.STRUCT_DECL', 'cmsghdr'],
#  692: ['CursorKind.FIELD_DECL', 'cmsg_len'],
#  693: ['CursorKind.FIELD_DECL', 'cmsg_level'],
#  694: ['CursorKind.FIELD_DECL', 'cmsg_type'],
#  695: ['CursorKind.FIELD_DECL', '__cmsg_data'],
#  696: ['CursorKind.FUNCTION_DECL',
#   '__cmsg_nxthdr(struct msghdr *, struct cmsghdr *)'],
#  697: ['CursorKind.UNEXPOSED_ATTR', ''],
#  698: ['CursorKind.TYPE_REF', 'struct cmsghdr'],
#  699: ['CursorKind.PARM_DECL', '__mhdr'],
#  700: ['CursorKind.TYPE_REF', 'struct msghdr'],
#  701: ['CursorKind.PARM_DECL', '__cmsg'],
#  702: ['CursorKind.TYPE_REF', 'struct cmsghdr'],
#  703: ['CursorKind.ENUM_DECL', ''],
#  704: ['CursorKind.ENUM_CONSTANT_DECL', 'SCM_RIGHTS'],
#  705: ['CursorKind.INTEGER_LITERAL', ''],
#  706: ['CursorKind.STRUCT_DECL', 'linger'],
#  707: ['CursorKind.FIELD_DECL', 'l_onoff'],
#  708: ['CursorKind.FIELD_DECL', 'l_linger'],
#  709: ['CursorKind.STRUCT_DECL', 'osockaddr'],
#  710: ['CursorKind.FIELD_DECL', 'sa_family'],
#  711: ['CursorKind.FIELD_DECL', 'sa_data'],
#  712: ['CursorKind.INTEGER_LITERAL', ''],
#  713: ['CursorKind.ENUM_DECL', ''],
#  714: ['CursorKind.ENUM_CONSTANT_DECL', 'SHUT_RD'],
#  715: ['CursorKind.INTEGER_LITERAL', ''],
#  716: ['CursorKind.ENUM_CONSTANT_DECL', 'SHUT_WR'],
#  717: ['CursorKind.ENUM_CONSTANT_DECL', 'SHUT_RDWR'],
#  718: ['CursorKind.FUNCTION_DECL', 'socket(int, int, int)'],
#  719: ['CursorKind.UNEXPOSED_ATTR', ''],
#  720: ['CursorKind.PARM_DECL', '__domain'],
#  721: ['CursorKind.PARM_DECL', '__type'],
#  722: ['CursorKind.PARM_DECL', '__protocol'],
#  723: ['CursorKind.FUNCTION_DECL', 'socketpair(int, int, int, int *)'],
#  724: ['CursorKind.UNEXPOSED_ATTR', ''],
#  725: ['CursorKind.PARM_DECL', '__domain'],
#  726: ['CursorKind.PARM_DECL', '__type'],
#  727: ['CursorKind.PARM_DECL', '__protocol'],
#  728: ['CursorKind.PARM_DECL', '__fds'],
#  729: ['CursorKind.INTEGER_LITERAL', ''],
#  730: ['CursorKind.FUNCTION_DECL',
#   'bind(int, const struct sockaddr *, socklen_t)'],
#  731: ['CursorKind.UNEXPOSED_ATTR', ''],
#  732: ['CursorKind.PARM_DECL', '__fd'],
#  733: ['CursorKind.PARM_DECL', '__addr'],
#  734: ['CursorKind.TYPE_REF', 'struct sockaddr'],
#  735: ['CursorKind.PARM_DECL', '__len'],
#  736: ['CursorKind.TYPE_REF', 'socklen_t'],
#  737: ['CursorKind.FUNCTION_DECL',
#   'getsockname(int, struct sockaddr *restrict, socklen_t *restrict)'],
#  738: ['CursorKind.UNEXPOSED_ATTR', ''],
#  739: ['CursorKind.PARM_DECL', '__fd'],
#  740: ['CursorKind.PARM_DECL', '__addr'],
#  741: ['CursorKind.TYPE_REF', 'struct sockaddr'],
#  742: ['CursorKind.PARM_DECL', '__len'],
#  743: ['CursorKind.TYPE_REF', 'socklen_t'],
#  744: ['CursorKind.FUNCTION_DECL',
#   'connect(int, const struct sockaddr *, socklen_t)'],
#  745: ['CursorKind.PARM_DECL', '__fd'],
#  746: ['CursorKind.PARM_DECL', '__addr'],
#  747: ['CursorKind.TYPE_REF', 'struct sockaddr'],
#  748: ['CursorKind.PARM_DECL', '__len'],
#  749: ['CursorKind.TYPE_REF', 'socklen_t'],
#  750: ['CursorKind.FUNCTION_DECL',
#   'getpeername(int, struct sockaddr *restrict, socklen_t *restrict)'],
#  751: ['CursorKind.UNEXPOSED_ATTR', ''],
#  752: ['CursorKind.PARM_DECL', '__fd'],
#  753: ['CursorKind.PARM_DECL', '__addr'],
#  754: ['CursorKind.TYPE_REF', 'struct sockaddr'],
#  755: ['CursorKind.PARM_DECL', '__len'],
#  756: ['CursorKind.TYPE_REF', 'socklen_t'],
#  757: ['CursorKind.FUNCTION_DECL', 'send(int, const void *, int, int)'],
#  758: ['CursorKind.TYPE_REF', 'ssize_t'],
#  759: ['CursorKind.PARM_DECL', '__fd'],
#  760: ['CursorKind.PARM_DECL', '__buf'],
#  761: ['CursorKind.PARM_DECL', '__n'],
#  762: ['CursorKind.PARM_DECL', '__flags'],
#  763: ['CursorKind.FUNCTION_DECL', 'recv(int, void *, int, int)'],
#  764: ['CursorKind.TYPE_REF', 'ssize_t'],
#  765: ['CursorKind.PARM_DECL', '__fd'],
#  766: ['CursorKind.PARM_DECL', '__buf'],
#  767: ['CursorKind.PARM_DECL', '__n'],
#  768: ['CursorKind.PARM_DECL', '__flags'],
#  769: ['CursorKind.FUNCTION_DECL',
#   'sendto(int, const void *, int, int, const struct sockaddr *, socklen_t)'],
#  770: ['CursorKind.TYPE_REF', 'ssize_t'],
#  771: ['CursorKind.PARM_DECL', '__fd'],
#  772: ['CursorKind.PARM_DECL', '__buf'],
#  773: ['CursorKind.PARM_DECL', '__n'],
#  774: ['CursorKind.PARM_DECL', '__flags'],
#  775: ['CursorKind.PARM_DECL', '__addr'],
#  776: ['CursorKind.TYPE_REF', 'struct sockaddr'],
#  777: ['CursorKind.PARM_DECL', '__addr_len'],
#  778: ['CursorKind.TYPE_REF', 'socklen_t'],
#  779: ['CursorKind.FUNCTION_DECL',
#   'recvfrom(int, void *restrict, int, int, struct sockaddr *restrict, socklen_t *restrict)'],
#  780: ['CursorKind.TYPE_REF', 'ssize_t'],
#  781: ['CursorKind.PARM_DECL', '__fd'],
#  782: ['CursorKind.PARM_DECL', '__buf'],
#  783: ['CursorKind.PARM_DECL', '__n'],
#  784: ['CursorKind.PARM_DECL', '__flags'],
#  785: ['CursorKind.PARM_DECL', '__addr'],
#  786: ['CursorKind.TYPE_REF', 'struct sockaddr'],
#  787: ['CursorKind.PARM_DECL', '__addr_len'],
#  788: ['CursorKind.TYPE_REF', 'socklen_t'],
#  789: ['CursorKind.FUNCTION_DECL', 'sendmsg(int, const struct msghdr *, int)'],
#  790: ['CursorKind.TYPE_REF', 'ssize_t'],
#  791: ['CursorKind.PARM_DECL', '__fd'],
#  792: ['CursorKind.PARM_DECL', '__message'],
#  793: ['CursorKind.TYPE_REF', 'struct msghdr'],
#  794: ['CursorKind.PARM_DECL', '__flags'],
#  795: ['CursorKind.FUNCTION_DECL', 'recvmsg(int, struct msghdr *, int)'],
#  796: ['CursorKind.TYPE_REF', 'ssize_t'],
#  797: ['CursorKind.PARM_DECL', '__fd'],
#  798: ['CursorKind.PARM_DECL', '__message'],
#  799: ['CursorKind.TYPE_REF', 'struct msghdr'],
#  800: ['CursorKind.PARM_DECL', '__flags'],
#  801: ['CursorKind.FUNCTION_DECL',
#   'getsockopt(int, int, int, void *restrict, socklen_t *restrict)'],
#  802: ['CursorKind.UNEXPOSED_ATTR', ''],
#  803: ['CursorKind.PARM_DECL', '__fd'],
#  804: ['CursorKind.PARM_DECL', '__level'],
#  805: ['CursorKind.PARM_DECL', '__optname'],
#  806: ['CursorKind.PARM_DECL', '__optval'],
#  807: ['CursorKind.PARM_DECL', '__optlen'],
#  808: ['CursorKind.TYPE_REF', 'socklen_t'],
#  809: ['CursorKind.FUNCTION_DECL',
#   'setsockopt(int, int, int, const void *, socklen_t)'],
#  810: ['CursorKind.UNEXPOSED_ATTR', ''],
#  811: ['CursorKind.PARM_DECL', '__fd'],
#  812: ['CursorKind.PARM_DECL', '__level'],
#  813: ['CursorKind.PARM_DECL', '__optname'],
#  814: ['CursorKind.PARM_DECL', '__optval'],
#  815: ['CursorKind.PARM_DECL', '__optlen'],
#  816: ['CursorKind.TYPE_REF', 'socklen_t'],
#  817: ['CursorKind.FUNCTION_DECL', 'listen(int, int)'],
#  818: ['CursorKind.UNEXPOSED_ATTR', ''],
#  819: ['CursorKind.PARM_DECL', '__fd'],
#  820: ['CursorKind.PARM_DECL', '__n'],
#  821: ['CursorKind.FUNCTION_DECL',
#   'accept(int, struct sockaddr *restrict, socklen_t *restrict)'],
#  822: ['CursorKind.PARM_DECL', '__fd'],
#  823: ['CursorKind.PARM_DECL', '__addr'],
#  824: ['CursorKind.TYPE_REF', 'struct sockaddr'],
#  825: ['CursorKind.PARM_DECL', '__addr_len'],
#  826: ['CursorKind.TYPE_REF', 'socklen_t'],
#  827: ['CursorKind.FUNCTION_DECL', 'shutdown(int, int)'],
#  828: ['CursorKind.UNEXPOSED_ATTR', ''],
#  829: ['CursorKind.PARM_DECL', '__fd'],
#  830: ['CursorKind.PARM_DECL', '__how'],
#  831: ['CursorKind.FUNCTION_DECL', 'sockatmark(int)'],
#  832: ['CursorKind.UNEXPOSED_ATTR', ''],
#  833: ['CursorKind.PARM_DECL', '__fd'],
#  834: ['CursorKind.FUNCTION_DECL', 'isfdtype(int, int)'],
#  835: ['CursorKind.UNEXPOSED_ATTR', ''],
#  836: ['CursorKind.PARM_DECL', '__fd'],
#  837: ['CursorKind.PARM_DECL', '__fdtype'],
#  838: ['CursorKind.TYPEDEF_DECL', 'uint8_t'],
#  839: ['CursorKind.TYPE_REF', '__uint8_t'],
#  840: ['CursorKind.TYPEDEF_DECL', 'uint16_t'],
#  841: ['CursorKind.TYPE_REF', '__uint16_t'],
#  842: ['CursorKind.TYPEDEF_DECL', 'uint32_t'],
#  843: ['CursorKind.TYPE_REF', '__uint32_t'],
#  844: ['CursorKind.TYPEDEF_DECL', 'uint64_t'],
#  845: ['CursorKind.TYPE_REF', '__uint64_t'],
#  846: ['CursorKind.TYPEDEF_DECL', 'in_addr_t'],
#  847: ['CursorKind.TYPE_REF', 'uint32_t'],
#  848: ['CursorKind.STRUCT_DECL', 'in_addr'],
#  849: ['CursorKind.FIELD_DECL', 's_addr'],
#  850: ['CursorKind.TYPE_REF', 'in_addr_t'],
#  851: ['CursorKind.STRUCT_DECL', 'ip_opts'],
#  852: ['CursorKind.FIELD_DECL', 'ip_dst'],
#  853: ['CursorKind.TYPE_REF', 'struct in_addr'],
#  854: ['CursorKind.FIELD_DECL', 'ip_opts'],
#  855: ['CursorKind.INTEGER_LITERAL', ''],
#  856: ['CursorKind.STRUCT_DECL', 'ip_mreqn'],
#  857: ['CursorKind.FIELD_DECL', 'imr_multiaddr'],
#  858: ['CursorKind.TYPE_REF', 'struct in_addr'],
#  859: ['CursorKind.FIELD_DECL', 'imr_address'],
#  860: ['CursorKind.TYPE_REF', 'struct in_addr'],
#  861: ['CursorKind.FIELD_DECL', 'imr_ifindex'],
#  862: ['CursorKind.STRUCT_DECL', 'in_pktinfo'],
#  863: ['CursorKind.FIELD_DECL', 'ipi_ifindex'],
#  864: ['CursorKind.FIELD_DECL', 'ipi_spec_dst'],
#  865: ['CursorKind.TYPE_REF', 'struct in_addr'],
#  866: ['CursorKind.FIELD_DECL', 'ipi_addr'],
#  867: ['CursorKind.TYPE_REF', 'struct in_addr'],
#  868: ['CursorKind.ENUM_DECL', ''],
#  869: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_IP'],
#  870: ['CursorKind.INTEGER_LITERAL', ''],
#  871: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_ICMP'],
#  872: ['CursorKind.INTEGER_LITERAL', ''],
#  873: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_IGMP'],
#  874: ['CursorKind.INTEGER_LITERAL', ''],
#  875: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_IPIP'],
#  876: ['CursorKind.INTEGER_LITERAL', ''],
#  877: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_TCP'],
#  878: ['CursorKind.INTEGER_LITERAL', ''],
#  879: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_EGP'],
#  880: ['CursorKind.INTEGER_LITERAL', ''],
#  881: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_PUP'],
#  882: ['CursorKind.INTEGER_LITERAL', ''],
#  883: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_UDP'],
#  884: ['CursorKind.INTEGER_LITERAL', ''],
#  885: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_IDP'],
#  886: ['CursorKind.INTEGER_LITERAL', ''],
#  887: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_TP'],
#  888: ['CursorKind.INTEGER_LITERAL', ''],
#  889: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_DCCP'],
#  890: ['CursorKind.INTEGER_LITERAL', ''],
#  891: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_IPV6'],
#  892: ['CursorKind.INTEGER_LITERAL', ''],
#  893: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_RSVP'],
#  894: ['CursorKind.INTEGER_LITERAL', ''],
#  895: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_GRE'],
#  896: ['CursorKind.INTEGER_LITERAL', ''],
#  897: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_ESP'],
#  898: ['CursorKind.INTEGER_LITERAL', ''],
#  899: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_AH'],
#  900: ['CursorKind.INTEGER_LITERAL', ''],
#  901: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_MTP'],
#  902: ['CursorKind.INTEGER_LITERAL', ''],
#  903: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_BEETPH'],
#  904: ['CursorKind.INTEGER_LITERAL', ''],
#  905: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_ENCAP'],
#  906: ['CursorKind.INTEGER_LITERAL', ''],
#  907: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_PIM'],
#  908: ['CursorKind.INTEGER_LITERAL', ''],
#  909: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_COMP'],
#  910: ['CursorKind.INTEGER_LITERAL', ''],
#  911: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_SCTP'],
#  912: ['CursorKind.INTEGER_LITERAL', ''],
#  913: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_UDPLITE'],
#  914: ['CursorKind.INTEGER_LITERAL', ''],
#  915: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_MPLS'],
#  916: ['CursorKind.INTEGER_LITERAL', ''],
#  917: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_RAW'],
#  918: ['CursorKind.INTEGER_LITERAL', ''],
#  919: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_MAX'],
#  920: ['CursorKind.ENUM_DECL', ''],
#  921: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_HOPOPTS'],
#  922: ['CursorKind.INTEGER_LITERAL', ''],
#  923: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_ROUTING'],
#  924: ['CursorKind.INTEGER_LITERAL', ''],
#  925: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_FRAGMENT'],
#  926: ['CursorKind.INTEGER_LITERAL', ''],
#  927: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_ICMPV6'],
#  928: ['CursorKind.INTEGER_LITERAL', ''],
#  929: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_NONE'],
#  930: ['CursorKind.INTEGER_LITERAL', ''],
#  931: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_DSTOPTS'],
#  932: ['CursorKind.INTEGER_LITERAL', ''],
#  933: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPROTO_MH'],
#  934: ['CursorKind.INTEGER_LITERAL', ''],
#  935: ['CursorKind.TYPEDEF_DECL', 'in_port_t'],
#  936: ['CursorKind.TYPE_REF', 'uint16_t'],
#  937: ['CursorKind.ENUM_DECL', ''],
#  938: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_ECHO'],
#  939: ['CursorKind.INTEGER_LITERAL', ''],
#  940: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_DISCARD'],
#  941: ['CursorKind.INTEGER_LITERAL', ''],
#  942: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_SYSTAT'],
#  943: ['CursorKind.INTEGER_LITERAL', ''],
#  944: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_DAYTIME'],
#  945: ['CursorKind.INTEGER_LITERAL', ''],
#  946: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_NETSTAT'],
#  947: ['CursorKind.INTEGER_LITERAL', ''],
#  948: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_FTP'],
#  949: ['CursorKind.INTEGER_LITERAL', ''],
#  950: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_TELNET'],
#  951: ['CursorKind.INTEGER_LITERAL', ''],
#  952: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_SMTP'],
#  953: ['CursorKind.INTEGER_LITERAL', ''],
#  954: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_TIMESERVER'],
#  955: ['CursorKind.INTEGER_LITERAL', ''],
#  956: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_NAMESERVER'],
#  957: ['CursorKind.INTEGER_LITERAL', ''],
#  958: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_WHOIS'],
#  959: ['CursorKind.INTEGER_LITERAL', ''],
#  960: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_MTP'],
#  961: ['CursorKind.INTEGER_LITERAL', ''],
#  962: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_TFTP'],
#  963: ['CursorKind.INTEGER_LITERAL', ''],
#  964: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_RJE'],
#  965: ['CursorKind.INTEGER_LITERAL', ''],
#  966: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_FINGER'],
#  967: ['CursorKind.INTEGER_LITERAL', ''],
#  968: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_TTYLINK'],
#  969: ['CursorKind.INTEGER_LITERAL', ''],
#  970: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_SUPDUP'],
#  971: ['CursorKind.INTEGER_LITERAL', ''],
#  972: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_EXECSERVER'],
#  973: ['CursorKind.INTEGER_LITERAL', ''],
#  974: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_LOGINSERVER'],
#  975: ['CursorKind.INTEGER_LITERAL', ''],
#  976: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_CMDSERVER'],
#  977: ['CursorKind.INTEGER_LITERAL', ''],
#  978: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_EFSSERVER'],
#  979: ['CursorKind.INTEGER_LITERAL', ''],
#  980: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_BIFFUDP'],
#  981: ['CursorKind.INTEGER_LITERAL', ''],
#  982: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_WHOSERVER'],
#  983: ['CursorKind.INTEGER_LITERAL', ''],
#  984: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_ROUTESERVER'],
#  985: ['CursorKind.INTEGER_LITERAL', ''],
#  986: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_RESERVED'],
#  987: ['CursorKind.INTEGER_LITERAL', ''],
#  988: ['CursorKind.ENUM_CONSTANT_DECL', 'IPPORT_USERRESERVED'],
#  989: ['CursorKind.INTEGER_LITERAL', ''],
#  990: ['CursorKind.STRUCT_DECL', 'in6_addr'],
#  991: ['CursorKind.UNION_DECL', ''],
#  992: ['CursorKind.FIELD_DECL', '__u6_addr8'],
#  993: ['CursorKind.TYPE_REF', 'uint8_t'],
#  994: ['CursorKind.INTEGER_LITERAL', ''],
#  995: ['CursorKind.FIELD_DECL', '__u6_addr16'],
#  996: ['CursorKind.TYPE_REF', 'uint16_t'],
#  997: ['CursorKind.INTEGER_LITERAL', ''],
#  998: ['CursorKind.FIELD_DECL', '__u6_addr32'],
#  999: ['CursorKind.TYPE_REF', 'uint32_t'],
#  1000: ['CursorKind.INTEGER_LITERAL', ''],
#  ...}

# %%
final_features = set()
for i in range(len(feature_sets)):
    final_features.update(feature_sets.iloc[i])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-26eac2d91e8b> in <module>
# ----> 1 ast_roots.children
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'children'

# %%
final_features = pd.Series(list(final_features))

# %%
pd.get_dummies(final_features)
