# %% [markdown]
# # Joern-ey into Progol
#
# We have [generated](./generate_minimal_ilp_dataset.ipynb) a subset of the Juliet dataset consisting of small buffer overflow examples, and have [transformed](./Joern-ey%20into%20ILP.ipynb) each piece of source code into a a set of Prolog facts. In this notebook we generate Progol scripts from this dataset, and try to get it to learn rules to determine when a buffer overflow occurs.

# %% [markdown]
# ## Generating Progol
# In this section we load in the ILP dataset and its Progol representations, manually find the "error" node in each example, then define the `make_progol_script` function which will generate a script from the given testcase id's.

# %%
import pandas as pd

# %%
import tempfile
import subprocess

# %%
ilp_data = pd.read_csv("../data/ilp_dataset.csv.gz")
ilp_data = ilp_data.drop("Unnamed: 0", axis=1)
ilp_data
# Out:
#     testcase_ID                                           filename  \
# 0         62804  000/062/804/CWE121_Stack_Based_Buffer_Overflow...
# 1         62852  000/062/852/CWE121_Stack_Based_Buffer_Overflow...
# 2         62853  000/062/853/CWE121_Stack_Based_Buffer_Overflow...
# 3         62854  000/062/854/CWE121_Stack_Based_Buffer_Overflow...
# 4         62869  000/062/869/CWE121_Stack_Based_Buffer_Overflow...
# 5         62900  000/062/900/CWE121_Stack_Based_Buffer_Overflow...
# 6         62901  000/062/901/CWE121_Stack_Based_Buffer_Overflow...
# 7         62917  000/062/917/CWE121_Stack_Based_Buffer_Overflow...
# 8        232012  000/232/012/CWE122_Heap_Based_Buffer_Overflow_...
# 9        232086  000/232/086/CWE122_Heap_Based_Buffer_Overflow_...
# 10       -62804  000/062/804/CWE121_Stack_Based_Buffer_Overflow...
# 11       -62852  000/062/852/CWE121_Stack_Based_Buffer_Overflow...
# 12       -62853  000/062/853/CWE121_Stack_Based_Buffer_Overflow...
# 13       -62854  000/062/854/CWE121_Stack_Based_Buffer_Overflow...
# 14       -62869  000/062/869/CWE121_Stack_Based_Buffer_Overflow...
# 15       -62900  000/062/900/CWE121_Stack_Based_Buffer_Overflow...
# 16       -62901  000/062/901/CWE121_Stack_Based_Buffer_Overflow...
# 17       -62917  000/062/917/CWE121_Stack_Based_Buffer_Overflow...
# 18      -232012  000/232/012/CWE122_Heap_Based_Buffer_Overflow_...
# 19      -232086  000/232/086/CWE122_Heap_Based_Buffer_Overflow_...
#
#                                                  code     flaw  flaw_loc  \
# 0   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 1   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 2   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 3   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 4   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        32
# 5   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 6   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 7   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        32
# 8   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        31
# 9   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        31
# 10  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 11  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 12  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 13  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 14  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        32
# 15  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 16  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 17  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        32
# 18  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        31
# 19  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        31
#
#       bug  code_length
# 0   False         1722
# 1   False         1674
# 2   False         2396
# 3   False         2414
# 4   False         1760
# 5   False         1680
# 6   False         2403
# 7   False         1766
# 8   False         1723
# 9   False         1729
# 10   True         1618
# 11   True         1570
# 12   True         1621
# 13   True         1630
# 14   True         1616
# 15   True         1576
# 16   True         1627
# 17   True         1622
# 18   True         1619
# 19   True         1625

# %%
prolog = pd.read_csv("../data/ilp_prolog_data.csv.gz")
prolog = prolog.drop("Unnamed: 0", axis=1)
prolog
# Out:
#     testcase_ID     flaw    bug  code_length  \
# 0       -232086  CWE-122   True         1625
# 1       -232012  CWE-122   True         1619
# 2        -62917  CWE-121   True         1622
# 3        -62901  CWE-121   True         1627
# 4        -62900  CWE-121   True         1576
# 5        -62869  CWE-121   True         1616
# 6        -62854  CWE-121   True         1630
# 7        -62853  CWE-121   True         1621
# 8        -62852  CWE-121   True         1570
# 9        -62804  CWE-121   True         1618
# 10        62804  CWE-121  False         1722
# 11        62852  CWE-121  False         1674
# 12        62853  CWE-121  False         2396
# 13        62854  CWE-121  False         2414
# 14        62869  CWE-121  False         1760
# 15        62900  CWE-121  False         1680
# 16        62901  CWE-121  False         2403
# 17        62917  CWE-121  False         1766
# 18       232012  CWE-122  False         1723
# 19       232086  CWE-122  False         1729
#
#                                                  tree  \
# 0   % START: Generated Prolog\n% NODE PROPERTIES \...
# 1   % START: Generated Prolog\n% NODE PROPERTIES \...
# 2   % START: Generated Prolog\n% NODE PROPERTIES \...
# 3   % START: Generated Prolog\n% NODE PROPERTIES \...
# 4   % START: Generated Prolog\n% NODE PROPERTIES \...
# 5   % START: Generated Prolog\n% NODE PROPERTIES \...
# 6   % START: Generated Prolog\n% NODE PROPERTIES \...
# 7   % START: Generated Prolog\n% NODE PROPERTIES \...
# 8   % START: Generated Prolog\n% NODE PROPERTIES \...
# 9   % START: Generated Prolog\n% NODE PROPERTIES \...
# 10  % START: Generated Prolog\n% NODE PROPERTIES \...
# 11  % START: Generated Prolog\n% NODE PROPERTIES \...
# 12  % START: Generated Prolog\n% NODE PROPERTIES \...
# 13  % START: Generated Prolog\n% NODE PROPERTIES \...
# 14  % START: Generated Prolog\n% NODE PROPERTIES \...
# 15  % START: Generated Prolog\n% NODE PROPERTIES \...
# 16  % START: Generated Prolog\n% NODE PROPERTIES \...
# 17  % START: Generated Prolog\n% NODE PROPERTIES \...
# 18  % START: Generated Prolog\n% NODE PROPERTIES \...
# 19  % START: Generated Prolog\n% NODE PROPERTIES \...
#
#                                            source_map
# 0   % CODE\nsource_code(bad_232086_id_0_f_l_c_, ""...
# 1   % CODE\nsource_code(bad_232012_id_1_f_l_c_, "p...
# 2   % CODE\nsource_code(bad_62917_id_0_f_l_c_, "p1...
# 3   % CODE\nsource_code(bad_62901_id_0_f_l_c_, "p2...
# 4   % CODE\nsource_code(bad_62900_id_0_f_l_c_, "p1...
# 5   % CODE\nsource_code(bad_62869_id_0_f_l_c_, "p1...
# 6   % CODE\nsource_code(bad_62854_id_0_f_l_c_, "p2...
# 7   % CODE\nsource_code(bad_62853_id_0_f_l_c_, "p1...
# 8   % CODE\nsource_code(bad_62852_id_0_f_l_c_, "p1...
# 9   % CODE\nsource_code(bad_62804_id_0_f_l_c_, "p1...
# 10  % CODE\nsource_code(good_62804_id_0_f_l_c_, "p...
# 11  % CODE\nsource_code(good_62852_id_0_f_l_c_, "p...
# 12  % CODE\nsource_code(good_62853_id_0_f_l_c_, "d...
# 13  % CODE\nsource_code(good_62854_id_0_f_memcpy_0...
# 14  % CODE\nsource_code(good_62869_id_0_f_l_c_, "p...
# 15  % CODE\nsource_code(good_62900_id_0_f_l_c_, "p...
# 16  % CODE\nsource_code(good_62901_id_0_f_memmove_...
# 17  % CODE\nsource_code(good_62917_id_0_f_l_c_, "p...
# 18  % CODE\nsource_code(good_232012_id_1_f_l_c_, "...
# 19  % CODE\nsource_code(good_232086_id_1_f_l_c_, "...

# %%
good_examples = prolog[prolog['bug'] == False]
bad_examples = prolog[prolog['bug'] == True]

# %%
def extract_node_ids(tree):
    nodes = set()
    
    in_ast_section = False
    
    for line in tree.split('\n'):
        line = line.strip()
        
        if line == '% AST':
            in_ast_section = True
        
        if line == '% CFG':
            in_ast_section = False
            
        if line == '% REF':
            in_ast_section = False
        
        if in_ast_section and not line.startswith("%"):
            parent, child = line[4:-2].split(", ")
            nodes.add(parent)
            nodes.add(child)
            
    return nodes

# %%
# good nodes_g
nodes_g = set()

for i in range(len(good_examples)):
    good_nodes = extract_node_ids(good_examples.iloc[i].tree)
    nodes_g = set.union(nodes_g,good_nodes)

    
# bad nodes_b
nodes_b = set()

for i in range(len(bad_examples)):
    bad_nodes = extract_node_ids(bad_examples.iloc[i].tree)
    nodes_b = set.union(nodes_b,bad_nodes)

nodes = set.union(nodes_g,nodes_b)

# %% [markdown]
# Manually find the "error" node for each testcase, and tag those as the positive or  negative examples.

# %%
print(good_examples.source_map.iloc[8])
# Out:
# % CODE
# source_code(good_232012_id_1_f_l_c_, "p1").
# source_code(good_232012_id_2_f_l_c_, "p2").
# source_code(good_232012_id_3_f_l_54_c_19_, "char * argv[]").
# source_code(good_232012_id_4_f_l_c_, "p2").
# source_code(good_232012_id_5_f_l_c_, "p1").
# source_code(good_232012_id_6_f_l_54_c_9_, "int argc").
# source_code(good_232012_id_7_f_l_c_, "p1").
# source_code(good_232012_id_8_f_l_c_, "p1").
# source_code(good_232012_id_9_f_l_c_, "p1").
# source_code(good_232012_id_10_f_l_c_, "p1").
# source_code(good_232012_id_11_f_l_c_, "p1").
# source_code(good_232012_id_12_f_l_c_, "p1").
# source_code(good_232012_id_13_f_l_c_, "p1").
# source_code(good_232012_id_14_f_l_c_, "p1").
# source_code(good_232012_id_15_f_l_c_, "p2").
# source_code(good_232012_id_16_f_l_c_, "p1").
# source_code(good_232012_id_17_f_l_c_, "p1").
# source_code(good_232012_id_18_f_l_c_, "p2").
# source_code(good_232012_id_19_f_l_c_, "p1").
# source_code(good_232012_id_20_f_l_c_, "p2").
# source_code(good_232012_id_21_f_l_c_, "p3").
# source_code(good_232012_id_22_f_l_c_, "p1").
# source_code(good_232012_id_23_f_l_c_, "p1").
# source_code(good_232012_id_24_f_l_c_, "p2").
# source_code(good_232012_id_25_f_l_c_, "").
# source_code(good_232012_id_28_f_l_c_, "").
# source_code(good_232012_id_29_f_l_c_, "p2").
# source_code(good_232012_id_31_f_l_c_, "RET").
# source_code(good_232012_id_32_f_l_c_, "RET").
# source_code(good_232012_id_33_f_l_c_, "p1").
# source_code(good_232012_id_34_f_l_c_, "RET").
# source_code(good_232012_id_35_f_l_c_, "RET").
# source_code(good_232012_id_36_f_l_c_, "").
# source_code(good_232012_id_37_f_l_c_, "p1").
# source_code(good_232012_id_38_f_l_c_, "p3").
# source_code(good_232012_id_40_f_l_c_, "p1").
# source_code(good_232012_id_41_f_l_c_, "p1").
# source_code(good_232012_id_42_f_l_c_, "p1").
# source_code(good_232012_id_43_f_l_c_, "RET").
# source_code(good_232012_id_46_f_l_c_, "RET").
# source_code(good_232012_id_47_f_l_c_, "RET").
# source_code(good_232012_id_48_f_l_c_, "").
# source_code(good_232012_id_49_f_l_c_, "RET").
# source_code(good_232012_id_50_f_l_c_, "RET").
# source_code(good_232012_id_51_f_l_c_, "RET").
# source_code(good_232012_id_53_f_l_c_, "p1").
# source_code(good_232012_id_54_f_l_c_, "").
# source_code(good_232012_id_56_f_l_c_, "p2").
# source_code(good_232012_id_57_f_l_c_, "p2").
# source_code(good_232012_id_58_f_l_c_, "").
# source_code(good_232012_id_59_f_l_c_, "p1").
# source_code(good_232012_id_60_f_l_c_, "RET").
# source_code(good_232012_id_61_f_l_c_, "p1").
# source_code(good_232012_id_62_f_l_c_, "").
# source_code(good_232012_id_63_f_l_c_, "p1").
# source_code(good_232012_id_64_f_l_c_, "").
# source_code(good_232012_id_65_f_l_c_, "p1").
# source_code(good_232012_id_66_f_l_c_, "p1").
# source_code(good_232012_id_67_f_l_c_, "p2").
# source_code(good_232012_id_68_f_l_c_, "p1").
# source_code(good_232012_id_69_f_l_c_, "p2").
# source_code(good_232012_id_70_f_l_c_, "RET").
# source_code(good_232012_id_71_f_l_c_, "").
# source_code(good_232012_id_72_f_l_c_, "").
# source_code(good_232012_id_76_f_l_c_, "").
# source_code(good_232012_id_77_f_l_c_, "p1").
# source_code(good_232012_id_78_f_l_c_, "").
# source_code(good_232012_id_80_f_l_c_, "p1").
# source_code(good_232012_id_81_f_l_c_, "").
# source_code(good_232012_id_83_f_l_c_, "RET").
# source_code(good_232012_id_84_f_l_c_, "p1").
# source_code(good_232012_id_85_f_l_c_, "").
# source_code(good_232012_id_86_f_l_c_, "").
# source_code(good_232012_id_87_f_l_c_, "RET").
# source_code(good_232012_id_88_f_l_c_, "RET").
# source_code(good_232012_id_90_f_l_c_, "p2").
# source_code(good_232012_id_102_f_memcpy_01_c_l_62_c_11_, "0").
# source_code(good_232012_id_103_f_memcpy_01_c_l_62_c_4_, "return 0;").
# source_code(good_232012_id_104_f_memcpy_01_c_l_60_c_14_, ""Finished good()"").
# source_code(good_232012_id_105_f_memcpy_01_c_l_60_c_4_, "printLine("Finished good()")").
# source_code(good_232012_id_107_f_memcpy_01_c_l_59_c_4_, "CWE122_Heap_Based_Buffer_Overflow__CWE131_memcpy_01_good()").
# source_code(good_232012_id_108_f_memcpy_01_c_l_58_c_14_, ""Calling good()..."").
# source_code(good_232012_id_110_f_memcpy_01_c_l_58_c_4_, "printLine("Calling good()...")").
# source_code(good_232012_id_111_f_memcpy_01_c_l_56_c_26_, "NULL").
# source_code(good_232012_id_113_f_memcpy_01_c_l_56_c_21_, "time(good_232012_NULL)").
# source_code(good_232012_id_114_f_memcpy_01_c_l_56_c_12_, "unsigned").
# source_code(good_232012_id_115_f_memcpy_01_c_l_56_c_11_, "(good_232012_unsigned)time(good_232012_NULL)").
# source_code(good_232012_id_117_f_memcpy_01_c_l_56_c_4_, "srand( (good_232012_unsigned)time(good_232012_NULL) )").
# source_code(good_232012_id_118_f_memcpy_01_c_l_55_c_0_, "").
# source_code(good_232012_id_119_f_l_54_c_0_, "RET").
# source_code(good_232012_id_120_f_l_54_c_19_, "char * argv[]").
# source_code(good_232012_id_121_f_l_54_c_9_, "int argc").
# source_code(good_232012_id_124_f_memcpy_01_c_l_40_c_4_, "goodG2B()").
# source_code(good_232012_id_125_f_memcpy_01_c_l_40_c_0_, "").
# source_code(good_232012_id_126_f_l_39_c_0_, "RET").
# source_code(good_232012_id_134_f_memcpy_01_c_l_34_c_13_, "data").
# source_code(good_232012_id_136_f_memcpy_01_c_l_34_c_8_, "free(good_232012_data)").
# source_code(good_232012_id_137_f_memcpy_01_c_l_33_c_26_, "0").
# source_code(good_232012_id_138_f_memcpy_01_c_l_33_c_21_, "data").
# source_code(good_232012_id_140_f_memcpy_01_c_l_33_c_21_, "data[0]").
# source_code(good_232012_id_142_f_memcpy_01_c_l_33_c_8_, "printIntLine(data[0])").
# source_code(good_232012_id_143_f_memcpy_01_c_l_32_c_39_, "int").
# source_code(good_232012_id_144_f_memcpy_01_c_l_32_c_32_, "sizeof(good_232012_int)").
# source_code(good_232012_id_145_f_memcpy_01_c_l_32_c_29_, "10").
# source_code(good_232012_id_146_f_memcpy_01_c_l_32_c_29_, "10*sizeof(good_232012_int)").
# source_code(good_232012_id_147_f_memcpy_01_c_l_32_c_21_, "source").
# source_code(good_232012_id_148_f_memcpy_01_c_l_32_c_15_, "data").
# source_code(good_232012_id_150_f_memcpy_01_c_l_32_c_8_, "memcpy(data, source, 10*sizeof(good_232012_int))").
# source_code(good_232012_id_151_f_memcpy_01_c_l_30_c_12_, "source").
# source_code(good_232012_id_152_f_memcpy_01_c_l_30_c_12_, "source[10] = {0}").
# source_code(good_232012_id_153_f_l_c_, "source").
# source_code(good_232012_id_154_f_memcpy_01_c_l_30_c_8_, "").
# source_code(good_232012_id_155_f_memcpy_01_c_l_28_c_29_, "1").
# source_code(good_232012_id_157_f_memcpy_01_c_l_28_c_28_, "-1").
# source_code(good_232012_id_159_f_memcpy_01_c_l_28_c_23_, "exit(-1)").
# source_code(good_232012_id_160_f_memcpy_01_c_l_28_c_22_, "").
# source_code(good_232012_id_161_f_memcpy_01_c_l_28_c_16_, "NULL").
# source_code(good_232012_id_162_f_memcpy_01_c_l_28_c_8_, "data").
# source_code(good_232012_id_164_f_memcpy_01_c_l_28_c_8_, "data == NULL").
# source_code(good_232012_id_165_f_memcpy_01_c_l_28_c_4_, "if (data == NULL)").
# source_code(good_232012_id_166_f_memcpy_01_c_l_27_c_35_, "int").
# source_code(good_232012_id_168_f_memcpy_01_c_l_27_c_28_, "sizeof(good_232012_int)").
# source_code(good_232012_id_169_f_memcpy_01_c_l_27_c_25_, "10").
# source_code(good_232012_id_171_f_memcpy_01_c_l_27_c_25_, "10*sizeof(good_232012_int)").
# source_code(good_232012_id_173_f_memcpy_01_c_l_27_c_18_, "malloc(10*sizeof(good_232012_int))").
# source_code(good_232012_id_174_f_memcpy_01_c_l_27_c_12_, "int *").
# source_code(good_232012_id_176_f_memcpy_01_c_l_27_c_11_, "(int *)malloc(10*sizeof(good_232012_int))").
# source_code(good_232012_id_177_f_memcpy_01_c_l_27_c_4_, "data").
# source_code(good_232012_id_178_f_memcpy_01_c_l_27_c_4_, "data = (int *)malloc(10*sizeof(good_232012_int))").
# source_code(good_232012_id_179_f_memcpy_01_c_l_25_c_11_, "NULL").
# source_code(good_232012_id_180_f_memcpy_01_c_l_25_c_4_, "data").
# source_code(good_232012_id_182_f_memcpy_01_c_l_25_c_4_, "data = NULL").
# source_code(good_232012_id_183_f_l_c_, "data").
# source_code(good_232012_id_184_f_memcpy_01_c_l_24_c_0_, "").
# source_code(good_232012_id_185_f_l_23_c_0_, "RET").
# source_code(good_232012_id_187_f_l_56_c_, "/* seed randomness */").
# source_code(id_188_f_l_46_c_, "/* Below is the main(). It is only used when building this testcase on
#  * its own for testing or for building a binary to use in testing binary
#  * analysis tools. It is not used when compiling all the testcases as one
#  * application, which is how source code analysis tools are tested.
#  */").
# source_code(good_232012_id_189_f_l_32_c_, "/* POTENTIAL FLAW: Possible buffer overflow if data was not allocated correctly in the source */").
# source_code(good_232012_id_190_f_l_27_c_, "/* FIX: Allocate memory using sizeof(good_232012_int) */").
# source_code(good_232012_id_191_f_l_22_c_, "/* goodG2B uses the GoodSource with the BadSink */").
# source_code(id_192_f_l_6_c_, "/*
#  * @description
#  * CWE: 122 Heap Based Buffer Overflow
#  * BadSource:  Allocate memory without using sizeof(good_232012_int)
#  * GoodSource: Allocate memory using sizeof(good_232012_int)
#  * Sink: memcpy
#  *    BadSink : Copy array to data using memcpy()
#  * Flow Variant: 01 Baseline
#  *
#  * */").
# source_code(id_193_f_l_1_c_, "/* TEMPLATE GENERATED TESTCASE FILE
# Filename: CWE122_Heap_Based_Buffer_Overflow__CWE131_memcpy_01.c
# Label Definition File: CWE122_Heap_Based_Buffer_Overflow__CWE131.label.xml
# Template File: sources-sink-01.tmpl.c
# */").

# %%
types = [
    'node('+node_id+').' for node_id in nodes
]

positive_examples = [
    """
    bug(bad_232086_id_146_f_memmove_01_c_l_30_c_8_).
    bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).
    bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).
    bug(bad_62901_id_121_f_memmove_02_c_l_32_c_8_).
    bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).
    bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).
    bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).
    bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).
    bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).
    bug(bad_62804_id_111_f_loop_01_c_l_32_c_12_).
    """,
]

negative_examples = [
    """
:- bug(good_62804_id_130_f_loop_01_c_l_34_c_12_).
:- bug(good_62852_id_126_f_memcpy_01_c_l_31_c_8_).
:- bug(good_62853_id_122_f_memcpy_02_c_l_57_c_8_).
:- bug(good_62854_id_130_f_memcpy_03_c_l_57_c_8_).
:- bug(good_62869_id_126_f_memcpy_18_c_l_33_c_8_).
:- bug(good_62900_id_125_f_memmove_01_c_l_31_c_8_).
:- bug(good_62901_id_116_f_memmove_02_c_l_57_c_8_).
:- bug(good_62917_id_125_f_memmove_18_c_l_33_c_8_).
:- bug(good_232012_id_150_f_memcpy_01_c_l_32_c_8_).
:- bug(good_232086_id_150_f_memmove_01_c_l_32_c_8_).
    """,
]

# %%
def make_progol_script(header, testcases):
    script_template = """
{header}

%% Types
{types}

%% background knowledge
{bg_knowledge}

%% learning task
%% positive examples
{positive_examples}

%% negative examples
{negative_examples}

    """

    script = script_template.format(
        header = header,
        types = '\n'.join(types),
        bg_knowledge = '\n'.join(prolog['tree']),
        positive_examples='\n'.join(positive_examples),
        negative_examples='\n'.join(negative_examples),
    )
    
    # remove all lines not related to this testcase
    script = '\n'.join([
        line for line in script.split("\n")  if any(
            str(testcase) in line for testcase in testcases
        ) or not ("good_" in line or "bad_" in line)
    ])
    
    return script

# %% [markdown]
# ## Experimentation
# In this section we try different subsets of the dataset with different Progol settings.

# %% [markdown]
# We try by setting the following header:

# %%
header = """
% Settings
:- set(c,30)?
:- set(i,30)?
:- set(h,500)?
:- set(cover)?
:- set(inflate,500)?
%:- set(noise,0.2)?

% Mode declarations
:- modeh(*, bug(+node))?

:- modeb(*, ast(+node,-node))?

:- modeb(*, ref(+node,-node))?
:- modeb(*, ref(-node,+node))?

:- modeb(*, assignment(+node))?
:- modeb(*, compMemberAccess(+node))?
:- modeb(*, sizeOf(+node))?
:- modeb(*, malloc(+node))?
:- modeb(*, alloc(+node))?
:- modeb(*, writeToPointer(+node))?
"""

script = make_progol_script(header, {62804, 62852, 62869, 232012, 62900})

with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,30)? - Time taken 0.00s]
# [:- set(i,30)? - Time taken 0.00s]
# [:- set(h,500)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,500)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ast(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,assignment(+node))? - Time taken 0.00s]
# [:- modeb(100,compMemberAccess(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,malloc(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,H), ref(N,H), ref(O,G), sizeOf(E).
# [Most-specific clause reduced by 9 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:10,5,1,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62804_id_111_f_loop_01_c_l_32_c_12_).]
# [Generalising <bug(bad_62804_id_111_f_loop_01_c_l_32_c_12_).>]
# bug(A) :- ast(A,B), ast(A,C), assignment(A), ast(B,D), ast(B,E), ast(C,F), ast(C,G), compMemberAccess(B), compMemberAccess(C), ref(F,H), ref(G,I), ref(D,H), ref(E,J), ref(K,I), ref(L,I), ref(M,I), ref(N,H), ref(O,H), ref(P,H), ref(Q,J).
# [Most-specific clause reduced by 15 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), assignment(A), ast(B,C), compMemberAccess(B),
# 	ref(C,D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:10,5,1,0 bug(A) :- assignment(A).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
#
# [Total time taken 0.014s]

# %% [markdown]
# This creates one rule per example, but is unable to create a general one. These rules succinctly describe the situation, and three of the examples have the same rule!
#
# ```
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C, E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), assignment(A), ast(B,C), compMemberAccess(B), ref(C,D).
# ```

# %% [markdown]
# We try the same setup, but only for those buffer overflows which happen due to a `memcpy`:

# %%
script = make_progol_script(header, {
    62852,
    62853,
    62854,
    62869,
    232012,
})

with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,30)? - Time taken 0.00s]
# [:- set(i,30)? - Time taken 0.00s]
# [:- set(h,500)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,500)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ast(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,assignment(+node))? - Time taken 0.00s]
# [:- modeb(100,compMemberAccess(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,malloc(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,H), ref(N,H), ref(O,G), sizeOf(E).
# [Most-specific clause reduced by 9 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
#
# [Total time taken 0.013s]

# %% [markdown]
# It produces 5 of the exact same "most specific clauses", but is still unable to give a final output?
# ```
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# ```
#
# **Question:** Why is it unable to combine them?

# %% [markdown]
# Finally, try for all the examples:

# %%
script = make_progol_script(header, {
    62804,
    62852,
    62853,
    62854,
    62869,
    62900,
    62901,
    62917,
    232012,
    232086,
})

with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,30)? - Time taken 0.00s]
# [:- set(i,30)? - Time taken 0.00s]
# [:- set(h,500)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,500)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ast(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,assignment(+node))? - Time taken 0.00s]
# [:- modeb(100,compMemberAccess(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,malloc(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232086_id_146_f_memmove_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232086_id_146_f_memmove_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), ref(N,H), ref(O,H), sizeOf(E).
# [Most-specific clause reduced by 9 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:35,20,4,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,H), ref(N,H), ref(O,G), sizeOf(E).
# [Most-specific clause reduced by 9 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:35,20,4,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62901_id_121_f_memmove_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62901_id_121_f_memmove_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:35,20,4,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:35,20,4,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62804_id_111_f_loop_01_c_l_32_c_12_).]
# [Generalising <bug(bad_62804_id_111_f_loop_01_c_l_32_c_12_).>]
# bug(A) :- ast(A,B), ast(A,C), assignment(A), ast(B,D), ast(B,E), ast(C,F), ast(C,G), compMemberAccess(B), compMemberAccess(C), ref(F,H), ref(G,I), ref(D,H), ref(E,J), ref(K,I), ref(L,I), ref(M,I), ref(N,H), ref(O,H), ref(P,H), ref(Q,J).
# [Most-specific clause reduced by 15 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), assignment(A), ast(B,C), compMemberAccess(B),
# 	ref(C,D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:20,5,1,0 bug(A) :- assignment(A).]
# [3 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
#
# [Total time taken 0.065s]

# %% [markdown]
# It produces three different rules (grouped below by rule not output or testcase):
#
# ```
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C, E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C, E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C, E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C, E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), assignment(A), ast(B,C), compMemberAccess(B), ref(C,D).
# ```

# %% [markdown]
# **Question:** Can ILP learn logical or's? And so could these three rules be considered in composite?
#
# **Question:** Can we create probabilistic model from these rules?

# %%
script = make_progol_script("""
% Settings
:- set(c,40)?
:- set(i,40)?
:- set(h,500)?
:- set(cover)?
:- set(inflate,200)?
:- set(noise,0.2)?

% Mode declarations
:- modeh(*, bug(+node))?

:- modeb(*, ast(+node,-node))?

:- modeb(*, cfg(+node,-node))?
:- modeb(*, cfg(-node,+node))?

:- modeb(*, ref(+node,-node))?
:- modeb(*, ref(-node,+node))?

:- modeb(*, assignment(+node))?
:- modeb(*, compMemberAccess(+node))?
:- modeb(*, sizeOf(+node))?
:- modeb(*, malloc(+node))?
:- modeb(*, alloc(+node))?
:- modeb(*, writeToPointer(+node))? """, {
    62804,
    62852,
    62853,
    62854,
    62869,
    62900,
    62901,
    62917,
    232012,
    232086,
})

with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,40)? - Time taken 0.00s]
# [:- set(i,40)? - Time taken 0.00s]
# [:- set(h,500)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,200)? - Time taken 0.00s]
# [:- set(noise,0.200)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ast(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,cfg(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,cfg(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,assignment(+node))? - Time taken 0.00s]
# [:- modeb(100,compMemberAccess(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,malloc(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232086_id_146_f_memmove_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232086_id_146_f_memmove_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J), ref(O,K), ref(P,K), ref(Q,K), ref(R,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,S), cfg(O,T), cfg(P,U), cfg(Q,V), cfg(R,W), cfg(S,O), cfg(X,P), cfg(Y,M), cfg(Z,M), cfg(A0,Q), cfg(B0,R), compMemberAccess(N), ast(T,O), ast(S,N), ast(X,Q), ast(X,C0), ast(Y,D0), ast(Z,P), ast(Z,U), ast(A0,R), ast(A0,W), ast(B0,E0), ast(B0,F0), cfg(T,F0), cfg(U,Z), cfg(V,G0), cfg(W,A0), cfg(Z,H0), cfg(C0,X), cfg(D0,Y), ref(I0,B0), assignment(X), assignment(A0), ast(C0,G0), ast(C0,J0), ast(D0,H0), ast(E0,K), ast(E0,X), ast(E0,A0), ast(E0,K0), ast(E0,L0), ast(G0,V), cfg(G0,C0), cfg(H0,D0), alloc(G0), ast(K0,A), ast(K0,I), ast(K0,J), ast(K0,T), ast(K0,S), ast(L0,Z), ast(L0,M0), ast(M0,Y).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A),
# 	ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,
# 	B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L),
# 	ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,
# 	J), ref(O,K), ref(P,K), ref(Q,K), ref(R,K), assignment(I),
# 	sizeOf(F), ast(N,E), ast(N,H), cfg(N,S), cfg(O,T), cfg(P,
# 	U), cfg(Q,V), cfg(R,W), cfg(S,O), cfg(X,P), cfg(Y,M),
# 	cfg(Z,M), cfg(A0,Q), cfg(B0,R), compMemberAccess(N),
# 	ast(T,O), ast(S,N), ast(X,Q), ast(X,C0), ast(Y,D0),
# 	ast(Z,P), ast(Z,U), ast(A0,R), ast(A0,W), ast(B0,E0),
# 	ast(B0,F0), cfg(T,F0), cfg(U,Z), cfg(V,G0), cfg(W,A0),
# 	cfg(Z,H0), cfg(C0,X), cfg(D0,Y), ref(I0,B0), assignment(X),
# 	assignment(A0), ast(C0,G0), ast(D0,H0), ast(E0,K), ast(E0,
# 	X), ast(E0,A0), ast(E0,J0), ast(E0,K0), ast(G0,V), cfg(G0,
# 	C0), cfg(H0,D0), alloc(G0), ast(J0,A), ast(J0,I), ast(J0,
# 	J), ast(J0,T), ast(J0,S), ast(K0,Z), ast(K0,L0), ast(L0,
# 	Y).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [C:5,8,4,0 bug(A) :- writeToPointer(A).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,J), ref(O,K), ref(P,K), ref(Q,K), ref(R,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,S), cfg(O,T), cfg(P,U), cfg(Q,V), cfg(R,W), cfg(S,O), cfg(X,Q), cfg(Y,P), cfg(Z,M), cfg(A0,M), cfg(B0,R), compMemberAccess(N), ast(S,N), ast(T,O), ast(X,R), ast(X,W), ast(Y,Q), ast(Y,C0), ast(Z,D0), ast(A0,P), ast(A0,U), ast(B0,E0), ast(B0,F0), cfg(V,G0), cfg(U,A0), cfg(T,F0), cfg(W,X), cfg(A0,H0), cfg(D0,Z), cfg(C0,Y), ref(I0,B0), assignment(X), assignment(Y), ast(D0,H0), ast(C0,G0), ast(C0,J0), ast(E0,K), ast(E0,X), ast(E0,Y), ast(E0,K0), ast(E0,L0), ast(G0,V), cfg(G0,C0), cfg(H0,D0), alloc(G0), ast(K0,A), ast(K0,I), ast(K0,J), ast(K0,S), ast(K0,T), ast(L0,A0), ast(L0,M0), ast(M0,Z).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,
# 	F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B),
# 	cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,
# 	M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,J),
# 	ref(O,K), ref(P,K), ref(Q,K), ref(R,K), assignment(I),
# 	sizeOf(F), ast(N,E), ast(N,H), cfg(N,S), cfg(O,T), cfg(P,
# 	U), cfg(Q,V), cfg(R,W), cfg(S,O), cfg(X,Q), cfg(Y,P),
# 	cfg(Z,M), cfg(A0,M), cfg(B0,R), compMemberAccess(N),
# 	ast(S,N), ast(T,O), ast(X,R), ast(X,W), ast(Y,Q), ast(Y,
# 	C0), ast(Z,D0), ast(A0,P), ast(A0,U), ast(B0,E0), ast(B0,
# 	F0), cfg(V,G0), cfg(U,A0), cfg(T,F0), cfg(W,X), cfg(A0,
# 	H0), cfg(D0,Z), cfg(C0,Y), ref(I0,B0), assignment(X),
# 	assignment(Y), ast(D0,H0), ast(C0,G0), ast(E0,K), ast(E0,
# 	X), ast(E0,Y), ast(E0,J0), ast(E0,K0), ast(G0,V), cfg(G0,
# 	C0), cfg(H0,D0), alloc(G0), ast(J0,A), ast(J0,I), ast(J0,
# 	J), ast(J0,S), ast(J0,T), ast(K0,A0), ast(K0,L0), ast(L0,
# 	Z).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [6 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,O), cfg(U,P), cfg(V,M), compMemberAccess(N), ast(Q,N), ast(U,W), ast(U,X), ast(V,O), ast(V,Y), cfg(R,Z), cfg(S,A0), cfg(Q,X), cfg(Y,V), cfg(A0,T), ref(B0,U), assignment(V), ast(Y,Z), ast(Y,C0), ast(W,K), ast(W,T), ast(W,V), ast(W,A0), ast(W,D0), ast(W,E0), ast(Z,R), ast(A0,P), ast(A0,S), cfg(Z,Y), assignment(A0), alloc(Z), ast(D0,A), ast(D0,I), ast(D0,J), ast(D0,Q).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A),
# 	ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,
# 	B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L),
# 	ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,
# 	J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,O),
# 	cfg(U,P), cfg(V,M), compMemberAccess(N), ast(Q,N), ast(U,
# 	W), ast(U,X), ast(V,O), ast(V,Y), cfg(R,Z), cfg(S,A0),
# 	cfg(Q,X), cfg(Y,V), cfg(A0,T), ref(B0,U), assignment(V),
# 	ast(Y,Z), ast(W,K), ast(W,T), ast(W,V), ast(W,A0), ast(W,
# 	C0), ast(Z,R), ast(A0,P), ast(A0,S), cfg(Z,Y), assignment(A0),
# 	alloc(Z), ast(C0,A), ast(C0,I), ast(C0,J), ast(C0,Q).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [C:5,8,4,0 bug(A) :- writeToPointer(A).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62901_id_121_f_memmove_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62901_id_121_f_memmove_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M), cfg(U,M), cfg(U,O), cfg(V,P), compMemberAccess(N), ast(Q,N), ast(T,O), ast(T,W), ast(V,X), ast(V,Y), cfg(S,Z), cfg(R,A0), cfg(Q,Y), cfg(W,T), cfg(Z,U), ref(B0,V), assignment(T), ast(X,K), ast(X,Z), ast(X,C0), ast(X,D0), ast(W,A0), ast(W,E0), ast(Z,P), ast(Z,S), ast(A0,R), cfg(A0,W), assignment(Z), alloc(A0), ast(C0,A), ast(C0,I), ast(C0,J), ast(C0,Q), ast(D0,U), ast(D0,F0), ast(F0,T).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A),
# 	ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,
# 	B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L),
# 	ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,
# 	J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M),
# 	cfg(U,M), cfg(U,O), cfg(V,P), compMemberAccess(N), ast(Q,
# 	N), ast(T,O), ast(T,W), ast(V,X), ast(V,Y), cfg(S,Z),
# 	cfg(R,A0), cfg(Q,Y), cfg(W,T), cfg(Z,U), ref(B0,V),
# 	assignment(T), ast(X,K), ast(X,Z), ast(X,C0), ast(X,D0),
# 	ast(W,A0), ast(Z,P), ast(Z,S), ast(A0,R), cfg(A0,W),
# 	assignment(Z), alloc(A0), ast(C0,A), ast(C0,I), ast(C0,
# 	J), ast(C0,Q), ast(D0,U), ast(D0,E0), ast(E0,T).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [C:5,8,4,0 bug(A) :- writeToPointer(A).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,P), cfg(U,O), cfg(V,M), compMemberAccess(N), ast(Q,N), ast(T,W), ast(T,X), ast(U,P), ast(U,S), ast(V,O), ast(V,Y), cfg(S,U), cfg(Q,X), cfg(R,Z), cfg(Y,V), ref(A0,T), assignment(U), assignment(V), ast(W,K), ast(W,U), ast(W,V), ast(W,B0), ast(Y,Z), ast(Y,C0), ast(Z,R), cfg(Z,Y), alloc(Z), ast(B0,A), ast(B0,I), ast(B0,J), ast(B0,Q).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A),
# 	ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,
# 	B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L),
# 	ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,
# 	J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,P),
# 	cfg(U,O), cfg(V,M), compMemberAccess(N), ast(Q,N), ast(T,
# 	W), ast(T,X), ast(U,P), ast(U,S), ast(V,O), ast(V,Y),
# 	cfg(S,U), cfg(Q,X), cfg(R,Z), cfg(Y,V), ref(A0,T), assignment(U),
# 	assignment(V), ast(W,K), ast(W,U), ast(W,V), ast(W,B0),
# 	ast(Y,Z), ast(Z,R), cfg(Z,Y), alloc(Z), ast(B0,A), ast(B0,
# 	I), ast(B0,J), ast(B0,Q).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [C:5,8,4,0 bug(A) :- writeToPointer(A).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M), cfg(U,P), cfg(V,O), compMemberAccess(N), ast(Q,N), ast(T,O), ast(T,W), ast(U,X), ast(U,Y), cfg(S,Z), cfg(R,A0), cfg(Q,Y), cfg(W,T), cfg(Z,V), ref(B0,U), assignment(T), ast(W,A0), ast(W,C0), ast(X,K), ast(X,T), ast(X,V), ast(X,Z), ast(X,D0), ast(X,E0), ast(A0,R), ast(Z,P), ast(Z,S), cfg(A0,W), assignment(Z), alloc(A0), ast(D0,A), ast(D0,I), ast(D0,J), ast(D0,Q).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,
# 	F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B),
# 	cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,
# 	M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,J),
# 	ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M),
# 	cfg(U,P), cfg(V,O), compMemberAccess(N), ast(Q,N), ast(T,
# 	O), ast(T,W), ast(U,X), ast(U,Y), cfg(S,Z), cfg(R,A0),
# 	cfg(Q,Y), cfg(W,T), cfg(Z,V), ref(B0,U), assignment(T),
# 	ast(W,A0), ast(X,K), ast(X,T), ast(X,V), ast(X,Z), ast(X,
# 	C0), ast(A0,R), ast(Z,P), ast(Z,S), cfg(A0,W), assignment(Z),
# 	alloc(A0), ast(C0,A), ast(C0,I), ast(C0,J), ast(C0,Q).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [6 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M), cfg(U,M), cfg(U,O), cfg(V,P), compMemberAccess(N), ast(Q,N), ast(T,O), ast(T,W), ast(U,X), ast(U,Y), ast(V,Z), ast(V,A0), cfg(S,B0), cfg(R,C0), cfg(Q,A0), cfg(X,U), cfg(W,T), ref(D0,V), assignment(T), ast(Z,K), ast(Z,B0), ast(Z,E0), ast(Z,F0), ast(W,C0), ast(W,G0), ast(B0,P), ast(B0,S), ast(C0,R), cfg(Y,X), cfg(B0,Y), cfg(C0,W), assignment(B0), alloc(C0), ast(E0,A), ast(E0,I), ast(E0,J), ast(E0,Q), ast(F0,U), ast(F0,H0), ast(H0,T).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,
# 	F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B),
# 	cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,
# 	M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J),
# 	ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M),
# 	cfg(U,M), cfg(U,O), cfg(V,P), compMemberAccess(N), ast(Q,
# 	N), ast(T,O), ast(T,W), ast(U,X), ast(U,Y), ast(V,Z),
# 	ast(V,A0), cfg(S,B0), cfg(R,C0), cfg(Q,A0), cfg(X,U),
# 	cfg(W,T), ref(D0,V), assignment(T), ast(Z,K), ast(Z,
# 	B0), ast(Z,E0), ast(Z,F0), ast(W,C0), ast(B0,P), ast(B0,
# 	S), ast(C0,R), cfg(Y,X), cfg(B0,Y), cfg(C0,W), assignment(B0),
# 	alloc(C0), ast(E0,A), ast(E0,I), ast(E0,J), ast(E0,Q),
# 	ast(F0,U), ast(F0,G0), ast(G0,T).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [6 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,P), cfg(U,M), cfg(U,O), cfg(V,M), compMemberAccess(N), ast(Q,N), ast(T,W), ast(T,X), ast(V,O), ast(V,Y), cfg(S,Z), cfg(R,A0), cfg(Q,X), cfg(Y,V), cfg(Z,U), ref(B0,T), assignment(V), ast(Y,A0), ast(Y,C0), ast(W,K), ast(W,Z), ast(W,D0), ast(W,E0), ast(A0,R), ast(Z,P), ast(Z,S), cfg(A0,Y), assignment(Z), alloc(A0), ast(D0,A), ast(D0,I), ast(D0,J), ast(D0,Q), ast(E0,U), ast(E0,F0), ast(F0,V).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,
# 	F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B),
# 	cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,
# 	M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,J),
# 	ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,P),
# 	cfg(U,M), cfg(U,O), cfg(V,M), compMemberAccess(N), ast(Q,
# 	N), ast(T,W), ast(T,X), ast(V,O), ast(V,Y), cfg(S,Z),
# 	cfg(R,A0), cfg(Q,X), cfg(Y,V), cfg(Z,U), ref(B0,T),
# 	assignment(V), ast(Y,A0), ast(W,K), ast(W,Z), ast(W,C0),
# 	ast(W,D0), ast(A0,R), ast(Z,P), ast(Z,S), cfg(A0,Y),
# 	assignment(Z), alloc(A0), ast(C0,A), ast(C0,I), ast(C0,
# 	J), ast(C0,Q), ast(D0,U), ast(D0,E0), ast(E0,V).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [6 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,O), cfg(U,M), cfg(V,P), compMemberAccess(N), ast(Q,N), ast(T,P), ast(T,S), ast(U,O), ast(U,W), ast(V,X), ast(V,Y), cfg(Q,Y), cfg(R,Z), cfg(S,T), cfg(W,U), ref(A0,V), assignment(T), assignment(U), ast(W,Z), ast(W,B0), ast(X,K), ast(X,T), ast(X,U), ast(X,C0), ast(Z,R), cfg(Z,W), alloc(Z), ast(C0,A), ast(C0,I), ast(C0,J), ast(C0,Q).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,
# 	F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B),
# 	cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,
# 	M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J),
# 	ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,O),
# 	cfg(U,M), cfg(V,P), compMemberAccess(N), ast(Q,N), ast(T,
# 	P), ast(T,S), ast(U,O), ast(U,W), ast(V,X), ast(V,Y),
# 	cfg(Q,Y), cfg(R,Z), cfg(S,T), cfg(W,U), ref(A0,V), assignment(T),
# 	assignment(U), ast(W,Z), ast(X,K), ast(X,T), ast(X,U),
# 	ast(X,B0), ast(Z,R), cfg(Z,W), alloc(Z), ast(B0,A),
# 	ast(B0,I), ast(B0,J), ast(B0,Q).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [6 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62804_id_111_f_loop_01_c_l_32_c_12_).]
# [Generalising <bug(bad_62804_id_111_f_loop_01_c_l_32_c_12_).>]
# bug(A) :- ast(A,B), ast(A,C), cfg(A,D), cfg(B,A), assignment(A), ast(B,E), ast(B,F), ast(C,G), ast(C,H), cfg(C,F), cfg(D,I), cfg(G,C), cfg(E,B), ref(D,J), compMemberAccess(B), compMemberAccess(C), ast(I,D), cfg(H,G), cfg(F,E), cfg(I,K), cfg(L,H), ref(G,J), ref(H,M), ref(E,J), ref(F,N), ref(K,J), ref(O,J), ast(L,K), ast(L,P), cfg(K,P), cfg(L,Q), cfg(O,R), cfg(P,L), cfg(S,O), cfg(T,K), ref(Q,M), ref(U,M), ref(V,M), ref(W,N), ast(S,W), ast(T,O), ast(T,R), cfg(R,T), cfg(Q,X), cfg(U,Y), cfg(V,Z), cfg(W,S), cfg(A0,U), cfg(B0,W), cfg(C0,V), assignment(S), assignment(T), ast(A0,V), ast(A0,Z), ast(B0,U), ast(B0,D0), ast(C0,E0), ast(C0,F0), cfg(Y,G0), cfg(X,H0), cfg(Z,A0), cfg(D0,B0), ref(I0,C0), assignment(A0), assignment(B0), ast(E0,M), ast(E0,A0), ast(E0,B0), ast(E0,J0), ast(D0,G0), ast(D0,K0), ast(G0,Y), ast(H0,Q), ast(H0,X), cfg(G0,D0), cfg(H0,L0), cfg(L0,F0), compMemberAccess(H0), alloc(G0), ast(J0,J), ast(J0,N), ast(J0,S), ast(J0,L0), ast(J0,M0), ast(L0,H0), ast(M0,I), ast(M0,L), ast(M0,T), ast(M0,N0), ast(N0,A).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), cfg(A,D), cfg(B,A), assignment(A),
# 	ast(B,E), ast(B,F), ast(C,G), ast(C,H), cfg(C,F), cfg(D,
# 	I), cfg(G,C), cfg(E,B), ref(D,J), compMemberAccess(B),
# 	compMemberAccess(C), ast(I,D), cfg(H,G), cfg(F,E), cfg(I,
# 	K), cfg(L,H), ref(G,J), ref(H,M), ref(E,J), ref(F,N),
# 	ref(K,J), ref(O,J), ast(L,K), ast(L,P), cfg(K,P), cfg(L,
# 	Q), cfg(O,R), cfg(P,L), cfg(S,O), cfg(T,K), ref(Q,M),
# 	ref(U,M), ref(V,M), ref(W,N), ast(S,W), ast(T,O), ast(T,
# 	R), cfg(R,T), cfg(Q,X), cfg(U,Y), cfg(V,Z), cfg(W,S),
# 	cfg(A0,U), cfg(B0,W), cfg(C0,V), assignment(S), assignment(T),
# 	ast(A0,V), ast(A0,Z), ast(B0,U), ast(B0,D0), ast(C0,
# 	E0), ast(C0,F0), cfg(Y,G0), cfg(X,H0), cfg(Z,A0), cfg(D0,
# 	B0), ref(I0,C0), assignment(A0), assignment(B0), ast(E0,
# 	M), ast(E0,A0), ast(E0,B0), ast(E0,J0), ast(D0,G0), ast(G0,
# 	Y), ast(H0,Q), ast(H0,X), cfg(G0,D0), cfg(H0,K0), cfg(K0,
# 	F0), compMemberAccess(H0), alloc(G0), ast(J0,J), ast(J0,
# 	N), ast(J0,S), ast(J0,K0), ast(J0,L0), ast(K0,H0), ast(L0,
# 	I), ast(L0,L), ast(L0,T), ast(L0,M0), ast(M0,A).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [5 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
#
# [Total time taken 2.997s]

# %% [markdown]
# ## High-level Rules
#
# As we add more examples, Progol is able to learn more complex rules. However, the long rules can become noisy, and make it much harder to find rules which apply generally. In this section we try to add a bunch of rules which give Progol the opportunity to compress its rules into smaller, normalised forms.
#
# First, we add the `runs_before` relation, which should compress and normalise many CFG relations. For example, if ILP had found the following two rules:
#
#   1. `bug(A) :- writeToPointer(A), cfg(A,B), cfg(B,C), cfg(C,D), alloc(D).`
#   2. `bug(A) :- writeToPointer(A), cfg(A,B), alloc(B).`
#
# It may not be able to reconcile them. But, we (the humans) know that it doesn't really matter that there were three cfg edges instead of one, we only care that the allocation happened before the `writeToPointer`.

# %%
header = """
% Settings
:- set(c,10)?
:- set(i,10)?
:- set(h,1000)?
:- set(cover)?
:- set(inflate,200)?

% Mode declarations
:- modeh(*, bug(+node))?

:- modeb(*, ast(+node,-node))?

:- modeb(*, ref(+node,-node))?
:- modeb(*, ref(-node,+node))?

:- modeb(*, assignment(+node))?
:- modeb(*, compMemberAccess(+node))?
:- modeb(*, sizeOf(+node))?
:- modeb(*, malloc(+node))?
:- modeb(*, alloc(+node))?
:- modeb(*, writeToPointer(+node))?

:- modeb(10, runs_before(+node, -node))?

runs_before(A,C) :- cfg(A,B), runs_before(B,C).
runs_before(A,C) :- cfg(A,B), cfg(B,C).
"""

script = make_progol_script(header, {
    62804,
    62852,
    62853,
    62854,
    62869,
    62900,
    62901,
    62917,
    232012,
    232086,
})
with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,10)? - Time taken 0.00s]
# [:- set(i,10)? - Time taken 0.00s]
# [:- set(h,1000)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,200)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ast(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,assignment(+node))? - Time taken 0.00s]
# [:- modeb(100,compMemberAccess(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,malloc(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [:- modeb(10,runs_before(+node,-node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232086_id_146_f_memmove_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232086_id_146_f_memmove_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), runs_before(A,I), runs_before(A,J), ast(B,K), ast(B,L), ast(F,G), ast(H,I), ast(I,J), ast(I,M), ref(C,N), ref(D,O), ref(G,O), compMemberAccess(I), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,I), runs_before(B,J), runs_before(B,M), runs_before(C,A), runs_before(C,B), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,I), runs_before(C,J), runs_before(C,K), runs_before(C,M), runs_before(D,A), runs_before(D,B), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,I), runs_before(D,J), runs_before(D,K), runs_before(D,M), runs_before(G,E), runs_before(H,E), runs_before(H,F), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), ast(K,P), ref(M,O), ref(Q,N), ref(R,O), ref(S,O), ref(T,O), sizeOf(K), runs_before(K,A), runs_before(K,E), runs_before(K,F), runs_before(K,G), runs_before(K,H), runs_before(K,I), runs_before(K,J), runs_before(K,M), runs_before(L,A), runs_before(L,B), runs_before(L,E), runs_before(L,F), runs_before(L,G), runs_before(L,H), runs_before(L,I), runs_before(L,J), runs_before(L,K), runs_before(L,M), runs_before(M,E), runs_before(M,F), runs_before(M,G), runs_before(M,H), runs_before(M,I), runs_before(P,A), runs_before(P,B), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,I), runs_before(P,J), runs_before(P,M), runs_before(Q,A), runs_before(Q,B), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,I), runs_before(Q,J), runs_before(Q,K), runs_before(Q,M), runs_before(R,A), runs_before(R,B), runs_before(R,E), runs_before(R,F), runs_before(R,G), runs_before(R,H), runs_before(R,I), runs_before(R,J), runs_before(R,K), runs_before(R,M), runs_before(S,A), runs_before(S,B), runs_before(S,E), runs_before(S,F), runs_before(S,G), runs_before(S,H), runs_before(S,I), runs_before(S,J), runs_before(S,K), runs_before(S,M), runs_before(T,A), runs_before(T,B), runs_before(T,E), runs_before(T,F), runs_before(T,G), runs_before(T,H), runs_before(T,I), runs_before(T,J), runs_before(T,K), runs_before(T,M).
# [Most-specific clause reduced by 56 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), runs_before(A,
# 	D), runs_before(A,E), runs_before(A,F), runs_before(A,
# 	G), runs_before(A,H), runs_before(A,I), ast(B,J), ast(B,
# 	K), ast(E,F), ast(G,H), ast(H,I), ast(H,L), ref(C,M),
# 	ref(F,M), compMemberAccess(H), runs_before(B,D), runs_before(B,
# 	E), runs_before(B,F), runs_before(B,G), runs_before(B,
# 	H), runs_before(B,I), runs_before(B,L), runs_before(C,
# 	A), runs_before(C,B), runs_before(C,D), runs_before(C,
# 	E), runs_before(C,F), runs_before(C,G), runs_before(C,
# 	H), runs_before(C,I), runs_before(C,J), runs_before(C,
# 	L), runs_before(F,D), runs_before(G,D), runs_before(G,
# 	E), runs_before(H,D), runs_before(H,E), runs_before(H,
# 	F), runs_before(I,D), runs_before(I,E), runs_before(I,
# 	F), runs_before(I,G), ast(J,N), ref(L,M), sizeOf(J),
# 	runs_before(J,A), runs_before(J,D), runs_before(J,E),
# 	runs_before(J,F), runs_before(J,G), runs_before(J,H),
# 	runs_before(J,I), runs_before(J,L), runs_before(K,A),
# 	runs_before(K,B), runs_before(K,D), runs_before(K,E),
# 	runs_before(K,F), runs_before(K,G), runs_before(K,H),
# 	runs_before(K,I), runs_before(K,J), runs_before(K,L),
# 	runs_before(L,D), runs_before(L,E), runs_before(L,F),
# 	runs_before(L,G), runs_before(L,H), runs_before(N,A),
# 	runs_before(N,B), runs_before(N,D), runs_before(N,E),
# 	runs_before(N,F), runs_before(N,G), runs_before(N,H),
# 	runs_before(N,I), runs_before(N,L).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:5,8,4,0 bug(A) :- writeToPointer(A).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [10 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), runs_before(A,I), runs_before(A,J), ast(B,K), ast(B,L), ast(F,G), ast(H,I), ast(I,J), ast(I,M), ref(C,N), ref(D,O), ref(G,O), compMemberAccess(I), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,I), runs_before(B,J), runs_before(B,M), runs_before(C,A), runs_before(C,B), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,I), runs_before(C,J), runs_before(C,M), runs_before(C,K), runs_before(D,A), runs_before(D,B), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,I), runs_before(D,J), runs_before(D,M), runs_before(D,K), runs_before(G,E), runs_before(H,E), runs_before(H,F), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), ast(K,P), ref(M,O), ref(Q,O), ref(R,O), ref(S,O), ref(T,N), sizeOf(K), runs_before(M,E), runs_before(M,F), runs_before(M,G), runs_before(M,H), runs_before(M,I), runs_before(K,A), runs_before(K,E), runs_before(K,F), runs_before(K,G), runs_before(K,H), runs_before(K,I), runs_before(K,J), runs_before(K,M), runs_before(L,A), runs_before(L,B), runs_before(L,E), runs_before(L,F), runs_before(L,G), runs_before(L,H), runs_before(L,I), runs_before(L,J), runs_before(L,M), runs_before(L,K), runs_before(P,A), runs_before(P,B), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,I), runs_before(P,J), runs_before(P,M), runs_before(Q,A), runs_before(Q,B), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,I), runs_before(Q,J), runs_before(Q,M), runs_before(Q,K), runs_before(R,A), runs_before(R,B), runs_before(R,E), runs_before(R,F), runs_before(R,G), runs_before(R,H), runs_before(R,I), runs_before(R,J), runs_before(R,M), runs_before(R,K), runs_before(S,A), runs_before(S,B), runs_before(S,E), runs_before(S,F), runs_before(S,G), runs_before(S,H), runs_before(S,I), runs_before(S,J), runs_before(S,M), runs_before(S,K), runs_before(T,A), runs_before(T,B), runs_before(T,E), runs_before(T,F), runs_before(T,G), runs_before(T,H), runs_before(T,I), runs_before(T,J), runs_before(T,M), runs_before(T,K).
# [Most-specific clause reduced by 56 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), runs_before(A,D), runs_before(A,
# 	E), runs_before(A,F), runs_before(A,G), runs_before(A,
# 	H), runs_before(A,I), ast(B,J), ast(B,K), ast(E,F), ast(G,
# 	H), ast(H,I), ast(H,L), ref(C,M), ref(F,M), compMemberAccess(H),
# 	runs_before(B,D), runs_before(B,E), runs_before(B,F),
# 	runs_before(B,G), runs_before(B,H), runs_before(B,I),
# 	runs_before(B,L), runs_before(C,A), runs_before(C,B),
# 	runs_before(C,D), runs_before(C,E), runs_before(C,F),
# 	runs_before(C,G), runs_before(C,H), runs_before(C,I),
# 	runs_before(C,L), runs_before(C,J), runs_before(F,D),
# 	runs_before(G,D), runs_before(G,E), runs_before(H,D),
# 	runs_before(H,E), runs_before(H,F), runs_before(I,D),
# 	runs_before(I,E), runs_before(I,F), runs_before(I,G),
# 	ast(J,N), ref(L,M), sizeOf(J), runs_before(L,D), runs_before(L,
# 	E), runs_before(L,F), runs_before(L,G), runs_before(L,
# 	H), runs_before(J,A), runs_before(J,D), runs_before(J,
# 	E), runs_before(J,F), runs_before(J,G), runs_before(J,
# 	H), runs_before(J,I), runs_before(J,L), runs_before(K,
# 	A), runs_before(K,B), runs_before(K,D), runs_before(K,
# 	E), runs_before(K,F), runs_before(K,G), runs_before(K,
# 	H), runs_before(K,I), runs_before(K,L), runs_before(K,
# 	J), runs_before(N,A), runs_before(N,B), runs_before(N,
# 	D), runs_before(N,E), runs_before(N,F), runs_before(N,
# 	G), runs_before(N,H), runs_before(N,I), runs_before(N,
# 	L).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [9 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), ast(B,I), ast(B,J), ast(F,G), ast(G,H), ast(G,K), ref(C,L), ref(D,M), compMemberAccess(G), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,K), runs_before(C,A), runs_before(C,B), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,I), runs_before(C,K), runs_before(C,N), runs_before(D,A), runs_before(D,B), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,I), runs_before(D,J), runs_before(D,K), runs_before(D,N), runs_before(G,E), runs_before(H,E), runs_before(H,F), ast(I,N), ref(K,M), ref(O,L), ref(P,M), ref(Q,M), sizeOf(I), runs_before(I,A), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(I,H), runs_before(I,K), runs_before(J,A), runs_before(J,B), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), runs_before(J,I), runs_before(J,K), runs_before(K,E), runs_before(K,F), runs_before(K,G), runs_before(N,A), runs_before(N,B), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,K), runs_before(O,A), runs_before(O,B), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,I), runs_before(O,J), runs_before(O,K), runs_before(O,N), runs_before(P,A), runs_before(P,B), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,I), runs_before(P,J), runs_before(P,K), runs_before(P,N), runs_before(Q,A), runs_before(Q,B), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,I), runs_before(Q,J), runs_before(Q,K), runs_before(Q,N).
# [Most-specific clause reduced by 44 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), runs_before(A,
# 	D), runs_before(A,E), runs_before(A,F), runs_before(A,
# 	G), ast(B,H), ast(B,I), ast(E,F), ast(F,G), ast(F,J),
# 	ref(C,K), compMemberAccess(F), runs_before(B,D), runs_before(B,
# 	E), runs_before(B,F), runs_before(B,G), runs_before(B,
# 	J), runs_before(C,A), runs_before(C,B), runs_before(C,
# 	D), runs_before(C,E), runs_before(C,F), runs_before(C,
# 	G), runs_before(C,H), runs_before(C,I), runs_before(C,
# 	J), runs_before(C,L), runs_before(F,D), runs_before(G,
# 	D), runs_before(G,E), ast(H,L), ref(J,K), sizeOf(H),
# 	runs_before(H,A), runs_before(H,D), runs_before(H,E),
# 	runs_before(H,F), runs_before(H,G), runs_before(H,J),
# 	runs_before(I,A), runs_before(I,B), runs_before(I,D),
# 	runs_before(I,E), runs_before(I,F), runs_before(I,G),
# 	runs_before(I,H), runs_before(I,J), runs_before(J,D),
# 	runs_before(J,E), runs_before(J,F), runs_before(L,A),
# 	runs_before(L,B), runs_before(L,D), runs_before(L,E),
# 	runs_before(L,F), runs_before(L,G), runs_before(L,J).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:5,8,4,0 bug(A) :- writeToPointer(A).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [8 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62901_id_121_f_memmove_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62901_id_121_f_memmove_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), ast(B,I), ast(B,J), ast(F,G), ast(G,H), ast(G,K), ref(C,L), ref(D,M), compMemberAccess(G), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,K), runs_before(C,A), runs_before(C,B), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,I), runs_before(C,K), runs_before(C,N), runs_before(D,A), runs_before(D,B), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,I), runs_before(D,J), runs_before(D,K), runs_before(D,N), runs_before(G,E), runs_before(H,E), runs_before(H,F), ast(I,N), ref(K,M), ref(O,M), ref(P,M), ref(Q,L), sizeOf(I), runs_before(I,A), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(I,H), runs_before(I,K), runs_before(J,A), runs_before(J,B), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), runs_before(J,I), runs_before(J,K), runs_before(K,E), runs_before(K,F), runs_before(K,G), runs_before(N,A), runs_before(N,B), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,K), runs_before(O,A), runs_before(O,B), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,I), runs_before(O,J), runs_before(O,K), runs_before(O,N), runs_before(P,A), runs_before(P,B), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,I), runs_before(P,J), runs_before(P,K), runs_before(P,N), runs_before(Q,A), runs_before(Q,B), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,I), runs_before(Q,J), runs_before(Q,K), runs_before(Q,N).
# [Most-specific clause reduced by 44 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), runs_before(A,
# 	D), runs_before(A,E), runs_before(A,F), runs_before(A,
# 	G), ast(B,H), ast(B,I), ast(E,F), ast(F,G), ast(F,J),
# 	ref(C,K), compMemberAccess(F), runs_before(B,D), runs_before(B,
# 	E), runs_before(B,F), runs_before(B,G), runs_before(B,
# 	J), runs_before(C,A), runs_before(C,B), runs_before(C,
# 	D), runs_before(C,E), runs_before(C,F), runs_before(C,
# 	G), runs_before(C,H), runs_before(C,I), runs_before(C,
# 	J), runs_before(C,L), runs_before(F,D), runs_before(G,
# 	D), runs_before(G,E), ast(H,L), ref(J,K), sizeOf(H),
# 	runs_before(H,A), runs_before(H,D), runs_before(H,E),
# 	runs_before(H,F), runs_before(H,G), runs_before(H,J),
# 	runs_before(I,A), runs_before(I,B), runs_before(I,D),
# 	runs_before(I,E), runs_before(I,F), runs_before(I,G),
# 	runs_before(I,H), runs_before(I,J), runs_before(J,D),
# 	runs_before(J,E), runs_before(J,F), runs_before(L,A),
# 	runs_before(L,B), runs_before(L,D), runs_before(L,E),
# 	runs_before(L,F), runs_before(L,G), runs_before(L,J).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:5,8,4,0 bug(A) :- writeToPointer(A).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [8 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), ast(B,I), ast(B,J), ast(F,G), ast(G,H), ast(G,K), ref(C,L), ref(D,M), compMemberAccess(G), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,K), runs_before(C,A), runs_before(C,B), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,K), runs_before(C,I), runs_before(C,N), runs_before(D,A), runs_before(D,B), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,K), runs_before(D,I), runs_before(D,J), runs_before(D,N), runs_before(G,E), runs_before(H,E), runs_before(H,F), ast(I,N), ref(K,M), ref(O,L), ref(P,M), ref(Q,M), sizeOf(I), runs_before(K,E), runs_before(K,F), runs_before(K,G), runs_before(I,A), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(I,H), runs_before(I,K), runs_before(J,A), runs_before(J,B), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), runs_before(J,K), runs_before(J,I), runs_before(N,A), runs_before(N,B), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,K), runs_before(O,A), runs_before(O,B), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,K), runs_before(O,I), runs_before(O,J), runs_before(O,N), runs_before(P,A), runs_before(P,B), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,K), runs_before(P,I), runs_before(P,J), runs_before(P,N), runs_before(Q,A), runs_before(Q,B), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,K), runs_before(Q,I), runs_before(Q,J), runs_before(Q,N).
# [Most-specific clause reduced by 44 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), runs_before(A,
# 	D), runs_before(A,E), runs_before(A,F), runs_before(A,
# 	G), ast(B,H), ast(B,I), ast(E,F), ast(F,G), ast(F,J),
# 	ref(C,K), compMemberAccess(F), runs_before(B,D), runs_before(B,
# 	E), runs_before(B,F), runs_before(B,G), runs_before(B,
# 	J), runs_before(C,A), runs_before(C,B), runs_before(C,
# 	D), runs_before(C,E), runs_before(C,F), runs_before(C,
# 	G), runs_before(C,J), runs_before(C,H), runs_before(C,
# 	I), runs_before(C,L), runs_before(F,D), runs_before(G,
# 	D), runs_before(G,E), ast(H,L), ref(J,K), sizeOf(H),
# 	runs_before(J,D), runs_before(J,E), runs_before(J,F),
# 	runs_before(H,A), runs_before(H,D), runs_before(H,E),
# 	runs_before(H,F), runs_before(H,G), runs_before(H,J),
# 	runs_before(I,A), runs_before(I,B), runs_before(I,D),
# 	runs_before(I,E), runs_before(I,F), runs_before(I,G),
# 	runs_before(I,J), runs_before(I,H), runs_before(L,A),
# 	runs_before(L,B), runs_before(L,D), runs_before(L,E),
# 	runs_before(L,F), runs_before(L,G), runs_before(L,J).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:5,8,4,0 bug(A) :- writeToPointer(A).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [8 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), ast(B,I), ast(B,J), ast(F,G), ast(G,H), ast(G,K), ref(C,L), ref(D,M), compMemberAccess(G), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,K), runs_before(C,A), runs_before(C,B), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,I), runs_before(C,K), runs_before(C,N), runs_before(D,A), runs_before(D,B), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,I), runs_before(D,J), runs_before(D,K), runs_before(D,N), runs_before(G,E), runs_before(H,E), runs_before(H,F), ast(I,N), ref(K,M), ref(O,M), ref(P,M), ref(Q,L), sizeOf(I), runs_before(I,A), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(I,H), runs_before(I,K), runs_before(J,A), runs_before(J,B), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), runs_before(J,I), runs_before(J,K), runs_before(K,E), runs_before(K,F), runs_before(K,G), runs_before(N,A), runs_before(N,B), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,K), runs_before(O,A), runs_before(O,B), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,I), runs_before(O,J), runs_before(O,K), runs_before(O,N), runs_before(P,A), runs_before(P,B), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,I), runs_before(P,J), runs_before(P,K), runs_before(P,N), runs_before(Q,A), runs_before(Q,B), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,I), runs_before(Q,J), runs_before(Q,K), runs_before(Q,N).
# [Most-specific clause reduced by 44 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), runs_before(A,D), runs_before(A,
# 	E), runs_before(A,F), runs_before(A,G), ast(B,H), ast(B,
# 	I), ast(E,F), ast(F,G), ast(F,J), ref(C,K), compMemberAccess(F),
# 	runs_before(B,D), runs_before(B,E), runs_before(B,F),
# 	runs_before(B,G), runs_before(B,J), runs_before(C,A),
# 	runs_before(C,B), runs_before(C,D), runs_before(C,E),
# 	runs_before(C,F), runs_before(C,G), runs_before(C,H),
# 	runs_before(C,I), runs_before(C,J), runs_before(C,L),
# 	runs_before(F,D), runs_before(G,D), runs_before(G,E),
# 	ast(H,L), ref(J,K), sizeOf(H), runs_before(H,A), runs_before(H,
# 	D), runs_before(H,E), runs_before(H,F), runs_before(H,
# 	G), runs_before(H,J), runs_before(I,A), runs_before(I,
# 	B), runs_before(I,D), runs_before(I,E), runs_before(I,
# 	F), runs_before(I,G), runs_before(I,H), runs_before(I,
# 	J), runs_before(J,D), runs_before(J,E), runs_before(J,
# 	F), runs_before(L,A), runs_before(L,B), runs_before(L,
# 	D), runs_before(L,E), runs_before(L,F), runs_before(L,
# 	G), runs_before(L,J).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), ast(B,I), ast(B,J), ast(F,G), ast(G,H), ast(G,K), ref(C,L), ref(D,M), compMemberAccess(G), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,K), runs_before(C,A), runs_before(C,B), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,I), runs_before(C,K), runs_before(C,N), runs_before(D,A), runs_before(D,B), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,I), runs_before(D,J), runs_before(D,K), runs_before(D,N), runs_before(G,E), runs_before(H,E), runs_before(H,F), ast(I,N), ref(K,M), ref(O,M), ref(P,M), ref(Q,L), sizeOf(I), runs_before(I,A), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(I,H), runs_before(I,K), runs_before(J,A), runs_before(J,B), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), runs_before(J,I), runs_before(J,K), runs_before(K,E), runs_before(K,F), runs_before(K,G), runs_before(N,A), runs_before(N,B), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,K), runs_before(O,A), runs_before(O,B), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,I), runs_before(O,J), runs_before(O,K), runs_before(O,N), runs_before(P,A), runs_before(P,B), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,I), runs_before(P,J), runs_before(P,K), runs_before(P,N), runs_before(Q,A), runs_before(Q,B), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,I), runs_before(Q,J), runs_before(Q,K), runs_before(Q,N).
# [Most-specific clause reduced by 44 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), runs_before(A,D), runs_before(A,
# 	E), runs_before(A,F), runs_before(A,G), ast(B,H), ast(B,
# 	I), ast(E,F), ast(F,G), ast(F,J), ref(C,K), compMemberAccess(F),
# 	runs_before(B,D), runs_before(B,E), runs_before(B,F),
# 	runs_before(B,G), runs_before(B,J), runs_before(C,A),
# 	runs_before(C,B), runs_before(C,D), runs_before(C,E),
# 	runs_before(C,F), runs_before(C,G), runs_before(C,H),
# 	runs_before(C,I), runs_before(C,J), runs_before(C,L),
# 	runs_before(F,D), runs_before(G,D), runs_before(G,E),
# 	ast(H,L), ref(J,K), sizeOf(H), runs_before(H,A), runs_before(H,
# 	D), runs_before(H,E), runs_before(H,F), runs_before(H,
# 	G), runs_before(H,J), runs_before(I,A), runs_before(I,
# 	B), runs_before(I,D), runs_before(I,E), runs_before(I,
# 	F), runs_before(I,G), runs_before(I,H), runs_before(I,
# 	J), runs_before(J,D), runs_before(J,E), runs_before(J,
# 	F), runs_before(L,A), runs_before(L,B), runs_before(L,
# 	D), runs_before(L,E), runs_before(L,F), runs_before(L,
# 	G), runs_before(L,J).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), ast(B,I), ast(B,J), ast(F,G), ast(G,H), ast(G,K), ref(C,L), ref(D,M), compMemberAccess(G), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,K), runs_before(C,A), runs_before(C,B), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,I), runs_before(C,K), runs_before(C,N), runs_before(D,A), runs_before(D,B), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,I), runs_before(D,J), runs_before(D,K), runs_before(D,N), runs_before(G,E), runs_before(H,E), runs_before(H,F), ast(I,N), ref(K,M), ref(O,L), ref(P,M), ref(Q,M), sizeOf(I), runs_before(I,A), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(I,H), runs_before(I,K), runs_before(J,A), runs_before(J,B), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), runs_before(J,I), runs_before(J,K), runs_before(K,E), runs_before(K,F), runs_before(K,G), runs_before(N,A), runs_before(N,B), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,K), runs_before(O,A), runs_before(O,B), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,I), runs_before(O,J), runs_before(O,K), runs_before(O,N), runs_before(P,A), runs_before(P,B), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,I), runs_before(P,J), runs_before(P,K), runs_before(P,N), runs_before(Q,A), runs_before(Q,B), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,I), runs_before(Q,J), runs_before(Q,K), runs_before(Q,N).
# [Most-specific clause reduced by 44 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), runs_before(A,D), runs_before(A,
# 	E), runs_before(A,F), runs_before(A,G), ast(B,H), ast(B,
# 	I), ast(E,F), ast(F,G), ast(F,J), ref(C,K), compMemberAccess(F),
# 	runs_before(B,D), runs_before(B,E), runs_before(B,F),
# 	runs_before(B,G), runs_before(B,J), runs_before(C,A),
# 	runs_before(C,B), runs_before(C,D), runs_before(C,E),
# 	runs_before(C,F), runs_before(C,G), runs_before(C,H),
# 	runs_before(C,I), runs_before(C,J), runs_before(C,L),
# 	runs_before(F,D), runs_before(G,D), runs_before(G,E),
# 	ast(H,L), ref(J,K), sizeOf(H), runs_before(H,A), runs_before(H,
# 	D), runs_before(H,E), runs_before(H,F), runs_before(H,
# 	G), runs_before(H,J), runs_before(I,A), runs_before(I,
# 	B), runs_before(I,D), runs_before(I,E), runs_before(I,
# 	F), runs_before(I,G), runs_before(I,H), runs_before(I,
# 	J), runs_before(J,D), runs_before(J,E), runs_before(J,
# 	F), runs_before(L,A), runs_before(L,B), runs_before(L,
# 	D), runs_before(L,E), runs_before(L,F), runs_before(L,
# 	G), runs_before(L,J).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), ast(B,I), ast(B,J), ast(F,G), ast(G,H), ast(G,K), ref(C,L), ref(D,M), compMemberAccess(G), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,K), runs_before(C,A), runs_before(C,B), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,K), runs_before(C,I), runs_before(C,N), runs_before(D,A), runs_before(D,B), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,K), runs_before(D,I), runs_before(D,J), runs_before(D,N), runs_before(G,E), runs_before(H,E), runs_before(H,F), ast(I,N), ref(K,M), ref(O,L), ref(P,M), ref(Q,M), sizeOf(I), runs_before(K,E), runs_before(K,F), runs_before(K,G), runs_before(I,A), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(I,H), runs_before(I,K), runs_before(J,A), runs_before(J,B), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), runs_before(J,K), runs_before(J,I), runs_before(N,A), runs_before(N,B), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,K), runs_before(O,A), runs_before(O,B), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,K), runs_before(O,I), runs_before(O,J), runs_before(O,N), runs_before(P,A), runs_before(P,B), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,K), runs_before(P,I), runs_before(P,J), runs_before(P,N), runs_before(Q,A), runs_before(Q,B), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,K), runs_before(Q,I), runs_before(Q,J), runs_before(Q,N).
# [Most-specific clause reduced by 44 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), runs_before(A,D), runs_before(A,
# 	E), runs_before(A,F), runs_before(A,G), ast(B,H), ast(B,
# 	I), ast(E,F), ast(F,G), ast(F,J), ref(C,K), compMemberAccess(F),
# 	runs_before(B,D), runs_before(B,E), runs_before(B,F),
# 	runs_before(B,G), runs_before(B,J), runs_before(C,A),
# 	runs_before(C,B), runs_before(C,D), runs_before(C,E),
# 	runs_before(C,F), runs_before(C,G), runs_before(C,J),
# 	runs_before(C,H), runs_before(C,I), runs_before(C,L),
# 	runs_before(F,D), runs_before(G,D), runs_before(G,E),
# 	ast(H,L), ref(J,K), sizeOf(H), runs_before(J,D), runs_before(J,
# 	E), runs_before(J,F), runs_before(H,A), runs_before(H,
# 	D), runs_before(H,E), runs_before(H,F), runs_before(H,
# 	G), runs_before(H,J), runs_before(I,A), runs_before(I,
# 	B), runs_before(I,D), runs_before(I,E), runs_before(I,
# 	F), runs_before(I,G), runs_before(I,J), runs_before(I,
# 	H), runs_before(L,A), runs_before(L,B), runs_before(L,
# 	D), runs_before(L,E), runs_before(L,F), runs_before(L,
# 	G), runs_before(L,J).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62804_id_111_f_loop_01_c_l_32_c_12_).]
# [Generalising <bug(bad_62804_id_111_f_loop_01_c_l_32_c_12_).>]
# bug(A) :- ast(A,B), ast(A,C), assignment(A), runs_before(A,D), runs_before(A,E), runs_before(A,F), ast(B,G), ast(B,H), ast(C,I), ast(C,J), ast(E,F), ast(F,K), ast(F,L), compMemberAccess(B), compMemberAccess(C), compMemberAccess(F), runs_before(B,D), runs_before(B,E), runs_before(B,F), runs_before(C,D), runs_before(C,E), runs_before(C,F), runs_before(F,D), ref(L,M), ref(I,N), ref(J,M), ref(G,N), ref(H,O), runs_before(K,D), runs_before(K,E), runs_before(L,D), runs_before(L,E), runs_before(L,F), runs_before(I,D), runs_before(I,E), runs_before(I,F), runs_before(J,D), runs_before(J,E), runs_before(J,F), runs_before(G,D), runs_before(G,E), runs_before(G,F), runs_before(H,D), runs_before(H,E), runs_before(H,F), ref(P,M), ref(Q,M), ref(R,N), ref(S,N), ref(T,N), ref(U,O), runs_before(P,D), runs_before(P,E), runs_before(P,F), runs_before(Q,D), runs_before(Q,E), runs_before(Q,F), runs_before(R,D), runs_before(R,E), runs_before(R,F), runs_before(S,D), runs_before(S,E), runs_before(S,F), runs_before(T,D), runs_before(T,E), runs_before(T,F), runs_before(U,D), runs_before(U,E), runs_before(U,F).
# [Most-specific clause reduced by 47 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), assignment(A), runs_before(A,C), runs_before(A,
# 	D), runs_before(A,E), ast(B,F), ast(D,E), ast(E,G), compMemberAccess(B),
# 	compMemberAccess(E), runs_before(B,C), runs_before(B,
# 	D), runs_before(B,E), runs_before(E,C), ref(G,H), ref(F,
# 	H), runs_before(G,C), runs_before(G,D), runs_before(G,
# 	E), runs_before(F,C), runs_before(F,D), runs_before(F,
# 	E).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [5 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
#
# [Total time taken 29.365s]

# %% [markdown]
# Next, we add an equivelant for the `ast` relation, `ancestor`:

# %%
header = """
% Settings
:- set(c,6)?
:- set(i,6)?
:- set(h,1000)?
:- set(cover)?
:- set(inflate,1000)?

% Mode declarations
:- modeh(*, bug(+node))?

:- modeb(*, ref(+node,-node))?
:- modeb(*, ref(-node,+node))?

:- modeb(*, assignment(+node))?
:- modeb(*, compMemberAccess(+node))?
:- modeb(*, sizeOf(+node))?
:- modeb(*, malloc(+node))?
:- modeb(*, alloc(+node))?
:- modeb(*, writeToPointer(+node))?

:- modeb(20, runs_before(+node, -node))?

runs_before(A,C) :- cfg(A,B), runs_before(B,C).
runs_before(A,C) :- cfg(A,B), cfg(B,C).

:- modeb(20, ancestor(+node, -node))?

ancestor(A,C) :- ast(A,B), ancestor(B,C).
ancestor(A,C) :- ast(A,B), ast(B,C).
"""

script = make_progol_script(header, {
    62804,
    62852,
    62853,
    62854,
    62869,
    62900,
    62901,
    62917,
    232012,
    232086,
})
with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,6)? - Time taken 0.00s]
# [:- set(i,6)? - Time taken 0.00s]
# [:- set(h,1000)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,1000)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,assignment(+node))? - Time taken 0.00s]
# [:- modeb(100,compMemberAccess(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,malloc(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [:- modeb(20,runs_before(+node,-node))? - Time taken 0.00s]
# [:- modeb(20,ancestor(+node,-node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232086_id_146_f_memmove_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232086_id_146_f_memmove_01_c_l_30_c_8_).>]
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,C), runs_before(A,D), runs_before(A,E), runs_before(A,F), runs_before(A,G), ancestor(A,H), ancestor(A,I), ancestor(A,J), ref(D,K), compMemberAccess(F), sizeOf(I), runs_before(D,B), runs_before(E,B), runs_before(E,C), runs_before(F,B), runs_before(F,C), runs_before(F,D), runs_before(G,B), runs_before(G,C), runs_before(G,D), runs_before(G,E), runs_before(H,A), runs_before(H,B), runs_before(H,C), runs_before(H,D), runs_before(H,E), runs_before(H,F), runs_before(H,G), runs_before(H,L), runs_before(H,M), runs_before(I,A), runs_before(I,B), runs_before(I,C), runs_before(I,D), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(I,L), runs_before(J,A), runs_before(J,B), runs_before(J,C), runs_before(J,D), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,I), runs_before(J,L), runs_before(J,M), ancestor(E,G), ancestor(E,L), ref(L,K), ref(N,K), ref(O,K), ref(P,K), ref(Q,K), runs_before(L,B), runs_before(L,C), runs_before(L,D), runs_before(L,E), runs_before(L,F), runs_before(M,B), runs_before(M,C), runs_before(M,D), runs_before(M,E), runs_before(M,F), runs_before(M,G), runs_before(M,L), ancestor(M,H), runs_before(N,A), runs_before(N,B), runs_before(N,C), runs_before(N,D), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,I), runs_before(N,J), runs_before(N,L), runs_before(N,M), runs_before(O,A), runs_before(O,B), runs_before(O,C), runs_before(O,D), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,I), runs_before(O,J), runs_before(O,L), runs_before(O,M), runs_before(O,N), runs_before(O,R), runs_before(P,A), runs_before(P,B), runs_before(P,C), runs_before(P,D), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,I), runs_before(P,J), runs_before(P,L), runs_before(P,M), runs_before(P,N), runs_before(P,R), runs_before(Q,A), runs_before(Q,B), runs_before(Q,C), runs_before(Q,D), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,I), runs_before(Q,J), runs_before(Q,L), runs_before(Q,M), runs_before(Q,N), runs_before(Q,R), ref(R,S), runs_before(R,A), runs_before(R,B), runs_before(R,C), runs_before(R,D), runs_before(R,E), runs_before(R,F), runs_before(R,G), runs_before(R,H), runs_before(R,I), runs_before(R,L), runs_before(R,M), ref(T,S).
# [Most-specific clause reduced by 55 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,
# 	C), runs_before(A,D), runs_before(A,E), runs_before(A,
# 	F), ancestor(A,G), ancestor(A,H), ancestor(A,I), ref(C,
# 	J), compMemberAccess(E), sizeOf(H), runs_before(C,B),
# 	runs_before(D,B), runs_before(E,B), runs_before(E,C),
# 	runs_before(F,B), runs_before(F,C), runs_before(F,D),
# 	runs_before(G,A), runs_before(G,B), runs_before(G,C),
# 	runs_before(G,D), runs_before(G,E), runs_before(G,F),
# 	runs_before(G,K), runs_before(G,L), runs_before(H,A),
# 	runs_before(H,B), runs_before(H,C), runs_before(H,D),
# 	runs_before(H,E), runs_before(H,F), runs_before(H,K),
# 	runs_before(I,A), runs_before(I,B), runs_before(I,C),
# 	runs_before(I,D), runs_before(I,E), runs_before(I,F),
# 	runs_before(I,H), runs_before(I,K), runs_before(I,L),
# 	ancestor(D,F), ancestor(D,K), ref(K,J), ref(M,J), ref(N,
# 	J), runs_before(K,B), runs_before(K,C), runs_before(K,
# 	D), runs_before(K,E), runs_before(L,B), runs_before(L,
# 	C), runs_before(L,D), runs_before(L,E), runs_before(L,
# 	F), runs_before(L,K), ancestor(L,G), runs_before(M,A),
# 	runs_before(M,B), runs_before(M,C), runs_before(M,D),
# 	runs_before(M,E), runs_before(M,F), runs_before(M,G),
# 	runs_before(M,H), runs_before(M,I), runs_before(M,K),
# 	runs_before(M,L), runs_before(N,A), runs_before(N,B),
# 	runs_before(N,C), runs_before(N,D), runs_before(N,E),
# 	runs_before(N,F), runs_before(N,G), runs_before(N,H),
# 	runs_before(N,I), runs_before(N,K), runs_before(N,L),
# 	runs_before(N,M).
#
# [C:89,100,10,0 bug(A).]
# [C:85,40,4,0 bug(A) :- writeToPointer(A).]
# [C:88,100,10,0 bug(A) :- runs_before(A,B).]
# [C:88,100,10,0 bug(A) :- runs_before(A,B).]
# [C:88,100,10,0 bug(A) :- runs_before(A,B).]
# [C:88,100,10,0 bug(A) :- runs_before(A,B).]
# [C:88,100,10,0 bug(A) :- runs_before(A,B).]
# [C:88,100,10,0 bug(A) :- ancestor(A,B).]
# [C:88,100,10,0 bug(A) :- ancestor(A,B).]
# [C:88,100,10,0 bug(A) :- ancestor(A,B).]
# [10 explored search nodes]
# f=89,p=100,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).>]
# bug(A) :- runs_before(A,B), runs_before(A,C), runs_before(A,D), runs_before(A,E), runs_before(A,F), runs_before(A,G), ancestor(A,H), ancestor(A,I), ancestor(A,J), ref(D,K), compMemberAccess(F), sizeOf(I), runs_before(D,B), runs_before(E,B), runs_before(E,C), runs_before(F,B), runs_before(F,C), runs_before(F,D), runs_before(G,B), runs_before(G,C), runs_before(G,D), runs_before(G,E), runs_before(H,A), runs_before(H,B), runs_before(H,C), runs_before(H,D), runs_before(H,E), runs_before(H,F), runs_before(H,G), runs_before(H,L), runs_before(H,M), runs_before(I,A), runs_before(I,B), runs_before(I,C), runs_before(I,D), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(I,L), runs_before(J,A), runs_before(J,B), runs_before(J,C), runs_before(J,D), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,I), runs_before(J,L), runs_before(J,M), ancestor(E,G), ancestor(E,L), ref(L,K), ref(N,K), ref(O,K), ref(P,K), ref(Q,K), runs_before(L,B), runs_before(L,C), runs_before(L,D), runs_before(L,E), runs_before(L,F), runs_before(M,B), runs_before(M,C), runs_before(M,D), runs_before(M,E), runs_before(M,F), runs_before(M,G), runs_before(M,L), ancestor(M,H), runs_before(N,A), runs_before(N,B), runs_before(N,C), runs_before(N,D), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,I), runs_before(N,J), runs_before(N,L), runs_before(N,M), runs_before(O,A), runs_before(O,B), runs_before(O,C), runs_before(O,D), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,I), runs_before(O,J), runs_before(O,L), runs_before(O,M), runs_before(O,N), runs_before(O,R), runs_before(P,A), runs_before(P,B), runs_before(P,C), runs_before(P,D), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,I), runs_before(P,J), runs_before(P,L), runs_before(P,M), runs_before(P,N), runs_before(P,R), runs_before(Q,A), runs_before(Q,B), runs_before(Q,C), runs_before(Q,D), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,I), runs_before(Q,J), runs_before(Q,L), runs_before(Q,M), runs_before(Q,N), runs_before(Q,R), ref(R,S), runs_before(R,A), runs_before(R,B), runs_before(R,C), runs_before(R,D), runs_before(R,E), runs_before(R,F), runs_before(R,G), runs_before(R,H), runs_before(R,I), runs_before(R,L), runs_before(R,M), ref(T,S).
# [Most-specific clause reduced by 55 literals]
# [Most specific clause is]
#
# bug(A) :- runs_before(A,B), runs_before(A,C), runs_before(A,D),
# 	runs_before(A,E), runs_before(A,F), ancestor(A,G), ancestor(A,
# 	H), ancestor(A,I), ref(C,J), compMemberAccess(E), sizeOf(H),
# 	runs_before(C,B), runs_before(D,B), runs_before(E,B),
# 	runs_before(E,C), runs_before(F,B), runs_before(F,C),
# 	runs_before(F,D), runs_before(G,A), runs_before(G,B),
# 	runs_before(G,C), runs_before(G,D), runs_before(G,E),
# 	runs_before(G,F), runs_before(G,K), runs_before(G,L),
# 	runs_before(H,A), runs_before(H,B), runs_before(H,C),
# 	runs_before(H,D), runs_before(H,E), runs_before(H,F),
# 	runs_before(H,K), runs_before(I,A), runs_before(I,B),
# 	runs_before(I,C), runs_before(I,D), runs_before(I,E),
# 	runs_before(I,F), runs_before(I,H), runs_before(I,K),
# 	runs_before(I,L), ancestor(D,F), ancestor(D,K), ref(K,
# 	J), ref(M,J), ref(N,J), runs_before(K,B), runs_before(K,
# 	C), runs_before(K,D), runs_before(K,E), runs_before(L,
# 	B), runs_before(L,C), runs_before(L,D), runs_before(L,
# 	E), runs_before(L,F), runs_before(L,K), ancestor(L,G),
# 	runs_before(M,A), runs_before(M,B), runs_before(M,C),
# 	runs_before(M,D), runs_before(M,E), runs_before(M,F),
# 	runs_before(M,G), runs_before(M,H), runs_before(M,I),
# 	runs_before(M,K), runs_before(M,L), runs_before(N,A),
# 	runs_before(N,B), runs_before(N,C), runs_before(N,D),
# 	runs_before(N,E), runs_before(N,F), runs_before(N,G),
# 	runs_before(N,H), runs_before(N,I), runs_before(N,K),
# 	runs_before(N,L), runs_before(N,M).
#
# [C:89,100,10,0 bug(A).]
# [C:88,100,10,0 bug(A) :- runs_before(A,B).]
# [C:88,100,10,0 bug(A) :- runs_before(A,B).]
# [C:88,100,10,0 bug(A) :- runs_before(A,B).]
# [C:88,100,10,0 bug(A) :- runs_before(A,B).]
# [C:88,100,10,0 bug(A) :- runs_before(A,B).]
# [C:88,100,10,0 bug(A) :- ancestor(A,B).]
# [C:88,100,10,0 bug(A) :- ancestor(A,B).]
# [C:88,100,10,0 bug(A) :- ancestor(A,B).]
# [9 explored search nodes]
# f=89,p=100,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).>]
