# %% [markdown]
# # Joern-ey into ILP

# %%
import pandas as pd

# %%
import tempfile
import subprocess

# %%
ilp_data = pd.read_csv("../data/ilp_dataset.csv.gz")
ilp_data = ilp_data.drop("Unnamed: 0", axis=1)
ilp_data
# Out:
#     testcase_ID                                           filename  \
# 0         62804  000/062/804/CWE121_Stack_Based_Buffer_Overflow...
# 1         62852  000/062/852/CWE121_Stack_Based_Buffer_Overflow...
# 2         62853  000/062/853/CWE121_Stack_Based_Buffer_Overflow...
# 3         62854  000/062/854/CWE121_Stack_Based_Buffer_Overflow...
# 4         62869  000/062/869/CWE121_Stack_Based_Buffer_Overflow...
# 5         62900  000/062/900/CWE121_Stack_Based_Buffer_Overflow...
# 6         62901  000/062/901/CWE121_Stack_Based_Buffer_Overflow...
# 7         62917  000/062/917/CWE121_Stack_Based_Buffer_Overflow...
# 8        232012  000/232/012/CWE122_Heap_Based_Buffer_Overflow_...
# 9        232086  000/232/086/CWE122_Heap_Based_Buffer_Overflow_...
# 10       -62804  000/062/804/CWE121_Stack_Based_Buffer_Overflow...
# 11       -62852  000/062/852/CWE121_Stack_Based_Buffer_Overflow...
# 12       -62853  000/062/853/CWE121_Stack_Based_Buffer_Overflow...
# 13       -62854  000/062/854/CWE121_Stack_Based_Buffer_Overflow...
# 14       -62869  000/062/869/CWE121_Stack_Based_Buffer_Overflow...
# 15       -62900  000/062/900/CWE121_Stack_Based_Buffer_Overflow...
# 16       -62901  000/062/901/CWE121_Stack_Based_Buffer_Overflow...
# 17       -62917  000/062/917/CWE121_Stack_Based_Buffer_Overflow...
# 18      -232012  000/232/012/CWE122_Heap_Based_Buffer_Overflow_...
# 19      -232086  000/232/086/CWE122_Heap_Based_Buffer_Overflow_...
#
#                                                  code     flaw  flaw_loc  \
# 0   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 1   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 2   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 3   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 4   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        32
# 5   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 6   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 7   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        32
# 8   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        31
# 9   /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        31
# 10  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 11  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 12  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 13  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 14  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        32
# 15  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 16  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 17  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        32
# 18  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        31
# 19  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        31
#
#       bug  code_length
# 0   False         1722
# 1   False         1674
# 2   False         2396
# 3   False         2414
# 4   False         1760
# 5   False         1680
# 6   False         2403
# 7   False         1766
# 8   False         1723
# 9   False         1729
# 10   True         1618
# 11   True         1570
# 12   True         1621
# 13   True         1630
# 14   True         1616
# 15   True         1576
# 16   True         1627
# 17   True         1622
# 18   True         1619
# 19   True         1625

# %%
prolog = pd.read_csv("../data/ilp_prolog_data.csv.gz")
prolog = prolog.drop("Unnamed: 0", axis=1)
prolog
# Out:
#     testcase_ID     flaw    bug  code_length  \
# 0       -232086  CWE-122   True         1625
# 1       -232012  CWE-122   True         1619
# 2        -62917  CWE-121   True         1622
# 3        -62901  CWE-121   True         1627
# 4        -62900  CWE-121   True         1576
# 5        -62869  CWE-121   True         1616
# 6        -62854  CWE-121   True         1630
# 7        -62853  CWE-121   True         1621
# 8        -62852  CWE-121   True         1570
# 9        -62804  CWE-121   True         1618
# 10        62804  CWE-121  False         1722
# 11        62852  CWE-121  False         1674
# 12        62853  CWE-121  False         2396
# 13        62854  CWE-121  False         2414
# 14        62869  CWE-121  False         1760
# 15        62900  CWE-121  False         1680
# 16        62901  CWE-121  False         2403
# 17        62917  CWE-121  False         1766
# 18       232012  CWE-122  False         1723
# 19       232086  CWE-122  False         1729
#
#                                                  tree  \
# 0   % START: Generated Prolog\n% NODE PROPERTIES \...
# 1   % START: Generated Prolog\n% NODE PROPERTIES \...
# 2   % START: Generated Prolog\n% NODE PROPERTIES \...
# 3   % START: Generated Prolog\n% NODE PROPERTIES \...
# 4   % START: Generated Prolog\n% NODE PROPERTIES \...
# 5   % START: Generated Prolog\n% NODE PROPERTIES \...
# 6   % START: Generated Prolog\n% NODE PROPERTIES \...
# 7   % START: Generated Prolog\n% NODE PROPERTIES \...
# 8   % START: Generated Prolog\n% NODE PROPERTIES \...
# 9   % START: Generated Prolog\n% NODE PROPERTIES \...
# 10  % START: Generated Prolog\n% NODE PROPERTIES \...
# 11  % START: Generated Prolog\n% NODE PROPERTIES \...
# 12  % START: Generated Prolog\n% NODE PROPERTIES \...
# 13  % START: Generated Prolog\n% NODE PROPERTIES \...
# 14  % START: Generated Prolog\n% NODE PROPERTIES \...
# 15  % START: Generated Prolog\n% NODE PROPERTIES \...
# 16  % START: Generated Prolog\n% NODE PROPERTIES \...
# 17  % START: Generated Prolog\n% NODE PROPERTIES \...
# 18  % START: Generated Prolog\n% NODE PROPERTIES \...
# 19  % START: Generated Prolog\n% NODE PROPERTIES \...
#
#                                            source_map
# 0   % CODE\nsource_code(bad_232086_id_0_f_l_c_, ""...
# 1   % CODE\nsource_code(bad_232012_id_1_f_l_c_, "p...
# 2   % CODE\nsource_code(bad_62917_id_0_f_l_c_, "p1...
# 3   % CODE\nsource_code(bad_62901_id_0_f_l_c_, "p2...
# 4   % CODE\nsource_code(bad_62900_id_0_f_l_c_, "p1...
# 5   % CODE\nsource_code(bad_62869_id_0_f_l_c_, "p1...
# 6   % CODE\nsource_code(bad_62854_id_0_f_l_c_, "p2...
# 7   % CODE\nsource_code(bad_62853_id_0_f_l_c_, "p1...
# 8   % CODE\nsource_code(bad_62852_id_0_f_l_c_, "p1...
# 9   % CODE\nsource_code(bad_62804_id_0_f_l_c_, "p1...
# 10  % CODE\nsource_code(good_62804_id_0_f_l_c_, "p...
# 11  % CODE\nsource_code(good_62852_id_0_f_l_c_, "p...
# 12  % CODE\nsource_code(good_62853_id_0_f_l_c_, "d...
# 13  % CODE\nsource_code(good_62854_id_0_f_memcpy_0...
# 14  % CODE\nsource_code(good_62869_id_0_f_l_c_, "p...
# 15  % CODE\nsource_code(good_62900_id_0_f_l_c_, "p...
# 16  % CODE\nsource_code(good_62901_id_0_f_memmove_...
# 17  % CODE\nsource_code(good_62917_id_0_f_l_c_, "p...
# 18  % CODE\nsource_code(good_232012_id_1_f_l_c_, "...
# 19  % CODE\nsource_code(good_232086_id_1_f_l_c_, "...

# %%
good_examples = prolog[prolog['bug'] == False]
bad_examples = prolog[prolog['bug'] == True]

# %%
def extract_node_ids(tree):
    nodes = set()
    
    in_ast_section = False
    
    for line in tree.split('\n'):
        line = line.strip()
        
        if line == '% AST':
            in_ast_section = True
        
        if line == '% CFG':
            in_ast_section = False
            
        if line == '% REF':
            in_ast_section = False
        
        if in_ast_section and not line.startswith("%"):
            parent, child = line[4:-2].split(", ")
            nodes.add(parent)
            nodes.add(child)
            
    return nodes

# %%
# good nodes_g
nodes_g = set()

for i in range(len(good_examples)):
    good_nodes = extract_node_ids(good_examples.iloc[i].tree)
    nodes_g = set.union(nodes_g,good_nodes)

    
# bad nodes_b
nodes_b = set()

for i in range(len(bad_examples)):
    bad_nodes = extract_node_ids(bad_examples.iloc[i].tree)
    nodes_b = set.union(nodes_b,bad_nodes)

nodes = set.union(nodes_g,nodes_b)

# %% [markdown]
# Manually find the "error" node for each testcase, and tag those as the positive or  negative examples.

# %%
print(good_examples.source_map.iloc[9])
# Out:
# % CODE
# source_code(good_232086_id_1_f_l_c_, "p2").
# source_code(good_232086_id_2_f_l_c_, "p1").
# source_code(good_232086_id_3_f_l_c_, "p1").
# source_code(good_232086_id_4_f_l_c_, "p2").
# source_code(good_232086_id_5_f_l_c_, "p2").
# source_code(good_232086_id_6_f_l_c_, "p3").
# source_code(good_232086_id_7_f_l_c_, "p2").
# source_code(good_232086_id_8_f_l_c_, "p1").
# source_code(good_232086_id_9_f_l_c_, "p1").
# source_code(good_232086_id_10_f_l_c_, "p1").
# source_code(good_232086_id_11_f_l_c_, "p2").
# source_code(good_232086_id_12_f_l_c_, "p1").
# source_code(good_232086_id_13_f_l_c_, "p1").
# source_code(good_232086_id_14_f_l_c_, "p1").
# source_code(good_232086_id_15_f_l_c_, "p1").
# source_code(good_232086_id_16_f_l_c_, "p1").
# source_code(good_232086_id_17_f_l_c_, "p1").
# source_code(good_232086_id_18_f_l_54_c_19_, "char * argv[]").
# source_code(good_232086_id_19_f_l_54_c_9_, "int argc").
# source_code(good_232086_id_20_f_l_c_, "p1").
# source_code(good_232086_id_21_f_l_c_, "p1").
# source_code(good_232086_id_22_f_l_c_, "p1").
# source_code(good_232086_id_23_f_l_c_, "p2").
# source_code(good_232086_id_24_f_l_c_, "p1").
# source_code(good_232086_id_25_f_l_c_, "RET").
# source_code(good_232086_id_26_f_l_c_, "").
# source_code(good_232086_id_27_f_l_c_, "p1").
# source_code(good_232086_id_28_f_l_c_, "RET").
# source_code(good_232086_id_29_f_l_c_, "").
# source_code(good_232086_id_31_f_l_c_, "p1").
# source_code(good_232086_id_32_f_l_c_, "RET").
# source_code(good_232086_id_33_f_l_c_, "RET").
# source_code(good_232086_id_34_f_l_c_, "p2").
# source_code(good_232086_id_35_f_l_c_, "p3").
# source_code(good_232086_id_36_f_l_c_, "").
# source_code(good_232086_id_38_f_l_c_, "RET").
# source_code(good_232086_id_39_f_l_c_, "RET").
# source_code(good_232086_id_41_f_l_c_, "p2").
# source_code(good_232086_id_43_f_l_c_, "RET").
# source_code(good_232086_id_44_f_l_c_, "p2").
# source_code(good_232086_id_45_f_l_c_, "RET").
# source_code(good_232086_id_46_f_l_c_, "").
# source_code(good_232086_id_47_f_l_c_, "").
# source_code(good_232086_id_48_f_l_c_, "").
# source_code(good_232086_id_49_f_l_c_, "RET").
# source_code(good_232086_id_50_f_l_c_, "p1").
# source_code(good_232086_id_51_f_l_c_, "p1").
# source_code(good_232086_id_52_f_l_c_, "p1").
# source_code(good_232086_id_53_f_l_c_, "p1").
# source_code(good_232086_id_54_f_l_c_, "p2").
# source_code(good_232086_id_56_f_l_c_, "").
# source_code(good_232086_id_57_f_l_c_, "RET").
# source_code(good_232086_id_61_f_l_c_, "").
# source_code(good_232086_id_62_f_l_c_, "p1").
# source_code(good_232086_id_63_f_l_c_, "p1").
# source_code(good_232086_id_65_f_l_c_, "p1").
# source_code(good_232086_id_66_f_l_c_, "").
# source_code(good_232086_id_67_f_l_c_, "p1").
# source_code(good_232086_id_68_f_l_c_, "p2").
# source_code(good_232086_id_69_f_l_c_, "p1").
# source_code(good_232086_id_70_f_l_c_, "RET").
# source_code(good_232086_id_71_f_l_c_, "").
# source_code(good_232086_id_72_f_l_c_, "RET").
# source_code(good_232086_id_74_f_l_c_, "").
# source_code(good_232086_id_75_f_l_c_, "RET").
# source_code(good_232086_id_76_f_l_c_, "").
# source_code(good_232086_id_77_f_l_c_, "p1").
# source_code(good_232086_id_78_f_l_c_, "p1").
# source_code(good_232086_id_81_f_l_c_, "p1").
# source_code(good_232086_id_82_f_l_c_, "").
# source_code(good_232086_id_84_f_l_c_, "").
# source_code(good_232086_id_85_f_l_c_, "").
# source_code(good_232086_id_87_f_l_c_, "p2").
# source_code(good_232086_id_88_f_l_c_, "RET").
# source_code(good_232086_id_90_f_l_c_, "p1").
# source_code(good_232086_id_91_f_l_c_, "RET").
# source_code(good_232086_id_102_f_memmove_01_c_l_62_c_11_, "0").
# source_code(good_232086_id_103_f_memmove_01_c_l_62_c_4_, "return 0;").
# source_code(good_232086_id_104_f_memmove_01_c_l_60_c_14_, ""Finished good()"").
# source_code(good_232086_id_105_f_memmove_01_c_l_60_c_4_, "printLine("Finished good()")").
# source_code(good_232086_id_107_f_memmove_01_c_l_59_c_4_, "CWE122_Heap_Based_Buffer_Overflow__CWE131_memmove_01_good()").
# source_code(good_232086_id_108_f_memmove_01_c_l_58_c_14_, ""Calling good()..."").
# source_code(good_232086_id_110_f_memmove_01_c_l_58_c_4_, "printLine("Calling good()...")").
# source_code(good_232086_id_111_f_memmove_01_c_l_56_c_26_, "NULL").
# source_code(good_232086_id_113_f_memmove_01_c_l_56_c_21_, "time(good_232086_NULL)").
# source_code(good_232086_id_114_f_memmove_01_c_l_56_c_12_, "unsigned").
# source_code(good_232086_id_115_f_memmove_01_c_l_56_c_11_, "(good_232086_unsigned)time(good_232086_NULL)").
# source_code(good_232086_id_117_f_memmove_01_c_l_56_c_4_, "srand( (good_232086_unsigned)time(good_232086_NULL) )").
# source_code(good_232086_id_118_f_memmove_01_c_l_55_c_0_, "").
# source_code(good_232086_id_119_f_l_54_c_0_, "RET").
# source_code(good_232086_id_120_f_l_54_c_19_, "char * argv[]").
# source_code(good_232086_id_121_f_l_54_c_9_, "int argc").
# source_code(good_232086_id_126_f_memmove_01_c_l_40_c_4_, "goodG2B()").
# source_code(good_232086_id_127_f_memmove_01_c_l_40_c_0_, "").
# source_code(good_232086_id_128_f_l_39_c_0_, "RET").
# source_code(good_232086_id_134_f_memmove_01_c_l_34_c_13_, "data").
# source_code(good_232086_id_136_f_memmove_01_c_l_34_c_8_, "free(good_232086_data)").
# source_code(good_232086_id_137_f_memmove_01_c_l_33_c_26_, "0").
# source_code(good_232086_id_138_f_memmove_01_c_l_33_c_21_, "data").
# source_code(good_232086_id_140_f_memmove_01_c_l_33_c_21_, "data[0]").
# source_code(good_232086_id_142_f_memmove_01_c_l_33_c_8_, "printIntLine(data[0])").
# source_code(good_232086_id_143_f_memmove_01_c_l_32_c_40_, "int").
# source_code(good_232086_id_144_f_memmove_01_c_l_32_c_33_, "sizeof(good_232086_int)").
# source_code(good_232086_id_145_f_memmove_01_c_l_32_c_30_, "10").
# source_code(good_232086_id_146_f_memmove_01_c_l_32_c_30_, "10*sizeof(good_232086_int)").
# source_code(good_232086_id_147_f_memmove_01_c_l_32_c_22_, "source").
# source_code(good_232086_id_148_f_memmove_01_c_l_32_c_16_, "data").
# source_code(good_232086_id_150_f_memmove_01_c_l_32_c_8_, "memmove(data, source, 10*sizeof(good_232086_int))").
# source_code(good_232086_id_151_f_memmove_01_c_l_30_c_12_, "source").
# source_code(good_232086_id_152_f_memmove_01_c_l_30_c_12_, "source[10] = {0}").
# source_code(good_232086_id_153_f_l_c_, "source").
# source_code(good_232086_id_154_f_memmove_01_c_l_30_c_8_, "").
# source_code(good_232086_id_155_f_memmove_01_c_l_28_c_29_, "1").
# source_code(good_232086_id_157_f_memmove_01_c_l_28_c_28_, "-1").
# source_code(good_232086_id_159_f_memmove_01_c_l_28_c_23_, "exit(-1)").
# source_code(good_232086_id_160_f_memmove_01_c_l_28_c_22_, "").
# source_code(good_232086_id_161_f_memmove_01_c_l_28_c_16_, "NULL").
# source_code(good_232086_id_162_f_memmove_01_c_l_28_c_8_, "data").
# source_code(good_232086_id_164_f_memmove_01_c_l_28_c_8_, "data == NULL").
# source_code(good_232086_id_165_f_memmove_01_c_l_28_c_4_, "if (data == NULL)").
# source_code(good_232086_id_166_f_memmove_01_c_l_27_c_35_, "int").
# source_code(good_232086_id_168_f_memmove_01_c_l_27_c_28_, "sizeof(good_232086_int)").
# source_code(good_232086_id_169_f_memmove_01_c_l_27_c_25_, "10").
# source_code(good_232086_id_171_f_memmove_01_c_l_27_c_25_, "10*sizeof(good_232086_int)").
# source_code(good_232086_id_173_f_memmove_01_c_l_27_c_18_, "malloc(10*sizeof(good_232086_int))").
# source_code(good_232086_id_174_f_memmove_01_c_l_27_c_12_, "int *").
# source_code(good_232086_id_176_f_memmove_01_c_l_27_c_11_, "(int *)malloc(10*sizeof(good_232086_int))").
# source_code(good_232086_id_177_f_memmove_01_c_l_27_c_4_, "data").
# source_code(good_232086_id_178_f_memmove_01_c_l_27_c_4_, "data = (int *)malloc(10*sizeof(good_232086_int))").
# source_code(good_232086_id_179_f_memmove_01_c_l_25_c_11_, "NULL").
# source_code(good_232086_id_180_f_memmove_01_c_l_25_c_4_, "data").
# source_code(good_232086_id_182_f_memmove_01_c_l_25_c_4_, "data = NULL").
# source_code(good_232086_id_183_f_l_c_, "data").
# source_code(good_232086_id_184_f_memmove_01_c_l_24_c_0_, "").
# source_code(good_232086_id_185_f_l_23_c_0_, "RET").
# source_code(good_232086_id_187_f_l_56_c_, "/* seed randomness */").
# source_code(id_188_f_l_46_c_, "/* Below is the main(). It is only used when building this testcase on
#  * its own for testing or for building a binary to use in testing binary
#  * analysis tools. It is not used when compiling all the testcases as one
#  * application, which is how source code analysis tools are tested.
#  */").
# source_code(good_232086_id_189_f_l_32_c_, "/* POTENTIAL FLAW: Possible buffer overflow if data was not allocated correctly in the source */").
# source_code(good_232086_id_190_f_l_27_c_, "/* FIX: Allocate memory using sizeof(good_232086_int) */").
# source_code(good_232086_id_191_f_l_22_c_, "/* goodG2B uses the GoodSource with the BadSink */").
# source_code(id_192_f_l_6_c_, "/*
#  * @description
#  * CWE: 122 Heap Based Buffer Overflow
#  * BadSource:  Allocate memory without using sizeof(good_232086_int)
#  * GoodSource: Allocate memory using sizeof(good_232086_int)
#  * Sink: memmove
#  *    BadSink : Copy array to data using memmove()
#  * Flow Variant: 01 Baseline
#  *
#  * */").
# source_code(id_193_f_l_1_c_, "/* TEMPLATE GENERATED TESTCASE FILE
# Filename: CWE122_Heap_Based_Buffer_Overflow__CWE131_memmove_01.c
# Label Definition File: CWE122_Heap_Based_Buffer_Overflow__CWE131.label.xml
# Template File: sources-sink-01.tmpl.c
# */").

# %%
types = [
    'node('+node_id+').' for node_id in nodes
]

positive_examples = [
    """
    bug(bad_232086_id_146_f_memmove_01_c_l_30_c_8_).
    bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).
    bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).
    bug(bad_62901_id_121_f_memmove_02_c_l_32_c_8_).
    bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).
    bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).
    bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).
    bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).
    bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).
    bug(bad_62804_id_111_f_loop_01_c_l_32_c_12_).
    """,
]

negative_examples = [
    """
:- bug(good_62804_id_130_f_loop_01_c_l_34_c_12_).
:- bug(good_62852_id_126_f_memcpy_01_c_l_31_c_8_).
:- bug(good_62853_id_122_f_memcpy_02_c_l_57_c_8_).
:- bug(good_62854_id_130_f_memcpy_03_c_l_57_c_8_).
:- bug(good_62869_id_126_f_memcpy_18_c_l_33_c_8_).
:- bug(good_62900_id_125_f_memmove_01_c_l_31_c_8_).
:- bug(good_62901_id_116_f_memmove_02_c_l_57_c_8_).
:- bug(good_62917_id_125_f_memmove_18_c_l_33_c_8_).
:- bug(good_232012_id_150_f_memcpy_01_c_l_32_c_8_).
:- bug(good_232086_id_150_f_memmove_01_c_l_32_c_8_).
    """,
]

# %%
def make_progol_script(header, testcases):
    script_template = """
{header}

%% Types
{types}

%% background knowledge
{bg_knowledge}

%% learning task
%% positive examples
{positive_examples}

%% negative examples
{negative_examples}

    """

    script = script_template.format(
        header = header,
        types = '\n'.join(types),
        bg_knowledge = '\n'.join(prolog['tree']),
        positive_examples='\n'.join(positive_examples),
        negative_examples='\n'.join(negative_examples),
    )
    
    # remove all lines not related to this testcase
    script = '\n'.join([
        line for line in script.split("\n")  if any(
            str(testcase) in line for testcase in testcases
        ) or not ("good_" in line or "bad_" in line)
    ])
    
    return script

# %% [markdown]
# We try by setting the following header:

# %%
header = """
% Settings
:- set(c,30)?
:- set(i,30)?
:- set(h,500)?
:- set(cover)?
:- set(inflate,500)?
%:- set(noise,0.2)?

% Mode declarations
:- modeh(*, bug(+node))?

:- modeb(*, ast(+node,-node))?

:- modeb(*, ref(+node,-node))?
:- modeb(*, ref(-node,+node))?

:- modeb(*, assignment(+node))?
:- modeb(*, compMemberAccess(+node))?
:- modeb(*, sizeOf(+node))?
:- modeb(*, malloc(+node))?
:- modeb(*, alloc(+node))?
:- modeb(*, writeToPointer(+node))?
"""

script = make_progol_script(header, {62804, 62852, 62869, 232012, 62900})

with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,30)? - Time taken 0.00s]
# [:- set(i,30)? - Time taken 0.00s]
# [:- set(h,500)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,500)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ast(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,assignment(+node))? - Time taken 0.00s]
# [:- modeb(100,compMemberAccess(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,malloc(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), ref(N,H), ref(O,H), sizeOf(E).
# [Most-specific clause reduced by 9 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:10,5,1,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62804_id_111_f_loop_01_c_l_32_c_12_).]
# [Generalising <bug(bad_62804_id_111_f_loop_01_c_l_32_c_12_).>]
# bug(A) :- ast(A,B), ast(A,C), assignment(A), ast(B,D), ast(B,E), ast(C,F), ast(C,G), compMemberAccess(B), compMemberAccess(C), ref(D,H), ref(E,I), ref(F,H), ref(G,J), ref(K,H), ref(L,H), ref(M,H), ref(N,I), ref(O,J), ref(P,J), ref(Q,J).
# [Most-specific clause reduced by 15 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), assignment(A), ast(B,C), compMemberAccess(B),
# 	ref(C,D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:10,5,1,0 bug(A) :- assignment(A).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
#
# [Total time taken 0.011s]

# %% [markdown]
# This creates one rule per example, but is unable to create a general one. These rules succinctly describe the situation, and three of the examples have the same rule!
#
# ```
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C, E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), assignment(A), ast(B,C), compMemberAccess(B), ref(C,D).
# ```

# %% [markdown]
# We try the same setup, but only for those buffer overflows which happen due to a `memcpy`:

# %%
script = make_progol_script(header, {
    62852,
    62853,
    62854,
    62869,
    232012,
})

with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,30)? - Time taken 0.00s]
# [:- set(i,30)? - Time taken 0.00s]
# [:- set(h,500)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,500)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ast(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,assignment(+node))? - Time taken 0.00s]
# [:- modeb(100,compMemberAccess(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,malloc(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), ref(N,H), ref(O,H), sizeOf(E).
# [Most-specific clause reduced by 9 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
#
# [Total time taken 0.013s]

# %% [markdown]
# It produces 5 of the exact same "most specific clauses", but is still unable to give a final output?
# ```
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# ```
#
# **Question:** Why is it unable to combine them?

# %% [markdown]
# Finally, try for all the examples:

# %%
script = make_progol_script(header, {
    62804,
    62852,
    62853,
    62854,
    62869,
    62900,
    62901,
    62917,
    232012,
    232086,
})

with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,30)? - Time taken 0.00s]
# [:- set(i,30)? - Time taken 0.00s]
# [:- set(h,500)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,500)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ast(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,assignment(+node))? - Time taken 0.00s]
# [:- modeb(100,compMemberAccess(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,malloc(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232086_id_146_f_memmove_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232086_id_146_f_memmove_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,H), ref(N,H), ref(O,G), sizeOf(E).
# [Most-specific clause reduced by 9 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:35,20,4,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), ref(N,H), ref(O,H), sizeOf(E).
# [Most-specific clause reduced by 9 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:35,20,4,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62901_id_121_f_memmove_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62901_id_121_f_memmove_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:35,20,4,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:35,20,4,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [3 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62804_id_111_f_loop_01_c_l_32_c_12_).]
# [Generalising <bug(bad_62804_id_111_f_loop_01_c_l_32_c_12_).>]
# bug(A) :- ast(A,B), ast(A,C), assignment(A), ast(B,D), ast(B,E), ast(C,F), ast(C,G), compMemberAccess(B), compMemberAccess(C), ref(D,H), ref(E,I), ref(F,H), ref(G,J), ref(K,H), ref(L,H), ref(M,H), ref(N,I), ref(O,J), ref(P,J), ref(Q,J).
# [Most-specific clause reduced by 15 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), assignment(A), ast(B,C), compMemberAccess(B),
# 	ref(C,D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:20,5,1,0 bug(A) :- assignment(A).]
# [3 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
#
# [Total time taken 0.077s]

# %% [markdown]
# It produces three different rules (grouped below by rule not output or testcase):
#
# ```
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C, E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C, E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C, E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C, E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), assignment(A), ast(B,C), compMemberAccess(B), ref(C,D).
# ```

# %% [markdown]
# **Question:** Can ILP learn logical or's? And so could these three rules be considered in composite?
#
# **Question:** Can we create probabilistic model from these rules?

# %%
script = make_progol_script("""
% Settings
:- set(c,40)?
:- set(i,40)?
:- set(h,500)?
:- set(cover)?
:- set(inflate,200)?
:- set(noise,0.2)?

% Mode declarations
:- modeh(*, bug(+node))?

:- modeb(*, ast(+node,-node))?

:- modeb(*, cfg(+node,-node))?
:- modeb(*, cfg(-node,+node))?

:- modeb(*, ref(+node,-node))?
:- modeb(*, ref(-node,+node))?

:- modeb(*, assignment(+node))?
:- modeb(*, compMemberAccess(+node))?
:- modeb(*, sizeOf(+node))?
:- modeb(*, malloc(+node))?
:- modeb(*, alloc(+node))?
:- modeb(*, writeToPointer(+node))? """, {
    62804,
    62852,
    62853,
    62854,
    62869,
    62900,
    62901,
    62917,
    232012,
    232086,
})

with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,40)? - Time taken 0.00s]
# [:- set(i,40)? - Time taken 0.00s]
# [:- set(h,500)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,200)? - Time taken 0.00s]
# [:- set(noise,0.200)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ast(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,cfg(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,cfg(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,assignment(+node))? - Time taken 0.00s]
# [:- modeb(100,compMemberAccess(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,malloc(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232086_id_146_f_memmove_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232086_id_146_f_memmove_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J), ref(O,K), ref(P,K), ref(Q,K), ref(R,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,S), cfg(O,T), cfg(P,U), cfg(Q,V), cfg(R,W), cfg(S,O), cfg(X,P), cfg(Y,Q), cfg(Z,M), cfg(A0,M), cfg(B0,R), compMemberAccess(N), ast(S,N), ast(T,O), ast(X,Q), ast(X,C0), ast(Y,R), ast(Y,W), ast(Z,D0), ast(A0,P), ast(A0,U), ast(B0,E0), ast(B0,F0), cfg(U,A0), cfg(V,G0), cfg(T,F0), cfg(W,Y), cfg(A0,H0), cfg(D0,Z), cfg(C0,X), ref(I0,B0), assignment(X), assignment(Y), ast(D0,H0), ast(E0,K), ast(E0,X), ast(E0,Y), ast(E0,J0), ast(E0,K0), ast(C0,G0), ast(C0,L0), ast(G0,V), cfg(G0,C0), cfg(H0,D0), alloc(G0), ast(J0,A), ast(J0,I), ast(J0,J), ast(J0,S), ast(J0,T), ast(K0,A0), ast(K0,M0), ast(M0,Z).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A),
# 	ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,
# 	B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L),
# 	ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,
# 	J), ref(O,K), ref(P,K), ref(Q,K), ref(R,K), assignment(I),
# 	sizeOf(F), ast(N,E), ast(N,H), cfg(N,S), cfg(O,T), cfg(P,
# 	U), cfg(Q,V), cfg(R,W), cfg(S,O), cfg(X,P), cfg(Y,Q),
# 	cfg(Z,M), cfg(A0,M), cfg(B0,R), compMemberAccess(N),
# 	ast(S,N), ast(T,O), ast(X,Q), ast(X,C0), ast(Y,R), ast(Y,
# 	W), ast(Z,D0), ast(A0,P), ast(A0,U), ast(B0,E0), ast(B0,
# 	F0), cfg(U,A0), cfg(V,G0), cfg(T,F0), cfg(W,Y), cfg(A0,
# 	H0), cfg(D0,Z), cfg(C0,X), ref(I0,B0), assignment(X),
# 	assignment(Y), ast(D0,H0), ast(E0,K), ast(E0,X), ast(E0,
# 	Y), ast(E0,J0), ast(E0,K0), ast(C0,G0), ast(G0,V), cfg(G0,
# 	C0), cfg(H0,D0), alloc(G0), ast(J0,A), ast(J0,I), ast(J0,
# 	J), ast(J0,S), ast(J0,T), ast(K0,A0), ast(K0,L0), ast(L0,
# 	Z).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [C:5,8,4,0 bug(A) :- writeToPointer(A).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J), ref(O,K), ref(P,K), ref(Q,K), ref(R,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,S), cfg(O,T), cfg(P,U), cfg(Q,V), cfg(R,W), cfg(S,O), cfg(X,M), cfg(Y,M), cfg(Z,Q), cfg(A0,R), cfg(B0,P), compMemberAccess(N), ast(T,O), ast(S,N), ast(X,C0), ast(Y,P), ast(Y,U), ast(Z,R), ast(Z,W), ast(A0,D0), ast(A0,E0), ast(B0,Q), ast(B0,F0), cfg(V,G0), cfg(T,E0), cfg(W,Z), cfg(U,Y), cfg(Y,H0), cfg(C0,X), cfg(F0,B0), ref(I0,A0), assignment(Z), assignment(B0), ast(D0,K), ast(D0,Z), ast(D0,B0), ast(D0,J0), ast(D0,K0), ast(C0,H0), ast(F0,G0), ast(F0,L0), ast(G0,V), cfg(G0,F0), cfg(H0,C0), alloc(G0), ast(J0,A), ast(J0,I), ast(J0,J), ast(J0,T), ast(J0,S), ast(K0,Y), ast(K0,M0), ast(M0,X).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,
# 	F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B),
# 	cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,
# 	M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J),
# 	ref(O,K), ref(P,K), ref(Q,K), ref(R,K), assignment(I),
# 	sizeOf(F), ast(N,E), ast(N,H), cfg(N,S), cfg(O,T), cfg(P,
# 	U), cfg(Q,V), cfg(R,W), cfg(S,O), cfg(X,M), cfg(Y,M),
# 	cfg(Z,Q), cfg(A0,R), cfg(B0,P), compMemberAccess(N),
# 	ast(T,O), ast(S,N), ast(X,C0), ast(Y,P), ast(Y,U), ast(Z,
# 	R), ast(Z,W), ast(A0,D0), ast(A0,E0), ast(B0,Q), ast(B0,
# 	F0), cfg(V,G0), cfg(T,E0), cfg(W,Z), cfg(U,Y), cfg(Y,
# 	H0), cfg(C0,X), cfg(F0,B0), ref(I0,A0), assignment(Z),
# 	assignment(B0), ast(D0,K), ast(D0,Z), ast(D0,B0), ast(D0,
# 	J0), ast(D0,K0), ast(C0,H0), ast(F0,G0), ast(G0,V), cfg(G0,
# 	F0), cfg(H0,C0), alloc(G0), ast(J0,A), ast(J0,I), ast(J0,
# 	J), ast(J0,T), ast(J0,S), ast(K0,Y), ast(K0,L0), ast(L0,
# 	X).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [6 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M), cfg(U,P), cfg(V,O), compMemberAccess(N), ast(Q,N), ast(T,O), ast(T,W), ast(U,X), ast(U,Y), cfg(Q,Y), cfg(S,Z), cfg(R,A0), cfg(W,T), cfg(Z,V), ref(B0,U), assignment(T), ast(X,K), ast(X,T), ast(X,V), ast(X,Z), ast(X,C0), ast(X,D0), ast(W,A0), ast(W,E0), ast(A0,R), ast(Z,P), ast(Z,S), cfg(A0,W), assignment(Z), alloc(A0), ast(C0,A), ast(C0,I), ast(C0,J), ast(C0,Q).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A),
# 	ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,
# 	B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L),
# 	ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,
# 	J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M),
# 	cfg(U,P), cfg(V,O), compMemberAccess(N), ast(Q,N), ast(T,
# 	O), ast(T,W), ast(U,X), ast(U,Y), cfg(Q,Y), cfg(S,Z),
# 	cfg(R,A0), cfg(W,T), cfg(Z,V), ref(B0,U), assignment(T),
# 	ast(X,K), ast(X,T), ast(X,V), ast(X,Z), ast(X,C0), ast(W,
# 	A0), ast(A0,R), ast(Z,P), ast(Z,S), cfg(A0,W), assignment(Z),
# 	alloc(A0), ast(C0,A), ast(C0,I), ast(C0,J), ast(C0,Q).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [C:5,8,4,0 bug(A) :- writeToPointer(A).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62901_id_121_f_memmove_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62901_id_121_f_memmove_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M), cfg(U,M), cfg(U,O), cfg(V,P), compMemberAccess(N), ast(Q,N), ast(T,O), ast(T,W), ast(V,X), ast(V,Y), cfg(Q,Y), cfg(R,Z), cfg(S,A0), cfg(W,T), cfg(A0,U), ref(B0,V), assignment(T), ast(X,K), ast(X,A0), ast(X,C0), ast(X,D0), ast(W,Z), ast(W,E0), ast(A0,P), ast(A0,S), ast(Z,R), cfg(Z,W), assignment(A0), alloc(Z), ast(C0,A), ast(C0,I), ast(C0,J), ast(C0,Q), ast(D0,U), ast(D0,F0), ast(F0,T).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A),
# 	ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,
# 	B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L),
# 	ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,
# 	J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M),
# 	cfg(U,M), cfg(U,O), cfg(V,P), compMemberAccess(N), ast(Q,
# 	N), ast(T,O), ast(T,W), ast(V,X), ast(V,Y), cfg(Q,Y),
# 	cfg(R,Z), cfg(S,A0), cfg(W,T), cfg(A0,U), ref(B0,V),
# 	assignment(T), ast(X,K), ast(X,A0), ast(X,C0), ast(X,
# 	D0), ast(W,Z), ast(A0,P), ast(A0,S), ast(Z,R), cfg(Z,
# 	W), assignment(A0), alloc(Z), ast(C0,A), ast(C0,I), ast(C0,
# 	J), ast(C0,Q), ast(D0,U), ast(D0,E0), ast(E0,T).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [C:5,8,4,0 bug(A) :- writeToPointer(A).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,O), cfg(U,P), cfg(V,M), compMemberAccess(N), ast(Q,N), ast(T,P), ast(T,S), ast(U,W), ast(U,X), ast(V,O), ast(V,Y), cfg(R,Z), cfg(S,T), cfg(Q,X), cfg(Y,V), ref(A0,U), assignment(T), assignment(V), ast(Y,Z), ast(Y,B0), ast(W,K), ast(W,T), ast(W,V), ast(W,C0), ast(Z,R), cfg(Z,Y), alloc(Z), ast(C0,A), ast(C0,I), ast(C0,J), ast(C0,Q).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A),
# 	ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,
# 	B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L),
# 	ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,
# 	J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,O),
# 	cfg(U,P), cfg(V,M), compMemberAccess(N), ast(Q,N), ast(T,
# 	P), ast(T,S), ast(U,W), ast(U,X), ast(V,O), ast(V,Y),
# 	cfg(R,Z), cfg(S,T), cfg(Q,X), cfg(Y,V), ref(A0,U), assignment(T),
# 	assignment(V), ast(Y,Z), ast(W,K), ast(W,T), ast(W,V),
# 	ast(W,B0), ast(Z,R), cfg(Z,Y), alloc(Z), ast(B0,A),
# 	ast(B0,I), ast(B0,J), ast(B0,Q).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [C:5,8,4,0 bug(A) :- writeToPointer(A).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M), cfg(U,P), cfg(V,O), compMemberAccess(N), ast(Q,N), ast(T,O), ast(T,W), ast(U,X), ast(U,Y), cfg(Q,Y), cfg(S,Z), cfg(R,A0), cfg(W,T), cfg(Z,V), ref(B0,U), assignment(T), ast(X,K), ast(X,T), ast(X,V), ast(X,Z), ast(X,C0), ast(X,D0), ast(W,A0), ast(W,E0), ast(Z,P), ast(Z,S), ast(A0,R), cfg(A0,W), assignment(Z), alloc(A0), ast(C0,A), ast(C0,I), ast(C0,J), ast(C0,Q).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,
# 	F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B),
# 	cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,
# 	M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,J),
# 	ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M),
# 	cfg(U,P), cfg(V,O), compMemberAccess(N), ast(Q,N), ast(T,
# 	O), ast(T,W), ast(U,X), ast(U,Y), cfg(Q,Y), cfg(S,Z),
# 	cfg(R,A0), cfg(W,T), cfg(Z,V), ref(B0,U), assignment(T),
# 	ast(X,K), ast(X,T), ast(X,V), ast(X,Z), ast(X,C0), ast(W,
# 	A0), ast(Z,P), ast(Z,S), ast(A0,R), cfg(A0,W), assignment(Z),
# 	alloc(A0), ast(C0,A), ast(C0,I), ast(C0,J), ast(C0,Q).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [6 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M), cfg(T,O), cfg(U,P), cfg(V,M), compMemberAccess(N), ast(Q,N), ast(T,W), ast(T,X), ast(U,Y), ast(U,Z), ast(V,O), ast(V,A0), cfg(R,B0), cfg(S,C0), cfg(Q,Z), cfg(A0,V), cfg(W,T), ref(D0,U), assignment(V), ast(A0,B0), ast(A0,E0), ast(Y,K), ast(Y,C0), ast(Y,F0), ast(Y,G0), ast(B0,R), ast(C0,P), ast(C0,S), cfg(X,W), cfg(B0,A0), cfg(C0,X), assignment(C0), alloc(B0), ast(F0,A), ast(F0,I), ast(F0,J), ast(F0,Q), ast(G0,T), ast(G0,H0), ast(H0,V).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,
# 	F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B),
# 	cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,
# 	M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J),
# 	ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M),
# 	cfg(T,O), cfg(U,P), cfg(V,M), compMemberAccess(N), ast(Q,
# 	N), ast(T,W), ast(T,X), ast(U,Y), ast(U,Z), ast(V,O),
# 	ast(V,A0), cfg(R,B0), cfg(S,C0), cfg(Q,Z), cfg(A0,V),
# 	cfg(W,T), ref(D0,U), assignment(V), ast(A0,B0), ast(Y,
# 	K), ast(Y,C0), ast(Y,E0), ast(Y,F0), ast(B0,R), ast(C0,
# 	P), ast(C0,S), cfg(X,W), cfg(B0,A0), cfg(C0,X), assignment(C0),
# 	alloc(B0), ast(E0,A), ast(E0,I), ast(E0,J), ast(E0,Q),
# 	ast(F0,T), ast(F0,G0), ast(G0,V).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [6 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M), cfg(U,M), cfg(U,O), cfg(V,P), compMemberAccess(N), ast(Q,N), ast(T,O), ast(T,W), ast(V,X), ast(V,Y), cfg(Q,Y), cfg(S,Z), cfg(R,A0), cfg(W,T), cfg(Z,U), ref(B0,V), assignment(T), ast(W,A0), ast(W,C0), ast(X,K), ast(X,Z), ast(X,D0), ast(X,E0), ast(A0,R), ast(Z,P), ast(Z,S), cfg(A0,W), assignment(Z), alloc(A0), ast(D0,A), ast(D0,I), ast(D0,J), ast(D0,Q), ast(E0,U), ast(E0,F0), ast(F0,T).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,
# 	F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B),
# 	cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,
# 	M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J),
# 	ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M),
# 	cfg(U,M), cfg(U,O), cfg(V,P), compMemberAccess(N), ast(Q,
# 	N), ast(T,O), ast(T,W), ast(V,X), ast(V,Y), cfg(Q,Y),
# 	cfg(S,Z), cfg(R,A0), cfg(W,T), cfg(Z,U), ref(B0,V),
# 	assignment(T), ast(W,A0), ast(X,K), ast(X,Z), ast(X,C0),
# 	ast(X,D0), ast(A0,R), ast(Z,P), ast(Z,S), cfg(A0,W),
# 	assignment(Z), alloc(A0), ast(C0,A), ast(C0,I), ast(C0,
# 	J), ast(C0,Q), ast(D0,U), ast(D0,E0), ast(E0,T).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [6 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M), cfg(U,O), cfg(V,P), compMemberAccess(N), ast(Q,N), ast(T,O), ast(T,W), ast(U,P), ast(U,S), ast(V,X), ast(V,Y), cfg(R,Z), cfg(S,U), cfg(Q,Y), cfg(W,T), ref(A0,V), assignment(T), assignment(U), ast(X,K), ast(X,T), ast(X,U), ast(X,B0), ast(W,Z), ast(W,C0), ast(Z,R), cfg(Z,W), alloc(Z), ast(B0,A), ast(B0,I), ast(B0,J), ast(B0,Q).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), ast(B,
# 	F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B),
# 	cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,
# 	M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,J),
# 	ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M),
# 	cfg(U,O), cfg(V,P), compMemberAccess(N), ast(Q,N), ast(T,
# 	O), ast(T,W), ast(U,P), ast(U,S), ast(V,X), ast(V,Y),
# 	cfg(R,Z), cfg(S,U), cfg(Q,Y), cfg(W,T), ref(A0,V), assignment(T),
# 	assignment(U), ast(X,K), ast(X,T), ast(X,U), ast(X,B0),
# 	ast(W,Z), ast(Z,R), cfg(Z,W), alloc(Z), ast(B0,A), ast(B0,
# 	I), ast(B0,J), ast(B0,Q).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [6 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62804_id_111_f_loop_01_c_l_32_c_12_).]
# [Generalising <bug(bad_62804_id_111_f_loop_01_c_l_32_c_12_).>]
# bug(A) :- ast(A,B), ast(A,C), cfg(A,D), cfg(B,A), assignment(A), ast(B,E), ast(B,F), ast(C,G), ast(C,H), cfg(C,F), cfg(D,I), cfg(E,B), cfg(G,C), ref(D,J), compMemberAccess(B), compMemberAccess(C), ast(I,D), cfg(F,E), cfg(H,G), cfg(I,K), cfg(L,H), ref(E,J), ref(F,M), ref(G,J), ref(H,N), ref(K,J), ref(O,J), ast(L,K), ast(L,P), cfg(K,P), cfg(L,Q), cfg(O,R), cfg(P,L), cfg(S,K), cfg(T,O), ref(Q,N), ref(U,M), ref(V,N), ref(W,N), ast(S,O), ast(S,R), ast(T,U), cfg(R,S), cfg(Q,X), cfg(U,T), cfg(V,Y), cfg(W,Z), cfg(A0,V), cfg(B0,U), cfg(C0,W), assignment(S), assignment(T), ast(A0,W), ast(A0,Z), ast(B0,V), ast(B0,D0), ast(C0,E0), ast(C0,F0), cfg(Y,G0), cfg(X,H0), cfg(Z,A0), cfg(D0,B0), ref(I0,C0), assignment(A0), assignment(B0), ast(E0,N), ast(E0,A0), ast(E0,B0), ast(E0,J0), ast(D0,G0), ast(D0,K0), ast(H0,Q), ast(H0,X), ast(G0,Y), cfg(H0,L0), cfg(G0,D0), cfg(L0,F0), compMemberAccess(H0), alloc(G0), ast(J0,J), ast(J0,M), ast(J0,T), ast(J0,L0), ast(J0,M0), ast(L0,H0), ast(M0,I), ast(M0,L), ast(M0,S), ast(M0,N0), ast(N0,A).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), cfg(A,D), cfg(B,A), assignment(A),
# 	ast(B,E), ast(B,F), ast(C,G), ast(C,H), cfg(C,F), cfg(D,
# 	I), cfg(E,B), cfg(G,C), ref(D,J), compMemberAccess(B),
# 	compMemberAccess(C), ast(I,D), cfg(F,E), cfg(H,G), cfg(I,
# 	K), cfg(L,H), ref(E,J), ref(F,M), ref(G,J), ref(H,N),
# 	ref(K,J), ref(O,J), ast(L,K), ast(L,P), cfg(K,P), cfg(L,
# 	Q), cfg(O,R), cfg(P,L), cfg(S,K), cfg(T,O), ref(Q,N),
# 	ref(U,M), ref(V,N), ref(W,N), ast(S,O), ast(S,R), ast(T,
# 	U), cfg(R,S), cfg(Q,X), cfg(U,T), cfg(V,Y), cfg(W,Z),
# 	cfg(A0,V), cfg(B0,U), cfg(C0,W), assignment(S), assignment(T),
# 	ast(A0,W), ast(A0,Z), ast(B0,V), ast(B0,D0), ast(C0,
# 	E0), ast(C0,F0), cfg(Y,G0), cfg(X,H0), cfg(Z,A0), cfg(D0,
# 	B0), ref(I0,C0), assignment(A0), assignment(B0), ast(E0,
# 	N), ast(E0,A0), ast(E0,B0), ast(E0,J0), ast(D0,G0), ast(H0,
# 	Q), ast(H0,X), ast(G0,Y), cfg(H0,K0), cfg(G0,D0), cfg(K0,
# 	F0), compMemberAccess(H0), alloc(G0), ast(J0,J), ast(J0,
# 	M), ast(J0,T), ast(J0,K0), ast(J0,L0), ast(K0,H0), ast(L0,
# 	I), ast(L0,L), ast(L0,S), ast(L0,M0), ast(M0,A).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [5 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
#
# [Total time taken 3.116s]
