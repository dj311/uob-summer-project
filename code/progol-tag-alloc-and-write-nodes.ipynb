# %% [markdown]
# # Prolog Experiment: Tag the memory allocation and write nodes.

# %%
import pandas as pd
import tempfile
import subprocess
import graph_visualisation

# %% [markdown]
# *Idea:* in [previous experiments](./joern-ey-into-progol.ipynb) we've only tagged the memory write as a bug. This makes sense, since this is the spot where the program will crash. However, the memory allocation is also pretty important, since this is where the mistake lies. In this notebook we tag both nodes as buggy, like:
#
# `bug(MemoryAllocNode, MemoryWriteNode).`

# %% [markdown]
# This also has the potential to solve some complexity issues. Previously we've gotten rules which navigate across to the referenced pointer, but are unable to move up the ast edges to the memory allocation node. E.g.

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(
        "bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ast(A,D), ast(A,E), ref(E,F), sizeOf(C), ancestor(D,B), ast(C,B), ast(D,C)."
))

# %% [markdown]
# We believe the memory allocation is a parent of `F`, and so we want it to find a rule like:

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot("""
bug(A) :- writeToPointer(A), ancestor(A,C), ancestor(A,E), ref(E,F), sizeOf(C), ancestor(C,B), 
	ancestor(G,F), ancestor(G,H), alloc(H), ancestor(H,I), not(sizeOf(I)).
"""))

# %% [markdown]
# By directly tagging `A` and `G`, maybe our system will only have to find:
#
#   - the small sub graphs rooted at `A` and `G` respectively
#   - the reference edge linking them

# %% [markdown]
# In the section below we load in the dataset as in the "Joern-ey into Progol" notebook.

# %%
ilp_data = pd.read_csv("../data/ilp_dataset.csv.gz")
ilp_data = ilp_data.drop("Unnamed: 0", axis=1)
ilp_data.head()
# Out:
#    testcase_ID                                           filename  \
# 0        62804  000/062/804/CWE121_Stack_Based_Buffer_Overflow...
# 1        62821  000/062/821/CWE121_Stack_Based_Buffer_Overflow...
# 2        62852  000/062/852/CWE121_Stack_Based_Buffer_Overflow...
# 3        62853  000/062/853/CWE121_Stack_Based_Buffer_Overflow...
# 4        62854  000/062/854/CWE121_Stack_Based_Buffer_Overflow...
#
#                                                 code     flaw  flaw_loc  \
# 0  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 1  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        35
# 2  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 3  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 4  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
#
#      bug  code_length
# 0  False         1722
# 1  False         1808
# 2  False         1674
# 3  False         2396
# 4  False         2414

# %%
prolog = pd.read_csv("../data/ilp_prolog_data.csv.gz")
prolog = prolog.drop("Unnamed: 0", axis=1)
prolog.head()
# Out:
#    testcase_ID     flaw   bug  code_length  \
# 0      -232086  CWE-122  True         1625
# 1      -232012  CWE-122  True         1619
# 2       -62917  CWE-121  True         1622
# 3       -62916  CWE-121  True         1649
# 4       -62915  CWE-121  True         1638
#
#                                                 tree  \
# 0  % START: Generated Prolog\n% NODE PROPERTIES \...
# 1  % START: Generated Prolog\n% NODE PROPERTIES \...
# 2  % START: Generated Prolog\n% NODE PROPERTIES \...
# 3  % START: Generated Prolog\n% NODE PROPERTIES \...
# 4  % START: Generated Prolog\n% NODE PROPERTIES \...
#
#                                           source_map
# 0  % CODE\nsource_code(bad_232086_id_1_f_l_c_, "p...
# 1  % CODE\nsource_code(bad_232012_id_1_f_l_48_c_1...
# 2  % CODE\nsource_code(bad_62917_id_0_f_l_c_, "p1...
# 3  % CODE\nsource_code(bad_62916_id_0_f_l_c_, "p1...
# 4  % CODE\nsource_code(bad_62915_id_0_f_l_c_, "p2...

# %%
juliet = pd.read_csv("../data/buffer_overflow_data.csv.gz")
juliet.drop("Unnamed: 0", axis=1)

prolog['source_code'] = ''
prolog['flaw_loc'] = 0
prolog['bad_code'] = ''

for i in range(len(prolog)):
    label = prolog.iloc[i].testcase_ID == juliet.testcase_ID
    prolog['source_code'].iloc[i] = juliet.loc[label].iloc[0].code
    prolog['flaw_loc'].iloc[i] = juliet.loc[label].iloc[0].flaw_loc
    
for i in range(len(prolog)):
    loc =  prolog.iloc[i].flaw_loc
    testcase_ID = prolog.iloc[i].testcase_ID
    if testcase_ID < 0:
        prolog['bad_code'].iloc[i] = prolog.iloc[i].source_code.split('\n')[loc-1].strip()[0:-1]
    else:
        prolog['bad_code'].iloc[i] = prolog.loc[prolog.testcase_ID == -testcase_ID].iloc[0].bad_code
        
good_examples = prolog[prolog['bug'] == False]
bad_examples = prolog[prolog['bug'] == True]

# %%
def extract_node_ids(tree):
    nodes = set()
    
    in_ast_section = False
    
    for line in tree.split('\n'):
        line = line.strip()
        
        if line == '% AST':
            in_ast_section = True
        
        if line == '% CFG':
            in_ast_section = False
            
        if line == '% REF':
            in_ast_section = False
        
        if in_ast_section and not line.startswith("%"):
            parent, child = line[4:-2].split(", ")
            nodes.add(parent)
            nodes.add(child)
            
    return nodes

# %%
# good nodes_g
nodes_g = set()

for i in range(len(good_examples)):
    good_nodes = extract_node_ids(good_examples.iloc[i].tree)
    nodes_g = set.union(nodes_g,good_nodes)

    
# bad nodes_b
nodes_b = set()

for i in range(len(bad_examples)):
    bad_nodes = extract_node_ids(bad_examples.iloc[i].tree)
    nodes_b = set.union(nodes_b,bad_nodes)

nodes = set.union(nodes_g,nodes_b)

# %%
def find_bug_id(good_examples, i = 0):
    tree = good_examples.source_map.iloc[i]
    parents = []
    children = []
    in_code_section = False
    temp = 0
    for line in tree.split('\n'):
        line = line.strip()
        
        if line == '% CODE':
            in_code_section = True
        
        if in_code_section and not line.startswith("%"):
            try:
                #import pdb; pdb.set_trace()
                parent, child = line[12:-3].split(', "')
                parents.append(parent)
                children.append(child)
            except:
                temp +=1
    zipbObj = zip(children, parents)
    bug_node = dict(zipbObj)
    
    loc = good_examples.iloc[i].flaw_loc
    source_code = good_examples.iloc[i].bad_code

    return bug_node[source_code]

# %%
bad_node = []
good_node = []
for i in range(20):
    bad_node.append(find_bug_id(bad_examples,i))
    good_node.append(find_bug_id(good_examples,i))

# %%
node_and_tree = []
for node in nodes:
    start, end = node.split('_id')
    node_and_tree.append('(' +start+ ', ' +node+ ')')

node_and_tree[0:5]
# Out:
# ['(good_62902, good_62902_id_135_f_memmove_03_c_l_52_c_39_)',
#  '(good_62854, good_62854_id_18_f_l_c_)',
#  '(good_62865, good_62865_id_19_f_l_c_)',
#  '(good_62909, good_62909_id_42_f_l_c_)',
#  '(bad_62916, bad_62916_id_60_f_l_c_)']

# %%
node_tree_types = [
    'node_in_tree'+ node_tree +'.' for node_tree in node_and_tree
]

# %%
node_types = [
    'node('+ node_id +').' for node_id in nodes
]

# %%
def extract_tree_ids(tree):
    line = tree.split('\n')[2]
    line = line.strip()
    line = line.split('(')[1]
    tree_id = line.split('_id')[0]

    return tree_id

# %%
tree_ids = []
for tree in prolog.tree:
    tree_ids.append(extract_tree_ids(tree))

# %%
trees = [
    'tree('+ tree_label +').' for tree_label in tree_ids
]

# %%
def make_progol_script(header, positive_examples, negative_examples, testcases=None):
    script_template = """
{header}

%% Trees
{trees}

%% Types
{types}

%% background knowledge
{bg_knowledge}

%% learning task
%% positive examples
{positive_examples}

%% negative examples
{negative_examples}

    """
    script = script_template.format(
        header = header,
        trees =  '\n'.join(trees),
        types = '\n'.join(node_tree_types + node_types),
        bg_knowledge = '\n'.join(prolog['tree']),
        positive_examples='\n'.join(positive_examples),
        negative_examples='\n'.join(negative_examples),
    )
    
    # keep all testcases unless a testcases set is given in fn call
    if testcases:
        # remove all lines not related to this testcase
        script = '\n'.join([
            line for line in script.split("\n")  if any(
                str(testcase) in line for testcase in testcases
            ) or not ("good_" in line or "bad_" in line)
        ])
    
    return script

# %% [markdown]
# Here we try to locate the buggy nodes. For each test case this will be:
#   1. Location where the memory is _allocated_.
#   2. Location where the memory is _written to_.
#
# We already have code above to find the latter. Can we find the first as well?

# %%
bad_write_nodes = bad_node
good_write_nodes = good_node

# %%
# this code is horrible sorry. if you need to figure out what it does speak to Dan.

alloc_source_maps = [
    line
    for source_map in prolog['source_map']
    for line in source_map.split("\n")
    if 'data =' in line.lower() and 'alloc' in line.lower()
]
bad_alloc_nodes = [
    source_map.strip("source_code(").split(",")[0]
    for source_map in alloc_source_maps
    if 'bad' in source_map
]

good_alloc_nodes = [
    source_map.strip("source_code(").split(",")[0]
    for source_map in alloc_source_maps
    if 'good' in source_map
]

positive_examples = []
for write_node in bad_write_nodes:
    # find the alloc node which has a line number before the write
    write_node_id = write_node.strip("source_code(").split(",")[0] + "_"
    write_line = int(write_node_id.split("_")[-4])
    
    testcase_id = '_'.join(write_node_id.split("_")[0:2])
    
    potential_alloc_nodes = [node for node in bad_alloc_nodes if testcase_id in node]
    for alloc_node in potential_alloc_nodes:
        alloc_node_id = alloc_node.strip("source_code(").split(",")[0] + "_"
        alloc_line = int(alloc_node_id.split("_")[-4])
        
        if alloc_line <= write_line:
            positive_examples.append(
                "bug({},{}).".format(alloc_node_id, write_node_id)
            )
            
negative_examples = []
for write_node in good_write_nodes:
    # find the alloc node which has a line number before the write
    write_node_id = write_node.strip("source_code(").split(",")[0] + "_"
    write_line = int(write_node_id.split("_")[-4])
    
    testcase_id = '_'.join(write_node_id.split("_")[0:2])
    
    potential_alloc_nodes = [node for node in good_alloc_nodes if testcase_id in node]
    for alloc_node in potential_alloc_nodes:
        alloc_node_id = alloc_node.strip("source_code(").split(",")[0] + "_"
        alloc_line = int(alloc_node_id.split("_")[-4])
        
        if alloc_line <= write_line:
            negative_examples.append(
                ":- bug({},{}).".format(alloc_node_id, write_node_id)
            )

# %% [markdown]
# Next we experiment with settings and different rule structures to see if it can learn a rule:

# %%
header = """
% Settings
:- set(c,3)?
:- set(i,3)?
:- set(h,2000)?
:- set(cover)?
:- set(inflate,1500)?

% Mode declarations
:- modeh(*, bug(+node,+node))?

:- modeb(*, same_tree(+node,+node))?
:- modeb(*, same_tree(+node,-node))?
:- modeb(*, same_tree(-node,+node))?
:- modeb(*, same_tree(-node,-node))?

:- modeb(1, runs_before(+node,-node))?
:- modeb(5, ast(+node,-node))?

:- modeb(*, ref(+node,-node))?
:- modeb(*, ref(-node,+node))?

:- modeb(*, assignment(+node))?
:- modeb(*, compMemberAccess(+node))?
:- modeb(*, sizeOf(+node))?
:- modeb(*, alloc(+node))?
:- modeb(*, writeToPointer(+node))?

writeToPointer(A) :- ast(A,B), assignment(A), compMemberAccess(B). 

ancestor(A,C) :- ast(A,B), ancestor(B,C).
ancestor(A,C) :- ast(A,B), ast(B,C).

runs_before(A,C) :- cfg(A,B), runs_before(B,C).
runs_before(A,C) :- cfg(A,B), cfg(B,C).

same_tree(A,B) :- node_in_tree(T,A), node_in_tree(T,B).
"""

script = make_progol_script(
    header,
    positive_examples,
    negative_examples,
)

print(script)

with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# % Settings
# :- set(c,3)?
# :- set(i,)?
# :- set(h,2000)?
# :- set(cover)?
# :- set(inflate,1500)?
#
# % Mode declarations
# :- modeh(*, bug(+node,+node))?
#
# :- modeb(*, same_tree(+node,+node))?
# :- modeb(*, same_tree(+node,-node))?
# :- modeb(*, same_tree(-node,+node))?
# :- modeb(*, same_tree(-node,-node))?
#
# :- modeb(*, ancestor(+node,-node))?
#
# :- modeb(*, ref(+node,-node))?
# :- modeb(*, ref(-node,+node))?
#
# :- modeb(*, assignment(+node))?
# :- modeb(*, compMemberAccess(+node))?
# :- modeb(*, sizeOf(+node))?
# :- modeb(*, alloc(+node))?
# :- modeb(*, writeToPointer(+node))?
#
# writeToPointer(A) :- ast(A,B), assignment(A), compMemberAccess(B).
#
# ancestor(A,C) :- ast(A,B), ancestor(B,C).
# ancestor(A,C) :- ast(A,B), ast(B,C).
#
# runs_before(A,C) :- cfg(A,B), runs_before(B,C).
# runs_before(A,C) :- cfg(A,B), cfg(B,C).
#
# same_tree(A,B) :- node_in_tree(T,A), node_in_tree(T,B).
#
#
# %% Trees
# tree(bad_232086).
# tree(bad_232012).
# tree(bad_62917).
# tree(bad_62916).
# tree(bad_62915).
# tree(bad_62913).
# tree(bad_62909).
# tree(bad_62902).
# tree(bad_62901).
# tree(bad_62900).
# tree(bad_62869).
# tree(bad_62868).
# tree(bad_62867).
# tree(bad_62865).
# tree(bad_62861).
# tree(bad_62854).
# tree(bad_62853).
# tree(bad_62852).
# tree(bad_62821).
# tree(bad_62804).
# tree(good_62804).
# tree(good_62821).
# tree(good_62852).
# tree(good_62853).
# tree(good_62854).
# tree(good_62861).
# tree(good_62865).
# tree(good_62867).
# tree(good_62868).
# tree(good_62869).
# tree(good_62900).
# tree(good_62901).
# tree(good_62902).
# tree(good_62909).
# tree(good_62913).
# tree(good_62915).
# tree(good_62916).
# tree(good_62917).
# tree(good_232012).
# tree(good_232086).
#
# %% Types
# node_in_tree(good_62902, good_62902_id_135_f_memmove_03_c_l_52_c_39_).
# node_in_tree(good_62854, good_62854_id_18_f_l_c_).
# node_in_tree(good_62865, good_62865_id_19_f_l_c_).
# node_in_tree(good_62909, good_62909_id_42_f_l_c_).
# node_in_tree(bad_62916, bad_62916_id_60_f_l_c_).
# node_in_tree(good_62900, good_62900_id_0_f_l_c_).
# node_in_tree(good_62909, good_62909_id_79_f_memmove_10_c_l_87_c_11_).
# node_in_tree(bad_62917, bad_62917_id_74_f_l_c_).
# node_in_tree(bad_62916, bad_62916_id_19_f_l_c_).
# node_in_tree(bad_62916, bad_62916_id_100_f_memmove_17_c_l_52_c_26_).
# node_in_tree(bad_62854, bad_62854_id_36_f_l_c_).
# node_in_tree(good_232012, good_232012_id_96_f_l_c_).
# node_in_tree(good_62868, good_62868_id_100_f_memcpy_17_c_l_61_c_4_).
# node_in_tree(bad_62869, bad_62869_id_82_f_memcpy_18_c_l_56_c_11_).
# node_in_tree(bad_62861, bad_62861_id_17_f_l_c_).
# node_in_tree(good_62915, good_62915_id_139_f_memmove_16_c_l_29_c_16_).
# node_in_tree(bad_62861, bad_62861_id_134_f_memcpy_10_c_l_24_c_7_).
# node_in_tree(bad_62901, bad_62901_id_54_f_l_c_).
# node_in_tree(bad_62854, bad_62854_id_113_f_memcpy_03_c_l_33_c_21_).
# node_in_tree(good_62865, good_62865_id_18_f_l_c_).
# node_in_tree(bad_62804, bad_62804_id_66_f_l_c_).
# node_in_tree(bad_62865, bad_62865_id_41_f_l_c_).
# node_in_tree(bad_62902, bad_62902_id_31_f_l_c_).
# node_in_tree(good_62909, good_62909_id_48_f_l_c_).
# node_in_tree(good_232086, good_232086_id_15_f_l_54_c_19_).
# node_in_tree(good_62909, good_62909_id_4_f_l_c_).
# node_in_tree(bad_62868, bad_62868_id_165_f_l_21_c_0_).
# node_in_tree(bad_62909, bad_62909_id_94_f_memmove_10_c_l_51_c_12_).
# node_in_tree(bad_62868, bad_62868_id_49_f_l_c_).
# node_in_tree(bad_62821, bad_62821_id_119_f_loop_18_c_l_32_c_20_).
# node_in_tree(good_62917, good_62917_id_18_f_l_c_).
# node_in_tree(good_62909, good_62909_id_89_f_memmove_10_c_l_81_c_21_).
# node_in_tree(bad_232012, bad_232012_id_6_f_l_c_).
# node_in_tree(bad_62867, bad_62867_id_70_f_l_c_).
# node_in_tree(bad_232086, bad_232086_id_82_f_l_c_).
# node_in_tree(good_62916, good_62916_id_0_f_l_c_).
# node_in_tree(good_62917, good_62917_id_44_f_l_c_).
# node_in_tree(bad_62853, bad_62853_id_51_f_l_c_).
# node_in_tree(good_62909, good_62909_id_123_f_memmove_10_c_l_52_c_29_).
# node_in_tree(good_62861, good_62861_id_109_f_memcpy_10_c_l_64_c_0_).
# node_in_tree(bad_62902, bad_62902_id_11_f_l_c_).
# node_in_tree(bad_62902, bad_62902_id_64_f_l_c_).
# node_in_tree(bad_62865, bad_62865_id_32_f_l_c_).
# node_in_tree(bad_62902, bad_62902_id_161_f_l_c_).
# node_in_tree(good_62821, good_62821_id_45_f_l_c_).
# node_in_tree(bad_62865, bad_62865_id_141_f_memcpy_14_c_l_24_c_19_).
# node_in_tree(bad_232086, bad_232086_id_29_f_l_c_).
# node_in_tree(good_62869, good_62869_id_99_f_memcpy_18_c_l_56_c_4_).
# node_in_tree(bad_62804, bad_62804_id_88_f_l_50_c_0_).
# node_in_tree(good_62917, good_62917_id_131_f_memmove_18_c_l_29_c_35_).
# node_in_tree(bad_62852, bad_62852_id_139_f_l_21_c_0_).
# node_in_tree(good_62916, good_62916_id_62_f_l_c_).
# node_in_tree(bad_232012, bad_232012_id_13_f_l_c_).
# node_in_tree(good_62913, good_62913_id_85_f_l_c_).
# node_in_tree(bad_62854, bad_62854_id_24_f_l_c_).
# node_in_tree(good_62909, good_62909_id_107_f_memmove_10_c_l_58_c_21_).
# node_in_tree(good_62804, good_62804_id_12_f_l_c_).
# node_in_tree(good_62901, good_62901_id_170_f_memmove_02_c_l_34_c_29_).
# node_in_tree(good_62854, good_62854_id_34_f_l_c_).
# node_in_tree(good_62854, good_62854_id_133_f_memcpy_03_c_l_57_c_32_).
# node_in_tree(good_62869, good_62869_id_145_f_memcpy_18_c_l_25_c_11_).
# node_in_tree(bad_62901, bad_62901_id_47_f_l_c_).
# node_in_tree(good_62902, good_62902_id_174_f_memmove_03_c_l_39_c_22_).
# node_in_tree(good_62865, good_62865_id_112_f_l_79_c_19_).
# node_in_tree(bad_62867, bad_62867_id_2_f_l_c_).
# node_in_tree(good_62854, good_62854_id_64_f_l_c_).
# node_in_tree(good_62868, good_62868_id_34_f_l_c_).
# node_in_tree(good_62901, good_62901_id_182_f_memmove_02_c_l_29_c_8_).
# node_in_tree(bad_62913, bad_62913_id_69_f_l_c_).
# node_in_tree(good_62854, good_62854_id_31_f_l_c_).
# node_in_tree(good_62853, good_62853_id_147_f_memcpy_02_c_l_49_c_4_).
# node_in_tree(bad_232012, bad_232012_id_58_f_l_c_).
# node_in_tree(bad_62854, bad_62854_id_64_f_l_c_).
# node_in_tree(good_62853, good_62853_id_175_f_memcpy_02_c_l_34_c_22_).
# node_in_tree(bad_62916, bad_62916_id_4_f_l_50_c_19_).
# node_in_tree(good_62868, good_62868_id_158_f_memcpy_17_c_l_27_c_22_).
# node_in_tree(good_232012, good_232012_id_173_f_memcpy_01_c_l_27_c_18_).
# node_in_tree(bad_62868, bad_62868_id_102_f_memcpy_17_c_l_52_c_21_).
# node_in_tree(good_62901, good_62901_id_177_f_memmove_02_c_l_34_c_8_).
# node_in_tree(good_62804, good_62804_id_175_f_l_c_).
# node_in_tree(good_62868, good_62868_id_28_f_l_c_).
# node_in_tree(bad_62854, bad_62854_id_19_f_l_c_).
# node_in_tree(bad_62854, bad_62854_id_45_f_l_c_).
# node_in_tree(good_62916, good_62916_id_33_f_l_c_).
# node_in_tree(good_232012, good_232012_id_95_f_l_c_).
# node_in_tree(good_62902, good_62902_id_164_f_memmove_03_c_l_40_c_26_).
# node_in_tree(good_62853, good_62853_id_133_f_memcpy_02_c_l_52_c_39_).
# node_in_tree(good_62865, good_62865_id_64_f_l_c_).
# node_in_tree(good_62852, good_62852_id_60_f_l_c_).
# node_in_tree(good_232086, good_232086_id_72_f_l_c_).
# node_in_tree(bad_62867, bad_62867_id_111_f_memcpy_16_c_l_33_c_39_).
# node_in_tree(good_62869, good_62869_id_91_f_memcpy_18_c_l_58_c_4_).
# node_in_tree(good_62868, good_62868_id_131_f_memcpy_17_c_l_35_c_39_).
# node_in_tree(good_62902, good_62902_id_130_f_memmove_03_c_l_57_c_8_).
# node_in_tree(bad_62853, bad_62853_id_5_f_l_c_).
# node_in_tree(bad_62852, bad_62852_id_5_f_l_c_).
# node_in_tree(bad_62900, bad_62900_id_147_f_l_c_).
# node_in_tree(good_62869, good_62869_id_43_f_l_c_).
# node_in_tree(good_62804, good_62804_id_4_f_l_c_).
# node_in_tree(good_62902, good_62902_id_149_f_memmove_03_c_l_49_c_4_).
# node_in_tree(bad_62865, bad_62865_id_87_f_memcpy_14_c_l_57_c_4_).
# node_in_tree(good_62854, good_62854_id_135_f_memcpy_03_c_l_57_c_29_).
# node_in_tree(bad_62913, bad_62913_id_34_f_l_c_).
# node_in_tree(good_62853, good_62853_id_10_f_l_79_c_9_).
# node_in_tree(good_62909, good_62909_id_14_f_l_c_).
# node_in_tree(bad_62902, bad_62902_id
f_l_c_).
# node_in_tree(bad_62868, bad_62868_id_2_f_l_c_).
# node_in_tree(good_62869, good_62869_id_67_f_l_c_).
# node_in_tree(bad_62852, bad_62852_id_123_f_memcpy_01_c_l_27_c_12_).
# node_in_tree(bad_62821, bad_62821_id_35_f_l_c_).
# node_in_tree(good_62901, good_62901_id_15_f_l_c_).
# node_in_tree(bad_62821, bad_62821_id_101_f_loop_18_c_l_36_c_21_).
# node_in_tree(bad_62909, bad_62909_id_99_f_memmove_10_c_l_50_c_0_).
# node_in_tree(good_62821, good_62821_id_21_f_l_c_).
# node_in_tree(good_62867, good_62867_id_71_f_l_c_).
# node_in_tree(bad_62869, bad_62869_id_19_f_l_c_).
# node_in_tree(bad_62804, bad_62804_id_24_f_l_c_).
# node_in_tree(good_62916, good_62916_id_57_f_l_c_).
# node_in_tree(bad_62854, bad_62854_id_74_f_l_c_).
# node_in_tree(good_62804, good_62804_id_9_f_l_c_).
# node_in_tree(bad_62853, bad_62853_id_57_f_l_c_).
# node_in_tree(bad_62804, bad_62804_id_90_f_l_50_c_9_).
# node_in_tree(good_62869, good_62869_id_68_f_l_c_).
# node_in_tree(good_62909, good_62909_id_54_f_l_c_).
# node_in_tree(bad_62868, bad_62868_id_35_f_l_c_).
# node_in_tree(good_62821, good_62821_id_41_f_l_c_).
# node_in_tree(bad_62901, bad_62901_id_18_f_l_c_).
# node_in_tree(good_62869, good_62869_id_88_f_memcpy_18_c_l_59_c_4_).
# node_in_tree(good_62917, good_62917_id_30_f_l_c_).
# node_in_tree(good_62853, good_62853_id_65_f_l_c_).
# node_in_tree(good_62900, good_62900_id_74_f_l_c_).
# node_in_tree(good_62865, good_62865_id_44_f_l_c_).
# node_in_tree(bad_62821, bad_62821_id_142_f_l_c_).
# node_in_tree(bad_62916, bad_62916_id_157_f_memmove_17_c_l_24_c_11_).
# node_in_tree(bad_62804, bad_62804_id_30_f_l_c_).
# node_in_tree(bad_62913, bad_62913_id_126_f_memmove_14_c_l_32_c_16_).
# node_in_tree(bad_62915, bad_62915_id_109_f_memmove_16_c_l_34_c_21_).
# node_in_tree(good_62861, good_62861_id_196_f_l_57_c_).
# node_in_tree(good_62900, good_62900_id_16_f_l_c_).
# node_in_tree(good_62852, good_62852_id_126_f_memcpy_01_c_l_31_c_8_).
# node_in_tree(bad_62916, bad_62916_id_163_f_memmove_17_c_l_22_c_0_).
# node_in_tree(good_62854, good_62854_id_28_f_l_c_).
# node_in_tree(good_62913, good_62913_id_171_f_memmove_14_c_l_39_c_33_).
# node_in_tree(bad_62902, bad_62902_id_40_f_l_c_).
# node_in_tree(good_62852, good_62852_id_154_f_l_27_c_).
# node_in_tree(good_62868, good_62868_id_184_f_l_c_).
# node_in_tree(good_62865, good_62865_id_195_f_memcpy_14_c_l_34_c_8_).
# node_in_tree(bad_232086, bad_232086_id_23_f_l_c_).
# node_in_tree(good_62865, good_62865_id_154_f_memcpy_14_c_l_52_c_16_).
# node_in_tree(bad_62867, bad_62867_id_23_f_l_c_).
# node_in_tree(bad_62821, bad_62821_id_132_f_loop_18_c_l_27_c_12_).
# node_in_tree(bad_62865, bad_62865_id_137_f_memcpy_14_c_l_27_c_15_).
# node_in_tree(bad_62915, bad_62915_id_100_f_l_50_c_0_).
# node_in_tree(bad_62900, bad_62900_id_54_f_l_c_).
# node_in_tree(good_62913, good_62913_id_9_f_l_c_).
# node_in_tree(bad_232012, bad_232012_id_173_f_l_c_).
# node_in_tree(good_62909, good_62909_id_12_f_l_79_c_19_).
# node_in_tree(good_62915, good_62915_id_131_f_memmove_16_c_l_29_c_39_).
# node_in_tree(bad_62916, bad_62916_id_150_f_memmove_17_c_l_25_c_15_).
# node_in_tree(good_62853, good_62853_id_191_f_memcpy_02_c_l_24_c_0_).
# node_in_tree(good_62902, good_62902_id_107_f_memmove_03_c_l_81_c_4_).
# node_in_tree(good_232012, good_232012_id_24_f_l_c_).
# node_in_tree(good_62913, good_62913_id_40_f_l_c_).
# node_in_tree(good_62916, good_62916_id_75_f_l_c_).
# node_in_tree(good_62867, good_62867_id_119_f_memcpy_16_c_l_35_c_39_).
# node_in_tree(good_62916, good_62916_id_64_f_l_c_).
# node_in_tree(bad_62853, bad_62853_id
f_l_c_).
# node_in_tree(bad_62902, bad_62902_id_42_f_l_c_).
# node_in_tree(good_62854, good_62854_id_85_f_l_c_).
# node_in_tree(good_62909, good_62909_id_138_f_l_46_c_0_).
# node_in_tree(good_62821, good_62821_id_102_f_loop_18_c_l_59_c_0_).
# node_in_tree(bad_62916, bad_62916_id_0_f_l_c_).
# node_in_tree(bad_62861, bad_62861_id_28_f_l_c_).
# node_in_tree(bad_62861, bad_62861_id_136_f_memcpy_10_c_l_23_c_11_).
# node_in_tree(bad_62917, bad_62917_id_39_f_l_c_).
# node_in_tree(bad_62917, bad_62917_id_118_f_memmove_18_c_l_31_c_16_).
# node_in_tree(good_62861, good_62861_id_163_f_memcpy_10_c_l_37_c_12_).
# node_in_tree(good_62867, good_62867_id_26_f_l_c_).
# node_in_tree(good_62853, good_62853_id_89_f_memcpy_02_c_l_83_c_14_).
# node_in_tree(good_62917, good_62917_id_122_f_memmove_18_c_l_33_c_30_).
# node_in_tree(good_62909, good_62909_id_28_f_l_c_).
# node_in_tree(good_62916, good_62916_id_156_f_memmove_17_c_l_27_c_22_).
# node_in_tree(bad_62917, bad_62917_id_19_f_l_c_).
# node_in_tree(good_62853, good_62853_id_115_f_memcpy_02_c_l_58_c_26_).
# node_in_tree(good_232012, good_232012_id_73_f_l_c_).
# node_in_tree(bad_62852, bad_62852_id_46_f_l_c_).
# node_in_tree(good_62902, good_62902_id_118_f_l_63_c_0_).
# node_in_tree(bad_62821, bad_62821_id_112_f_loop_18_c_l_33_c_8_).
# node_in_tree(good_62902, good_62902_id_120_f_memmove_03_c_l_58_c_26_).
# node_in_tree(bad_232012, bad_232012_id_18_f_l_c_).
# node_in_tree(good_62900, good_62900_id_159_f_l_c_).
# node_in_tree(bad_62869, bad_62869_id_150_f_l_c_).
# node_in_tree(good_62865, good_62865_id_205_f_memcpy_14_c_l_26_c_7_).
# node_in_tree(bad_62909, bad_62909_id_11_f_l_c_).
# node_in_tree(good_62913, good_62913_id_175_f_memmove_14_c_l_39_c_16_).
# node_in_tree(good_62915, good_62915_id_120_f_memmove_16_c_l_35_c_30_).
# node_in_tree(bad_62868, bad_62868_id_46_f_l_c_).
# node_in_tree(good_62902, good_62902_id_146_f_memmove_03_c_l_49_c_7_).
# node_in_tree(good_62869, good_62869_id_75_f_l_c_).
# node_in_tree(good_62853, good_62853_id_167_f_memcpy_02_c_l_37_c_12_).
# node_in_tree(bad_232086, bad_232086_id_6_f_l_c_).
# node_in_tree(good_62915, good_62915_id_50_f_l_c_).
# node_in_tree(good_232012, good_232012_id_39_f_l_c_).
# node_in_tree(good_62854, good_62854_id_162_f_memcpy_03_c_l_49_c_4_).
# node_in_tree(good_62861, good_62861_id_89_f_memcpy_10_c_l_83_c_4_).
# node_in_tree(bad_62913, bad_62913_id_109_f_l_49_c_9_).
# node_in_tree(bad_232086, bad_232086_id_68_f_l_c_).
# node_in_tree(good_62901, good_62901_id_73_f_l_c_).
# node_in_tree(good_62869, good_62869_id_143_f_memcpy_18_c_l_27_c_0_).
# node_in_tree(bad_62861, bad_62861_id_85_f_memcpy_10_c_l_55_c_4_).
# node_in_tree(good_232012, good_232012_id_107_f_memcpy_01_c_l_59_c_4_).
# node_in_tree(bad_232086, bad_232086_id_11_f_l_c_).
# node_in_tree(bad_62902, bad_62902_id_54_f_l_c_).
# node_in_tree(bad_62867, bad_62867_id_15_f_l_c_).
# node_in_tree(good_62901, good_62901_id_154_f_memmove_02_c_l_40_c_8_).
# node_in_tree(bad_62804, bad_62804_id_53_f_l_c_).
# node_in_tree(bad_62913, bad_62913_id_95_f_memmove_14_c_l_53_c_14_).
# node_in_tree(good_62901, good_62901_id_40_f_l_c_).
# node_in_tree(good_62861, good_62861_id_35_f_l_c_).
# node_in_tree(good_62909, good_62909_id_136_f_l_c_).
# node_in_tree(bad_62900, bad_62900_id_49_f_l_c_).
# node_in_tree(good_62853, good_62853_id_11_f_l_c_).
# node_in_tree(good_62867, good_62867_id_3_f_l_c_).
# node_in_tree(good_62861, good_62861_id_159_f_memcpy_10_c_l_39_c_21_).
# node_in_tree(bad_62869, bad_62869_id_33_f_l_c_).
# node_in_tree(good_62869, good_62869_id_73_f_l_c_).
# node_in_tree(bad_62909, bad_62909_id_39_f_l_c_).
# node_in_tree(bad_62861, bad_62861_id_90_f_memcpy_10_c_l_53_c_4_).
# node_in_tree(bad_62869, bad_62869_id_62_f_l_c_).
# node_in_tree(good_62917, good_62917_id_2_f_l_c_).
# node_in_tree(bad_62901, bad_62901_id_9_f_l_c_).
# node_in_tree(good_62854, good_62854_id_226_f_l_c_).
# node_in_tree(good_62861, good_62861_id_45_f_l_c_).
# node_in_tree(good_62915, good_62915_id_57_f_l_c_).
# node_in_tree(bad_62867, bad_62867_id_153_f_l_c_).
# node_in_tree(bad_62917, bad_62917_id_121_f_memmove_18_c_l_29_c_12_).
# node_in_tree(bad_62869, bad_62869_id_57_f_l_c_).
# node_in_tree(good_62853, good_62853_id_149_f_memcpy_02_c_l_48_c_4_).
# node_in_tree(good_62868, good_62868_id_152_f_memcpy_17_c_l_30_c_15_).
# node_in_tree(good_62821, good_62821_id_161_f_loop_18_c_l_26_c_4_).
# node_in_tree(bad_62913, bad_62913_id_27_f_l_c_).
# node_in_tree(bad_62916, bad_62916_id_84_f_l_c_).
# node_in_tree(good_62901, good_62901_id_109_f_memmove_02_c_l_64_c_0_).
# node_in_tree(bad_62913, bad_62913_id_70_f_l_c_).
# node_in_tree(good_62861, good_62861_id_9_f_l_c_).
# node_in_tree(good_232012, good_232012_id_142_f_memcpy_01_c_l_33_c_8_).
# node_in_tree(good_62902, good_62902_id_33_f_l_c_).
# node_in_tree(bad_232012, bad_232012_id_42_f_l_c_).
# node_in_tree(good_62867, good_62867_id_9_f_l_c_).
# node_in_tree(good_62853, good_62853_id_71_f_l_c_).
# node_in_tree(good_62909, good_62909_id_97_f_l_79_c_9_).
# node_in_tree(bad_232012, bad_232012_id_153_f_memcpy_01_c_l_26_c_28_).
# node_in_tree(good_62865, good_62865_id_185_f_memcpy_14_c_l_37_c_12_).
# node_in_tree(good_62852, good_62852_id_2_f_l_c_).
# node_in_tree(good_232086, good_232086_id_79_f_l_c_).
# node_in_tree(good_62804, good_62804_id_174_f_l_1_c_).
# node_in_tree(good_232086, good_232086_id_152_f_memmove_01_c_l_30_c_12_).
# node_in_tree(good_62865, good_62865_id_71_f_l_c_).
# node_in_tree(bad_62821, bad_62821_id_141_f_loop_18_c_l_23_c_4_).
# node_in_tree(bad_62869, bad_62869_id_144_f_l_40_c_).
# node_in_tree(good_232012, good_232012_id_136_f_memcpy_01_c_l_34_c_8_).
# node_in_tree(bad_62915, bad_62915_id_72_f_l_c_).
# node_in_tree(bad_232012, bad_232012_id_63_f_l_c_).
# node_in_tree(bad_62900, bad_62900_id_107_f_memmove_01_c_l_30_c_21_).
# node_in_tree(bad_232086, bad_232086_id_185_f_l_c_).
# node_in_tree(bad_62916, bad_62916_id_152_f_memmove_17_c_l_25_c_15_).
# node_in_tree(good_62821, good_62821_id_127_f_loop_18_c_l_36_c_12_).
# node_in_tree(bad_62915, bad_62915_id_138_f_memmove_16_c_l_23_c_4_).
# node_in_tree(bad_232086, bad_232086_id_173_f_l_c_).
# node_in_tree(bad_62853, bad_62853_id_2_f_l_c_).
# node_in_tree(good_62861, good_62861_id_98_f_memcpy_10_c_l_80_c_0_).
# node_in_tree(bad_62909, bad_62909_id_87_f_memmove_10_c_l_54_c_4_).
# node_in_tree(good_232086, good_232086_id_166_f_memmove_01_c_l_27_c_35_).
# node_in_tree(bad_62865, bad_62865_id_36_f_l_c_).
# node_in_tree(good_62909, good_62909_id_170_f_memmove_10_c_l_34_c_29_).
# node_in_tree(good_62869, good_62869_id_161_f_l_c_).
# node_in_tree(bad_62900, bad_62900_id_121_f_memmove_01_c_l_29_c_8_).
# node_in_tree(bad_232086, bad_232086_id_1_f_l_c_).
# node_in_tree(bad_62915, bad_62915_id_22_f_l_c_).
# node_in_tree(good_62868, good_62868_id_42_f_l_c_).
# node_in_tree(bad_62821, bad_62821_id_135_f_loop_18_c_l_27_c_4_).
# node_in_tree(bad_62917, bad_62917_id_147_f_l_6_c_).
# node_in_tree(bad_62861, bad_62861_id_51_f_l_c_).
# node_in_tree(good_232086, good_232086_id_194_f_l_c_).
# node_in_tree(good_62916, good_62916_id_82_f_l_c_).
# node_in_tree(good_62861, good_62861_id_102_f_l_79_c_0_).
# node_in_tree(bad_62915, bad_62915_id_153_f_l_c_).
# node_in_tree(good_62852, good_62852_id_63_f_l_c_).
# node_in_tree(good_62868, good_62868_id_25_f_l_c_).
# node_in_tree(bad_62868, bad_62868_id_133_f_memcpy_17_c_l_31_c_12_).
# node_in_tree(good_62853, good_62853_id_164_f_memcpy_02_c_l_39_c_21_).
# node_in_tree(good_62804, good_62804_id_163_f_loop_01_c_l_25_c_4_).
# node_in_tree(good_62865, good_62865_id_206_f_memcpy_14_c_l_26_c_4_).
# node_in_tree(good_232086, good_232086_id_190_f_l_27_c_).
# node_in_tree(bad_62821, bad_62821_id_36_f_l_c_).
# node_in_tree(good_62913, good_62913_id_21_f_l_c_).
# node_in_tree(good_62853, good_62853_id_27_f_l_c_).
# node_in_tree(good_62869, good_62869_id_124_f_memcpy_18_c_l_33_c_15_).
# node_in_tree(bad_62869, bad_62869_id_75_f_l_c_).
# node_in_tree(good_62804, good_62804_id_62_f_l_c_).
# node_in_tree(bad_62915, bad_62915_id_90_f_memmove_16_c_l_54_c_4_).
# node_in_tree(good_62916, good_62916_id_58_f_l_c_).
# node_in_tree(good_62901, good_62901_id_207_f_l_c_).
# node_in_tree(good_232012, good_232012_id_72_f_l_c_).
# node_in_tree(good_62902, good_62902_id_195_f_memmove_03_c_l_32_c_4_).
# node_in_tree(bad_62853, bad_62853_id_11_f_l_c_).
# node_in_tree(bad_62916, bad_62916_id_45_f_l_c_).
# node_in_tree(bad_62868, bad_62868_id_15_f_l_c_).
# node_in_tree(bad_62900, bad_62900_id_123_f_memmove_01_c_l_27_c_12_).
# node_in_tree(good_62865, good_62865_id_13_f_l_c_).
# node_in_tree(bad_62865, bad_62865_id_27_f_l_c_).
# node_in_tree(good_62909, good_62909_id_115_f_memmove_10_c_l_57_c_16_).
# node_in_tree(bad_62867, bad_62867_id_95_f_memcpy_16_c_l_51_c_0_).
# node_in_tree(good_62913, good_62913_id_217_f_l_52_c_).
# node_in_tree(good_62804, good_62804_id_55_f_l_c_).
# node_in_tree(good_62804, good_62804_id_5_f_l_c_).
# node_in_tree(good_62913, good_62913_id_80_f_l_c_).
# node_in_tree(bad_62902, bad_62902_id_156_f_l_32_c_).
# node_in_tree(bad_62902, bad_62902_id_47_f_l_c_).
# node_in_tree(bad_62861, bad_62861_id_4_f_l_c_).
# node_in_tree(bad_62869, bad_62869_id_4_f_l_c_).
# node_in_tree(bad_62853, bad_62853_id_130_f_memcpy_02_c_l_27_c_15_).
# node_in_tree(bad_62804, bad_62804_id_10_f_l_c_).
# node_in_tree(good_62865, good_62865_id_141_f_memcpy_14_c_l_57_c_8_).
# node_in_tree(good_232086, good_232086_id_27_f_l_c_).
# node_in_tree(bad_62915, bad_62915_id_48_f_l_c_).
# node_in_tree(bad_62902, bad_62902_id_66_f_l_c_).
# node_in_tree(good_62917, good_62917_id_9_f_l_c_).
# node_in_tree(good_62868, good_62868_id_74_f_l_c_).
# node_in_tree(bad_62913, bad_62913_id_18_f_l_c_).
# node_in_tree(bad_62901, bad_62901_id_8_f_l_49_c_9_).
# node_in_tree(good_62853, good_62853_id_46_f_l_c_).
# node_in_tree(good_62915, good_62915_id_72_f_l_c_).
# node_in_tree(good_62869, good_62869_id_116_f_memcpy_18_c_l_34_c_21_).
# node_in_tree(good_62900, good_62900_id_106_f_memmove_01_c_l_38_c_4_).
# node_in_tree(bad_62913, bad_62913_id_124_f_memmove_14_c_l_32_c_30_).
# node_in_tree(bad_62853, bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).
# node_in_tree(good_62915, good_62915_id_27_f_l_c_).
# node_in_tree(good_62902, good_62902_id_153_f_l_c_).
# node_in_tree(bad_62865, bad_62865_id_19_f_l_c_).
# node_in_tree(bad_62913, bad_62913_id_110_f_l_49_c_0_).
# node_in_tree(good_62821, good_62821_id_55_f_l_c_).
# node_in_tree(good_62901, good_62901_id_114_f_memmove_02_c_l_58_c_21_).
# node_in_tree(bad_62821, bad_62821_id_9_f_l_c_).
# node_in_tree(bad_62909, bad_62909_id_15_f_l_c_).
# node_in_tree(good_62804, good_62804_id_161_f_loop_01_c_l_25_c_4_).
# node_in_tree(good_62913, good_62913_id_94_f_memmove_14_c_l_87_c_4_).
# node_in_tree(good_232012, good_232012_id_83_f_l_c_).
# node_in_tree(bad_62804, bad_62804_id_105_f_loop_01_c_l_32_c_22_).
# node_in_tree(bad_232086, bad_232086_id_73_f_l_c_).
# node_in_tree(bad_62868, bad_62868_id_142_f_memcpy_17_c_l_28_c_15_).
# node_in_tree(good_62916, good_62916_id_145_f_memmove_17_c_l_30_c_29_).
# node_in_tree(good_232086, good_232086_id_173_f_memmove_01_c_l_27_c_18_).
# node_in_tree(good_62867, good_62867_id_100_f_memcpy_16_c_l_57_c_0_).
# node_in_tree(good_62902, good_62902_id_66_f_l_c_).
# node_in_tree(good_62917, good_62917_id_54_f_l_c_).
# node_in_tree(good_62917, good_62917_id_152_f_l_23_c_0_).
# node_in_tree(bad_62821, bad_62821_id_110_f_loop_18_c_l_34_c_12_).
# node_in_tree(good_62902, good_62902_id_70_f_l_c_).
# node_in_tree(bad_62917, bad_62917_id_132_f_memmove_18_c_l_27_c_4_).
# node_in_tree(bad_62861, bad_62861_id_133_f_memcpy_10_c_l_25_c_4_).
# node_in_tree(good_62804, good_62804_id_157_f_loop_01_c_l_27_c_11_).
# node_in_tree(good_62909, good_62909_id_153_f_memmove_10_c_l_39_c_40_).
# node_in_tree(bad_62852, bad_62852_id_112_f_memcpy_01_c_l_29_c_39_).
# node_in_tree(bad_62869, bad_62869_id_71_f_l_c_).
# node_in_tree(good_62853, good_62853_id_37_f_l_c_).
# node_in_tree(bad_232086, bad_232086_id_103_f_memmove_01_c_l_54_c_14_).
# node_in_tree(bad_62804, bad_62804_id_13_f_l_50_c_19_).
# node_in_tree(bad_62915, bad_62915_id_56_f_l_c_).
# node_in_tree(bad_62861, bad_62861_id_59_f_l_c_).
# node_in_tree(good_62853, good_62853_id_173_f_memcpy_02_c_l_34_c_29_).
# node_in_tree(good_62915, good_62915_id_59_f_l_c_).
# node_in_tree(good_62854, good_62854_id_220_f_l_34_c_).
# node_in_tree(good_62852, good_62852_id_7_f_l_c_).
# node_in_tree(good_62852, good_62852_id_139_f_memcpy_01_c_l_27_c_12_).
# node_in_tree(bad_62867, bad_62867_id_29_f_l_c_).
# node_in_tree(bad_62854, bad_62854_id_20_f_l_c_).
# node_in_tree(bad_232086, bad_232086_id_136_f_memmove_01_c_l_30_c_40_).
# node_in_tree(good_62861, good_62861_id_60_f_l_c_).
# node_in_tree(bad_62867, bad_62867_id_55_f_l_c_).
# node_in_tree(good_62900, good_62900_id_144_f_memmove_01_c_l_25_c_4_).
# node_in_tree(good_62865, good_62865_id_200_f_memcpy_14_c_l_29_c_8_).
# node_in_tree(good_62865, good_62865_id_225_f_l_c_).
# node_in_tree(good_62868, good_62868_id_78_f_l_c_).
# node_in_tree(bad_62909, bad_62909_id_31_f_l_c_).
# node_in_tree(good_62902, good_62902_id_28_f_l_c_).
# node_in_tree(bad_62913, bad_62913_id_35_f_l_c_).
# node_in_tree(good_62900, good_62900_id_9_f_l_c_).
# node_in_tree(good_62853, good_62853_id_148_f_memcpy_02_c_l_48_c_11_).
# node_in_tree(bad_62854, bad_62854_id_91_f_memcpy_03_c_l_54_c_4_).
# node_in_tree(good_62909, good_62909_id_198_f_l_45_c_).
# node_in_tree(bad_62852, bad_62852_id_115_f_memcpy_01_c_l_29_c_29_).
# node_in_tree(bad_62867, bad_62867_id_126_f_memcpy_16_c_l_27_c_29_).
# node_in_tree(bad_62853, bad_62853_id_114_f_memcpy_02_c_l_32_c_32_).
# node_in_tree(bad_62901, bad_62901_id_11_f_l_c_).
# node_in_tree(good_62917, good_62917_id_157_f_l_22_c_).
# node_in_tree(bad_62902, bad_62902_id_153_f_l_21_c_0_).
# node_in_tree(good_232086, good_232086_id_5_f_l_c_).
# node_in_tree(bad_62913, bad_62913_id_140_f_memmove_14_c_l_25_c_4_).
# node_in_tree(bad_62867, bad_62867_id_147_f_l_33_c_).
# node_in_tree(bad_62902, bad_62902_id_20_f_l_c_).
# node_in_tree(good_62869, good_62869_id_0_f_l_c_).
# node_in_tree(good_62913, good_62913_id_110_f_l_79_c_19_).
# node_in_tree(bad_62865, bad_62865_id_17_f_l_c_).
# node_in_tree(good_62913, good_62913_id_206_f_memmove_14_c_l_25_c_11_).
# node_in_tree(bad_62852, bad_62852_id_48_f_l_c_).
# node_in_tree(good_62852, good_62852_id_18_f_l_c_).
# node_in_tree(good_62852, good_62852_id_157_f_l_1_c_).
# node_in_tree(good_62868, good_62868_id_83_f_l_c_).
# node_in_tree(good_62865, good_62865_id_79_f_l_c_).
# node_in_tree(good_232086, good_232086_id_108_f_memmove_01_c_l_58_c_14_).
# node_in_tree(bad_62913, bad_62913_id_1_f_l_49_c_19_).
# node_in_tree(good_62821, good_62821_id_160_f_loop_18_c_l_27_c_0_).
# node_in_tree(bad_62868, bad_62868_id_146_f_memcpy_17_c_l_25_c_22_).
# node_in_tree(good_62868, good_62868_id_5_f_l_c_).
# node_in_tree(bad_62867, bad_62867_id_146_f_l_42_c_).
# node_in_tree(bad_62852, bad_62852_id_103_f_l_46_c_0_).
# node_in_tree(bad_62901, bad_62901_id_16_f_l_c_).
# node_in_tree(good_62821, good_62821_id_130_f_loop_18_c_l_36_c_12_).
# node_in_tree(good_62917, good_62917_id_24_f_l_c_).
# node_in_tree(bad_62804, bad_62804_id_12_f_l_50_c_9_).
# node_in_tree(good_62869, good_62869_id_154_f_l_46_c_).
# node_in_tree(good_62861, good_62861_id_43_f_l_c_).
# node_in_tree(bad_62917, bad_62917_id_2_f_l_c_).
# node_in_tree(bad_62865, bad_62865_id_42_f_l_c_).
# node_in_tree(bad_62915, bad_62915_id_136_f_memmove_16_c_l_24_c_4_).
# node_in_tree(good_62861, good_62861_id_158_f_memcpy_10_c_l_39_c_29_).
# node_in_tree(bad_62869, bad_62869_id_54_f_l_c_).
# node_in_tree(good_62902, good_62902_id_126_f_memmove_03_c_l_57_c_30_).
# node_in_tree(good_62867, good_62867_id_151_f_l_c_).
# node_in_tree(bad_62901, bad_62901_id_73_f_l_c_).
# node_in_tree(bad_62868, bad_62868_id_28_f_l_c_).
# node_in_tree(bad_62852, bad_62852_id_134_f_memcpy_01_c_l_23_c_4_).
# node_in_tree(good_62902, good_62902_id_142_f_memmove_03_c_l_52_c_8_).
# node_in_tree(good_62865, good_62865_id_119_f_memcpy_14_c_l_64_c_0_).
# node_in_tree(good_62909, good_62909_id_154_f_memmove_10_c_l_39_c_33_).
# node_in_tree(bad_62901, bad_62901_id_79_f_memmove_02_c_l_57_c_11_).
# node_in_tree(bad_62916, bad_62916_id_52_f_l_c_).
# node_in_tree(good_62853, good_62853_id_188_f_memcpy_02_c_l_25_c_4_).
# node_in_tree(bad_62854, bad_62854_id_101_f_memcpy_03_c_l_51_c_4_).
# node_in_tree(good_62854, good_62854_id_195_f_memcpy_03_c_l_34_c_8_).
# node_in_tree(bad_62853, bad_62853_id_47_f_l_c_).
# node_in_tree(good_62868, good_62868_id_96_f_memcpy_17_c_l_64_c_4_).
# node_in_tree(bad_62915, bad_62915_id_15_f_l_c_).
# node_in_tree(good_62916, good_62916_id_111_f_l_56_c_9_).
# node_in_tree(good_62861, good_62861_id_21_f_l_c_).
# node_in_tree(good_62867, good_62867_id_137_f_memcpy_16_c_l_29_c_29_).
# node_in_tree(bad_62901, bad_62901_id_149_f_l_1_c_).
# node_in_tree(good_62853, good_62853_id_102_f_l_79_c_19_).
# node_in_tree(bad_62852, bad_62852_id_91_f_memcpy_01_c_l_48_c_26_).
# node_in_tree(good_232012, good_232012_id_17_f_l_c_).
# node_in_tree(bad_62909, bad_62909_id_133_f_memmove_10_c_l_25_c_4_).
# node_in_tree(bad_62867, bad_62867_id_28_f_l_c_).
# node_in_tree(good_62854, good_62854_id_201_f_memcpy_03_c_l_27_c_4_).
# node_in_tree(good_62821, good_62821_id_10_f_l_c_).
# node_in_tree(bad_62913, bad_62913_id_55_f_l_c_).
# node_in_tree(good_62909, good_62909_id_40_f_l_c_).
# node_in_tree(good_232086, good_232086_id_28_f_l_c_).
# node_in_tree(bad_232012, bad_232012_id_128_f_memcpy_01_c_l_32_c_13_).
# node_in_tree(bad_232012, bad_232012_id_1_f_l_48_c_19_).
# node_in_tree(bad_62902, bad_62902_id_118_f_memmove_03_c_l_33_c_8_).
# node_in_tree(good_62821, good_62821_id_5_f_l_c_).
# node_in_tree(good_62900, good_62900_id_40_f_l_c_).
# node_in_tree(good_62913, good_62913_id_225_f_l_c_).
# node_in_tree(good_62821, good_62821_id_119_f_loop_18_c_l_38_c_21_).
# node_in_tree(bad_62913, bad_62913_id_44_f_l_c_).
# node_in_tree(bad_62804, bad_62804_id_128_f_loop_01_c_l_25_c_25_).
# node_in_tree(bad_62854, bad_62854_id_67_f_l_c_).
# node_in_tree(good_62909, good_62909_id_102_f_memmove_10_c_l_64_c_4_).
# node_in_tree(good_62854, good_62854_id_155_f_memcpy_03_c_l_52_c_8_).
# node_in_tree(good_62901, good_62901_id_3_f_l_c_).
# node_in_tree(bad_232012, bad_232012_id_109_f_memcpy_01_c_l_53_c_4_).
# node_in_tree(bad_62869, bad_62869_id_47_f_l_c_).
# node_in_tree(good_62913, good_62913_id_103_f_memmove_14_c_l_81_c_21_).
# node_in_tree(bad_62854, bad_62854_id_3_f_l_c_).
# node_in_tree(good_62867, good_62867_id_153_f_l_23_c_0_).
# node_in_tree(bad_62868, bad_62868_id_69_f_l_c_).
# node_in_tree(good_62900, good_62900_id_160_f_l_c_).
# node_in_tree(good_62854, good_62854_id_210_f_l_c_).
# node_in_tree(good_62861, good_62861_id_11_f_l_c_).
# node_in_tree(good_62853, good_62853_id_161_f_memcpy_02_c_l_39_c_32_).
# node_in_tree(good_62901, good_62901_id_176_f_memmove_02_c_l_34_c_15_).
# node_in_tree(good_232086, good_232086_id_50_f_l_c_).
# node_in_tree(bad_232086, bad_232086_id_147_f_memmove_01_c_l_28_c_12_).
# node_in_tree(bad_232086, bad_232086_id_163_f_memmove_01_c_l_25_c_18_).
# node_in_tree(bad_62902, bad_62902_id_13_f_l_c_).
# node_in_tree(bad_62853, bad_62853_id_100_f_l_49_c_0_).
# node_in_tree(good_62901, good_62901_id_205_f_l_c_).
# node_in_tree(bad_62916, bad_62916_id_6_f_l_c_).
# node_in_tree(bad_62804, bad_62804_id_56_f_l_c_).
# node_in_tree(good_62854, good_62854_id_33_f_l_c_).
# node_in_tree(bad_62913, bad_62913_id_19_f_l_c_).
# node_in_tree(good_62853, good_62853_id_49_f_l_c_).
# node_in_tree(good_62854, good_62854_id_184_f_memcpy_03_c_l_37_c_12_).
# node_in_tree(bad_62804, bad_62804_id_17_f_l_c_).
# node_in_tree(good_62865, good_62865_id_136_f_memcpy_14_c_l_57_c_29_).
# node_in_tree(bad_62909, bad_62909_id_49_f_l_c_).
# node_in_tree(good_62854, good_62854_id_30_f_l_c_).
# node_in_tree(good_62868, good_62868_id_163_f_memcpy_17_c_l_27_c_12_).
# node_in_tree(bad_62909, bad_62909_id_24_f_l_c_).
# node_in_tree(bad_62853, bad_62853_id_82_f_memcpy_02_c_l_57_c_11_).
# node_in_tree(bad_62909, bad_62909_id_84_f_memmove_10_c_l_55_c_14_).
# node_in_tree(good_62909, good_62909_id_125_f_memmove_10_c_l_52_c_22_).
# node_in_tree(bad_62900, bad_62900_id_129_f_memmove_01_c_l_25_c_12_).
# node_in_tree(good_62861, good_62861_id_100_f_l_79_c_19_).
# node_in_tree(good_62901, good_62901_id_23_f_l_c_).
# node_in_tree(bad_62861, bad_62861_id_14_f_l_c_).
# node_in_tree(good_232012, good_232012_id_162_f_memcpy_01_c_l_28_c_8_).
# node_in_tree(good_62821, good_62821_id_75_f_l_c_).
# node_in_tree(bad_62917, bad_62917_id_41_f_l_c_).
# node_in_tree(bad_62861, bad_62861_id_82_f_memcpy_10_c_l_57_c_11_).
# node_in_tree(good_232012, good_232012_id_134_f_memcpy_01_c_l_34_c_13_).
# node_in_tree(bad_62853, bad_62853_id_145_f_l_41_c_).
# node_in_tree(bad_62916, bad_62916_id_94_f_memmove_17_c_l_56_c_4_).
# node_in_tree(bad_62868, bad_62868_id_54_f_l_c_).
# node_in_tree(good_62909, good_62909_id_39_f_l_c_).
# node_in_tree(good_62869, good_62869_id_144_f_memcpy_18_c_l_26_c_4_).
# node_in_tree(bad_62804, bad_62804_id_121_f_loop_01_c_l_30_c_13_).
# node_in_tree(bad_62865, bad_62865_id_129_f_memcpy_14_c_l_30_c_12_).
# node_in_tree(bad_62869, bad_62869_id_24_f_l_c_).
# node_in_tree(bad_62900, bad_62900_id_141_f_l_48_c_).
# node_in_tree(good_62865, good_62865_id_9_f_l_c_).
# node_in_tree(bad_62869, bad_62869_id_16_f_l_c_).
# node_in_tree(bad_62901, bad_62901_id_130_f_memmove_02_c_l_27_c_15_).
# node_in_tree(good_62852, good_62852_id_45_f_l_c_).
# node_in_tree(bad_232086, bad_232086_id_86_f_l_c_).
# node_in_tree(good_62861, good_62861_id_160_f_memcpy_10_c_l_39_c_15_).
# node_in_tree(bad_62821, bad_62821_id_146_f_l_54_c_).
# node_in_tree(bad_62861, bad_62861_id_58_f_l_c_).
# node_in_tree(bad_62913, bad_62913_id_31_f_l_c_).
# node_in_tree(bad_62861, bad_62861_id_52_f_l_c_).
# node_in_tree(bad_62909, bad_62909_id_117_f_memmove_10_c_l_32_c_30_).
# node_in_tree(bad_62909, bad_62909_id_4_f_l_c_).
# node_in_tree(bad_62900, bad_62900_id_36_f_l_c_).
# node_in_tree(good_62909, good_62909_id_96_f_l_79_c_19_).
# node_in_tree(bad_62913, bad_62913_id_61_f_l_c_).
# node_in_tree(good_62854, good_62854_id_119_f_l_63_c_0_).
# node_in_tree(good_62900, good_62900_id_51_f_l_c_).
# node_in_tree(bad_232012, bad_232012_id_105_f_memcpy_01_c_l_56_c_4_).
# node_in_tree(good_62865, good_62865_id_189_f_memcpy_14_c_l_34_c_32_).
# node_in_tree(good_62900, good_62900_id_56_f_l_c_).
# node_in_tree(bad_62902, bad_62902_id_149_f_memmove_03_c_l_23_c_4_).
# node_in_tree(good_62902, good_62902_id_83_f_l_c_).
# node_in_tree(good_62852, good_62852_id_83_f_memcpy_01_c_l_60_c_11_).
# node_in_tree(bad_62901, bad_62901_id_106_f_memmove_02_c_l_33_c_21_).
# node_in_tree(good_62852, good_62852_id_49_f_l_c_).
# node_in_tree(bad_62909, bad_62909_id_70_f_l_c_).
# node_in_tree(good_62852, good_62852_id_28_f_l_c_).
# node_in_tree(bad_232012, bad_232012_id_137_f_memcpy_01_c_l_30_c_39_).
# node_in_tree(bad_62821, bad_62821_id_49_f_l_c_).
# node_in_tree(good_62900, good_62900_id_25_f_l_c_).
# node_in_tree(bad_62852, bad_62852_id_75_f_l_c_).
# node_in_tree(bad_62852, bad_62852_id_60_f_l_c_).
# node_in_tree(good_62854, good_62854_id_143_f_memcpy_03_c_l_55_c_8_).
# node_in_tree(good_62868, good_62868_id_119_f_memcpy_17_c_l_42_c_0_).
# node_in_tree(bad_62915, bad_62915_id_35_f_l_c_).
# node_in_tree(bad_62867, bad_62867_id_113_f_memcpy_16_c_l_33_c_32_).
# node_in_tree(good_62901, good_62901_id_111_f_l_63_c_0_).
# node_in_tree(good_62913, good_62913_id_30_f_l_c_).
# node_in_tree(good_62869, good_62869_id_141_f_memcpy_18_c_l_29_c_4_).
# node_in_tree(good_62868, good_62868_id_18_f_l_c_).
# node_in_tree(bad_62869, bad_62869_id_119_f_memcpy_18_c_l_31_c_15_).
# node_in_tree(bad_62869, bad_62869_id_117_f_memcpy_18_c_l_31_c_29_).
# node_in_tree(bad_62853, bad_62853_id_150_f_l_c_).
# node_in_tree(good_62852, good_62852_id_107_f_memcpy_01_c_l_38_c_0_).
# node_in_tree(good_62917, good_62917_id_158_f_l_6_c_).
# node_in_tree(bad_62861, bad_62861_id_65_f_l_c_).
# node_in_tree(bad_62853, bad_62853_id_1_f_l_c_).
# node_in_tree(good_62867, good_62867_id_43_f_l_c_).
# node_in_tree(bad_62917, bad_62917_id_38_f_l_c_).
# node_in_tree(good_62861, good_62861_id_4_f_l_c_).
# node_in_tree(good_62821, good_62821_id_78_f_l_c_).
# node_in_tree(bad_62869, bad_62869_id_46_f_l_c_).
# node_in_tree(bad_62854, bad_62854_id_79_f_l_c_).
# node_in_tree(good_232086, good_232086_id_12_f_l_c_).
# node_in_tree(good_62902, good_62902_id_217_f_l_52_c_).
# node_in_tree(good_232086, good_232086_id_186_f_l_23_c_0_).
# node_in_tree(good_62917, good_62917_id_61_f_l_c_).
# node_in_tree(good_62852, good_62852_id_109_f_l_37_c_0_).
# node_in_tree(bad_62909, bad_62909_id_27_f_l_c_).
# node_in_tree(bad_62902, bad_62902_id_159_f_l_1_c_).
# node_in_tree(good_62869, good_62869_id_57_f_l_c_).
# node_in_tree(good_62867, good_62867_id_76_f_l_c_).
# node_in_tree(good_62869, good_62869_id_44_f_l_c_).
# node_in_tree(good_232086, good_232086_id_160_f_memmove_01_c_l_28_c_22_).
# node_in_tree(bad_62909, bad_62909_id_55_f_l_c_).
# node_in_tree(good_62865, good_62865_id_222_f_l_22_c_).
# node_in_tree(good_62902, good_62902_id_194_f_memmove_03_c_l_34_c_8_).
# node_in_tree(good_62909, good_62909_id_120_f_memmove_10_c_l_55_c_8_).
# node_in_tree(bad_62868, bad_62868_id_110_f_l_50_c_9_).
# node_in_tree(bad_62821, bad_62821_id_121_f_loop_18_c_l_32_c_13_).
# node_in_tree(good_62804, good_62804_id_71_f_l_c_).
# node_in_tree(bad_62902, bad_62902_id_116_f_memmove_03_c_l_33_c_21_).
# node_in_tree(bad_232086, bad_232086_id_131_f_memmove_01_c_l_31_c_21_).
# node_in_tree(good_62901, good_62901_id_7_f_l_c_).
# node_in_tree(bad_62902, bad_62902_id_91_f_memmove_03_c_l_55_c_14_).
# node_in_tree(good_62909, good_62909_id_13_f_l_c_).
# node_in_tree(good_62917, good_62917_id_5_f_l_c_).
# node_in_tree(bad_62854, bad_62854_id_121_f_memcpy_03_c_l_32_c_29_).
# node_in_tree(bad_232012, bad_232012_id_130_f_memcpy_01_c_l_32_c_8_).
# node_in_tree(good_62865, good_62865_id_113_f_l_79_c_9_).
# node_in_tree(good_62915, good_62915_id_34_f_l_c_).
# node_in_tree(bad_62852, bad_62852_id_143_f_l_29_c_).
# node_in_tree(good_62854, good_62854_id_117_f_memcpy_03_c_l_64_c_0_).
# node_in_tree(good_62901, good_62901_id_45_f_l_c_).
# node_in_tree(bad_232086, bad_232086_id_77_f_l_c_).
# node_in_tree(good_62861, good_62861_id_36_f_l_c_).
# node_in_tree(good_62854, good_62854_id_214_f_l_81_c_).
# node_in_tree(good_62917, good_62917_id_139_f_memmove_18_c_l_29_c_12_).
# node_in_tree(good_232086, good_232086_id_162_f_memmove_01_c_l_28_c_8_).
# node_in_tree(bad_62868, bad_62868_id_154_f_memcpy_17_c_l_25_c_8_).
# node_in_tree(bad_62853, bad_62853_id_40_f_l_c_).
# node_in_tree(good_62867, good_62867_id_157_f_l_35_c_).
# node_in_tree(bad_62853, bad_62853_id_59_f_l_c_).
# node_in_tree(bad_62852, bad_62852_id_68_f_l_c_).
# node_in_tree(good_62804, good_62804_id_140_f_loop_01_c_l_32_c_13_).
# node_in_tree(good_62869, good_62869_id_85_f_memcpy_18_c_l_60_c_14_).
# node_in_tree(good_232012, good_232012_id_127_f_memcpy_01_c_l_40_c_0_).
# node_in_tree(bad_62869, bad_62869_id_32_f_l_c_).
# node_in_tree(bad_62915, bad_62915_id_51_f_l_c_).
# node_in_tree(bad_62909, bad_62909_id_43_f_l_c_).
# node_in_tree(bad_62852, bad_62852_id_4_f_l_c_).
# node_in_tree(bad_62917, bad_62917_id_133_f_memmove_18_c_l_25_c_0_).
# node_in_tree(good_62804, good_62804_id_30_f_l_c_).
# node_in_tree(good_62869, good_62869_id_60_f_l_c_).
# node_in_tree(good_62901, good_62901_id_36_f_l_c_).
# node_in_tree(bad_62804, bad_62804_id_71_f_loop_01_c_l_58_c_11_).
# node_in_tree(bad_232086, bad_232086_id_157_f_memmove_01_c_l_26_c_8_).
# node_in_tree(bad_62867, bad_62867_id_92_f_memcpy_16_c_l_52_c_11_).
# node_in_tree(bad_62861, bad_62861_id_18_f_l_c_).
# node_in_tree(bad_62909, bad_62909_id_83_f_memmove_10_c_l_57_c_4_).
# node_in_tree(good_62909, good_62909_id_8_f_l_c_).
# node_in_tree(bad_62861, bad_62861_id_22_f_l_c_).
# node_in_tree(good_232012, good_232012_id_7_f_l_c_).
# node_in_tree(bad_62868, bad_62868_id_5_f_l_c_).
# node_in_tree(good_62868, good_62868_id_47_f_l_c_).
# node_in_tree(bad_62853, bad_62853_id_45_f_l_c_).
# node_in_tree(good_62916, good_62916_id_108_f_memmove_17_c_l_57_c_0_).
# node_in_tree(good_232086, good_232086_id_73_f_l_c_).
# node_in_tree(good_62821, good_62821_id_145_f_loop_18_c_l_31_c_12_).
# node_in_tree(good_62869, good_62869_id_51_f_l_c_).
# node_in_tree(good_62854, good_62854_id_14_f_l_c_).
# node_in_tree(good_62916, good_62916_id_176_f_l_58_c_).
# node_in_tree(good_62821, good_62821_id_172_f_l_34_c_).
# node_in_tree(good_62854, good_62854_id_114_f_memcpy_03_c_l_65_c_4_).
# node_in_tree(good_62867, good_62867_id_45_f_l_c_).
# node_in_tree(good_62901, good_62901_id_61_f_l_c_).
# node_in_tree(good_62916, good_62916_id_94_f_memmove_17_c_l_62_c_14_).
# node_in_tree(bad_62852, bad_62852_id_133_f_memcpy_01_c_l_23_c_11_).
# node_in_tree(bad_62867, bad_62867_id_9_f_l_c_).
# node_in_tree(bad_62867, bad_62867_id_32_f_l_c_).
# node_in_tree(bad_62909, bad_62909_id_20_f_l_c_).
# node_in_tree(bad_62901, bad_62901_id_81_f_memmove_02_c_l_55_c_14_).
# node_in_tree(good_62867, good_62867_id_40_f_l_c_).
# node_in_tree(good_62901, good_62901_id_149_f_memmove_02_c_l_40_c_26_).
# node_in_tree(bad_232012, bad_232012_id_81_f_l_c_).
# node_in_tree(bad_62902, bad_62902_id_154_f_l_51_c_).
# node_in_tree(good_62916, good_62916_id_13_f_l_56_c_19_).
# node_in_tree(good_62902, good_62902_id_209_f_memmove_03_c_l_25_c_4_).
# node_in_tree(bad_62916, bad_62916_id_153_f_memmove_17_c_l_25_c_12_).
# node_in_tree(bad_232086, bad_232086_id_56_f_l_c_).
# node_in_tree(good_62854, good_62854_id_139_f_memcpy_03_c_l_57_c_8_).
# node_in_tree(bad_62804, bad_62804_id_147_f_l_25_c_).
# node_in_tree(bad_62916, bad_62916_id_120_f_memmove_17_c_l_34_c_21_).
# node_in_tree(bad_62902, bad_62902_id_140_f_memmove_03_c_l_25_c_4_).
# node_in_tree(good_62867, good_62867_id_61_f_l_c_).
# node_in_tree(bad_62869, bad_62869_id_74_f_l_c_).
# node_in_tree(bad_62804, bad_62804_id_4_f_l_c_).
# node_in_tree(good_62854, good_62854_id_137_f_memcpy_03_c_l_57_c_15_).
# node_in_tree(bad_62854, bad_62854_id_153_f_l_21_c_0_).
# node_in_tree(good_62869, good_62869_id_54_f_l_c_).
# node_in_tree(bad_62916, bad_62916_id_57_f_l_c_).
# node_in_tree(bad_62901, bad_62901_id_116_f_memmove_02_c_l_32_c_30_).
# node_in_tree(good_62861, good_62861_id_201_f_l_29_c_).
# node_in_tree(bad_62917, bad_62917_id_81_f_memmove_18_c_l_54_c_14_).
# node_in_tree(good_62853, good_62853_id_48_f_l_c_).
# node_in_tree(good_62917, good_62917_id_26_f_l_c_).
# node_in_tree(bad_62854, bad_62854_id_132_f_memcpy_03_c_l_27_c_29_).
# node_in_tree(bad_62917, bad_62917_id_17_f_l_c_).
# node_in_tree(bad_62901, bad_62901_id_96_f_l_49_c_0_).
# node_in_tree(bad_232012, bad_232012_id_151_f_memcpy_01_c_l_26_c_29_).
# node_in_tree(good_62853, good_62853_id_118_f_memcpy_02_c_l_58_c_21_).
# node_in_tree(bad_62804, bad_62804_id_11_f_l_c_).
# :- bug(good_62867_id_143_f_memcpy_16_c_l_29_c_8_,good_62867_id_126_f_memcpy_16_c_l_35_c_8_).
# :- bug(good_62868_id_154_f_memcpy_17_c_l_30_c_8_,good_62868_id_138_f_memcpy_17_c_l_35_c_8_).
# :- bug(good_62869_id_142_f_memcpy_18_c_l_29_c_4_,good_62869_id_126_f_memcpy_18_c_l_33_c_8_).
# :- bug(good_62900_id_142_f_memmove_01_c_l_27_c_4_,good_62900_id_126_f_memmove_01_c_l_31_c_8_).
# :- bug(good_62901_id_178_f_memmove_02_c_l_34_c_8_,good_62901_id_162_f_memmove_02_c_l_39_c_8_).
# :- bug(good_62902_id_194_f_memmove_03_c_l_34_c_8_,good_62902_id_177_f_memmove_03_c_l_39_c_8_).
# :- bug(good_62909_id_177_f_memmove_10_c_l_34_c_8_,good_62909_id_160_f_memmove_10_c_l_39_c_8_).
# :- bug(good_62913_id_194_f_memmove_14_c_l_34_c_8_,good_62913_id_177_f_memmove_14_c_l_39_c_8_).
# :- bug(good_62915_id_143_f_memmove_16_c_l_29_c_8_,good_62915_id_125_f_memmove_16_c_l_35_c_8_).
# :- bug(good_62916_id_154_f_memmove_17_c_l_30_c_8_,good_62916_id_137_f_memmove_17_c_l_35_c_8_).
# :- bug(good_62917_id_142_f_memmove_18_c_l_29_c_4_,good_62917_id_126_f_memmove_18_c_l_33_c_8_).
# :- bug(good_232012_id_178_f_memcpy_01_c_l_27_c_4_,good_232012_id_150_f_memcpy_01_c_l_32_c_8_).
# :- bug(good_232086_id_178_f_memmove_01_c_l_27_c_4_,good_232086_id_150_f_memmove_01_c_l_32_c_8_).
#
#
# CProgol Version 5.0
#
# [:- set(c,3)? - Time taken 0.00s]
# [Syntax error at line 5 in file </tmp/progol_input.pl>]
# [:- set(h,2000)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,1500)? - Time taken 0.00s]
# [:- modeh(100,bug(+node,+node))? - Time taken 0.00s]
# [:- modeb(100,same_tree(+node,+node))? - Time taken 0.00s]
# [:- modeb(100,same_tree(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,same_tree(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,same_tree(-node,-node))? - Time taken 0.00s]
# [:- modeb(100,ancestor(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,assignment(+node))? - Time taken 0.00s]
# [:- modeb(100,compMemberAccess(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/2]
# [Generalising bug(bad_232086_id_168_f_memmove_01_c_l_25_c_4_,bad_232086_id_145_f_memmove_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232086_id_168_f_memmove_01_c_l_25_c_4_,bad_232086_id_145_f_memmove_01_c_l_30_c_8_).>]
# ^C
