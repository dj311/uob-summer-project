# %% [markdown]
# <a href="https://colab.research.google.com/github/dj311/uob-summer-project/blob/master/code/exploring_juliet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import xml.etree.ElementTree as ElementTree

# %%
#!git clone https://github.com/dj311/uob-summer-project.git

# %%
tree = ElementTree.parse('../data/juliet-dataset-c-and-cpp/manifest-2019-06-27-05-59-16-6CSdPs.xml')

# %%
root = tree.getroot()

# %%
#!cd uob-summer-project && git pull

# %%
import pandas as pd
juliet= pd.DataFrame(columns = ['testcase_ID', 'filename', 'code', 'flaw', 'flaw_loc'])

base_directory = '../data/juliet-dataset-c-and-cpp/SARD-testsuite-108/'

for testcase in root:
  for file in testcase:    
    for flaw in file:
      new_row = {
          "testcase_ID": testcase.attrib['id'],
          "filename": file.attrib['path'],
          "code": None,
          "flaw": None,
          "flaw_loc": None,
      }
      
      with open(base_directory + file.attrib['path']) as code_file:
        new_row['code'] = code_file.read()
        
      for mixed in file:
        
        new_row['flaw'] = mixed.attrib['name'].split(":")[0]
        new_row['flaw_loc'] = mixed.attrib['line']
        
      juliet = juliet.append(new_row, ignore_index= True)

# %%
juliet
# Out:
#       testcase_ID                                           filename  \
# 0           61940  000/061/940/CWE114_Process_Control__w32_char_c...
# 1           61941  000/061/941/CWE114_Process_Control__w32_char_c...
# 2           61942  000/061/942/CWE114_Process_Control__w32_char_c...
# 3           61943  000/061/943/CWE114_Process_Control__w32_char_c...
# 4           61944  000/061/944/CWE114_Process_Control__w32_char_c...
# 5           61945  000/061/945/CWE114_Process_Control__w32_char_c...
# 6           61946  000/061/946/CWE114_Process_Control__w32_char_c...
# 7           61947  000/061/947/CWE114_Process_Control__w32_char_c...
# 8           61948  000/061/948/CWE114_Process_Control__w32_char_c...
# 9           61949  000/061/949/CWE114_Process_Control__w32_char_c...
# 10          61950  000/061/950/CWE114_Process_Control__w32_char_c...
# 11          61951  000/061/951/CWE114_Process_Control__w32_char_c...
# 12          61952  000/061/952/CWE114_Process_Control__w32_char_c...
# 13          61953  000/061/953/CWE114_Process_Control__w32_char_c...
# 14          61954  000/061/954/CWE114_Process_Control__w32_char_c...
# 15          61955  000/061/955/CWE114_Process_Control__w32_char_c...
# 16          61956  000/061/956/CWE114_Process_Control__w32_char_c...
# 17          61957  000/061/957/CWE114_Process_Control__w32_char_c...
# 18          61958  000/061/958/CWE114_Process_Control__w32_char_c...
# 19          61959  000/061/959/CWE114_Process_Control__w32_char_c...
# 20          61960  000/061/960/CWE114_Process_Control__w32_char_c...
# 21          61961  000/061/961/CWE114_Process_Control__w32_char_c...
# 22          61962  000/061/962/CWE114_Process_Control__w32_char_c...
# 23          61963  000/061/963/CWE114_Process_Control__w32_char_c...
# 24          61964  000/061/964/CWE114_Process_Control__w32_char_c...
# 25          61965  000/061/965/CWE114_Process_Control__w32_char_c...
# 26          61966  000/061/966/CWE114_Process_Control__w32_char_c...
# 27          61967  000/061/967/CWE114_Process_Control__w32_char_c...
# 28          61968  000/061/968/CWE114_Process_Control__w32_char_c...
# 29          61969  000/061/969/CWE114_Process_Control__w32_char_c...
# ...           ...                                                ...
# 66317      248693  000/248/693/CWE78_OS_Command_Injection__wchar_...
# 66318      248694  000/248/694/CWE78_OS_Command_Injection__wchar_...
# 66319      248695  000/248/695/CWE78_OS_Command_Injection__wchar_...
# 66320      248696  000/248/696/CWE78_OS_Command_Injection__wchar_...
# 66321      248697  000/248/697/CWE78_OS_Command_Injection__wchar_...
# 66322      248698  000/248/698/CWE78_OS_Command_Injection__wchar_...
# 66323      248699  000/248/699/CWE78_OS_Command_Injection__wchar_...
# 66324      248700  000/248/700/CWE78_OS_Command_Injection__wchar_...
# 66325      248701  000/248/701/CWE78_OS_Command_Injection__wchar_...
# 66326      248702  000/248/702/CWE78_OS_Command_Injection__wchar_...
# 66327      248703  000/248/703/CWE78_OS_Command_Injection__wchar_...
# 66328      248704  000/248/704/CWE78_OS_Command_Injection__wchar_...
# 66329      248705  000/248/705/CWE78_OS_Command_Injection__wchar_...
# 66330      248706  000/248/706/CWE78_OS_Command_Injection__wchar_...
# 66331      248707  000/248/707/CWE78_OS_Command_Injection__wchar_...
# 66332      248708  000/248/708/CWE78_OS_Command_Injection__wchar_...
# 66333      248709  000/248/709/CWE78_OS_Command_Injection__wchar_...
# 66334      248710  000/248/710/CWE78_OS_Command_Injection__wchar_...
# 66335      248711  000/248/711/CWE78_OS_Command_Injection__wchar_...
# 66336      248712  000/248/712/CWE78_OS_Command_Injection__wchar_...
# 66337      248713  000/248/713/CWE78_OS_Command_Injection__wchar_...
# 66338      248714  000/248/714/CWE78_OS_Command_Injection__wchar_...
# 66339      248715  000/248/715/CWE78_OS_Command_Injection__wchar_...
# 66340      248716  000/248/716/CWE78_OS_Command_Injection__wchar_...
# 66341      248717  000/248/717/CWE78_OS_Command_Injection__wchar_...
# 66342      248718  000/248/718/CWE78_OS_Command_Injection__wchar_...
# 66343      248719  000/248/719/CWE78_OS_Command_Injection__wchar_...
# 66344      248720  000/248/720/CWE78_OS_Command_Injection__wchar_...
# 66345      248721  000/248/721/CWE78_OS_Command_Injection__wchar_...
# 66346      248722  000/248/722/CWE78_OS_Command_Injection__wchar_...
#
#                                                     code     flaw flaw_loc
# 0      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      121
# 1      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      124
# 2      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      124
# 3      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      131
# 4      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      131
# 5      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      128
# 6      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      130
# 7      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      138
# 8      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      124
# 9      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      124
# 10     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      124
# 11     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      129
# 12     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      124
# 13     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      124
# 14     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      130
# 15     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      125
# 16     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      125
# 17     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      123
# 18     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      134
# 19     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114       41
# 20     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      124
# 21     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      129
# 22     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      127
# 23     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      131
# 24     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114       51
# 25     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      127
# 26     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      129
# 27     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114       51
# 28     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114       55
# 29     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114       53
# ...                                                  ...      ...      ...
# 66317  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078      162
# 66318  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       57
# 66319  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078      152
# 66320  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078      157
# 66321  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078      155
# 66322  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078      159
# 66323  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       67
# 66324  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078      155
# 66325  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078      157
# 66326  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       67
# 66327  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       71
# 66328  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       69
# 66329  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       69
# 66330  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       69
# 66331  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       69
# 66332  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       74
# 66333  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       57
# 66334  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       68
# 66335  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       71
# 66336  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       67
# 66337  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       69
# 66338  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       73
# 66339  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       73
# 66340  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       55
# 66341  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       55
# 66342  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       55
# 66343  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       33
# 66344  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       33
# 66345  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078      137
# 66346  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078      137
#
# [66347 rows x 5 columns]

# %% [markdown]
# # Splitting Scripts into Good and Bad

# %%
print(juliet.iloc[0].code)
# Out:
# /* TEMPLATE GENERATED TESTCASE FILE
# Filename: CWE114_Process_Control__w32_char_connect_socket_01.c
# Label Definition File: CWE114_Process_Control__w32.label.xml
# Template File: sources-sink-01.tmpl.c
# */
# /*
#  * @description
#  * CWE: 114 Process Control
#  * BadSource: connect_socket Read data using a connect socket (client side)
#  * GoodSource: Hard code the full pathname to the library
#  * Sink:
#  *    BadSink : Load a dynamic link library
#  * Flow Variant: 01 Baseline
#  *
#  * */
#
# #include "std_testcase.h"
#
# #include <wchar.h>
#
# #ifdef _WIN32
# #include <winsock2.h>
# #include <windows.h>
# #include <direct.h>
# #pragma comment(lib, "ws2_32") /* include ws2_32.lib when linking */
# #define CLOSE_SOCKET closesocket
# #else /* NOT _WIN32 */
# #include <sys/types.h>
# #include <sys/socket.h>
# #include <netinet/in.h>
# #include <arpa/inet.h>
# #include <unistd.h>
# #define INVALID_SOCKET -1
# #define SOCKET_ERROR -1
# #define CLOSE_SOCKET close
# #define SOCKET int
# #endif
#
# #define TCP_PORT 27015
# #define IP_ADDRESS "127.0.0.1"
#
#
# #ifndef OMITBAD
#
# void CWE114_Process_Control__w32_char_connect_socket_01_bad()
# {
#     char * data;
#     char dataBuffer[100] = "";
#     data = dataBuffer;
#     {
# #ifdef _WIN32
#         WSADATA wsaData;
#         int wsaDataInit = 0;
# #endif
#         int recvResult;
#         struct sockaddr_in service;
#         char *replace;
#         SOCKET connectSocket = INVALID_SOCKET;
#         size_t dataLen = strlen(data);
#         do
#         {
# #ifdef _WIN32
#             if (WSAStartup(MAKEWORD(2,2), &wsaData) != NO_ERROR)
#             {
#                 break;
#             }
#             wsaDataInit = 1;
# #endif
#             /* POTENTIAL FLAW: Read data using a connect socket */
#             connectSocket = socket(AF_INET, SOCK_STREAM, IPPROTO_TCP);
#             if (connectSocket == INVALID_SOCKET)
#             {
#                 break;
#             }
#             memset(&service, 0, sizeof(service));
#             service.sin_family = AF_INET;
#             service.sin_addr.s_addr = inet_addr(IP_ADDRESS);
#             service.sin_port = htons(TCP_PORT);
#             if (connect(connectSocket, (struct sockaddr*)&service, sizeof(service)) == SOCKET_ERROR)
#             {
#                 break;
#             }
#             /* Abort on error or the connection was closed, make sure to recv one
#              * less char than is in the recv_buf in order to append a terminator */
#             /* Abort on error or the connection was closed */
#             recvResult = recv(connectSocket, (char *)(data + dataLen), sizeof(char) * (100 - dataLen - 1), 0);
#             if (recvResult == SOCKET_ERROR || recvResult == 0)
#             {
#                 break;
#             }
#             /* Append null terminator */
#             data[dataLen + recvResult / sizeof(char)] = '\0';
#             /* Eliminate CRLF */
#             replace = strchr(data, '\r');
#             if (replace)
#             {
#                 *replace = '\0';
#             }
#             replace = strchr(data, '\n');
#             if (replace)
#             {
#                 *replace = '\0';
#             }
#         }
#         while (0);
#         if (connectSocket != INVALID_SOCKET)
#         {
#             CLOSE_SOCKET(connectSocket);
#         }
# #ifdef _WIN32
#         if (wsaDataInit)
#         {
#             WSACleanup();
#         }
# #endif
#     }
#     {
#         HMODULE hModule;
#         /* POTENTIAL FLAW: If the path to the library is not specified, an attacker may be able to
#          * replace his own file with the intended library */
#         hModule = LoadLibraryA(data);
#         if (hModule != NULL)
#         {
#             FreeLibrary(hModule);
#             printLine("Library loaded and freed successfully");
#         }
#         else
#         {
#             printLine("Unable to load library");
#         }
#     }
# }
#
# #endif /* OMITBAD */
#
# #ifndef OMITGOOD
#
# /* goodG2B uses the GoodSource with the BadSink */
# static void goodG2B()
# {
#     char * data;
#     char dataBuffer[100] = "";
#     data = dataBuffer;
#     /* FIX: Specify the full pathname for the library */
#     strcpy(data, "C:\\Windows\\System32\\winsrv.dll");
#     {
#         HMODULE hModule;
#         /* POTENTIAL FLAW: If the path to the library is not specified, an attacker may be able to
#          * replace his own file with the intended library */
#         hModule = LoadLibraryA(data);
#         if (hModule != NULL)
#         {
#             FreeLibrary(hModule);
#             printLine("Library loaded and freed successfully");
#         }
#         else
#         {
#             printLine("Unable to load library");
#         }
#     }
# }
#
# void CWE114_Process_Control__w32_char_connect_socket_01_good()
# {
#     goodG2B();
# }
#
# #endif /* OMITGOOD */
#
# /* Below is the main(). It is only used when building this testcase on
#  * its own for testing or for building a binary to use in testing binary
#  * analysis tools. It is not used when compiling all the testcases as one
#  * application, which is how source code analysis tools are tested.
#  */
#
# #ifdef INCLUDEMAIN
#
# int main(int argc, char * argv[])
# {
#     /* seed randomness */
#     srand( (unsigned)time(NULL) );
# #ifndef OMITGOOD
#     printLine("Calling good()...");
#     CWE114_Process_Control__w32_char_connect_socket_01_good();
#     printLine("Finished good()");
# #endif /* OMITGOOD */
# #ifndef OMITBAD
#     printLine("Calling bad()...");
#     CWE114_Process_Control__w32_char_connect_socket_01_bad();
#     printLine("Finished bad()");
# #endif /* OMITBAD */
#     return 0;
# }
#
# #endif

# %% [markdown]
# If bad: we pretend OMITGOOD is defined, so we delete what is in #ifndef OMITGOOD ... #endif /* OMITGOOD *
# If good: we pretend OMITBAD is defined, so we delete what is in #ifndef OMITBAD ... #endif /* OMITBAD */

# %%
bad_df = juliet.copy()
good_df = juliet.copy()

# %%
def extract_good(text):
    '''Extract good script from code snippet'''
    
    text = text.split('\n')
    output_txt = []
    
    in_OMITBAD_block = False
        
    for line in text:
        if line == '#ifndef OMITBAD':
            in_OMITBAD_block = True
                
        if not in_OMITBAD_block:
            output_txt.append(line)
                
        if line == '#endif /* OMITBAD */':
            in_OMITBAD_block = False
    
    return '\n'.join(output_txt)

def extract_bad(text):
    '''Extract bad script from code snippet'''
    
    text = text.split('\n')
    output_txt = []
    
    in_OMITGOOD_block = False
        
    for line in text:
        if line == '#ifndef OMITGOOD':
            in_OMITGOOD_block = True
                
        if not in_OMITGOOD_block:
            output_txt.append(line)

        if line == '#endif /* OMITGOOD */':
            in_OMITGOOD_block = False
    
    return '\n'.join(output_txt)

# %%
print(extract_good(good_df.iloc[0].code))
# Out:
# /* TEMPLATE GENERATED TESTCASE FILE
# Filename: CWE114_Process_Control__w32_char_connect_socket_01.c
# Label Definition File: CWE114_Process_Control__w32.label.xml
# Template File: sources-sink-01.tmpl.c
# */
# /*
#  * @description
#  * CWE: 114 Process Control
#  * BadSource: connect_socket Read data using a connect socket (client side)
#  * GoodSource: Hard code the full pathname to the library
#  * Sink:
#  *    BadSink : Load a dynamic link library
#  * Flow Variant: 01 Baseline
#  *
#  * */
#
# #include "std_testcase.h"
#
# #include <wchar.h>
#
# #ifdef _WIN32
# #include <winsock2.h>
# #include <windows.h>
# #include <direct.h>
# #pragma comment(lib, "ws2_32") /* include ws2_32.lib when linking */
# #define CLOSE_SOCKET closesocket
# #else /* NOT _WIN32 */
# #include <sys/types.h>
# #include <sys/socket.h>
# #include <netinet/in.h>
# #include <arpa/inet.h>
# #include <unistd.h>
# #define INVALID_SOCKET -1
# #define SOCKET_ERROR -1
# #define CLOSE_SOCKET close
# #define SOCKET int
# #endif
#
# #define TCP_PORT 27015
# #define IP_ADDRESS "127.0.0.1"
#
#
#
# #ifndef OMITGOOD
#
# /* goodG2B uses the GoodSource with the BadSink */
# static void goodG2B()
# {
#     char * data;
#     char dataBuffer[100] = "";
#     data = dataBuffer;
#     /* FIX: Specify the full pathname for the library */
#     strcpy(data, "C:\\Windows\\System32\\winsrv.dll");
#     {
#         HMODULE hModule;
#         /* POTENTIAL FLAW: If the path to the library is not specified, an attacker may be able to
#          * replace his own file with the intended library */
#         hModule = LoadLibraryA(data);
#         if (hModule != NULL)
#         {
#             FreeLibrary(hModule);
#             printLine("Library loaded and freed successfully");
#         }
#         else
#         {
#             printLine("Unable to load library");
#         }
#     }
# }
#
# void CWE114_Process_Control__w32_char_connect_socket_01_good()
# {
#     goodG2B();
# }
#
# #endif /* OMITGOOD */
#
# /* Below is the main(). It is only used when building this testcase on
#  * its own for testing or for building a binary to use in testing binary
#  * analysis tools. It is not used when compiling all the testcases as one
#  * application, which is how source code analysis tools are tested.
#  */
#
# #ifdef INCLUDEMAIN
#
# int main(int argc, char * argv[])
# {
#     /* seed randomness */
#     srand( (unsigned)time(NULL) );
# #ifndef OMITGOOD
#     printLine("Calling good()...");
#     CWE114_Process_Control__w32_char_connect_socket_01_good();
#     printLine("Finished good()");
# #endif /* OMITGOOD */
#     return 0;
# }
#
# #endif

# %%
print(extract_bad(good_df.iloc[0].code))
# Out:
# /* TEMPLATE GENERATED TESTCASE FILE
# Filename: CWE114_Process_Control__w32_char_connect_socket_01.c
# Label Definition File: CWE114_Process_Control__w32.label.xml
# Template File: sources-sink-01.tmpl.c
# */
# /*
#  * @description
#  * CWE: 114 Process Control
#  * BadSource: connect_socket Read data using a connect socket (client side)
#  * GoodSource: Hard code the full pathname to the library
#  * Sink:
#  *    BadSink : Load a dynamic link library
#  * Flow Variant: 01 Baseline
#  *
#  * */
#
# #include "std_testcase.h"
#
# #include <wchar.h>
#
# #ifdef _WIN32
# #include <winsock2.h>
# #include <windows.h>
# #include <direct.h>
# #pragma comment(lib, "ws2_32") /* include ws2_32.lib when linking */
# #define CLOSE_SOCKET closesocket
# #else /* NOT _WIN32 */
# #include <sys/types.h>
# #include <sys/socket.h>
# #include <netinet/in.h>
# #include <arpa/inet.h>
# #include <unistd.h>
# #define INVALID_SOCKET -1
# #define SOCKET_ERROR -1
# #define CLOSE_SOCKET close
# #define SOCKET int
# #endif
#
# #define TCP_PORT 27015
# #define IP_ADDRESS "127.0.0.1"
#
#
# #ifndef OMITBAD
#
# void CWE114_Process_Control__w32_char_connect_socket_01_bad()
# {
#     char * data;
#     char dataBuffer[100] = "";
#     data = dataBuffer;
#     {
# #ifdef _WIN32
#         WSADATA wsaData;
#         int wsaDataInit = 0;
# #endif
#         int recvResult;
#         struct sockaddr_in service;
#         char *replace;
#         SOCKET connectSocket = INVALID_SOCKET;
#         size_t dataLen = strlen(data);
#         do
#         {
# #ifdef _WIN32
#             if (WSAStartup(MAKEWORD(2,2), &wsaData) != NO_ERROR)
#             {
#                 break;
#             }
#             wsaDataInit = 1;
# #endif
#             /* POTENTIAL FLAW: Read data using a connect socket */
#             connectSocket = socket(AF_INET, SOCK_STREAM, IPPROTO_TCP);
#             if (connectSocket == INVALID_SOCKET)
#             {
#                 break;
#             }
#             memset(&service, 0, sizeof(service));
#             service.sin_family = AF_INET;
#             service.sin_addr.s_addr = inet_addr(IP_ADDRESS);
#             service.sin_port = htons(TCP_PORT);
#             if (connect(connectSocket, (struct sockaddr*)&service, sizeof(service)) == SOCKET_ERROR)
#             {
#                 break;
#             }
#             /* Abort on error or the connection was closed, make sure to recv one
#              * less char than is in the recv_buf in order to append a terminator */
#             /* Abort on error or the connection was closed */
#             recvResult = recv(connectSocket, (char *)(data + dataLen), sizeof(char) * (100 - dataLen - 1), 0);
#             if (recvResult == SOCKET_ERROR || recvResult == 0)
#             {
#                 break;
#             }
#             /* Append null terminator */
#             data[dataLen + recvResult / sizeof(char)] = '\0';
#             /* Eliminate CRLF */
#             replace = strchr(data, '\r');
#             if (replace)
#             {
#                 *replace = '\0';
#             }
#             replace = strchr(data, '\n');
#             if (replace)
#             {
#                 *replace = '\0';
#             }
#         }
#         while (0);
#         if (connectSocket != INVALID_SOCKET)
#         {
#             CLOSE_SOCKET(connectSocket);
#         }
# #ifdef _WIN32
#         if (wsaDataInit)
#         {
#             WSACleanup();
#         }
# #endif
#     }
#     {
#         HMODULE hModule;
#         /* POTENTIAL FLAW: If the path to the library is not specified, an attacker may be able to
#          * replace his own file with the intended library */
#         hModule = LoadLibraryA(data);
#         if (hModule != NULL)
#         {
#             FreeLibrary(hModule);
#             printLine("Library loaded and freed successfully");
#         }
#         else
#         {
#             printLine("Unable to load library");
#         }
#     }
# }
#
# #endif /* OMITBAD */
#
#
# /* Below is the main(). It is only used when building this testcase on
#  * its own for testing or for building a binary to use in testing binary
#  * analysis tools. It is not used when compiling all the testcases as one
#  * application, which is how source code analysis tools are tested.
#  */
#
# #ifdef INCLUDEMAIN
#
# int main(int argc, char * argv[])
# {
#     /* seed randomness */
#     srand( (unsigned)time(NULL) );
# #ifndef OMITBAD
#     printLine("Calling bad()...");
#     CWE114_Process_Control__w32_char_connect_socket_01_bad();
#     printLine("Finished bad()");
# #endif /* OMITBAD */
#     return 0;
# }
#
# #endif

# %%
from preprocess_code import process_for_graph2vec

# %%
good_example = good_df.iloc[0]
good_example.code = extract_good(good_example.code)

# %%
good_df.code = good_df.code.apply(extract_good)
bad_df.code = bad_df.code.apply(extract_bad)

# %%
good_df.testcase_ID = good_df.testcase_ID.apply(lambda x: x + '_g')
bad_df.testcase_ID = bad_df.testcase_ID.apply(lambda x: x + '_b')

# %%
print(good_df.iloc[0].code)
# Out:
# /* TEMPLATE GENERATED TESTCASE FILE
# Filename: CWE114_Process_Control__w32_char_connect_socket_01.c
# Label Definition File: CWE114_Process_Control__w32.label.xml
# Template File: sources-sink-01.tmpl.c
# */
# /*
#  * @description
#  * CWE: 114 Process Control
#  * BadSource: connect_socket Read data using a connect socket (client side)
#  * GoodSource: Hard code the full pathname to the library
#  * Sink:
#  *    BadSink : Load a dynamic link library
#  * Flow Variant: 01 Baseline
#  *
#  * */
#
# #include "std_testcase.h"
#
# #include <wchar.h>
#
# #ifdef _WIN32
# #include <winsock2.h>
# #include <windows.h>
# #include <direct.h>
# #pragma comment(lib, "ws2_32") /* include ws2_32.lib when linking */
# #define CLOSE_SOCKET closesocket
# #else /* NOT _WIN32 */
# #include <sys/types.h>
# #include <sys/socket.h>
# #include <netinet/in.h>
# #include <arpa/inet.h>
# #include <unistd.h>
# #define INVALID_SOCKET -1
# #define SOCKET_ERROR -1
# #define CLOSE_SOCKET close
# #define SOCKET int
# #endif
#
# #define TCP_PORT 27015
# #define IP_ADDRESS "127.0.0.1"
#
#
#
# #ifndef OMITGOOD
#
# /* goodG2B uses the GoodSource with the BadSink */
# static void goodG2B()
# {
#     char * data;
#     char dataBuffer[100] = "";
#     data = dataBuffer;
#     /* FIX: Specify the full pathname for the library */
#     strcpy(data, "C:\\Windows\\System32\\winsrv.dll");
#     {
#         HMODULE hModule;
#         /* POTENTIAL FLAW: If the path to the library is not specified, an attacker may be able to
#          * replace his own file with the intended library */
#         hModule = LoadLibraryA(data);
#         if (hModule != NULL)
#         {
#             FreeLibrary(hModule);
#             printLine("Library loaded and freed successfully");
#         }
#         else
#         {
#             printLine("Unable to load library");
#         }
#     }
# }
#
# void CWE114_Process_Control__w32_char_connect_socket_01_good()
# {
#     goodG2B();
# }
#
# #endif /* OMITGOOD */
#
# /* Below is the main(). It is only used when building this testcase on
#  * its own for testing or for building a binary to use in testing binary
#  * analysis tools. It is not used when compiling all the testcases as one
#  * application, which is how source code analysis tools are tested.
#  */
#
# #ifdef INCLUDEMAIN
#
# int main(int argc, char * argv[])
# {
#     /* seed randomness */
#     srand( (unsigned)time(NULL) );
# #ifndef OMITGOOD
#     printLine("Calling good()...");
#     CWE114_Process_Control__w32_char_connect_socket_01_good();
#     printLine("Finished good()");
# #endif /* OMITGOOD */
#     return 0;
# }
#
# #endif

# %%
good_df['bug'] = 'False'
bad_df['bug'] = 'True'

# %%
juliet_split = good_df.append(bad_df)
juliet_split
# Out:
#       testcase_ID                                           filename  \
# 0         61940_g  000/061/940/CWE114_Process_Control__w32_char_c...
# 1         61941_g  000/061/941/CWE114_Process_Control__w32_char_c...
# 2         61942_g  000/061/942/CWE114_Process_Control__w32_char_c...
# 3         61943_g  000/061/943/CWE114_Process_Control__w32_char_c...
# 4         61944_g  000/061/944/CWE114_Process_Control__w32_char_c...
# 5         61945_g  000/061/945/CWE114_Process_Control__w32_char_c...
# 6         61946_g  000/061/946/CWE114_Process_Control__w32_char_c...
# 7         61947_g  000/061/947/CWE114_Process_Control__w32_char_c...
# 8         61948_g  000/061/948/CWE114_Process_Control__w32_char_c...
# 9         61949_g  000/061/949/CWE114_Process_Control__w32_char_c...
# 10        61950_g  000/061/950/CWE114_Process_Control__w32_char_c...
# 11        61951_g  000/061/951/CWE114_Process_Control__w32_char_c...
# 12        61952_g  000/061/952/CWE114_Process_Control__w32_char_c...
# 13        61953_g  000/061/953/CWE114_Process_Control__w32_char_c...
# 14        61954_g  000/061/954/CWE114_Process_Control__w32_char_c...
# 15        61955_g  000/061/955/CWE114_Process_Control__w32_char_c...
# 16        61956_g  000/061/956/CWE114_Process_Control__w32_char_c...
# 17        61957_g  000/061/957/CWE114_Process_Control__w32_char_c...
# 18        61958_g  000/061/958/CWE114_Process_Control__w32_char_c...
# 19        61959_g  000/061/959/CWE114_Process_Control__w32_char_c...
# 20        61960_g  000/061/960/CWE114_Process_Control__w32_char_c...
# 21        61961_g  000/061/961/CWE114_Process_Control__w32_char_c...
# 22        61962_g  000/061/962/CWE114_Process_Control__w32_char_c...
# 23        61963_g  000/061/963/CWE114_Process_Control__w32_char_c...
# 24        61964_g  000/061/964/CWE114_Process_Control__w32_char_c...
# 25        61965_g  000/061/965/CWE114_Process_Control__w32_char_c...
# 26        61966_g  000/061/966/CWE114_Process_Control__w32_char_c...
# 27        61967_g  000/061/967/CWE114_Process_Control__w32_char_c...
# 28        61968_g  000/061/968/CWE114_Process_Control__w32_char_c...
# 29        61969_g  000/061/969/CWE114_Process_Control__w32_char_c...
# ...           ...                                                ...
# 66317    248693_b  000/248/693/CWE78_OS_Command_Injection__wchar_...
# 66318    248694_b  000/248/694/CWE78_OS_Command_Injection__wchar_...
# 66319    248695_b  000/248/695/CWE78_OS_Command_Injection__wchar_...
# 66320    248696_b  000/248/696/CWE78_OS_Command_Injection__wchar_...
# 66321    248697_b  000/248/697/CWE78_OS_Command_Injection__wchar_...
# 66322    248698_b  000/248/698/CWE78_OS_Command_Injection__wchar_...
# 66323    248699_b  000/248/699/CWE78_OS_Command_Injection__wchar_...
# 66324    248700_b  000/248/700/CWE78_OS_Command_Injection__wchar_...
# 66325    248701_b  000/248/701/CWE78_OS_Command_Injection__wchar_...
# 66326    248702_b  000/248/702/CWE78_OS_Command_Injection__wchar_...
# 66327    248703_b  000/248/703/CWE78_OS_Command_Injection__wchar_...
# 66328    248704_b  000/248/704/CWE78_OS_Command_Injection__wchar_...
# 66329    248705_b  000/248/705/CWE78_OS_Command_Injection__wchar_...
# 66330    248706_b  000/248/706/CWE78_OS_Command_Injection__wchar_...
# 66331    248707_b  000/248/707/CWE78_OS_Command_Injection__wchar_...
# 66332    248708_b  000/248/708/CWE78_OS_Command_Injection__wchar_...
# 66333    248709_b  000/248/709/CWE78_OS_Command_Injection__wchar_...
# 66334    248710_b  000/248/710/CWE78_OS_Command_Injection__wchar_...
# 66335    248711_b  000/248/711/CWE78_OS_Command_Injection__wchar_...
# 66336    248712_b  000/248/712/CWE78_OS_Command_Injection__wchar_...
# 66337    248713_b  000/248/713/CWE78_OS_Command_Injection__wchar_...
# 66338    248714_b  000/248/714/CWE78_OS_Command_Injection__wchar_...
# 66339    248715_b  000/248/715/CWE78_OS_Command_Injection__wchar_...
# 66340    248716_b  000/248/716/CWE78_OS_Command_Injection__wchar_...
# 66341    248717_b  000/248/717/CWE78_OS_Command_Injection__wchar_...
# 66342    248718_b  000/248/718/CWE78_OS_Command_Injection__wchar_...
# 66343    248719_b  000/248/719/CWE78_OS_Command_Injection__wchar_...
# 66344    248720_b  000/248/720/CWE78_OS_Command_Injection__wchar_...
# 66345    248721_b  000/248/721/CWE78_OS_Command_Injection__wchar_...
# 66346    248722_b  000/248/722/CWE78_OS_Command_Injection__wchar_...
#
#                                                     code     flaw flaw_loc  \
# 0      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      121
# 1      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      124
# 2      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      124
# 3      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      131
# 4      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      131
# 5      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      128
# 6      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      130
# 7      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      138
# 8      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      124
# 9      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      124
# 10     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      124
# 11     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      129
# 12     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      124
# 13     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      124
# 14     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      130
# 15     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      125
# 16     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      125
# 17     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      123
# 18     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      134
# 19     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114       41
# 20     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      124
# 21     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      129
# 22     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      127
# 23     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      131
# 24     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114       51
# 25     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      127
# 26     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114      129
# 27     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114       51
# 28     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114       55
# 29     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-114       53
# ...                                                  ...      ...      ...
# 66317  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078      162
# 66318  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       57
# 66319  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078      152
# 66320  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078      157
# 66321  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078      155
# 66322  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078      159
# 66323  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       67
# 66324  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078      155
# 66325  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078      157
# 66326  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       67
# 66327  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       71
# 66328  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       69
# 66329  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       69
# 66330  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       69
# 66331  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       69
# 66332  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       74
# 66333  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       57
# 66334  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       68
# 66335  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       71
# 66336  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       67
# 66337  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       69
# 66338  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       73
# 66339  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       73
# 66340  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       55
# 66341  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       55
# 66342  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       55
# 66343  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       33
# 66344  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078       33
# 66345  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078      137
# 66346  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-078      137
#
#          bug
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# ...      ...
# 66317   True
# 66318   True
# 66319   True
# 66320   True
# 66321   True
# 66322   True
# 66323   True
# 66324   True
# 66325   True
# 66326   True
# 66327   True
# 66328   True
# 66329   True
# 66330   True
# 66331   True
# 66332   True
# 66333   True
# 66334   True
# 66335   True
# 66336   True
# 66337   True
# 66338   True
# 66339   True
# 66340   True
# 66341   True
# 66342   True
# 66343   True
# 66344   True
# 66345   True
# 66346   True
#
# [132694 rows x 6 columns]

# %%
juliet_split.to_csv('juliet_split.csv.gz')
