# %% [markdown]
# <a href="https://colab.research.google.com/github/dj311/uob-summer-project/blob/master/code/exploring_vdisc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploring VDISC

# %%
# !pip install h5py

# %%
# !git clone https://github.com/dj311/uob-summer-project.git

# !wget --output-document=uob-summer-project/data/vdisc_test.hdf5 https://osf.io/f9t6z/download
    
# Check the file we downloaded is correct and wasn't corrupted. Should be f12f4741e27f3f8f8863a26091c07307:
# !md5sum uob-summer-project/data/vdisc_test.hdf5

# Move working directory t be inside git repo, as if we were in a local jupyter in the project
import os
os.chdir('uob-summer-project')
# Out:
# Cloning into 'uob-summer-project'...
# remote: Enumerating objects: 8340, done.
# remote: Counting objects: 100% (8340/8340), done.
# remote: Compressing objects: 100% (660/660), done.
# remote: Total 8340 (delta 7719), reused 8250 (delta 7671), pack-reused 0
# Receiving objects: 100% (8340/8340), 3.29 MiB | 6.34 MiB/s, done.
# Resolving deltas: 100% (7719/7719), done.
# --2019-06-10 15:57:32--  https://osf.io/f9t6z/download
# Resolving osf.io (osf.io)... 35.190.84.173
# Connecting to osf.io (osf.io)|35.190.84.173|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://files.osf.io/v1/resources/d45bw/providers/osfstorage/5bf34e965603840019b1bdd2?action=download&version=1&direct [following]
# --2019-06-10 15:57:33--  https://files.osf.io/v1/resources/d45bw/providers/osfstorage/5bf34e965603840019b1bdd2?action=download&version=1&direct
# Resolving files.osf.io (files.osf.io)... 35.186.214.196
# ...

# %%
import h5py
import pandas as pd

# %%
vdisc_test_file = h5py.File('data/vdisc_test.hdf5')

# %%
cwes = set(open('data/combined-cwes.txt', 'r').read().strip().split('\n'))

# %%
# Manually construct the data frame as a dict with key=<column name> and value=<list of
# values for that column>.

length = vdisc_test_file['functionSource'].size

raw_dataframe = {
    'testcase_ID': ["vdisc_testcase_{}".format(index) for index in range(length)],
    'flaw_loc': [None]*length,
    'filename': [None]*length,
    'code': vdisc_test_file['functionSource'],
    'CWE-119': vdisc_test_file['CWE-119'],
    'CWE-120': vdisc_test_file['CWE-120'],
    'CWE-469': vdisc_test_file['CWE-469'],
    'CWE-476': vdisc_test_file['CWE-476'],
    'CWE-OTHERS': vdisc_test_file['CWE-other'],
}

empty_cwes = [
    cwe for cwe in cwes if cwe not in {
        'CWE-119',
        'CWE-120',
        'CWE-469',
        'CWE-476',
        'CWE-OTHERS',
    }
]

for cwe in empty_cwes:
    raw_dataframe[cwe] = [False]*length

    
vdisc = pd.DataFrame(data=raw_dataframe)

# %%
vdisc
# Out:
#                   testcase_ID flaw_loc filename  ... CWE-247  CWE-789  CWE-023
# 0            vdisc_testcase_0     None     None  ...   False    False    False
# 1            vdisc_testcase_1     None     None  ...   False    False    False
# 2            vdisc_testcase_2     None     None  ...   False    False    False
# 3            vdisc_testcase_3     None     None  ...   False    False    False
# 4            vdisc_testcase_4     None     None  ...   False    False    False
# 5            vdisc_testcase_5     None     None  ...   False    False    False
# 6            vdisc_testcase_6     None     None  ...   False    False    False
# 7            vdisc_testcase_7     None     None  ...   False    False    False
# 8            vdisc_testcase_8     None     None  ...   False    False    False
# 9            vdisc_testcase_9     None     None  ...   False    False    False
# 10          vdisc_testcase_10     None     None  ...   False    False    False
# ...
