# %% [markdown]
# <a href="https://colab.research.google.com/github/dj311/uob-summer-project/blob/master/code/exploring_vdisc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploring VDISC

# %%
# !pip install h5py
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.8.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.12.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.16.4)

# %%
# !git clone https://github.com/dj311/uob-summer-project.git
# Out:
# fatal: destination path 'uob-summer-project' already exists and is not an empty directory.

# %%
# !wget --output-document=uob-summer-project/data/vdisc_test.hdf5 https://osf.io/f9t6z/download
#MD5 should be f12f4741e27f3f8f8863a26091c07307
# !md5sum uob-summer-project/data/vdisc_test.hdf5
# Out:
# --2019-06-10 12:38:05--  https://osf.io/f9t6z/download
# Resolving osf.io (osf.io)... 35.190.84.173
# Connecting to osf.io (osf.io)|35.190.84.173|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://files.osf.io/v1/resources/d45bw/providers/osfstorage/5bf34e965603840019b1bdd2?action=download&version=1&direct [following]
# --2019-06-10 12:38:05--  https://files.osf.io/v1/resources/d45bw/providers/osfstorage/5bf34e965603840019b1bdd2?action=download&version=1&direct
# Resolving files.osf.io (files.osf.io)... 35.186.214.196
# Connecting to files.osf.io (files.osf.io)|35.186.214.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 107870135 (103M) [application/octet-stream]
# Saving to: ‘uob-summer-project/data/vdisc_test.hdf5’
#
# uob-summer-project/ 100%[===================>] 102.87M  43.8MB/s    in 2.3s
#
# 2019-06-10 12:38:08 (43.8 MB/s) - ‘uob-summer-project/data/vdisc_test.hdf5’ saved [107870135/107870135]
#
# f12f4741e27f3f8f8863a26091c07307  uob-summer-project/data/vdisc_test.hdf5

# %%
import h5py
import pandas as pd

# %%
vdisc_test_file = h5py.File('uob-summer-project/data/vdisc_test.hdf5')

# %%
vdisc_test_file['functionSource'].size
# Out:
# 127419

# %%
length = vdisc_test_file['functionSource'].size

code = vdisc_test_file['functionSource']
cwe_119 = vdisc_test_file['CWE-119']
cwe_120 = vdisc_test_file['CWE-120']
cwe_469 = vdisc_test_file['CWE-469']
cwe_476 = vdisc_test_file['CWE-476']
cwe_other = vdisc_test_file['CWE-other']

vdisc_raw = zip(range(length), code, cwe_119, cwe_120, cwe_469, cwe_476, cwe_other)
vdisc_raw = pd.DataFrame(
    columns=['index', 'code', 'cwe_119', 'cwe_120', 'cwe_469', 'cwe_476', 'cwe_other'],
    data=vdisc_raw,
)

# %%
vdisc_raw
# Out:
#          index  ... cwe_other
# 0            0  ...     False
# 1            1  ...     False
# 2            2  ...     False
# 3            3  ...     False
# 4            4  ...     False
# 5            5  ...     False
# 6            6  ...     False
# 7            7  ...     False
# 8            8  ...     False
# 9            9  ...     False
# 10          10  ...     False
# 11          11  ...     False
# 12          12  ...     False
# 13          13  ...     False
# 14          14  ...     False
# 15          15  ...     False
# 16          16  ...     False
# 17          17  ...     False
# 18          18  ...     False
# 19          19  ...      True
# 20          20  ...      True
# 21          21  ...      True
# 22          22  ...     False
# 23          23  ...     False
# 24          24  ...     False
# 25          25  ...     False
# 26          26  ...     False
# 27          27  ...     False
# 28          28  ...     False
# 29          29  ...     False
# ...        ...  ...       ...
# 127389  127389  ...     False
# 127390  127390  ...     False
# 127391  127391  ...     False
# 127392  127392  ...     False
# 127393  127393  ...     False
# 127394  127394  ...     False
# 127395  127395  ...     False
# 127396  127396  ...     False
# 127397  127397  ...     False
# 127398  127398  ...     False
# 127399  127399  ...     False
# 127400  127400  ...     False
# 127401  127401  ...     False
# 127402  127402  ...     False
# 127403  127403  ...     False
# 127404  127404  ...     False
# 127405  127405  ...     False
# 127406  127406  ...     False
# 127407  127407  ...     False
# 127408  127408  ...      True
# 127409  127409  ...     False
# 127410  127410  ...     False
# 127411  127411  ...     False
# 127412  127412  ...     False
# 127413  127413  ...     False
# 127414  127414  ...     False
# 127415  127415  ...     False
# 127416  127416  ...     False
# 127417  127417  ...     False
# 127418  127418  ...     False
#
# [127419 rows x 7 columns]

# %%
def convert_row(row):
    index, code, cwe_119, cwe_120, cwe_469, cwe_476, cwe_other = row.values
    
    testcase_ID = "vdisc_testcase_{}".format(index)
    
    if cwe_119:
        flaw = "CWE-119"
    elif cwe_120:
        flaw = "CWE-120"
    elif cwe_469:
        flaw = "CWE-469"
    elif cwe_476:
        flaw = "CWE-476"
    elif cwe_other:
        flaw = "CWE-UNKNOWN"
    else:
        flaw = None
        
    return {
        "testcase_ID": testcase_ID,
        "filename": None,
        "code": code,
        "flaw": flaw,
        "flaw_loc": None,
     }

vdisc = vdisc_raw.apply(convert_row, axis=1, result_type='expand')

# %%
vdisc
# Out:
#                                                      code  ...            testcase_ID
# 0       default_event_handler( \n    GuiWidget *widget...  ...       vdisc_testcase_0
# 1       krb5_krbhst_init_flags(krb5_context context,\n...  ...       vdisc_testcase_1
# 2       swap_info_get(swp_entry_t entry)\n{\n\tstruct ...  ...       vdisc_testcase_2
# 3       parseattribs4(char *&c, const Vec4 &ival = Vec...  ...       vdisc_testcase_3
# 4       generateExecCode(CompileState* comp)\n{\n    g...  ...       vdisc_testcase_4
# 5       use_vfp_abi (enum arm_pcs pcs_variant, bool is...  ...       vdisc_testcase_5
# 6       hasUsesToReplace(GlobalAlias &GA, const LLVMUs...  ...       vdisc_testcase_6
# 7       load_tile_set( const char *set ) {\n  string s...  ...       vdisc_testcase_7
# 8       BufFileSeek(BufFile *file, int fileno, long of...  ...       vdisc_testcase_8
# 9       sendPlayPacket(rtmp::RTMP& r, FakeNC& nc)\n{\n...  ...       vdisc_testcase_9
# 10      buildToken( char *text )\n#else\nbuildToken( t...  ...      vdisc_testcase_10
# 11      putcharacter(scheme *sc, int c) {\n  port *pt=...  ...      vdisc_testcase_11
# 12      mtk_i2c_init_hw(struct mtk_i2c *i2c)\n{\n\tu16...  ...      vdisc_testcase_12
# 13      check_conversion(const char *s, const char *ep...  ...      vdisc_testcase_13
# 14      isLoopInvariant(const Value *V) const {\n  if ...  ...      vdisc_testcase_14
# 15      efi_image_probe ( struct image *image ) {\n\tE...  ...      vdisc_testcase_15
# 16      raid1_spare_active(struct mddev *mddev)\n{\n\t...  ...      vdisc_testcase_16
# 17      httpSetRoutePathVar(HttpRoute *route, cchar *k...  ...      vdisc_testcase_17
# 18      clutter_gdk_set_display (GdkDisplay *display)\...  ...      vdisc_testcase_18
# 19      TTYtoVT(const char *tty)\n{\n    if (!memcmp(t...  ...      vdisc_testcase_19
# 20      gdip_region_bitmap_union (GpRegionBitmap *shap...  ...      vdisc_testcase_20
# 21      ParseCSVResponse(char* pszLine,\n             ...  ...      vdisc_testcase_21
# 22      Next()\n{\n   Real ak,y; int ir1;\n   if (NotR...  ...      vdisc_testcase_22
# 23      upper_layer_chksum_ipv4(struct uip_stack *usta...  ...      vdisc_testcase_23
# 24      find(FXint fd) {\n    FXMutexLock lock(mutex);...  ...      vdisc_testcase_24
# 25      CreateCategory(\n\tCategory_Struct *& category...  ...      vdisc_testcase_25
# 26      egg_asn1x_set_oid_as_quark (GNode *node,\n    ...  ...      vdisc_testcase_26
# 27      saveParzenPDFToTextFile(\n\tconst char\t*fileN...  ...      vdisc_testcase_27
# 28      cup_winselect_init(void)\n{\n\tint i = 0;\n\ti...  ...      vdisc_testcase_28
# 29      opera1_usb_i2c_msgxfer(struct dvb_usb_device *...  ...      vdisc_testcase_29
# ...                                                   ...  ...                    ...
# 127389  dispose (GObject *object)\n{\n\tDhSettings *se...  ...  vdisc_testcase_127389
# 127390  clone_from (ACE_InputCDR &cdr)\n{\n  this->do_...  ...  vdisc_testcase_127390
# 127391  H5Tset_precision(hid_t type_id, size_t prec)\n...  ...  vdisc_testcase_127391
# 127392  my_atan(int32_t arg)\n{\n    uint16_t index = ...  ...  vdisc_testcase_127392
# 127393  handleCollapseButton() {\n    fIsCollapsed = !...  ...  vdisc_testcase_127393
# 127394  eigen(double **M,\t\t/* Input matrix */\n\t  d...  ...  vdisc_testcase_127394
# 127395  update_bias (LqrCarver * r, gint32 layer_ID, g...  ...  vdisc_testcase_127395
# 127396  findstations(void)\n{\n    float maxg = 0, min...  ...  vdisc_testcase_127396
# 127397  ___device_tty_mode_save\n   ___P((___device_tt...  ...  vdisc_testcase_127397
# 127398  cameraFocal(double lm)\n\n{\n   double nfk=0.;...  ...  vdisc_testcase_127398
# 127399  S_mg_findext_flags(pTHX_ const SV *sv, int typ...  ...  vdisc_testcase_127399
# 127400  gst_spectra_scope_render (GstAudioVisualizer *...  ...  vdisc_testcase_127400
# 127401  skipnoopstat (LexState *ls) {\n  while (ls->t....  ...  vdisc_testcase_127401
# 127402  insertIntoPlaylist( Playlist::AddOptions optio...  ...  vdisc_testcase_127402
# 127403  gtk_sheet_forall (GtkContainer *container,\n  ...  ...  vdisc_testcase_127403
# 127404  CheckVisitedAndUnmark(Object** field) {\n    i...  ...  vdisc_testcase_127404
# 127405  omeg_(doublereal *dnrm, integer *iflag)\n{\n  ...  ...  vdisc_testcase_127405
# 127406  check_keys (gcry_sexp_t pkey, gcry_sexp_t skey...  ...  vdisc_testcase_127406
# 127407  rfc822_display_hdrvalue(const char *hdrname,\n...  ...  vdisc_testcase_127407
# 127408  syck_parser_read( SyckParser *p )\n{\n    long...  ...  vdisc_testcase_127408
# 127409  cmd_addhist(mlist, cmd, cs)\n\tstruct mlist *m...  ...  vdisc_testcase_127409
# 127410  htree_dump_leaf_node(ext2_filsys fs, ext2_ino_...  ...  vdisc_testcase_127410
# 127411  subgInduce(Agraph_t * root, Agraph_t * g, int ...  ...  vdisc_testcase_127411
# 127412  get_level(ptst_t * ptst)\n{\n    unsigned long...  ...  vdisc_testcase_127412
# 127413  relock_object (GkmGnome2Storage *self, GkmTran...  ...  vdisc_testcase_127413
# 127414  gucharmap_block_chapters_model_init (Gucharmap...  ...  vdisc_testcase_127414
# 127415  scomp(const void *v1, const void *v2)\n{\n    ...  ...  vdisc_testcase_127415
# 127416  text_chunk_line_free(TEXT_BUFFER_REC *buffer, ...  ...  vdisc_testcase_127416
# 127417  psmouse_disconnect(struct serio *serio)\n{\n\t...  ...  vdisc_testcase_127417
# 127418  brasero_tool_dialog_get_burn (BraseroToolDialo...  ...  vdisc_testcase_127418
#
# [127419 rows x 5 columns]
