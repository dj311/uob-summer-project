# %% [markdown]
# # Evaluation

# %% [markdown]
# ### Colab Setup

# %%
! mkdir -p /project/data && cd /project/data && wget -O stack-model.pkl https://github.com/dj311/uob-summer-project/raw/master/data/stack-model.pkl
! mkdir -p /project/data && cd /project/data && wget -O dense-model-binary https://github.com/dj311/uob-summer-project/raw/master/data/dense-model-binary
! mkdir -p /project/data && cd /project/data && wget -O binary-convolutional https://github.com/dj311/uob-summer-project/raw/master/data/binary-convolutional
! mkdir -p /project/data && cd /project/data && wget -O adjacency-matrix-model-binary.pickle https://github.com/dj311/uob-summer-project/raw/master/data/adjacency-matrix-model-binary.pickle
! mkdir -p /project/data && cd /project/data && wget -O adjacency-matrix-model-random-padding.pickle https://github.com/dj311/uob-summer-project/raw/master/data/adjacency-matrix-model-random-padding.pickle
! mkdir -p /project/data && cd /project/data && wget -O adjacency-feature-matrix-model-binary.pickle https://github.com/dj311/uob-summer-project/raw/master/data/adjacency-feature-matrix-model-binary.pickle
! mkdir -p /project/data && cd /project/data && wget -O adjacency-feature-matrix-random-padding-model-binary.pickle https://github.com/dj311/uob-summer-project/raw/master/data/adjacency-feature-matrix-random-padding-model-binary.pickle

! mkdir -p /project/data && cd /project/data && wget -O dense-graph2vec-y-test https://github.com/dj311/uob-summer-project/raw/master/data/dense-graph2vec-y-test
! mkdir -p /project/data && cd /project/data && wget -O dense-graph2vec-y-predict https://github.com/dj311/uob-summer-project/raw/master/data/dense-graph2vec-y-predict
! mkdir -p /project/data && cd /project/data && wget -O cnn-graph2vec-y-test https://github.com/dj311/uob-summer-project/raw/master/data/cnn-graph2vec-y-test
! mkdir -p /project/data && cd /project/data && wget -O cnn-graph2vec-y-predict https://github.com/dj311/uob-summer-project/raw/master/data/cnn-graph2vec-y-predict
! mkdir -p /project/data && cd /project/data && wget -O stack-model-y-test https://github.com/dj311/uob-summer-project/raw/master/data/stack-model-y-test
! mkdir -p /project/data && cd /project/data && wget -O stack-model-y-predict https://github.com/dj311/uob-summer-project/raw/master/data/stack-model-y-predict
! mkdir -p /project/data && cd /project/data && wget -O cnn-adj-y-test https://github.com/dj311/uob-summer-project/raw/master/data/cnn-adj-y-test
! mkdir -p /project/data && cd /project/data && wget -O cnn-adj-y-predict https://github.com/dj311/uob-summer-project/raw/master/data/cnn-adj-y-predict
! mkdir -p /project/data && cd /project/data && wget -O cnn-adj-rand-pad-y-test https://github.com/dj311/uob-summer-project/raw/master/data/cnn-adj-rand-y-test
! mkdir -p /project/data && cd /project/data && wget -O cnn-adj-rand-pad-y-predict https://github.com/dj311/uob-summer-project/raw/master/data/cnn-adj-rand-y-predict
#! mkdir -p /project/data && cd /project/data && wget -O cnn-adj-feat-y-test https://github.com/dj311/uob-summer-project/raw/master/data/cnn-adj-feat-y-test
#! mkdir -p /project/data && cd /project/data && wget -O cnn-adj-feat-y-predict https://github.com/dj311/uob-summer-project/raw/master/data/cnn-adj-feat-y-predict
! mkdir -p /project/data && cd /project/data && wget -O cnn-adj-feat-rand-pad-y-test https://github.com/dj311/uob-summer-project/raw/master/data/cnn-adj-feat-rand-pad-y-test
! mkdir -p /project/data && cd /project/data && wget -O cnn-adj-feat-rand-pad-y-predict https://github.com/dj311/uob-summer-project/raw/master/data/cnn-adj-feat-rand-pad-y-predict

! mkdir -p /project/data && cd /project/data && wget -O dense-model-history https://github.com/dj311/uob-summer-project/raw/master/data/dense-model-history
! mkdir -p /project/data && cd /project/data && wget -O binary-convolutional-history https://github.com/dj311/uob-summer-project/raw/master/data/binary-convolutional-history
! mkdir -p /project/data && cd /project/data && wget -O adjacency-matrix-history.pickle https://github.com/dj311/uob-summer-project/raw/master/data/adjacency-matrix-model-binary-training-history.pickle
! mkdir -p /project/data && cd /project/data && wget -O adjacency-matrix-random-padding-history.pickle https://github.com/dj311/uob-summer-project/raw/master/data/adjacency-matrix-model-random-training-history.pickle
! mkdir -p /project/data && cd /project/data && wget -O adjacency-feature-matrix-history.pickle https://github.com/dj311/uob-summer-project/raw/master/data/adjacency-feature-matrix-history.pickle
! mkdir -p /project/data && cd /project/data && wget -O adjacency-feature-matrix-random-padding-history.pickle https://github.com/dj311/uob-summer-project/raw/master/data/adjacency-feature-matrix-random-padding-history.pickle
# Out:
# --2019-08-23 16:03:59--  https://github.com/dj311/uob-summer-project/raw/master/data/stack-model.pkl
# Resolving github.com (github.com)... 192.30.253.112
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/dj311/uob-summer-project/master/data/stack-model.pkl [following]
# --2019-08-23 16:03:59--  https://media.githubusercontent.com/media/dj311/uob-summer-project/master/data/stack-model.pkl
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 118952 (116K) [application/octet-stream]
# Saving to: ‘stack-model.pkl’
#
# stack-model.pkl     100%[===================>] 116.16K  --.-KB/s    in 0.04s
#
# ...

# %%
# !mkdir -p /project/code
# !mkdir -p /project/images
# %cd /project/code
# Out:
# /project/code

# %% [markdown]
# ### Load in Models

# %%
import pickle

# %%
with open('../data/stack-model.pkl', 'rb') as f:
    stack_model = pickle.load(f)
    
with open('../data/dense-model-binary', 'rb') as f:
    dense_graph2vec = pickle.load(f)
    
with open('../data/binary-convolutional', 'rb') as f:
    conv_graph2vec = pickle.load(f)

with open('../data/adjacency-matrix-model-binary.pickle', 'rb') as f:
    adj_original = pickle.load(f)

with open('../data/adjacency-matrix-model-random-padding.pickle', 'rb') as f:
    adj_rand_pad_final = pickle.load(f)
    
with open('../data/adjacency-feature-matrix-model-binary.pickle', 'rb') as f:
    adj_feat_original = pickle.load(f)
    
with open('../data/adjacency-feature-matrix-random-padding-model-binary.pickle', 'rb') as f:
    adj_feat_rand_pad_final = pickle.load(f)
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0823 16:05:04.436211 139725441599360 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0823 16:05:04.483006 139725441599360 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0823 16:05:04.542576 139725441599360 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ...

# %%
with open('../data/dense-graph2vec-y-test', 'rb') as f:
    dense_graph2vec_y_test = pickle.load(f)
with open('../data/dense-graph2vec-y-predict', 'rb') as f:
    dense_graph2vec_y_predict = pickle.load(f)

with open('../data/cnn-graph2vec-y-test', 'rb') as f:
    cnn_graph2vec_y_test = pickle.load(f)
with open('../data/cnn-graph2vec-y-predict', 'rb') as f:
    cnn_graph2vec_y_predict = pickle.load(f)

with open('../data/stack-model-y-test', 'rb') as f:
    stack_model_y_test = pickle.load(f)
with open('../data/stack-model-y-predict', 'rb') as f:
    stack_model_y_predict = pickle.load(f)

with open('../data/cnn-adj-y-test', 'rb') as f:
    cnn_adj_y_test = pickle.load(f)
with open('../data/cnn-adj-y-predict', 'rb') as f:
    cnn_adj_y_predict = pickle.load(f)

with open('../data/cnn-adj-rand-pad-y-test', 'rb') as f:
    cnn_adj_rand_pad_y_test = pickle.load(f)
with open('../data/cnn-adj-rand-pad-y-predict', 'rb') as f:
    cnn_adj_rand_pad_y_predict = pickle.load(f)

# with open('../data/cnn-adj-feat-y-test', 'rb') as f:
#     cnn_adj_feat_y_test = pickle.load(f)
# with open('../data/cnn-adj-feat-y-predict', 'rb') as f:
#     cnn_adj_feat_y_predict = pickle.load(f)

with open('../data/cnn-adj-feat-rand-pad-y-test', 'rb') as f:
    cnn_adj_feat_rand_pad_y_test = pickle.load(f)
with open('../data/cnn-adj-feat-rand-pad-y-predict', 'rb') as f:
    cnn_adj_feat_rand_pad_y_predict = pickle.load(f)

# %% [markdown]
# ## Metrics Table

# %%
from sklearn.metrics import roc_curve, precision_recall_curve, matthews_corrcoef, f1_score, roc_auc_score, auc, confusion_matrix, precision_score, recall_score
import numpy as np
import pandas as pd

def rates(y_test, y_predict):
    tn, fp, fn, tp = confusion_matrix(
    y_test.astype(int), 
    np.rint(y_predict)
    ).flatten().tolist()

    fpr = fp/(fp+tp)
    fnr = fn/(fn+tn)
    return fpr, fnr

def get_metrics(y_test, y_predict):
    fpr_plot, tpr_plot, thresholds_roc = roc_curve(y_test, y_predict)
    precision_plot, recall_plot, thresholds_pr = precision_recall_curve(y_test, y_predict)
    roc_auc = roc_auc_score(y_test, y_predict)
    pr_auc = auc(recall_plot, precision_plot)
    f1 = f1_score(y_test, np.rint(y_predict))
    mcc = matthews_corrcoef(y_test, np.rint(y_predict))
    precision = precision_score(y_test, np.rint(y_predict))
    recall = recall_score(y_test, np.rint(y_predict))
    fpr, fnr = rates(y_test, y_predict)
    metric_values = {
        'fpr_plot' : fpr_plot,
        'tpr_plot' : tpr_plot,
        'precision_plot' : precision_plot,
        'recall_plot' : recall_plot,
        'thresholds_pr' : thresholds_pr,
        'ROC AUC' : roc_auc,
        'Precision Recall AUC' : pr_auc,
        'F1 Score' : f1,
        'Matthews Correlation Coefficient' : mcc,
        'Precision' : precision,
        'Recall' : recall,
        'FPR' : fpr,
        'FNR' : fnr
    }
    return metric_values

# %%
metrics_dense_graph2vec = get_metrics(dense_graph2vec_y_test, dense_graph2vec_y_predict)
metrics_cnn_graph2vec = get_metrics(cnn_graph2vec_y_test, cnn_graph2vec_y_predict)
metrics_stack_model = get_metrics(stack_model_y_test, stack_model_y_predict)
metrics_cnn_adj = get_metrics(cnn_adj_y_test, cnn_adj_y_predict)
metrics_cnn_adj_rand_pad = get_metrics(cnn_adj_rand_pad_y_test, cnn_adj_rand_pad_y_predict)
#metrics_cnn_adj_feat = get_metrics(cnn_adj_feat_y_test, cnn_adj_feat_y_predict)
metrics_cnn_adj_feat_rand_pad = get_metrics(cnn_adj_feat_rand_pad_y_test, cnn_adj_feat_rand_pad_y_predict)

# %%
model_names = pd.DataFrame({
  'Model': [
    'Dense NN on graph2vec (Baseline)', 
    'CNN on graph2vec', 
    'Stacked Model', 
    'CNN on Adjacency Matrices (Original Padding)', 
    'CNN on Adjacency Matrices (Randomly Padded)', 
    'CNN on Adjacency and Feature Matrices (Original Padding)',
    'CNN on Adjacency and Feature Matrices (Randomly Padded)'
  ]
})

model_accuracies = pd.DataFrame({
  'Accuracy' : [
      0.954,
      0.950,
      0.920,
      0.988,
      0.936,
      0.976,
      0.709              
  ]
})

all_metrics = pd.DataFrame(
    [metrics_dense_graph2vec, metrics_cnn_graph2vec, metrics_stack_model, metrics_cnn_adj, metrics_cnn_adj_rand_pad, {}, metrics_cnn_adj_feat_rand_pad] #add in cnn adj and cnn adj/feat random padded
)
all_metrics = model_names.join(model_accuracies).join(all_metrics)

key_metrics = all_metrics.filter(['Model', 'Accuracy', 'Precision', 'Recall', 'FPR', 'FNR'])

deep_learning_metrics = all_metrics.filter(['Model', 'ROC AUC', 'Precision Recall AUC', 'F1 Score', 'Matthews Correlation Coefficient'])

# %%
key_metrics.round(decimals = 3)
# Out:
#                                                Model  Accuracy  ...    FPR    FNR
# 0                   Dense NN on graph2vec (Baseline)     0.954  ...  0.031  0.059
# 1                                   CNN on graph2vec     0.950  ...  0.060  0.039
# 2                                      Stacked Model     0.920  ...  0.089  0.070
# 3       CNN on Adjacency Matrices (Original Padding)     0.000  ...  0.085  0.029
# 4        CNN on Adjacency Matrices (Randomly Padded)     0.000  ...  0.085  0.077
# 5  CNN on Adjacency and Feature Matrices (Origina...     0.000  ...    NaN    NaN
# 6  CNN on Adjacency and Feature Matrices (Randoml...     0.000  ...  0.093  0.134
#
# [7 rows x 6 columns]

# %%
deep_learning_metrics.round(decimals = 3)
# Out:
#                                                Model  ...  Matthews Correlation Coefficient
# 0                   Dense NN on graph2vec (Baseline)  ...                             0.909
# 1                                   CNN on graph2vec  ...                             0.901
# 2                                      Stacked Model  ...                             0.841
# 3       CNN on Adjacency Matrices (Original Padding)  ...                             0.883
# 4        CNN on Adjacency Matrices (Randomly Padded)  ...                             0.838
# 5  CNN on Adjacency and Feature Matrices (Origina...  ...                               NaN
# 6  CNN on Adjacency and Feature Matrices (Randoml...  ...                             0.772
#
# [7 rows x 5 columns]

# %%
# original padding dropped

model_names_drop = pd.DataFrame({
  'Model': [
    'Dense NN on graph2vec (Baseline)', 
    'CNN on graph2vec', 
    'Stacked Model', 
    'CNN on Adjacency Matrices (Randomly Padded)', 
    'CNN on Adjacency and Feature Matrices (Randomly Padded)'
  ]
})

model_accuracies_drop = model_accuracies.filter([0,1,2,4,6], axis=0)

all_metrics_drop = pd.DataFrame(
    [metrics_dense_graph2vec, metrics_cnn_graph2vec, metrics_stack_model] #add in cnn adj and cnn adj/feat random padded
)
all_metrics_drop = model_names_drop.join(model_accuracies_drop).join(all_metrics_drop)

key_metrics_drop = all_metrics_drop.filter(['Model', 'Accuracy', 'Precision', 'Recall', 'FPR', 'FNR'])

deep_learning_metrics_drop = all_metrics_drop.filter(['Model', 'ROC AUC', 'Precision Recall AUC', 'F1 Score', 'Matthews Correlation Coefficient'])

# %%
key_metrics_drop
# Out:
#                                                Model  ...       FNR
# 0                   Dense NN on graph2vec (Baseline)  ...  0.059428
# 1                                   CNN on graph2vec  ...  0.038716
# 2                                      Stacked Model  ...  0.069746
# 3        CNN on Adjacency Matrices (Randomly Padded)  ...       NaN
# 4  CNN on Adjacency and Feature Matrices (Randoml...  ...       NaN
#
# [5 rows x 6 columns]

# %%
deep_learning_metrics_drop
# Out:
#                                                Model  ...  Matthews Correlation Coefficient
# 0                   Dense NN on graph2vec (Baseline)  ...                          0.909310
# 1                                   CNN on graph2vec  ...                          0.900744
# 2                                      Stacked Model  ...                          0.841177
# 3        CNN on Adjacency Matrices (Randomly Padded)  ...                               NaN
# 4  CNN on Adjacency and Feature Matrices (Randoml...  ...                               NaN
#
# [5 rows x 5 columns]

# %% [markdown]
# ## ROC Curves

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,15))
for index, row in all_metrics.iterrows():
  plt.plot(row['fpr_plot'], row['tpr_plot'], label='{} (area = {:.3f})'.format(row['Model'], row['ROC AUC']))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='best')
plt.show()
plt.savefig('../images/roc_curve')

# %% [markdown]
# ## Precision-Recall Curves

# %%
plt.figure(figsize=(15,15))
for index, row in all_metrics.iterrows():
  plt.plot(row['recall_plot'], row['precision_plot'], label='{} (area = {:.3f})'.format(row['Model'], row['Precision Recall AUC']))
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision Recall Curve')
plt.legend(loc='best')
plt.show()
plt.savefig('../images/pr_curve')

# %%
def plot_prec_recall_vs_tresh(precisions, recalls, thresholds, index, model):
    j = index%4
    i = index//4
    axs[i, j].plot(thresholds, precisions[:-1], label='precision')
    axs[i, j].plot(thresholds, recalls[:-1], label = 'recall')
    axs[i, j].set_title(model)
    axs[i, j].set_xlabel('Threshold')
    axs[i, j].legend(loc='lower left')
    axs[i, j].set_ylim([0,1])

fig, axs = plt.subplots(2, 4, figsize=(18, 6), sharey=True)
for index, row in all_metrics.iterrows():
  plot_prec_recall_vs_tresh(row['precision_plot'], row['recall_plot'], row['thresholds_pr'], index, row['Model'])
  plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-9653827dde41> in <module>()
#      11 fig, axs = plt.subplots(2, 4, figsize=(18, 6), sharey=True)
#      12 for index, row in all_metrics.iterrows():
# ---> 13   plot_prec_recall_vs_tresh(row['precision_plot'], row['recall_plot'], row['thresholds_pr'], index, row['Model'])
#      14   plt.show
#
# <ipython-input-31-9653827dde41> in plot_prec_recall_vs_tresh(precisions, recalls, thresholds, index, model)
#       2     j = index%4
#       3     i = index//4
# ----> 4     axs[i, j].plot(thresholds, precisions[:-1], label='precision')
#       5     axs[i, j].plot(thresholds, recalls[:-1], label = 'recall')
#       6     axs[i, j].set_title(model)
#
# TypeError: 'float' object is not subscriptable

# %% [markdown]
# ## Train vs Val Loss Plots

# %%
with open('../data/dense-model-history', 'rb') as f:
    dense_model_history = pickle.load(f)
with open('../data/binary-convolutional-history', 'rb') as f:
    binary_convolutional_history = pickle.load(f)
with open('../data/adjacency-matrix-history.pickle', 'rb') as f:
    adjacency_matrix_history = pickle.load(f)
with open('../data/adjacency-matrix-random-padding-history.pickle', 'rb') as f:
    adjacency_matrix_random_padding_history = pickle.load(f)
with open('../data/adjacency-feature-matrix-history.pickle', 'rb') as f:
    adjacency_feature_matrix_history = pickle.load(f)
with open('../data/adjacency-feature-matrix-random-padding-history.pickle', 'rb') as f:
    adjacency_feature_matrix_random_padding_history = pickle.load(f)

# %%
plt.plot(dense_model_history.history['loss'])
plt.plot(dense_model_history.history['val_loss'])
plt.title('Dense NN on graph2vec Model Losses')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
plt.plot(binary_convolutional_history.history['loss'])
plt.plot(binary_convolutional_history.history['val_loss'])
plt.title('CNN on graph2vec Model Losses')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 6), sharey=True)
axs[0].plot(adjacency_matrix_history.history['loss'])
axs[0].plot(adjacency_matrix_history.history['val_loss'])
axs[0].set_title('CNN on Adjacency Matrices (Original Padding) Model Losses')
axs[0].set_ylabel('Loss')
axs[0].set_xlabel('Epoch')
axs[0].legend(['train', 'test'], loc='upper right')
axs[1].plot(adjacency_matrix_random_padding_history.history['loss'])
axs[1].plot(adjacency_matrix_random_padding_history.history['val_loss'])
axs[1].set_title('CNN on Adjacency Matrices (Random Padding) Model Losses')
axs[1].set_ylabel('Loss')
axs[1].set_xlabel('Epoch')
axs[1].legend(['train', 'test'], loc='upper right')
fig.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 6), sharey=True)
axs[0].plot(adjacency_feature_matrix_history.history['loss'])
axs[0].plot(adjacency_feature_matrix_history.history['val_loss'])
axs[0].set_title('CNN on Adjacency and Feature Matrices (Original Padding) Model Losses')
axs[0].set_ylabel('Loss')
axs[0].set_xlabel('Epoch')
axs[0].legend(['train', 'test'], loc='upper right')
axs[1].plot(adjacency_feature_matrix_random_padding_history.history['loss'])
axs[1].plot(adjacency_feature_matrix_random_padding_history.history['val_loss'])
axs[1].set_title('CNN on Adjacency and Feature Matrices (Random Padding) Model Losses')
axs[1].set_ylabel('Loss')
axs[1].set_xlabel('Epoch')
axs[1].legend(['train', 'test'], loc='upper right')
fig.show()
