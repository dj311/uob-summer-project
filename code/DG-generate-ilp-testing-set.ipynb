# %% [markdown]
# # Generating ILP Testing Set
#
# Finds a group of small buffer overflow examples from the Juliet dataset, then generates their Prolog representations from the code property graph generated by Joern. These are saved to `../data/ilp_data.csv.gz`  and `../data/ilp_prolog_data.csv.gz` respectively.
#
#
# ## Find a nice subset
#
# Find a small number of short buffer overflow examples from the Juliet dataset, and save them into the `../data/ilp_test_data.csv.gz` dataframe.

# %%
import pandas as pd

# %%
buffer_overflow_juliet = pd.read_csv("../data/buffer_overflow_data.csv.gz")

# %%
buffer_overflow_juliet['code_length'] = buffer_overflow_juliet.code.apply(len)
buffer_overflow_juliet
# Out:
#        Unnamed: 0  Unnamed: 0.1  testcase_ID  \
# 0             984           984        62516
# 1             985           985        62517
# 2             986           986        62518
# 3             987           987        62519
# 4             988           988        62520
# 5             989           989        62521
# 6             990           990        62522
# 7             991           991        62523
# 8             992           992        62524
# 9             993           993        62525
# 10            994           994        62526
# 11            995           995        62527
# 12            996           996        62528
# 13            997           997        62529
# 14            998           998        62530
# 15            999           999        62531
# 16           1000          1000        62532
# 17           1001          1001        62533
# 18           1002          1002        62534
# 19           1003          1003        62535
# 20           1004          1004        62535
# 21           1005          1005        62536
# 22           1006          1006        62537
# 23           1007          1007        62538
# 24           1008          1008        62539
# 25           1009          1009        62540
# 26           1010          1010        62541
# 27           1011          1011        62542
# 28           1012          1012        62543
# 29           1013          1013        62544
# ...           ...           ...          ...
# 36270      189196         84013      -234234
# 36271      189197         84014      -234235
# 36272      189198         84015      -234235
# 36273      189199         84016      -234235
# 36274      189200         84017      -234235
# 36275      189201         84018      -234236
# 36276      189202         84019      -234236
# 36277      189203         84020      -234236
# 36278      189204         84021      -234236
# 36279      189205         84022      -234237
# 36280      189206         84023      -234238
# 36281      189207         84024      -234239
# 36282      189208         84025      -234240
# 36283      189211         84028      -234243
# 36284      189212         84029      -234244
# 36285      189216         84033      -234248
# 36286      189217         84034      -234249
# 36287      189218         84035      -234250
# 36288      189219         84036      -234251
# 36289      189220         84037      -234252
# 36290      189221         84038      -234253
# 36291      189222         84039      -234254
# 36292      189223         84040      -234255
# 36293      189224         84041      -234256
# 36294      189227         84044      -234259
# 36295      189228         84045      -234260
# 36296      189231         84048      -234263
# 36297      189237         84054      -234269
# 36298      189238         84055      -234270
# 36299      189239         84056      -234271
#
#                                                 filename  \
# 0      000/062/516/CWE121_Stack_Based_Buffer_Overflow...
# 1      000/062/517/CWE121_Stack_Based_Buffer_Overflow...
# 2      000/062/518/CWE121_Stack_Based_Buffer_Overflow...
# 3      000/062/519/CWE121_Stack_Based_Buffer_Overflow...
# 4      000/062/520/CWE121_Stack_Based_Buffer_Overflow...
# 5      000/062/521/CWE121_Stack_Based_Buffer_Overflow...
# 6      000/062/522/CWE121_Stack_Based_Buffer_Overflow...
# 7      000/062/523/CWE121_Stack_Based_Buffer_Overflow...
# 8      000/062/524/CWE121_Stack_Based_Buffer_Overflow...
# 9      000/062/525/CWE121_Stack_Based_Buffer_Overflow...
# 10     000/062/526/CWE121_Stack_Based_Buffer_Overflow...
# 11     000/062/527/CWE121_Stack_Based_Buffer_Overflow...
# 12     000/062/528/CWE121_Stack_Based_Buffer_Overflow...
# 13     000/062/529/CWE121_Stack_Based_Buffer_Overflow...
# 14     000/062/530/CWE121_Stack_Based_Buffer_Overflow...
# 15     000/062/531/CWE121_Stack_Based_Buffer_Overflow...
# 16     000/062/532/CWE121_Stack_Based_Buffer_Overflow...
# 17     000/062/533/CWE121_Stack_Based_Buffer_Overflow...
# 18     000/062/534/CWE121_Stack_Based_Buffer_Overflow...
# 19     000/062/535/CWE121_Stack_Based_Buffer_Overflow...
# 20     000/062/535/CWE121_Stack_Based_Buffer_Overflow...
# 21     000/062/536/CWE121_Stack_Based_Buffer_Overflow...
# 22     000/062/537/CWE121_Stack_Based_Buffer_Overflow...
# 23     000/062/538/CWE121_Stack_Based_Buffer_Overflow...
# 24     000/062/539/CWE121_Stack_Based_Buffer_Overflow...
# 25     000/062/540/CWE121_Stack_Based_Buffer_Overflow...
# 26     000/062/541/CWE121_Stack_Based_Buffer_Overflow...
# 27     000/062/542/CWE121_Stack_Based_Buffer_Overflow...
# 28     000/062/543/CWE121_Stack_Based_Buffer_Overflow...
# 29     000/062/544/CWE121_Stack_Based_Buffer_Overflow...
# ...                                                  ...
# 36270  000/234/234/CWE122_Heap_Based_Buffer_Overflow_...
# 36271  000/234/235/CWE122_Heap_Based_Buffer_Overflow_...
# 36272  000/234/235/CWE122_Heap_Based_Buffer_Overflow_...
# 36273  000/234/235/CWE122_Heap_Based_Buffer_Overflow_...
# 36274  000/234/235/CWE122_Heap_Based_Buffer_Overflow_...
# 36275  000/234/236/CWE122_Heap_Based_Buffer_Overflow_...
# 36276  000/234/236/CWE122_Heap_Based_Buffer_Overflow_...
# 36277  000/234/236/CWE122_Heap_Based_Buffer_Overflow_...
# 36278  000/234/236/CWE122_Heap_Based_Buffer_Overflow_...
# 36279  000/234/237/CWE122_Heap_Based_Buffer_Overflow_...
# 36280  000/234/238/CWE122_Heap_Based_Buffer_Overflow_...
# 36281  000/234/239/CWE122_Heap_Based_Buffer_Overflow_...
# 36282  000/234/240/CWE122_Heap_Based_Buffer_Overflow_...
# 36283  000/234/243/CWE122_Heap_Based_Buffer_Overflow_...
# 36284  000/234/244/CWE122_Heap_Based_Buffer_Overflow_...
# 36285  000/234/248/CWE122_Heap_Based_Buffer_Overflow_...
# 36286  000/234/249/CWE122_Heap_Based_Buffer_Overflow_...
# 36287  000/234/250/CWE122_Heap_Based_Buffer_Overflow_...
# 36288  000/234/251/CWE122_Heap_Based_Buffer_Overflow_...
# 36289  000/234/252/CWE122_Heap_Based_Buffer_Overflow_...
# 36290  000/234/253/CWE122_Heap_Based_Buffer_Overflow_...
# 36291  000/234/254/CWE122_Heap_Based_Buffer_Overflow_...
# 36292  000/234/255/CWE122_Heap_Based_Buffer_Overflow_...
# 36293  000/234/256/CWE122_Heap_Based_Buffer_Overflow_...
# 36294  000/234/259/CWE122_Heap_Based_Buffer_Overflow_...
# 36295  000/234/260/CWE122_Heap_Based_Buffer_Overflow_...
# 36296  000/234/263/CWE122_Heap_Based_Buffer_Overflow_...
# 36297  000/234/269/CWE122_Heap_Based_Buffer_Overflow_...
# 36298  000/234/270/CWE122_Heap_Based_Buffer_Overflow_...
# 36299  000/234/271/CWE122_Heap_Based_Buffer_Overflow_...
#
#                                                     code     flaw  flaw_loc  \
# 0      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       112
# 1      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       117
# 2      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       117
# 3      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       123
# 4      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       123
# 5      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       122
# 6      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       122
# 7      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       130
# 8      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       117
# 9      /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       117
# 10     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       117
# 11     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       123
# 12     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       117
# 13     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       117
# 14     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       124
# 15     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       118
# 16     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       118
# 17     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       116
# 18     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        58
# 19     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        36
# 20     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        36
# 21     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       115
# 22     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       120
# 23     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       118
# 24     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       122
# 25     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        53
# 26     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       118
# 27     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       120
# 28     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        53
# 29     /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        58
# ...                                                  ...      ...       ...
# 36270  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        34
# 36271  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        27
# 36272  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        27
# 36273  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        27
# 36274  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        27
# 36275  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        27
# 36276  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        27
# 36277  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        27
# 36278  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        27
# 36279  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        42
# 36280  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36281  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36282  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        50
# 36283  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        49
# 36284  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        57
# 36285  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36286  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36287  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36288  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        45
# 36289  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36290  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        45
# 36291  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36292  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        42
# 36293  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36294  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        50
# 36295  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        49
# 36296  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36297  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        45
# 36298  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        44
# 36299  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        45
#
#          bug  code_length
# 0      False         5108
# 1      False         9668
# 2      False         9710
# 3      False        10162
# 4      False        10084
# 5      False        10123
# 6      False        10054
# 7      False        10190
# 8      False         9897
# 9      False         9799
# 10     False         9925
# 11     False         9329
# 12     False         9934
# 13     False         9836
# 14     False        10128
# 15     False         5735
# 16     False         5697
# 17     False         5314
# 18     False         8623
# 19     False         7369
# 20     False         3771
# 21     False         5446
# 22     False         5862
# 23     False         5552
# 24     False         5819
# 25     False         5314
# 26     False         5355
# 27     False         5439
# 28     False         5432
# 29     False         5906
# ...      ...          ...
# 36270   True         1078
# 36271   True         1074
# 36272   True         1030
# 36273   True          606
# 36274   True         2001
# 36275   True         1050
# 36276   True         1022
# 36277   True          604
# 36278   True         2019
# 36279   True         2265
# 36280   True         2360
# 36281   True         2369
# 36282   True         2674
# 36283   True         2614
# 36284   True         2680
# 36285   True         3259
# 36286   True         2417
# 36287   True         2396
# 36288   True         2475
# 36289   True         2371
# 36290   True         2382
# 36291   True         2307
# 36292   True         2242
# 36293   True         2333
# 36294   True         2646
# 36295   True         2579
# 36296   True         2382
# 36297   True         2452
# 36298   True         2344
# 36299   True         2355
#
# [36300 rows x 9 columns]

# %% [markdown]
# Pick next 5 smallest (20 smallest were chosen for our training):

# %%
buffer_overflow_juliet.groupby(['testcase_ID']).apply(
    lambda testcase, **kwargs: sum(testcase['code_length']),
    axis='columns',
).sort_values()
# Out:
# testcase_ID
# -62852      1570
# -62900      1576
# -62869      1616
# -62804      1618
# -232012     1619
# -62853      1621
# -62917      1622
# -232086     1625
# -62901      1627
# -62854      1630
# -62867      1632
# -62902      1636
# -62915      1638
# -62868      1643
# -62861      1649
# -62916      1649
# -62909      1655
# -62865      1657
# -62913      1663
# -62821      1664
# -232029     1665
# -231979     1667
# -62805      1669
# -62860      1670
# -232103     1671
#  62852      1674
# -232013     1674
# -62908      1676
# -62862      1676
# -62806      1678
#            ...
#  232342    11388
#  67724     11389
#  232346    11425
#  232341    11486
#  232347    11501
#  232196    11511
#  67718     11512
#  232343    11514
#  232345    11523
#  67716     11542
#  70687     11546
#  67717     11581
#  67759     11584
#  67715     11620
#  232339    11643
#  67719     11648
#  232337    11673
#  232364    11690
#  62727     11694
#  232338    11712
#  232336    11751
#  232340    11779
#  232184    11843
#  232352    12397
#  67552     12449
#  67744     12616
#  62548     13047
#  62740     13194
#  232197    13474
#  232365    13621
# Length: 21502, dtype: int64

# %%
ilp_test_data= buffer_overflow_juliet[
    (buffer_overflow_juliet['testcase_ID'] == 232029) | 
    (buffer_overflow_juliet['testcase_ID'] == 231979) | 
    (buffer_overflow_juliet['testcase_ID'] == 62805) | 
    (buffer_overflow_juliet['testcase_ID'] == 62860) | 
    (buffer_overflow_juliet['testcase_ID'] == 232103) | 
    (buffer_overflow_juliet['testcase_ID'] == -232029) | 
    (buffer_overflow_juliet['testcase_ID'] == -231979) | 
    (buffer_overflow_juliet['testcase_ID'] == -62805) | 
    (buffer_overflow_juliet['testcase_ID'] == -62860) | 
    (buffer_overflow_juliet['testcase_ID'] == -232103)
]

ilp_test_data
# Out:
#        Unnamed: 0  Unnamed: 0.1  testcase_ID  \
# 517          1501          1501        62805
# 589          1573          1573        62860
# 15137       80988         80988       231979
# 15196       81047         81047       232029
# 15298       81149         81149       232103
# 18667      106684          1501       -62805
# 18739      106756          1573       -62860
# 33287      186171         80988      -231979
# 33346      186230         81047      -232029
# 33448      186332         81149      -232103
#
#                                                 filename  \
# 517    000/062/805/CWE121_Stack_Based_Buffer_Overflow...
# 589    000/062/860/CWE121_Stack_Based_Buffer_Overflow...
# 15137  000/231/979/CWE122_Heap_Based_Buffer_Overflow_...
# 15196  000/232/029/CWE122_Heap_Based_Buffer_Overflow_...
# 15298  000/232/103/CWE122_Heap_Based_Buffer_Overflow_...
# 18667  000/062/805/CWE121_Stack_Based_Buffer_Overflow...
# 18739  000/062/860/CWE121_Stack_Based_Buffer_Overflow...
# 33287  000/231/979/CWE122_Heap_Based_Buffer_Overflow_...
# 33346  000/232/029/CWE122_Heap_Based_Buffer_Overflow_...
# 33448  000/232/103/CWE122_Heap_Based_Buffer_Overflow_...
#
#                                                     code     flaw  flaw_loc  \
# 517    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        36
# 589    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 15137  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        34
# 15196  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        33
# 15298  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        33
# 18667  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        36
# 18739  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 33287  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        34
# 33346  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        33
# 33448  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        33
#
#          bug  code_length
# 517    False         2502
# 589    False         2495
# 15137  False         1771
# 15196  False         1809
# 15298  False         1815
# 18667   True         1669
# 18739   True         1670
# 33287   True         1667
# 33346   True         1665
# 33448   True         1671

# %%
ilp_test_data = ilp_test_data.drop(["Unnamed: 0", "Unnamed: 0.1"], axis='columns')

# %%
ilp_test_data
# Out:
#        testcase_ID                                           filename  \
# 517          62805  000/062/805/CWE121_Stack_Based_Buffer_Overflow...
# 589          62860  000/062/860/CWE121_Stack_Based_Buffer_Overflow...
# 15137       231979  000/231/979/CWE122_Heap_Based_Buffer_Overflow_...
# 15196       232029  000/232/029/CWE122_Heap_Based_Buffer_Overflow_...
# 15298       232103  000/232/103/CWE122_Heap_Based_Buffer_Overflow_...
# 18667       -62805  000/062/805/CWE121_Stack_Based_Buffer_Overflow...
# 18739       -62860  000/062/860/CWE121_Stack_Based_Buffer_Overflow...
# 33287      -231979  000/231/979/CWE122_Heap_Based_Buffer_Overflow_...
# 33346      -232029  000/232/029/CWE122_Heap_Based_Buffer_Overflow_...
# 33448      -232103  000/232/103/CWE122_Heap_Based_Buffer_Overflow_...
#
#                                                     code     flaw  flaw_loc  \
# 517    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        36
# 589    /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 15137  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        34
# 15196  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        33
# 15298  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        33
# 18667  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        36
# 18739  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 33287  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        34
# 33346  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        33
# 33448  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-122        33
#
#          bug  code_length
# 517    False         2502
# 589    False         2495
# 15137  False         1771
# 15196  False         1809
# 15298  False         1815
# 18667   True         1669
# 18739   True         1670
# 33287   True         1667
# 33346   True         1665
# 33448   True         1671

# %%
ilp_test_data.to_csv("../data/ilp_test_data.csv.gz")

# %% [markdown]
# ## Generating Prolog Representations

# %% [markdown]
# Now that we have a set of examples, we want to generate a Prolog representation. To do this we use Joern to derive a code property graph from each source file. Then, using our `../code/ILP-joern-cfg-to-prolog.scala` script, we convert a subset of this graph into a set of prolog facts.

# %%
import os
import subprocess
import tempfile

# %%
testcase_IDs = []
flaws = []
bugs = []
code_lengths = []
trees = []

# %%
def generate_prolog(testcase):
    tmp_dir = tempfile.TemporaryDirectory()

    for file in testcase.itertuples():
        short_filename = file.filename.split("/")[-1]
        with open(tmp_dir.name + "/" + short_filename, 'w') as f:
            f.write(file.code)

    subprocess.check_call(["/joern/joern-parse", "--out", tmp_dir.name + "/cpg.bin.zip", tmp_dir.name])

    tree = subprocess.check_output(
        "cd /joern && /joern/joern-query --cpg "+tmp_dir.name + "/cpg.bin.zip -f /project/code/ILP-joern-cfg-to-prolog.scala",
        shell=True,
        universal_newlines=True,
    )

    testcase_IDs.append(file.testcase_ID)
    flaws.append( file.flaw)
    bugs.append(file.bug)
    code_lengths.append(file.code_length)
    trees.append(tree)

    tmp_dir.cleanup()

# %%
ilp_test_data.groupby('testcase_ID').apply(generate_prolog)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
prolog_test = pd.DataFrame({
    'testcase_ID': testcase_IDs,
    'flaw': flaws,
    'bug': bugs,
    'code_length': code_lengths,
    'tree': trees,
})
prolog_test = prolog_test[1:11]  # when we run apply it duplicates the first group
prolog_test
# Out:
#     testcase_ID     flaw    bug  code_length  \
# 1       -232103  CWE-122   True         1671
# 2       -232029  CWE-122   True         1665
# 3       -231979  CWE-122   True         1667
# 4        -62860  CWE-121   True         1670
# 5        -62805  CWE-121   True         1669
# 6         62805  CWE-121  False         2502
# 7         62860  CWE-121  False         2495
# 8        231979  CWE-122  False         1771
# 9        232029  CWE-122  False         1809
# 10       232103  CWE-122  False         1815
#
#                                                  tree
# 1   % START: Generated Prolog\n% NODE PROPERTIES \...
# 2   % START: Generated Prolog\n% NODE PROPERTIES \...
# 3   % START: Generated Prolog\n% NODE PROPERTIES \...
# 4   % START: Generated Prolog\n% NODE PROPERTIES \...
# 5   % START: Generated Prolog\n% NODE PROPERTIES \...
# 6   % START: Generated Prolog\n% NODE PROPERTIES \...
# 7   % START: Generated Prolog\n% NODE PROPERTIES \...
# 8   % START: Generated Prolog\n% NODE PROPERTIES \...
# 9   % START: Generated Prolog\n% NODE PROPERTIES \...
# 10  % START: Generated Prolog\n% NODE PROPERTIES \...

# %%
print(prolog_test.tree.iloc[0])
# Out:
# % START: Generated Prolog
# % NODE PROPERTIES
# alloc(id_57).
# sizeOf(id_66).
# writeToPointer(id_69).
# compMemberAccess(id_76).
# assignment(id_81).
# compMemberAccess(id_133).
# compMemberAccess(id_134).
# sizeOf(id_138).
# sizeOf(id_139).
# writeToPointer(id_145).
# writeToPointer(id_146).
# assignment(id_148).
# alloc(id_163).
# alloc(id_164).
# assignment(id_168).
# assignment(id_173).
# assignment(id_174).
# % METHOD
# pointer(id_7).
# voidPointer(id_121).
# pointer(id_123).
# pointer(id_128).
# pointer(id_132).
# sizeOfInt(id_143).
# array10(id_143).
# pointer(id_144).
# sizeOfInt(id_147).
# array10(id_147).
# sizeOfInt(id_149).
# array10(id_149).
# voidPointer(id_150).
# voidPointer(id_156).
# pointer(id_158).
# pointer(id_167).
# pointer(id_172).
# pointer(id_175).
# voidPointer(id_176).
# voidPointer(id_177).
# % CODE
# source_code(id_1, "p2").
# source_code(id_2, "p1").
# source_code(id_3, "p2").
# source_code(id_4, "p1").
# source_code(id_5, "p1").
# source_code(id_6, "p1").
# source_code(id_7, "char * argv[]").
# source_code(id_8, "int argc").
# source_code(id_9, "p1").
# source_code(id_10, "p2").
# source_code(id_11, "p1").
# source_code(id_12, "p1").
# source_code(id_13, "p1").
# source_code(id_14, "p1").
# source_code(id_15, "p1").
# source_code(id_16, "p1").
# source_code(id_17, "p1").
# source_code(id_18, "p2").
# source_code(id_19, "p1").
# source_code(id_20, "p2").
# source_code(id_21, "p1").
# source_code(id_22, "p1").
# source_code(id_23, "p2").
# source_code(id_24, "p3").
# source_code(id_25, "p1").
# source_code(id_26, "").
# source_code(id_27, "p1").
# source_code(id_28, "p1").
# source_code(id_29, "RET").
# source_code(id_30, "").
# source_code(id_31, "p1").
# source_code(id_32, "").
# source_code(id_33, "").
# source_code(id_34, "RET").
# source_code(id_35, "p2").
# source_code(id_36, "p1").
# source_code(id_37, "RET").
# source_code(id_38, "").
# source_code(id_39, "p2").
# source_code(id_42, "p1").
# source_code(id_43, "p1").
# source_code(id_44, "RET").
# source_code(id_45, "RET").
# source_code(id_46, "").
# source_code(id_47, "").
# source_code(id_48, "p1").
# source_code(id_49, "RET").
# source_code(id_50, "p2").
# source_code(id_51, "").
# source_code(id_52, "").
# source_code(id_54, "RET").
# source_code(id_55, "p1").
# source_code(id_56, "p2").
# source_code(id_58, "").
# source_code(id_59, "p1").
# source_code(id_60, "p3").
# source_code(id_61, "").
# source_code(id_63, "p1").
# source_code(id_65, "").
# source_code(id_67, "p1").
# source_code(id_68, "RET").
# source_code(id_70, "").
# source_code(id_72, "p1").
# source_code(id_73, "RET").
# source_code(id_74, "RET").
# source_code(id_75, "p1").
# source_code(id_78, "p1").
# source_code(id_79, "p2").
# source_code(id_80, "").
# source_code(id_82, "RET").
# source_code(id_83, "RET").
# source_code(id_84, "RET").
# source_code(id_85, "").
# source_code(id_86, "RET").
# source_code(id_88, "p2").
# source_code(id_89, "RET").
# source_code(id_104, "0").
# source_code(id_105, "return 0;").
# source_code(id_106, ""Finished bad()"").
# source_code(id_107, "printLine("Finished bad()")").
# source_code(id_109, "CWE122_Heap_Based_Buffer_Overflow__CWE131_memmove_18_bad()").
# source_code(id_110, ""Calling bad()..."").
# source_code(id_112, "printLine("Calling bad()...")").
# source_code(id_113, "NULL").
# source_code(id_115, "time(NULL)").
# source_code(id_116, "unsigned").
# source_code(id_118, "(unsigned)time(NULL)").
# source_code(id_120, "srand( (unsigned)time(NULL) )").
# source_code(id_121, "").
# source_code(id_122, "RET").
# source_code(id_123, "char * argv[]").
# source_code(id_124, "int argc").
# source_code(id_128, "data").
# source_code(id_130, "free(data)").
# source_code(id_131, "0").
# source_code(id_132, "data").
# source_code(id_134, "data[0]").
# source_code(id_136, "printIntLine(data[0])").
# source_code(id_137, "int").
# source_code(id_139, "sizeof(int)").
# source_code(id_140, "10").
# source_code(id_142, "10*sizeof(int)").
# source_code(id_143, "source").
# source_code(id_144, "data").
# source_code(id_146, "memmove(data, source, 10*sizeof(int))").
# source_code(id_147, "source").
# source_code(id_148, "source[10] = {0}").
# source_code(id_149, "source").
# source_code(id_150, "").
# source_code(id_151, "1").
# source_code(id_153, "-1").
# source_code(id_155, "exit(-1)").
# source_code(id_156, "").
# source_code(id_157, "NULL").
# source_code(id_158, "data").
# source_code(id_160, "data == NULL").
# source_code(id_161, "if (data == NULL)").
# source_code(id_162, "10").
# source_code(id_164, "malloc(10)").
# source_code(id_165, "int *").
# source_code(id_166, "(int *)malloc(10)").
# source_code(id_167, "data").
# source_code(id_168, "data = (int *)malloc(10)").
# source_code(id_169, "source:").
# source_code(id_170, "goto source;").
# source_code(id_171, "NULL").
# source_code(id_172, "data").
# source_code(id_174, "data = NULL").
# source_code(id_175, "data").
# source_code(id_176, "").
# source_code(id_177, "RET").
# source_code(id_179, "/* seed randomness */").
# source_code(id_180, "/* Below is the main(). It is only used when building this testcase on
#  * its own for testing or for building a binary to use in testing binary
#  * analysis tools. It is not used when compiling all the testcases as one
#  * application, which is how source code analysis tools are tested.
#  */").
# source_code(id_181, "/* POTENTIAL FLAW: Possible buffer overflow if data was not allocated correctly in the source */").
# source_code(id_182, "/* FLAW: Allocate memory without using sizeof(int) */").
# source_code(id_183, "/*
#  * @description
#  * CWE: 122 Heap Based Buffer Overflow
#  * BadSource:  Allocate memory without using sizeof(int)
#  * GoodSource: Allocate memory using sizeof(int)
#  * Sink: memmove
#  *    BadSink : Copy array to data using memmove()
#  * Flow Variant: 18 Control flow: goto statements
#  *
#  * */").
# source_code(id_184, "/* TEMPLATE GENERATED TESTCASE FILE
# Filename: CWE122_Heap_Based_Buffer_Overflow__CWE131_memmove_18.c
# Label Definition File: CWE122_Heap_Based_Buffer_Overflow__CWE131.label.xml
# Template File: sources-sink-18.tmpl.c
# */").
# % AST
# ast(id_187, id_91).
#  ast(id_187, id_90).
#  ast(id_187, id_87).
#  ast(id_187, id_81).
#  ast(id_187, id_77).
#  ast(id_187, id_76).
#  ast(id_187, id_71).
#  ast(id_187, id_69).
#  ast(id_187, id_66).
#  ast(id_187, id_64).
#  ast(id_187, id_62).
#  ast(id_187, id_57).
#  ast(id_187, id_53).
#  ast(id_187, id_0).
#  ast(id_187, id_40).
#  ast(id_187, id_98).
#  ast(id_187, id_97).
#  ast(id_187, id_96).
#  ast(id_187, id_95).
#  ast(id_187, id_94).
#  ast(id_187, id_93).
#  ast(id_187, id_92).
#  ast(id_81, id_46).
#  ast(id_81, id_89).
#  ast(id_81, id_56).
#  ast(id_81, id_48).
#  ast(id_57, id_80).
#  ast(id_57, id_73).
#  ast(id_57, id_42).
#  ast(id_62, id_85).
#  ast(id_62, id_45).
#  ast(id_62, id_50).
#  ast(id_62, id_55).
#  ast(id_90, id_70).
#  ast(id_90, id_34).
#  ast(id_90, id_75).
#  ast(id_87, id_33).
#  ast(id_87, id_49).
#  ast(id_87, id_27).
#  ast(id_69, id_52).
#  ast(id_69, id_54).
#  ast(id_69, id_60).
#  ast(id_69, id_35).
#  ast(id_69, id_43).
#  ast(id_77, id_30).
#  ast(id_77, id_44).
#  ast(id_77, id_39).
#  ast(id_77, id_78).
#  ast(id_66, id_58).
#  ast(id_66, id_84).
#  ast(id_66, id_31).
#  ast(id_91, id_65).
#  ast(id_91, id_82).
#  ast(id_91, id_28).
#  ast(id_76, id_61).
#  ast(id_76, id_83).
#  ast(id_76, id_79).
#  ast(id_76, id_36).
#  ast(id_40, id_47).
#  ast(id_40, id_29).
#  ast(id_40, id_72).
#  ast(id_64, id_32).
#  ast(id_64, id_37).
#  ast(id_64, id_59).
#  ast(id_53, id_51).
#  ast(id_53, id_74).
#  ast(id_53, id_88).
#  ast(id_53, id_63).
#  ast(id_71, id_38).
#  ast(id_71, id_86).
#  ast(id_71, id_67).
#  ast(id_0, id_26).
#  ast(id_0, id_68).
#  ast(id_0, id_25).
#  ast(id_186, id_185).
#  ast(id_125, id_8).
#  ast(id_125, id_7).
#  ast(id_53, id_3).
#  ast(id_76, id_23).
#  ast(id_77, id_17).
#  ast(id_90, id_4).
#  ast(id_40, id_16).
#  ast(id_71, id_21).
#  ast(id_53, id_12).
#  ast(id_69, id_24).
#  ast(id_64, id_11).
#  ast(id_81, id_18).
#  ast(id_62, id_14).
#  ast(id_62, id_20).
#  ast(id_81, id_9).
#  ast(id_69, id_19).
#  ast(id_57, id_22).
#  ast(id_77, id_10).
#  ast(id_76, id_6).
#  ast(id_69, id_1).
#  ast(id_66, id_15).
#  ast(id_91, id_13).
#  ast(id_87, id_2).
#  ast(id_0, id_5).
#  ast(id_186, id_179).
#  ast(id_186, id_180).
#  ast(id_186, id_181).
#  ast(id_186, id_182).
#  ast(id_186, id_183).
#  ast(id_186, id_184).
#  ast(id_130, id_128).
#  ast(id_150, id_130).
#  ast(id_134, id_131).
#  ast(id_134, id_132).
#  ast(id_136, id_134).
#  ast(id_150, id_136).
#  ast(id_139, id_137).
#  ast(id_142, id_139).
#  ast(id_142, id_140).
#  ast(id_146, id_142).
#  ast(id_146, id_143).
#  ast(id_146, id_144).
#  ast(id_150, id_146).
#  ast(id_148, id_147).
#  ast(id_150, id_148).
#  ast(id_150, id_149).
#  ast(id_176, id_150).
#  ast(id_153, id_151).
#  ast(id_155, id_153).
#  ast(id_156, id_155).
#  ast(id_161, id_156).
#  ast(id_160, id_157).
#  ast(id_160, id_158).
#  ast(id_161, id_160).
#  ast(id_176, id_161).
#  ast(id_164, id_162).
#  ast(id_166, id_164).
#  ast(id_166, id_165).
#  ast(id_168, id_166).
#  ast(id_168, id_167).
#  ast(id_176, id_168).
#  ast(id_176, id_169).
#  ast(id_176, id_170).
#  ast(id_174, id_171).
#  ast(id_174, id_172).
#  ast(id_176, id_174).
#  ast(id_176, id_175).
#  ast(id_178, id_176).
#  ast(id_178, id_177).
#  ast(id_185, id_178).
#  ast(id_105, id_104).
#  ast(id_121, id_105).
#  ast(id_107, id_106).
#  ast(id_121, id_107).
#  ast(id_121, id_109).
#  ast(id_112, id_110).
#  ast(id_121, id_112).
#  ast(id_115, id_113).
#  ast(id_118, id_115).
#  ast(id_118, id_116).
#  ast(id_120, id_118).
#  ast(id_121, id_120).
#  ast(id_125, id_121).
#  ast(id_125, id_122).
#  ast(id_125, id_123).
#  ast(id_125, id_124).
#  ast(id_185, id_125).
#  % CFG
# cfg(id_170, id_167).
#  cfg(id_130, id_177).
#  cfg(id_128, id_130).
#  cfg(id_136, id_128).
#  cfg(id_134, id_136).
#  cfg(id_131, id_134).
#  cfg(id_132, id_131).
#  cfg(id_146, id_132).
#  cfg(id_142, id_146).
#  cfg(id_139, id_142).
#  cfg(id_137, id_139).
#  cfg(id_140, id_137).
#  cfg(id_143, id_140).
#  cfg(id_144, id_143).
#  cfg(id_148, id_144).
#  cfg(id_147, id_148).
#  cfg(id_155, id_147).
#  cfg(id_160, id_147).
#  cfg(id_153, id_155).
#  cfg(id_151, id_153).
#  cfg(id_160, id_151).
#  cfg(id_157, id_160).
#  cfg(id_158, id_157).
#  cfg(id_168, id_158).
#  cfg(id_166, id_168).
#  cfg(id_164, id_166).
#  cfg(id_162, id_164).
#  cfg(id_167, id_162).
#  cfg(id_174, id_170).
#  cfg(id_171, id_174).
#  cfg(id_172, id_171).
#  cfg(id_178, id_172).
#  cfg(id_105, id_122).
#  cfg(id_104, id_105).
#  cfg(id_107, id_104).
#  cfg(id_106, id_107).
#  cfg(id_109, id_106).
#  cfg(id_112, id_109).
#  cfg(id_110, id_112).
#  cfg(id_120, id_110).
#  cfg(id_118, id_120).
#  cfg(id_115, id_118).
#  cfg(id_113, id_115).
#  cfg(id_125, id_113).
#  % REF
# ref(id_173, id_81).
#  ref(id_163, id_57).
#  ref(id_159, id_62).
#  ref(id_154, id_90).
#  ref(id_152, id_87).
#  ref(id_145, id_69).
#  ref(id_141, id_77).
#  ref(id_138, id_66).
#  ref(id_135, id_91).
#  ref(id_133, id_76).
#  ref(id_129, id_40).
#  ref(id_119, id_64).
#  ref(id_117, id_53).
#  ref(id_114, id_71).
#  ref(id_111, id_0).
#  ref(id_108, id_178).
#  ref(id_127, id_97).
#  ref(id_126, id_96).
#  ref(id_103, id_94).
#  ref(id_102, id_98).
#  ref(id_101, id_95).
#  ref(id_100, id_93).
#  ref(id_99, id_92).
#  ref(id_187, id_41).
#  ref(id_185, id_41).
#  ref(id_128, id_175).
#  ref(id_132, id_175).
#  ref(id_143, id_149).
#  ref(id_144, id_175).
#  ref(id_147, id_149).
#  ref(id_158, id_175).
#  ref(id_167, id_175).
#  ref(id_172, id_175).
#  % END: Generated Prolog

# %%
import re

# %%
def fix_single_rules(testcase):
    find_node_ids = re.compile('\((\w+)\)\.')
    replacement_node_ids = '({bug}_{testcase_id}_\\1).'.format(
        bug='bad' if testcase.bug else 'good',
        testcase_id=abs(testcase.testcase_ID),
    )
    return find_node_ids.sub(replacement_node_ids, testcase['tree'])

def fix_tree_rules(testcase):
    find_node_ids = re.compile('\((\w+), (\w+)\)\.')
    replacement_node_ids = '({bug}_{testcase_id}_\\1, {bug}_{testcase_id}_\\2).'.format(
        bug='bad' if testcase.bug else 'good',
        testcase_id=abs(testcase.testcase_ID),
    )
    return find_node_ids.sub(replacement_node_ids, testcase['tree'])

def fix_code_rules(testcase):
    find_node_ids = re.compile('\((\w+), "(.*)"\)\.')
    replacement_node_ids = '({bug}_{testcase_id}_\\1, "\\2").'.format(
        bug='bad' if testcase.bug else 'good',
        testcase_id=abs(testcase.testcase_ID),
    )
    return find_node_ids.sub(replacement_node_ids, testcase['tree'])

# %%
prolog_test['tree'] = prolog_test.apply(fix_single_rules, axis='columns')
prolog_test['tree'] = prolog_test.apply(fix_tree_rules, axis='columns')
prolog_test['tree'] = prolog_test.apply(fix_code_rules, axis='columns')

# %%
prolog_test
# Out:
#     testcase_ID     flaw    bug  code_length  \
# 1       -232103  CWE-122   True         1671
# 2       -232029  CWE-122   True         1665
# 3       -231979  CWE-122   True         1667
# 4        -62860  CWE-121   True         1670
# 5        -62805  CWE-121   True         1669
# 6         62805  CWE-121  False         2502
# 7         62860  CWE-121  False         2495
# 8        231979  CWE-122  False         1771
# 9        232029  CWE-122  False         1809
# 10       232103  CWE-122  False         1815
#
#                                                  tree
# 1   % START: Generated Prolog\n% NODE PROPERTIES \...
# 2   % START: Generated Prolog\n% NODE PROPERTIES \...
# 3   % START: Generated Prolog\n% NODE PROPERTIES \...
# 4   % START: Generated Prolog\n% NODE PROPERTIES \...
# 5   % START: Generated Prolog\n% NODE PROPERTIES \...
# 6   % START: Generated Prolog\n% NODE PROPERTIES \...
# 7   % START: Generated Prolog\n% NODE PROPERTIES \...
# 8   % START: Generated Prolog\n% NODE PROPERTIES \...
# 9   % START: Generated Prolog\n% NODE PROPERTIES \...
# 10  % START: Generated Prolog\n% NODE PROPERTIES \...

# %%
def extract_source_map(prolog_src):
    output_lines = []
    
    in_source_code_section = False
    
    for line in prolog_src.split("\n"):
        if line == "% CODE":
            in_source_code_section = True
            
        if line == "% AST":
            in_source_code_section = False
        
        if in_source_code_section:
            output_lines.append(line)
            
    return '\n'.join(output_lines)
            
    
def remove_source_map(prolog_src):
    output_lines = []
    
    in_source_code_section = False
    
    for line in prolog_src.split("\n"):
        if line == "% CODE":
            in_source_code_section = True
            
        if line == "% AST":
            in_source_code_section = False
        
        if not in_source_code_section:
            output_lines.append(line)
            
    return '\n'.join(output_lines)

# %%
prolog_test['source_map'] = prolog_test['tree'].apply(extract_source_map)
prolog_test['tree'] = prolog_test['tree'].apply(remove_source_map)

# %%
prolog_test.to_csv("../data/ilp_prolog_test_data.csv.gz")
